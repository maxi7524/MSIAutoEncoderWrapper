# %% [markdown]
# # Dataset management 01: Explore annotated mouse-bladder MSI data in PRIDE
#
# This notebook searches metadata only. It displays accepted image pairs, remote sizes, annotation compatibility, rejected records, and PRIDE links before MSI data are downloaded. The exported JSON is consumed by the `msi-datasets query --filters` command.

# %%
from pathlib import Path

from msi_dataset_manager.exploration import DatasetExplorer

explorer = DatasetExplorer(source="pride")

# %% [markdown]
# ## Inspect and configure filters
#
# The source reports supported fields and their meaning. The configuration requires unambiguous organism and organ metadata, a complete imzML/ibd pair, a supported curated molecule-to-pixel table, and downloadable checksums.

# %%
explorer.available_filters()
# Out:
# {'keyword': {'type': 'string', 'default': 'imzML'},
#  'filter': {'type': 'string', 'description': 'Raw PRIDE API filter.'},
#  'organisms': {'type': 'list[string]', 'api_field': 'organisms'},
#  'organism_parts': {'type': 'list[string]', 'api_field': 'organismsPart'},
#  'diseases': {'type': 'list[string]', 'api_field': 'diseases'},
#  'instruments': {'type': 'list[string]', 'api_field': 'instruments'},
#  'experiment_types': {'type': 'list[string]', 'api_field': 'experimentTypes'},
#  'submission_types': {'type': 'list[string]', 'api_field': 'submissionType'},
#  'publication_date_from': {'type': 'YYYY-MM-DD | null'},
#  'publication_date_to': {'type': 'YYYY-MM-DD | null'},
#  'required_metadata_fields': {'type': 'list[string]'},
#  'single_value_metadata_fields': {'type': 'list[string]'},
#  'max_pair_size_bytes': {'type': 'integer | null'},
#  'exclude_dataset_ids': {'type': 'list[string]'},
#  'require_annotation_source': {'type': 'boolean', 'required': True},
#  'require_checksum': {'type': 'boolean', 'required': True},
#  'page_size': {'type': 'positive integer', 'default': 100},
#  'max_projects': {'type': 'positive integer', 'default': 500}}

# %%
filters = {
    "keyword": "imzML",
    # "organisms": ["Mus musculus (mouse)"],
    # "organism_parts": ["Urinary bladder", "Bladder"],
    # "experiment_types": ["mass spectrometry imaging"],
    # "required_metadata_fields": ["organisms", "organismParts"],
    # "single_value_metadata_fields": ["organisms", "organismParts", "diseases"],
    # "require_annotation_source": True,
    # "require_checksum": True,
    # "page_size": 100,
    # "max_projects": 500,
    # "exclude_dataset_ids": [],
}
explorer.set_filters(filters)
# Out:
# {'keyword': 'imzML'}

# %% [markdown]
# ## Search and review
#
# Accepted rows are independent MSI image pairs. `total_size_bytes` is the imzML plus ibd size reported before download. Open `project_url` to inspect the source. Rejected rows explain missing metadata, incomplete pairs, unavailable checksums, or unsupported annotations.

# %%
accepted = explorer.search()
accepted
# Out:
# 2026-07-28 22:27:47,794 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD070149
# Connected to the streaming API. Fetching data...
# Successfully retrieved 207 items.
# 2026-07-28 22:27:49,347 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB929_cancer_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,348 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB929_cancer_20um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,348 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB929_normal_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,349 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB929_normal_20um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,349 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB931_cancer_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,350 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB931_cancer_20um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,351 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB931_normal_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,352 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB934_cancer_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,352 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB934_normal_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,353 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB941_cancer_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,354 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB941_normal_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,354 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB941_normal_20um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,355 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB943_cancer_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,355 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB943_cancer_20um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,356 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB943_normal_20um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,356 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB947_cancer_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,357 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB947_normal_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,357 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB950_cancer_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,358 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB950_normal_20um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,359 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB952_cancer_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,360 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD070149: unsupported annotation format for image 'PWB952_normal_10um_recal_M2' (https://www.ebi.ac.uk/pride/archive/projects/PXD070149)
# 2026-07-28 22:27:49,759 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD059505
# Connected to the streaming API. Fetching data...
# Successfully retrieved 13 items.
# 2026-07-28 22:27:50,196 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD059505: unsupported annotation format for image 'Mouse_brain_tryptic_digest_10um_Fig4F' (https://www.ebi.ac.uk/pride/archive/projects/PXD059505)
# 2026-07-28 22:27:50,197 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD059505: unsupported annotation format for image 'Mouse_brain_tryptic_digest_10um_Fig4L' (https://www.ebi.ac.uk/pride/archive/projects/PXD059505)
# 2026-07-28 22:27:50,198 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD059505: unsupported annotation format for image 'Mouse_brain_tryptic_digest_10um_Fig4M' (https://www.ebi.ac.uk/pride/archive/projects/PXD059505)
# 2026-07-28 22:27:50,199 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD059505: unsupported annotation format for image 'Mouse_brain_tryptic_digest_10um_FigS7B' (https://www.ebi.ac.uk/pride/archive/projects/PXD059505)
# 2026-07-28 22:27:50,766 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD053247
# Connected to the streaming API. Fetching data...
# Successfully retrieved 419 items.
# 2026-07-28 22:27:53,572 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD053247: unsupported annotation format for image '2022_07_11_MB-TV_292061_s11' (https://www.ebi.ac.uk/pride/archive/projects/PXD053247)
# 2026-07-28 22:27:53,573 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD053247: unsupported annotation format for image '2022_07_19_MB-TV_1-10_s06_img' (https://www.ebi.ac.uk/pride/archive/projects/PXD053247)
# 2026-07-28 22:27:53,574 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD053247: unsupported annotation format for image '2022_08_24_MB-hSOD1wt-B1_s03' (https://www.ebi.ac.uk/pride/archive/projects/PXD053247)
# 2026-07-28 22:27:53,575 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD053247: unsupported annotation format for image '2022_09_27_L1-27' (https://www.ebi.ac.uk/pride/archive/projects/PXD053247)
# 2026-07-28 22:27:53,575 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD053247: unsupported annotation format for image '2022_10_25_cerebimg2_30x50_33L' (https://www.ebi.ac.uk/pride/archive/projects/PXD053247)
# 2026-07-28 22:27:53,576 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD053247: unsupported annotation format for image '2022_10_31_MB-292061_s09_hires_30x50' (https://www.ebi.ac.uk/pride/archive/projects/PXD053247)
# 2026-07-28 22:27:53,577 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD053247: unsupported annotation format for image '2022_11_01_MB_hWT_st02_hires_HPF' (https://www.ebi.ac.uk/pride/archive/projects/PXD053247)
# 2026-07-28 22:27:53,577 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD053247: unsupported annotation format for image '2023_06_21_MSC_327570_94x100_fix' (https://www.ebi.ac.uk/pride/archive/projects/PXD053247)
# 2026-07-28 22:27:53,578 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD053247: unsupported annotation format for image '2023_06_21_MSC_327571_94x100_fix' (https://www.ebi.ac.uk/pride/archive/projects/PXD053247)
# 2026-07-28 22:27:53,579 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD053247: unsupported annotation format for image '2023_07_11_MB-hSOD-327571_10ums_200x200' (https://www.ebi.ac.uk/pride/archive/projects/PXD053247)
# 2026-07-28 22:27:53,580 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD053247: unsupported annotation format for image '2023_10_02_MSC-348484L_94x100' (https://www.ebi.ac.uk/pride/archive/projects/PXD053247)
# 2026-07-28 22:27:53,581 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD053247: unsupported annotation format for image '2023_10_03_MSC-348486_94x100_s09' (https://www.ebi.ac.uk/pride/archive/projects/PXD053247)
# 2026-07-28 22:27:53,582 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD053247: unsupported annotation format for image '2023_10_09_MSC-348486_s06_28x30_23Lfix' (https://www.ebi.ac.uk/pride/archive/projects/PXD053247)
# 2026-07-28 22:27:54,082 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD049325
# Connected to the streaming API. Fetching data...
# Successfully retrieved 66 items.
# 2026-07-28 22:27:54,948 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S15_210716_pa_ucl_pa_neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,948 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S15_210716_pa_ucl_s15_pa_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,949 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S15_210716_pa_ucl_sad1_lip' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,951 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S15_210716_pa_ucl_sad1_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,951 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S16_20210819_pa_ucl_pa_neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,952 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S16_20210819_pa_ucl_pa_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,953 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S1_pa_p7403_lip-neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,954 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S1_pa_p7403_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,955 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S1_sad_p4719_lip-neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,956 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S1_sad_p4719_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,957 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S2_20201105_pa_ucl_s2_pa_neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,958 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S2_20201105_pa_ucl_s2_pa_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,959 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S2_20201105_pa_ucl_s2_sad_neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,960 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S2_20201105_pa_ucl_s2_sad_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,960 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S3_20201111_pa_ucl_s3_pa_neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,961 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S3_20201111_pa_ucl_s3_pa_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,962 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S3_20201111_pa_ucl_s3_sad_neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,963 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S3_20201111_pa_ucl_s3_sad_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,964 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S4_20201119_pa_ucl_s4_pa_neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,965 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S4_20201119_pa_ucl_s4_pa_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,966 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S5_2001126_pa_ucl_s5_pa_neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,967 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S5_2001126_pa_ucl_s5_pa_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,967 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S5_2001126_pa_ucl_s5_sad_neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,968 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S5_2001126_pa_ucl_s5_sad_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,969 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S6_20201203_pa_ucl_pa_neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,970 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S6_20201203_pa_ucl_pa_p7311' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,970 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S6_20201203_pa_ucl_s6_sad_p1210' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,971 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S6_20201203_pa_ucl_sad_neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,972 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S7_20210121_pa_ucl_pa_neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,973 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S7_20210121_pa_ucl_pa_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,974 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S7_20210121_pa_ucl_sad_neg' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:54,975 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD049325: unsupported annotation format for image 'S7_20210121_pa_ucl_sad_pep' (https://www.ebi.ac.uk/pride/archive/projects/PXD049325)
# 2026-07-28 22:27:53,791 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD048809
# Connected to the streaming API. Fetching data...
# Successfully retrieved 17 items.
# 2026-07-28 22:27:54,427 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD048809: unsupported annotation format for image '20230130_rf1_msi2023001_slide001_ctrls'; tabular project files: Muscle_1_Pixel-info.csv, Muscle_2_Pixel-info.csv, Muscle_3_Pixel-info.csv (https://www.ebi.ac.uk/pride/archive/projects/PXD048809)
# 2026-07-28 22:27:54,428 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD048809: unsupported annotation format for image '20230130_rf1_msi2023001_slide001_m1'; tabular project files: Muscle_1_Pixel-info.csv, Muscle_2_Pixel-info.csv, Muscle_3_Pixel-info.csv (https://www.ebi.ac.uk/pride/archive/projects/PXD048809)
# 2026-07-28 22:27:54,429 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD048809: unsupported annotation format for image '20230130_rf1_msi2023001_slide001_m2'; tabular project files: Muscle_1_Pixel-info.csv, Muscle_2_Pixel-info.csv, Muscle_3_Pixel-info.csv (https://www.ebi.ac.uk/pride/archive/projects/PXD048809)
# 2026-07-28 22:27:54,429 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD048809: unsupported annotation format for image '20230130_rf1_msi2023001_slide001_m3'; tabular project files: Muscle_1_Pixel-info.csv, Muscle_2_Pixel-info.csv, Muscle_3_Pixel-info.csv (https://www.ebi.ac.uk/pride/archive/projects/PXD048809)
# 2026-07-28 22:27:54,869 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD047820
# Connected to the streaming API. Fetching data...
# Successfully retrieved 33 items.
# 2026-07-28 22:27:55,389 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD047820: unsupported annotation format for image 'Sample1' (https://www.ebi.ac.uk/pride/archive/projects/PXD047820)
# 2026-07-28 22:27:55,390 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD047820: unsupported annotation format for image 'Sample1_cal33_6_1_0_15' (https://www.ebi.ac.uk/pride/archive/projects/PXD047820)
# 2026-07-28 22:27:55,391 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD047820: unsupported annotation format for image 'Sample2' (https://www.ebi.ac.uk/pride/archive/projects/PXD047820)
# 2026-07-28 22:27:55,392 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD047820: unsupported annotation format for image 'Sample2_cal33_6_1_0_15' (https://www.ebi.ac.uk/pride/archive/projects/PXD047820)
# 2026-07-28 22:27:55,393 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD047820: unsupported annotation format for image 'Sample3' (https://www.ebi.ac.uk/pride/archive/projects/PXD047820)
# 2026-07-28 22:27:55,394 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD047820: unsupported annotation format for image 'Sample3_cal33_6_1_0_15' (https://www.ebi.ac.uk/pride/archive/projects/PXD047820)
# 2026-07-28 22:27:55,394 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD047820: unsupported annotation format for image 'Sample4' (https://www.ebi.ac.uk/pride/archive/projects/PXD047820)
# 2026-07-28 22:27:55,395 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD047820: unsupported annotation format for image 'Sample4_cal33_6_1_0_15' (https://www.ebi.ac.uk/pride/archive/projects/PXD047820)
# 2026-07-28 22:27:55,395 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD047820: unsupported annotation format for image 'Sample5' (https://www.ebi.ac.uk/pride/archive/projects/PXD047820)
# 2026-07-28 22:27:55,396 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD047820: unsupported annotation format for image 'Sample5_cal33_6_1_0_15' (https://www.ebi.ac.uk/pride/archive/projects/PXD047820)
# 2026-07-28 22:27:55,898 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD045377
# Connected to the streaming API. Fetching data...
# Successfully retrieved 60 items.
# 2026-07-28 22:27:56,613 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoA1cristalA1' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,614 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoA1cristalA4_v2' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,614 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoA2cristalA1' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,615 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'TejidoA2cristalA2' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,615 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoA2cristalA4_v2' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,616 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoAcristalB3' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,617 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoAcristalB4' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,619 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoBcristalA1' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,620 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'TejidoBcristalA2' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,621 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoBcristalA4' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,622 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoBcristalB3' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,623 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoBcristalB4' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,624 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoC1cristalB4' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,625 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoC2cristalB3' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,626 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoC2cristalB4' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,627 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'TejidoCcristalA2' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,629 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoCcristalA4_v2' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,630 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoD1cristalA1' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,632 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'TejidoD1cristalA2' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,633 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoD1cristalA4_v2' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,633 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoD2cristalA1' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,634 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'TejidoD2cristalA2' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,635 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoD2cristalA4_v2' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,636 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoD3cristalA4' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,637 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoDcristalB3' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:56,638 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD045377: unsupported annotation format for image 'tejidoDcristalB4' (https://www.ebi.ac.uk/pride/archive/projects/PXD045377)
# 2026-07-28 22:27:57,182 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD039398
# Connected to the streaming API. Fetching data...
# Successfully retrieved 100 items.
# 2026-07-28 22:27:58,689 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD038114
# Connected to the streaming API. Fetching data...
# Successfully retrieved 103 items.
# 2026-07-28 22:27:59,705 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image '1.5.1'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,706 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image '14.9'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,706 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image '15.10'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,707 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image '16.15.1'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,708 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image '16.15.2'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,708 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image '17.2'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,709 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image '3.6.1'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,710 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image '3.6.2'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,711 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image '4.8.1'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,711 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image '4.8.2'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,712 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image '5.10.1'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,714 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image '6.14.1'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,714 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image '6.14.2'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,715 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image 'M1.3'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,716 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image 'M13.6'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,716 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image 'M7.8'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,717 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image 'M8.20.1'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:27:59,718 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD038114: unsupported annotation format for image 'M8.20.2'; tabular project files: AllQuantifiedPeaks.tsv, AllQuantifiedPeptides.tsv, AllQuantifiedProteinGroups.tsv, RA1-calib_ProteinGroups.tsv, RA14-calib_ProteinGroups.tsv, RA15-calib_ProteinGroups.tsv, RA16-calib_ProteinGroups.tsv, RA17-calib_ProteinGroups.tsv, RA3-calib_ProteinGroups.tsv, RA4-calib_ProteinGroups.tsv, RA5-calib_ProteinGroups.tsv, RA6-calib_ProteinGroups.tsv, RAM1-calib_ProteinGroups.tsv, RAM13-calib_ProteinGroups.tsv, RAM7-calib_ProteinGroups.tsv, RAM8-calib_ProteinGroups.tsv, RA_Blank_2-calib_ProteinGroups.tsv, RA_Blank_ProteinGroups.tsv (https://www.ebi.ac.uk/pride/archive/projects/PXD038114)
# 2026-07-28 22:28:00,199 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD028949
# Connected to the streaming API. Fetching data...
# Successfully retrieved 60 items.
# 2026-07-28 22:28:01,336 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD026459
# Connected to the streaming API. Fetching data...
# Successfully retrieved 18 items.
# 2026-07-28 22:28:01,794 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD026459: unsupported annotation format for image 'TMA1' (https://www.ebi.ac.uk/pride/archive/projects/PXD026459)
# 2026-07-28 22:28:01,794 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD026459: unsupported annotation format for image 'TMA2' (https://www.ebi.ac.uk/pride/archive/projects/PXD026459)
# 2026-07-28 22:28:02,171 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD025826
# Connected to the streaming API. Fetching data...
# Successfully retrieved 11 items.
# 2026-07-28 22:28:02,629 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD025826: unsupported annotation format for image '20180425_glioma' (https://www.ebi.ac.uk/pride/archive/projects/PXD025826)
# 2026-07-28 22:28:02,630 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD025826: unsupported annotation format for image '20180510_VH153520A' (https://www.ebi.ac.uk/pride/archive/projects/PXD025826)
# ...
# 2026-07-28 22:28:16,290 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '10Day_L3_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,291 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '10Day_L5_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,293 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '10Day_L6_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,294 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '10Day_R2_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,294 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '10Day_R3_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,295 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '10Day_R3_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,297 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '1Day_C1_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,298 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '1day_C4_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,299 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '1Day_C9_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,299 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '1Day_L21_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,300 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '1Day_L5_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,301 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '1Day_L7_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,302 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '1Day_R21_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,303 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '1Day_R2_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,304 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '1day_R3_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,305 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '3Day_C1_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,306 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '3Day_C3_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,307 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '3Day_C7_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,307 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '3Day_L5_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,309 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '3Day_L6_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,311 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '3Day_L7_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,312 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '3Day_R2_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,314 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '3Day_R2_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,315 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '3Day_R2_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,317 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '7Day_C11_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,317 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '7Day_C3_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,318 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '7Day_C6_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,319 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '7Day_L21_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,320 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '7Day_L6_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,321 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '7Day_L7_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,322 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '7Day_R21_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,323 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '7Day_R2_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,324 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image '7Day_R3_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,325 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image 'Sham_10_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,326 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image 'Sham_10_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,326 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image 'Sham_12-9_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,327 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image 'Sham_15_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,328 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image 'Sham_17_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,329 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image 'Sham_17_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,330 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image 'Sham_4_n1' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,331 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image 'Sham_4_n2' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,333 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD011262: unsupported annotation format for image 'Sham_6_n3' (https://www.ebi.ac.uk/pride/archive/projects/PXD011262)
# 2026-07-28 22:28:16,778 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD010990
# Connected to the streaming API. Fetching data...
# Successfully retrieved 20 items.
# 2026-07-28 22:28:17,243 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD010990: unsupported annotation format for image 'Ds1' (https://www.ebi.ac.uk/pride/archive/projects/PXD010990)
# 2026-07-28 22:28:17,244 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD010990: unsupported annotation format for image 'Ds18' (https://www.ebi.ac.uk/pride/archive/projects/PXD010990)
# 2026-07-28 22:28:17,245 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD010990: unsupported annotation format for image 'Ds19' (https://www.ebi.ac.uk/pride/archive/projects/PXD010990)
# 2026-07-28 22:28:17,246 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD010990: unsupported annotation format for image 'Ds2' (https://www.ebi.ac.uk/pride/archive/projects/PXD010990)
# 2026-07-28 22:28:17,247 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD010990: unsupported annotation format for image 'Ds20' (https://www.ebi.ac.uk/pride/archive/projects/PXD010990)
# 2026-07-28 22:28:17,247 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD010990: unsupported annotation format for image 'Ds24' (https://www.ebi.ac.uk/pride/archive/projects/PXD010990)
# 2026-07-28 22:28:17,248 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD010990: unsupported annotation format for image 'Ds26' (https://www.ebi.ac.uk/pride/archive/projects/PXD010990)
# 2026-07-28 22:28:17,249 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD010990: unsupported annotation format for image 'Ds3' (https://www.ebi.ac.uk/pride/archive/projects/PXD010990)
# 2026-07-28 22:28:17,252 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD010990: unsupported annotation format for image 'Ds4' (https://www.ebi.ac.uk/pride/archive/projects/PXD010990)
# 2026-07-28 22:28:17,703 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD009808
# Connected to the streaming API. Fetching data...
# Successfully retrieved 10 items.
# 2026-07-28 22:28:18,203 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD009808: unsupported annotation format for image 'cal-nonormalization' (https://www.ebi.ac.uk/pride/archive/projects/PXD009808)
# 2026-07-28 22:28:18,204 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD009808: unsupported annotation format for image 'control-nonormalization' (https://www.ebi.ac.uk/pride/archive/projects/PXD009808)
# 2026-07-28 22:28:18,205 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD009808: unsupported annotation format for image 'png1-nonormalization' (https://www.ebi.ac.uk/pride/archive/projects/PXD009808)
# 2026-07-28 22:28:18,205 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD009808: unsupported annotation format for image 'png2-nonormalization' (https://www.ebi.ac.uk/pride/archive/projects/PXD009808)
# 2026-07-28 22:28:18,597 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD003172
# Connected to the streaming API. Fetching data...
# Successfully retrieved 3 items.
# 2026-07-28 22:28:18,977 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD003172: unsupported annotation format for image 'T019_Recall716.12461' (https://www.ebi.ac.uk/pride/archive/projects/PXD003172)
# 2026-07-28 22:28:19,358 - INFO - Fetching checksum file from https://www.ebi.ac.uk/pride/ws/archive/v3/files/checksum/PXD001283
# Connected to the streaming API. Fetching data...
# Successfully retrieved 4 items.
# 2026-07-28 22:28:19,733 | WARNING  | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:617 | Rejected PRIDE record PXD001283: unsupported annotation format for image 'HR2MSImouseurinarybladderS096'; tabular project files: HR2MSImouseurinarybladderS096-results.csv (https://www.ebi.ac.uk/pride/archive/projects/PXD001283)
# 2026-07-28 22:28:19,734 | INFO     | msi_autoencoder_wrapper.dataset_management.sources.strategies.pride:190 | PRIDE discovery accepted 0 image pairs and rejected 300 records
# 2026-07-28 22:28:19,734 | INFO     | msi_autoencoder_wrapper.dataset_management.exploration.dataset_explorer:100 | Explorer retained 0 records from source pride
# Empty DataFrame
# Columns: [dataset_id, name, source, project_accession, project_url, organisms, organism_parts, diseases, instruments, total_size_bytes, download_size_bytes, annotation_status, excluded]
# Index: []

# %%
rejected = explorer.rejected()
rejected
# Out:
#     project_accession dataset_id  \
# 0           PXD070149       None
# 1           PXD070149       None
# 2           PXD070149       None
# 3           PXD070149       None
# 4           PXD070149       None
# ..                ...        ...
# 295         PXD009808       None
# 296         PXD009808       None
# 297         PXD009808       None
# 298         PXD003172       None
# 299         PXD001283       None
#
#                                                 reason  \
# 0    unsupported annotation format for image 'PWB92...
# 1    unsupported annotation format for image 'PWB92...
# 2    unsupported annotation format for image 'PWB92...
# 3    unsupported annotation format for image 'PWB92...
# 4    unsupported annotation format for image 'PWB93...
# ..                                                 ...
# 295  unsupported annotation format for image 'contr...
# 296  unsupported annotation format for image 'png1-...
# 297  unsupported annotation format for image 'png2-...
# 298  unsupported annotation format for image 'T019_...
# 299  unsupported annotation format for image 'HR2MS...
#
#                                            project_url
# 0    https://www.ebi.ac.uk/pride/archive/projects/P...
# 1    https://www.ebi.ac.uk/pride/archive/projects/P...
# 2    https://www.ebi.ac.uk/pride/archive/projects/P...
# 3    https://www.ebi.ac.uk/pride/archive/projects/P...
# 4    https://www.ebi.ac.uk/pride/archive/projects/P...
# ..                                                 ...
# 295  https://www.ebi.ac.uk/pride/archive/projects/P...
# 296  https://www.ebi.ac.uk/pride/archive/projects/P...
# 297  https://www.ebi.ac.uk/pride/archive/projects/P...
# 298  https://www.ebi.ac.uk/pride/archive/projects/P...
# 299  https://www.ebi.ac.uk/pride/archive/projects/P...
#
# [300 rows x 4 columns]

# %% [markdown]
# ## Exclude reviewed images
#
# After opening project links, place unwanted `dataset_id` values below. Exclusions become part of the exported query configuration.

# %%
excluded_dataset_ids = []
if excluded_dataset_ids:
    explorer.exclude(excluded_dataset_ids)
explorer.results()

# %%
output_path = Path("workspace/configs/datasets/pride-mouse-bladder/filter.json")
explorer.export_config(output_path)

# %% [markdown]
# ## Use the exported configuration
#
# Run `msi-datasets query --source pride --workspace-path workspace --filters workspace/configs/datasets/pride-mouse-bladder/filter.json --selection workspace/configs/datasets/pride-mouse-bladder/selection.json`, review the selection, and then pass that selection to `download --source pride`. See [Use the msi-datasets CLI](../../how-to/dataset-management/command-line-workflow.md) for the complete command reference.
