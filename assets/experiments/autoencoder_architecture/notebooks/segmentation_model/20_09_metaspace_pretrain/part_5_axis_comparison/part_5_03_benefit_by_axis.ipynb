# %% [markdown]
# # Does the benefit of pretraining depend on the m/z range?
#
# Combines the axis-comparable reconstruction and head quantities: the improvement over the own baseline on each axis and the stage transitions, as wide-minus-narrow interactions.

# %% [markdown]
# ## Introduction
#
# The thesis tested in parts 2-6 is that synthetic pretraining improves on the model trained on real data only.
# Every table therefore contains the **real-only baseline** of the same axis (10 real epochs from the same
# initialization) and every comparison is a **paired difference to that baseline**.
#
# The ten pretraining variants differ only in the synthetic data seen before real data (campaign methodology,
# `pretraining_campaign_methodology.md`):
#
# | Variant | Synthetic phases | Construction |
# | --- | --- | --- |
# | P0 single bins | 1 x 10 epochs | ten spectra per axis bin; annotated bins carry their labels, blank bins are known negatives |
# | P1 permutations | 1 x 10 epochs | component-token bag (30 per class and per blank bin) packed into mixed spectra |
# | P2 joint / staged | 1 x 10 / 2 x 10 epochs | P0 and P1 rows shuffled together / P0 first, then P1 |
# | P3 joint / staged | as P2 | P2 + overlap quota (30 extra tokens per class that shares a bin with another class in a training pixel) |
# | P4 joint / staged | as P2 | P2 + rare quota (30 extra tokens per class of the least-annotated quarter) |
# | P5 joint / staged | as P2 | P2 + both quotas |
#
# Every variant yields three models along one lineage (stages): `pretrained`, `frozen_head` and `unfrozen_head`.
# The staged schedules train twice as many synthetic epochs as the joint ones, so schedule and budget are
# confounded (methodology, "Pretraining ablation").
#
# ### Assumptions
#
# * **Pairing.** Repetition $r$ uses one initialization seed for the baseline and for every variant and stage
#   (verified for all 310 models in the campaign-plan verification). The difference between a variant and the
#   baseline of the same repetition removes the initialization effect; the five repetitions are the independent
#   units. Pixels are not independent units and never enter a test as such.
# * **Data.** Every model is evaluated on identical pixels: the same `train`, `test`, `test_extended` and
#   `heldout_image` populations as in part 1, decoded once in the shared cache.
# * **Objectives.** Synthetic phases: Masserstein (1.0) + BCE (0.2) on complete synthetic targets. Real phases
#   (baseline and both fine-tuning stages): Masserstein (1.0) + VPU (0.2) + contractive (2e-3) + InfoNCE (1e-3,
#   multilabel-Jaccard negatives, added by mistake and kept because every model used it).
# * **Threshold metrics.** Precision, recall and F1 use $\hat Y \ge 0.5$, as in part 1. A head whose
#   probabilities never reach 0.5 on real data has F1 = 0 although its ranking may still carry information;
#   average precision is threshold free and is the primary head metric.
# * **Uncertainty.** With five repetitions the Student-t interval has 4 degrees of freedom
#   ($t_{0.975,4} = 2.78$); an interval that excludes zero is a strong statement, one that includes zero is not
#   evidence of no effect.
#
# * **Comparable quantities only.** Global $W_1$ is not comparable across axes (different m/z ranges and bins).
#   Reconstruction is compared on the 100 Da windows inside 200-900 m/z shared by both axes, the head on the classes
#   that are head columns on both axes (`common`), the latent capacity by dimension-free quantities.
# * **Axis difference** $s_m(v^{\mathrm{wide}}_r - v^{\mathrm{narrow}}_r)$, paired by variant, stage and repetition
#   (identical pixels and initialization seed across axes): positive = the 100-3000 axis is better.
# * **Benefit interaction** $\Delta^{\mathrm{wide}}_r - \Delta^{\mathrm{narrow}}_r$: positive = the wide axis gains
#   more from pretraining (relative to its own baseline) than the narrow axis.
#
# ### Notation
#
# * $b_r$, $v_r$: value of a metric for the baseline and for a variant (at one stage) in repetition $r$.
# * $s_m \in \{-1, +1\}$: direction of metric $m$; $-1$ for lower-is-better metrics (Masserstein $W_1$,
#   spectral angle, MSE, Hamming loss, window contribution and within-window $W_1$, absolute mass imbalance, ECE,
#   Brier score, true-label rank, false-positive rate and lift, losses), $+1$ otherwise.
# * **Improvement** $\Delta_r = s_m (v_r - b_r)$: positive is always better than the baseline.
#   **Relative improvement** $\Delta_r / |b_r|$.
# * Summary over repetitions: mean $\bar\Delta$, SD $s$, interval $\bar\Delta \pm t_{0.975, n-1}\, s / \sqrt{n}$,
#   and the numbers of repetitions with $\Delta_r > 0$ (`+k`) and $\Delta_r < 0$ (`-m`).
# * Evaluations: `test` (withheld pixels of training images), `test_combined` (test + rare-class extension, the
#   main per-class estimate), `heldout_image` (three images never seen; pooled), `heldout_image_per_image` (mean of
#   the per-image values; pooled held-out values understate the ranking because annotations are incomplete across
#   images, part 1_08).
# * $W_1$: exact one-dimensional Wasserstein-1 distance between TIC-normalized input and reconstruction (m/z
#   units); $u$: canonical latent code (LayerNorm affine removed).

# %% [markdown]
# ## Configuration

# %%
import logging
import os
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display

# Library modules log INFO to stdout; warnings stay visible, progress messages do not.
logging.disable(logging.INFO)
current_path = Path.cwd().resolve()
repository_root = next(path for path in (current_path, *current_path.parents) if (path / "pyproject.toml").is_file())
os.chdir(repository_root)

from msi_autoencoder_wrapper.analysis.autoencoder.experiments import pretraining_campaign as campaign
from msi_autoencoder_wrapper.analysis.autoencoder.experiments.pretraining_campaign_precompute import (
    load_metadata, load_table, run_command,
)
from msi_autoencoder_wrapper.analysis.precompute.notebook_inputs import load_model_catalog, load_visualization_theme
from msi_autoencoder_wrapper.visualization import pretraining as figures

SETTINGS_PATH = Path("assets/experiments/autoencoder_architecture/notebooks/segmentation_model/20_09_metaspace_pretrain/analysis_settings.yaml")
ANALYSIS = "axis_benefit"
AXIS = None
STAGE = None

settings = campaign.load_settings(SETTINGS_PATH)
theme = load_visualization_theme(settings).with_overrides(figure_dpi=100)
catalog = load_model_catalog(settings)
metadata = load_metadata(settings, ANALYSIS, AXIS, STAGE)
pd.set_option("display.precision", 4)
pd.set_option("display.width", 200)
pd.set_option("display.max_columns", 40)
pd.set_option("display.max_rows", 80)


def table(name: str) -> pd.DataFrame:
    """Load one canonical table written for this notebook by the precompute."""
    return load_table(settings, ANALYSIS, name, AXIS, STAGE)


def mean_sd(frame: pd.DataFrame, keys: list, columns: list) -> pd.DataFrame:
    """Mean and SD over repetitions of the given columns (presentation helper)."""
    long = frame.melt(id_vars=keys, value_vars=columns, var_name="quantity", value_name="value")
    return long.groupby([*keys, "quantity"]).value.agg(["mean", "std"]).unstack("quantity")


POPULATION_COLORS = {name: figures.population_color(name, theme) for name in figures.POPULATION_ORDER}
print("Analysis:", ANALYSIS, "| axis:", AXIS, "| stage:", STAGE, "| models:", metadata["models"] if isinstance(metadata["models"], int) else len(metadata["models"]))
print("Cache keys:", metadata["cache_keys"])

BASELINE = "baseline"
VARIANTS = list(settings["variants"])
VARIANT_LABELS = {BASELINE: "real-only baseline", **{name: value["label"] for name, value in settings["variants"].items()}}
## The baseline keeps its catalog colour (the dark theme baseline colour is reserved for reference lines)
BASELINE_COLOR = next(value["visualization"]["color"] for value in settings["models"].values()
                      if value.get("select", {}).get("role") == settings["baseline_role"])
VARIANT_COLORS = {BASELINE: BASELINE_COLOR, **{name: value["color"] for name, value in settings["variants"].items()}}
STAGES = list(settings["stages"])
STAGE_LABELS = {"real_only": "real-only baseline", **{name: value["label"] for name, value in settings["stages"].items()}}
KEY_METRICS = settings["comparison"]["key_metrics"]
AXES = list(settings["axes"])
AXIS_LABELS = {name: value["label"] for name, value in settings["axes"].items()}
SHORT = {"masserstein": "W1", "spectral_angle": "spectral angle", "average_precision": "macro AP",
         "micro_average_precision": "micro AP", "f1": "macro F1 at 0.5"}
EVALUATION_NAMES = {**figures.DISPLAY_NAMES, "heldout_image_per_image": "held-out, per image"}


def key_panels(reconstruction=("test", "heldout_image"), prediction=("test_combined", "heldout_image_per_image")):
    """Forest-plot panels of the key metrics: (title, row selector)."""
    panels = []
    for spec in KEY_METRICS:
        for evaluation in (reconstruction if spec["family"] == "reconstruction" else prediction):
            selector = {"family": spec["family"], "metric": spec["metric"], "evaluation": evaluation,
                        "ranking": spec.get("ranking", "none")}
            panels.append((f"{SHORT.get(spec['metric'], spec['metric'])}, {EVALUATION_NAMES.get(evaluation, evaluation)}", selector))
    return panels


def interval(frame, digits=3):
    """'mean [ci_low, ci_high] (+k/-m)' strings of a summary table."""
    form = "{:." + str(digits) + "g}"
    return (frame["mean"].map(form.format) + " [" + frame.ci_low.map(form.format) + ", "
            + frame.ci_high.map(form.format) + "] (+" + frame.positive.astype(int).astype(str) + "/-"
            + frame.negative.astype(int).astype(str) + ")")

from msi_autoencoder_wrapper.analysis.autoencoder.experiments.pretraining_campaign_comparison import summarize

ORDER = [BASELINE, *VARIANTS]

interaction = table('interaction')
transition_interaction = table('transition_interaction')
QUANTITIES = [('W1 contribution in 200-900, test', {'family': 'common_windows', 'metric': 'contribution', 'evaluation': 'test'}),
              ('W1 contribution in 200-900, held-out', {'family': 'common_windows', 'metric': 'contribution', 'evaluation': 'heldout_image'}),
              ('common-class AP, test + ext.', {'family': 'common_classes', 'metric': 'average_precision', 'evaluation': 'test_combined'}),
              ('common-class AP, held-out', {'family': 'common_classes', 'metric': 'average_precision', 'evaluation': 'heldout_image'})]
TRANSITIONS = ['frozen_minus_pretrained', 'unfrozen_minus_pretrained', 'unfrozen_minus_frozen']
# Out:
# Analysis: axis_benefit | axis: None | stage: None | models: 310
# Cache keys: {'plan': 'f34a92a8f6f7833f', 'populations': '513690bdd78a83ce', 'synthetic_reference': '6ba5bc1e0839ba0e', 'inference': '0243c1efb93b9c4c'}

# %% [markdown]
# ## Producing the tables this notebook reads
#
# ### Methodology
#
# #### Implementation
#
# `axis_benefit` recomputes the shared-window and shared-class quantities (as 5_01 and 5_02) and forms the
# interactions of the improvement over the own baseline and of the stage transitions.
#
# The command below is generated by the precompute entry point itself; if a table is missing, `load_table` raises with the same command.

# %%
print(run_command(settings, ANALYSIS))
# Out:
# nohup uv run --extra cu118 python -m msi_autoencoder_wrapper.analysis.precompute --settings /home/max/repositories/MSIAutoEncoderWrapper/assets/experiments/autoencoder_architecture/notebooks/segmentation_model/20_09_metaspace_pretrain/analysis_settings.yaml --analysis axis_benefit > /home/max/repositories/MSIAutoEncoderWrapper/assets/experiments/autoencoder_architecture/notebooks/segmentation_model/20_09_metaspace_pretrain/shared_precompute.log 2>&1 &

# %% [markdown]
# ### Remarks

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Absolute values of both axes against their real-only baselines

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# The axis-comparison statistics as levels: for every axis, the value of each model (baseline and every stage),
# so that a difference between axes can be read against what each axis reaches.

# %% [markdown]
# #### Implementation
#
# `metrics` holds one value per model, metric and evaluation population on both axes.

# %% [markdown]
# #### Figure descriptions
#
#         Figure: one panel per axis, metric and evaluation; x = real-only baseline and stages (variants pooled: 50 models
#         per stage against 5 baseline models). Tables: rows = baseline and variants, columns = axis | stage; the
#         baseline row repeats each axis's baseline value.
#         Last figure: the unfrozen-head stage only, split by variant (x = real-only baseline and every variant, five
#         repetitions each), because pooling the variants of a stage mixes variants with very different effects.
#
# Colours: in the figures the baseline is grey (its mean is the dashed line) and every other group is green when its
# mean is better than the baseline mean and red when it is worse. In the tables every cell is mean +/- SD over the
# repetitions; green / red cells are better / worse than the baseline cell of the same column (stronger colour = larger
# difference within the column), the black frame marks the three best rows of the column and the grey bold row is the
# real-only baseline.

# %%
LOWER_IS_BETTER = {'masserstein', 'spectral_angle', 'mse', 'hamming_loss', 'expected_calibration_error', 'brier_score',
                   'within', 'contribution', 'absolute_mass_imbalance', 'bic'}
METRIC_ORDER = ['average_precision', 'micro_average_precision', 'roc_auc', 'micro_roc_auc', 'ap_above_prevalence',
                'precision', 'recall', 'f1', 'micro_precision', 'micro_recall', 'micro_f1', 'micro_prevalence',
                'hamming_loss']
ABS_ORDER = [BASELINE, *VARIANTS]
LABELS_ABS = {**VARIANT_LABELS, **{name: VARIANT_LABELS.get(name, name) for name in ABS_ORDER}}


def better(metric):
    """Direction of a metric: 'lower' or 'higher' is better."""
    return 'lower' if metric in LOWER_IS_BETTER else 'higher'

# %%
metrics_abs = table('metrics')
SELECTORS_ABS = [["axis-200-900: window contribution to W1, test", {"axis": "axis-200-900", "family": "common_windows", "metric": "contribution", "evaluation": "test", "ranking": "none"}, "lower"], ["axis-200-900: within-window W1, test", {"axis": "axis-200-900", "family": "common_windows", "metric": "within", "evaluation": "test", "ranking": "none"}, "lower"], ["axis-200-900: window contribution to W1, heldout_image", {"axis": "axis-200-900", "family": "common_windows", "metric": "contribution", "evaluation": "heldout_image", "ranking": "none"}, "lower"], ["axis-200-900: within-window W1, heldout_image", {"axis": "axis-200-900", "family": "common_windows", "metric": "within", "evaluation": "heldout_image", "ranking": "none"}, "lower"], ["axis-200-900: macro AP, heldout_image", {"axis": "axis-200-900", "family": "common_classes", "metric": "average_precision", "evaluation": "heldout_image", "ranking": "annotation_retrieval"}, "higher"], ["axis-200-900: macro AP, test_combined", {"axis": "axis-200-900", "family": "common_classes", "metric": "average_precision", "evaluation": "test_combined", "ranking": "annotation_retrieval"}, "higher"], ["axis-200-900: macro ROC AUC, heldout_image", {"axis": "axis-200-900", "family": "common_classes", "metric": "roc_auc", "evaluation": "heldout_image", "ranking": "annotation_retrieval"}, "higher"], ["axis-200-900: macro ROC AUC, test_combined", {"axis": "axis-200-900", "family": "common_classes", "metric": "roc_auc", "evaluation": "test_combined", "ranking": "annotation_retrieval"}, "higher"], ["axis-100-3000: window contribution to W1, test", {"axis": "axis-100-3000", "family": "common_windows", "metric": "contribution", "evaluation": "test", "ranking": "none"}, "lower"], ["axis-100-3000: within-window W1, test", {"axis": "axis-100-3000", "family": "common_windows", "metric": "within", "evaluation": "test", "ranking": "none"}, "lower"], ["axis-100-3000: window contribution to W1, heldout_image", {"axis": "axis-100-3000", "family": "common_windows", "metric": "contribution", "evaluation": "heldout_image", "ranking": "none"}, "lower"], ["axis-100-3000: within-window W1, heldout_image", {"axis": "axis-100-3000", "family": "common_windows", "metric": "within", "evaluation": "heldout_image", "ranking": "none"}, "lower"], ["axis-100-3000: macro AP, heldout_image", {"axis": "axis-100-3000", "family": "common_classes", "metric": "average_precision", "evaluation": "heldout_image", "ranking": "annotation_retrieval"}, "higher"], ["axis-100-3000: macro AP, test_combined", {"axis": "axis-100-3000", "family": "common_classes", "metric": "average_precision", "evaluation": "test_combined", "ranking": "annotation_retrieval"}, "higher"], ["axis-100-3000: macro ROC AUC, heldout_image", {"axis": "axis-100-3000", "family": "common_classes", "metric": "roc_auc", "evaluation": "heldout_image", "ranking": "annotation_retrieval"}, "higher"], ["axis-100-3000: macro ROC AUC, test_combined", {"axis": "axis-100-3000", "family": "common_classes", "metric": "roc_auc", "evaluation": "test_combined", "ranking": "annotation_retrieval"}, "higher"]]
STAGE_ORDER = ['real_only', *STAGES]
figures.metric_panels(metrics_abs, panels=[tuple(item) for item in SELECTORS_ABS], group='stage', order=STAGE_ORDER,
                      labels=STAGE_LABELS, baseline='real_only', columns=4, theme=theme);
plt.show()
for (family, metric, evaluation, ranking), rows in metrics_abs.groupby(['family', 'metric', 'evaluation', 'ranking']):
    base = rows[rows.stage == 'real_only']
    grid = pd.concat([rows[rows.stage != 'real_only'], *[base.assign(stage=stage) for stage in STAGES]])
    grid = grid.assign(column=grid.axis + ' | ' + grid.stage)
    columns = [f'{axis} | {stage}' for axis in AXES for stage in STAGES]
    print(metric, '|', evaluation)
    display(figures.comparison_table(grid, index='variant', columns='column', baseline=BASELINE, order=ABS_ORDER,
                                     column_order=columns, direction={column: better(metric) for column in columns}))
# Out:
# average_precision | heldout_image
# <style type="text/css">
# #T_35d32_row0_col0, #T_35d32_row0_col1, #T_35d32_row0_col2, #T_35d32_row0_col3, #T_35d32_row0_col4, #T_35d32_row0_col5 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_35d32_row1_col0, #T_35d32_row4_col4, #T_35d32_row5_col4 {
#   background-color: rgba(215, 48, 39, 0.70);
# }
# #T_35d32_row1_col1, #T_35d32_row1_col4, #T_35d32_row2_col1, #T_35d32_row6_col0, #T_35d32_row7_col3 {
#   background-color: rgba(215, 48, 39, 0.67);
#   border: 2px solid black;
# }
# #T_35d32_row1_col2, #T_35d32_row1_col3, #T_35d32_row3_col3, #T_35d32_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.67);
# }
# #T_35d32_row1_col5, #T_35d32_row3_col0, #T_35d32_row4_col0, #T_35d32_row5_col0, #T_35d32_row5_col1, #T_35d32_row6_col1, #T_35d32_row8_col4 {
#   background-color: rgba(215, 48, 39, 0.71);
# }
# #T_35d32_row2_col0, #T_35d32_row2_col3, #T_35d32_row3_col1, #T_35d32_row4_col1, #T_35d32_row10_col4 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_35d32_row2_col2 {
#   background-color: rgba(215, 48, 39, 0.27);
#   border: 2px solid black;
# }
# #T_35d32_row2_col4, #T_35d32_row5_col3 {
#   background-color: rgba(215, 48, 39, 0.64);
#   border: 2px solid black;
# }
# #T_35d32_row2_col5 {
#   background-color: rgba(215, 48, 39, 0.17);
# }
# #T_35d32_row3_col2, #T_35d32_row8_col3 {
#   background-color: rgba(215, 48, 39, 0.68);
# }
# #T_35d32_row3_col4, #T_35d32_row4_col3, #T_35d32_row6_col4 {
#   background-color: rgba(215, 48, 39, 0.73);
# }
# #T_35d32_row3_col5 {
#   background-color: rgba(26, 152, 80, 0.20);
#   border: 2px solid black;
# }
# #T_35d32_row4_col2, #T_35d32_row6_col3, #T_35d32_row6_col5, #T_35d32_row7_col4, #T_35d32_row8_col1, #T_35d32_row9_col0 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_35d32_row4_col5 {
#   background-color: rgba(215, 48, 39, 0.41);
# }
# #T_35d32_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.46);
# }
# #T_35d32_row5_col5 {
#   background-color: rgba(26, 152, 80, 0.23);
#   border: 2px solid black;
# }
# #T_35d32_row6_col2 {
#   background-color: rgba(215, 48, 39, 0.61);
# }
# #T_35d32_row7_col0, #T_35d32_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.72);
# }
# #T_35d32_row7_col1, #T_35d32_row9_col3 {
#   background-color: rgba(215, 48, 39, 0.66);
#   border: 2px solid black;
# }
# #T_35d32_row7_col2 {
#   background-color: rgba(215, 48, 39, 0.37);
#   border: 2px solid black;
# }
# #T_35d32_row7_col5 {
#   background-color: rgba(215, 48, 39, 0.43);
# }
# #T_35d32_row8_col0 {
#   background-color: rgba(215, 48, 39, 0.62);
#   border: 2px solid black;
# }
# #T_35d32_row8_col2 {
#   background-color: rgba(215, 48, 39, 0.31);
#   border: 2px solid black;
# }
# #T_35d32_row8_col5 {
#   background-color: rgba(215, 48, 39, 0.57);
# }
# #T_35d32_row9_col2 {
#   background-color: rgba(215, 48, 39, 0.54);
# }
# #T_35d32_row9_col4 {
#   background-color: rgba(215, 48, 39, 0.69);
#   border: 2px solid black;
# }
# #T_35d32_row9_col5 {
#   background-color: rgba(215, 48, 39, 0.17);
#   border: 2px solid black;
# }
# #T_35d32_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.68);
#   border: 2px solid black;
# }
# #T_35d32_row10_col2 {
#   background-color: rgba(215, 48, 39, 0.49);
# }
# #T_35d32_row10_col3 {
#   background-color: rgba(215, 48, 39, 0.69);
# }
# #T_35d32_row10_col5 {
#   background-color: rgba(215, 48, 39, 0.56);
# }
# </style>
# <table id="T_35d32">
#   <thead>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th id="T_35d32_level0_col0" class="col_heading level0 col0" >axis-200-900 | pretrained</th>
#       <th id="T_35d32_level0_col1" class="col_heading level0 col1" >axis-200-900 | frozen_head</th>
#       <th id="T_35d32_level0_col2" class="col_heading level0 col2" >axis-200-900 | unfrozen_head</th>
#       <th id="T_35d32_level0_col3" class="col_heading level0 col3" >axis-100-3000 | pretrained</th>
#       <th id="T_35d32_level0_col4" class="col_heading level0 col4" >axis-100-3000 | frozen_head</th>
#       <th id="T_35d32_level0_col5" class="col_heading level0 col5" >axis-100-3000 | unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35d32_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_35d32_row0_col0" class="data row0 col0" >0.356 +/- 0.007</td>
#       <td id="T_35d32_row0_col1" class="data row0 col1" >0.356 +/- 0.007</td>
#       <td id="T_35d32_row0_col2" class="data row0 col2" >0.356 +/- 0.007</td>
#       <td id="T_35d32_row0_col3" class="data row0 col3" >0.372 +/- 0.014</td>
#       <td id="T_35d32_row0_col4" class="data row0 col4" >0.372 +/- 0.014</td>
#       <td id="T_35d32_row0_col5" class="data row0 col5" >0.372 +/- 0.014</td>
#     </tr>
#     <tr>
#       <th id="T_35d32_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_35d32_row1_col0" class="data row1 col0" >0.262 +/- 0.023</td>
#       <td id="T_35d32_row1_col1" class="data row1 col1" >0.253 +/- 0.031</td>
#       <td id="T_35d32_row1_col2" class="data row1 col2" >0.343 +/- 0.008</td>
#       <td id="T_35d32_row1_col3" class="data row1 col3" >0.271 +/- 0.016</td>
#       <td id="T_35d32_row1_col4" class="data row1 col4" >0.256 +/- 0.016</td>
#       <td id="T_35d32_row1_col5" class="data row1 col5" >0.357 +/- 0.006</td>
#     </tr>
#     <tr>
#       <th id="T_35d32_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_35d32_row2_col0" class="data row2 col0" >0.254 +/- 0.001</td>
#       <td id="T_35d32_row2_col1" class="data row2 col1" >0.252 +/- 0.002</td>
#       <td id="T_35d32_row2_col2" class="data row2 col2" >0.353 +/- 0.012</td>
#       <td id="T_35d32_row2_col3" class="data row2 col3" >0.258 +/- 0.004</td>
#       <td id="T_35d32_row2_col4" class="data row2 col4" >0.264 +/- 0.017</td>
#       <td id="T_35d32_row2_col5" class="data row2 col5" >0.372 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_35d32_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_35d32_row3_col0" class="data row3 col0" >0.260 +/- 0.014</td>
#       <td id="T_35d32_row3_col1" class="data row3 col1" >0.239 +/- 0.010</td>
#       <td id="T_35d32_row3_col2" class="data row3 col2" >0.343 +/- 0.013</td>
#       <td id="T_35d32_row3_col3" class="data row3 col3" >0.271 +/- 0.013</td>
#       <td id="T_35d32_row3_col4" class="data row3 col4" >0.244 +/- 0.010</td>
#       <td id="T_35d32_row3_col5" class="data row3 col5" >0.374 +/- 0.023</td>
#     </tr>
#     <tr>
#       <th id="T_35d32_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_35d32_row4_col0" class="data row4 col0" >0.259 +/- 0.008</td>
#       <td id="T_35d32_row4_col1" class="data row4 col1" >0.238 +/- 0.012</td>
#       <td id="T_35d32_row4_col2" class="data row4 col2" >0.341 +/- 0.008</td>
#       <td id="T_35d32_row4_col3" class="data row4 col3" >0.261 +/- 0.011</td>
#       <td id="T_35d32_row4_col4" class="data row4 col4" >0.249 +/- 0.011</td>
#       <td id="T_35d32_row4_col5" class="data row4 col5" >0.365 +/- 0.013</td>
#     </tr>
#     <tr>
#       <th id="T_35d32_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_35d32_row5_col0" class="data row5 col0" >0.259 +/- 0.009</td>
#       <td id="T_35d32_row5_col1" class="data row5 col1" >0.244 +/- 0.004</td>
#       <td id="T_35d32_row5_col2" class="data row5 col2" >0.348 +/- 0.019</td>
#       <td id="T_35d32_row5_col3" class="data row5 col3" >0.278 +/- 0.026</td>
#       <td id="T_35d32_row5_col4" class="data row5 col4" >0.250 +/- 0.009</td>
#       <td id="T_35d32_row5_col5" class="data row5 col5" >0.374 +/- 0.013</td>
#     </tr>
#     <tr>
#       <th id="T_35d32_level0_row6" class="row_heading level0 row6" >P3_staged_overlap</th>
#       <td id="T_35d32_row6_col0" class="data row6 col0" >0.266 +/- 0.016</td>
#       <td id="T_35d32_row6_col1" class="data row6 col1" >0.244 +/- 0.006</td>
#       <td id="T_35d32_row6_col2" class="data row6 col2" >0.345 +
# average_precision | test_combined
# <style type="text/css">
# #T_20049_row0_col0, #T_20049_row0_col1, #T_20049_row0_col2, #T_20049_row0_col3, #T_20049_row0_col4, #T_20049_row0_col5 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_20049_row1_col0, #T_20049_row6_col4, #T_20049_row8_col4, #T_20049_row9_col0, #T_20049_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.73);
# }
# #T_20049_row1_col1, #T_20049_row4_col1, #T_20049_row8_col1, #T_20049_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.67);
# }
# #T_20049_row1_col2 {
#   background-color: rgba(215, 48, 39, 0.17);
# }
# #T_20049_row1_col3, #T_20049_row3_col3 {
#   background-color: rgba(215, 48, 39, 0.74);
#   border: 2px solid black;
# }
# #T_20049_row1_col4 {
#   background-color: rgba(215, 48, 39, 0.69);
# }
# #T_20049_row1_col5, #T_20049_row6_col2 {
#   background-color: rgba(26, 152, 80, 0.75);
#   border: 2px solid black;
# }
# #T_20049_row2_col0, #T_20049_row7_col0 {
#   background-color: rgba(215, 48, 39, 0.71);
#   border: 2px solid black;
# }
# #T_20049_row2_col1, #T_20049_row2_col4, #T_20049_row4_col0, #T_20049_row4_col3, #T_20049_row5_col3, #T_20049_row6_col0, #T_20049_row6_col3, #T_20049_row7_col3, #T_20049_row8_col3, #T_20049_row9_col3, #T_20049_row10_col3 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_20049_row2_col2 {
#   background-color: rgba(215, 48, 39, 0.57);
# }
# #T_20049_row2_col3 {
#   background-color: rgba(215, 48, 39, 0.67);
#   border: 2px solid black;
# }
# #T_20049_row2_col5 {
#   background-color: rgba(215, 48, 39, 0.58);
# }
# #T_20049_row3_col0 {
#   background-color: rgba(215, 48, 39, 0.72);
# }
# #T_20049_row3_col1 {
#   background-color: rgba(215, 48, 39, 0.64);
#   border: 2px solid black;
# }
# #T_20049_row3_col2 {
#   background-color: rgba(215, 48, 39, 0.55);
# }
# #T_20049_row3_col4 {
#   background-color: rgba(215, 48, 39, 0.64);
# }
# #T_20049_row3_col5 {
#   background-color: rgba(215, 48, 39, 0.47);
# }
# #T_20049_row4_col2 {
#   background-color: rgba(26, 152, 80, 0.40);
# }
# #T_20049_row4_col4 {
#   background-color: rgba(215, 48, 39, 0.71);
# }
# #T_20049_row4_col5 {
#   background-color: rgba(215, 48, 39, 0.59);
# }
# #T_20049_row5_col0 {
#   background-color: rgba(215, 48, 39, 0.72);
#   border: 2px solid black;
# }
# #T_20049_row5_col1 {
#   background-color: rgba(215, 48, 39, 0.61);
#   border: 2px solid black;
# }
# #T_20049_row5_col2 {
#   background-color: rgba(26, 152, 80, 0.38);
# }
# #T_20049_row5_col4, #T_20049_row7_col1, #T_20049_row7_col4, #T_20049_row9_col4 {
#   background-color: rgba(215, 48, 39, 0.63);
#   border: 2px solid black;
# }
# #T_20049_row5_col5 {
#   background-color: rgba(26, 152, 80, 0.35);
#   border: 2px solid black;
# }
# #T_20049_row6_col1, #T_20049_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.65);
# }
# #T_20049_row6_col5 {
#   background-color: rgba(215, 48, 39, 0.50);
# }
# #T_20049_row7_col2 {
#   background-color: rgba(26, 152, 80, 0.29);
# }
# #T_20049_row7_col5 {
#   background-color: rgba(215, 48, 39, 0.23);
# }
# #T_20049_row8_col0, #T_20049_row10_col4 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_20049_row8_col2 {
#   background-color: rgba(26, 152, 80, 0.62);
#   border: 2px solid black;
# }
# #T_20049_row8_col5 {
#   background-color: rgba(215, 48, 39, 0.27);
# }
# #T_20049_row9_col2 {
#   background-color: rgba(215, 48, 39, 0.34);
# }
# #T_20049_row9_col5 {
#   background-color: rgba(215, 48, 39, 0.19);
# }
# #T_20049_row10_col2 {
#   background-color: rgba(26, 152, 80, 0.57);
#   border: 2px solid black;
# }
# #T_20049_row10_col5 {
#   background-color: rgba(26, 152, 80, 0.23);
#   border: 2px solid black;
# }
# </style>
# <table id="T_20049">
#   <thead>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th id="T_20049_level0_col0" class="col_heading level0 col0" >axis-200-900 | pretrained</th>
#       <th id="T_20049_level0_col1" class="col_heading level0 col1" >axis-200-900 | frozen_head</th>
#       <th id="T_20049_level0_col2" class="col_heading level0 col2" >axis-200-900 | unfrozen_head</th>
#       <th id="T_20049_level0_col3" class="col_heading level0 col3" >axis-100-3000 | pretrained</th>
#       <th id="T_20049_level0_col4" class="col_heading level0 col4" >axis-100-3000 | frozen_head</th>
#       <th id="T_20049_level0_col5" class="col_heading level0 col5" >axis-100-3000 | unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20049_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_20049_row0_col0" class="data row0 col0" >0.709 +/- 0.003</td>
#       <td id="T_20049_row0_col1" class="data row0 col1" >0.709 +/- 0.003</td>
#       <td id="T_20049_row0_col2" class="data row0 col2" >0.709 +/- 0.003</td>
#       <td id="T_20049_row0_col3" class="data row0 col3" >0.705 +/- 0.007</td>
#       <td id="T_20049_row0_col4" class="data row0 col4" >0.705 +/- 0.007</td>
#       <td id="T_20049_row0_col5" class="data row0 col5" >0.705 +/- 0.007</td>
#     </tr>
#     <tr>
#       <th id="T_20049_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_20049_row1_col0" class="data row1 col0" >0.096 +/- 0.032</td>
#       <td id="T_20049_row1_col1" class="data row1 col1" >0.232 +/- 0.021</td>
#       <td id="T_20049_row1_col2" class="data row1 col2" >0.709 +/- 0.004</td>
#       <td id="T_20049_row1_col3" class="data row1 col3" >0.071 +/- 0.018</td>
#       <td id="T_20049_row1_col4" class="data row1 col4" >0.234 +/- 0.055</td>
#       <td id="T_20049_row1_col5" class="data row1 col5" >0.710 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_20049_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_20049_row2_col0" class="data row2 col0" >0.120 +/- 0.012</td>
#       <td id="T_20049_row2_col1" class="data row2 col1" >0.158 +/- 0.016</td>
#       <td id="T_20049_row2_col2" class="data row2 col2" >0.706 +/- 0.005</td>
#       <td id="T_20049_row2_col3" class="data row2 col3" >0.142 +/- 0.010</td>
#       <td id="T_20049_row2_col4" class="data row2 col4" >0.179 +/- 0.025</td>
#       <td id="T_20049_row2_col5" class="data row2 col5" >0.701 +/- 0.007</td>
#     </tr>
#     <tr>
#       <th id="T_20049_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_20049_row3_col0" class="data row3 col0" >0.099 +/- 0.009</td>
#       <td id="T_20049_row3_col1" class="data row3 col1" >0.260 +/- 0.013</td>
#       <td id="T_20049_row3_col2" class="data row3 col2" >0.706 +/- 0.005</td>
#       <td id="T_20049_row3_col3" class="data row3 col3" >0.065 +/- 0.019</td>
#       <td id="T_20049_row3_col4" class="data row3 col4" >0.272 +/- 0.020</td>
#       <td id="T_20049_row3_col5" class="data row3 col5" >0.702 +/- 0.004</td>
#     </tr>
#     <tr>
#       <th id="T_20049_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_20049_row4_col0" class="data row4 col0" >0.073 +/- 0.007</td>
#       <td id="T_20049_row4_col1" class="data row4 col1" >0.234 +/- 0.015</td>
#       <td id="T_20049_row4_col2" class="data row4 col2" >0.710 +/- 0.003</td>
#       <td id="T_20049_row4_col3" class="data row4 col3" >0.055 +/- 0.005</td>
#       <td id="T_20049_row4_col4" class="data row4 col4" >0.213 +/- 0.080</td>
#       <td id="T_20049_row4_col5" class="data row4 col5" >0.701 +/- 0.007</td>
#     </tr>
#     <tr>
#       <th id="T_20049_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_20049_row5_col0" class="data row5 col0" >0.105 +/- 0.016</td>
#       <td id="T_20049_row5_col1" class="data row5 col1" >0.287 +/- 0.019</td>
#       <td id="T_20049_row5_col2" class="data row5 col2" >0.710 +/- 0.003</td>
#       <td id="T_20049_row5_col3" class="data row5 col3" >0.057 +/- 0.004</td>
#       <td id="T_20049_row5_col4" class="data row5 col4" >0.285 +/- 0.025</td>
#       <td id="T_20049_row5_col5" class="data row5 col5" >0.707 +/- 0.003</td>
#     </tr>
#     <tr>
#       <th id="T_20049_level0_row6" class="row_heading level0 row6" >P3_
# roc_auc | heldout_image
# <style type="text/css">
# #T_96c51_row0_col0, #T_96c51_row0_col1, #T_96c51_row0_col2, #T_96c51_row0_col3, #T_96c51_row0_col4, #T_96c51_row0_col5 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_96c51_row1_col0, #T_96c51_row10_col1, #T_96c51_row10_col4 {
#   background-color: rgba(215, 48, 39, 0.64);
#   border: 2px solid black;
# }
# #T_96c51_row1_col1, #T_96c51_row5_col4, #T_96c51_row7_col3, #T_96c51_row8_col1, #T_96c51_row9_col3 {
#   background-color: rgba(215, 48, 39, 0.71);
# }
# #T_96c51_row1_col2 {
#   background-color: rgba(215, 48, 39, 0.27);
# }
# #T_96c51_row1_col3, #T_96c51_row1_col5, #T_96c51_row2_col1, #T_96c51_row4_col2, #T_96c51_row7_col4, #T_96c51_row9_col0 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_96c51_row1_col4, #T_96c51_row3_col0, #T_96c51_row6_col0, #T_96c51_row7_col0, #T_96c51_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_96c51_row2_col0, #T_96c51_row3_col1, #T_96c51_row4_col1 {
#   background-color: rgba(215, 48, 39, 0.72);
# }
# #T_96c51_row2_col2 {
#   background-color: rgba(215, 48, 39, 0.29);
# }
# #T_96c51_row2_col3 {
#   background-color: rgba(215, 48, 39, 0.63);
#   border: 2px solid black;
# }
# #T_96c51_row2_col4 {
#   background-color: rgba(215, 48, 39, 0.58);
#   border: 2px solid black;
# }
# #T_96c51_row2_col5 {
#   background-color: rgba(215, 48, 39, 0.21);
#   border: 2px solid black;
# }
# #T_96c51_row3_col2 {
#   background-color: rgba(215, 48, 39, 0.24);
#   border: 2px solid black;
# }
# #T_96c51_row3_col3, #T_96c51_row8_col4 {
#   background-color: rgba(215, 48, 39, 0.70);
# }
# #T_96c51_row3_col4, #T_96c51_row5_col3, #T_96c51_row6_col3 {
#   background-color: rgba(215, 48, 39, 0.68);
#   border: 2px solid black;
# }
# #T_96c51_row3_col5 {
#   background-color: rgba(215, 48, 39, 0.26);
#   border: 2px solid black;
# }
# #T_96c51_row4_col0 {
#   background-color: rgba(215, 48, 39, 0.73);
# }
# #T_96c51_row4_col3, #T_96c51_row6_col4 {
#   background-color: rgba(215, 48, 39, 0.69);
# }
# #T_96c51_row4_col4, #T_96c51_row8_col3, #T_96c51_row9_col4, #T_96c51_row10_col3 {
#   background-color: rgba(215, 48, 39, 0.68);
# }
# #T_96c51_row4_col5 {
#   background-color: rgba(215, 48, 39, 0.40);
# }
# #T_96c51_row5_col0 {
#   background-color: rgba(215, 48, 39, 0.71);
#   border: 2px solid black;
# }
# #T_96c51_row5_col1 {
#   background-color: rgba(215, 48, 39, 0.61);
#   border: 2px solid black;
# }
# #T_96c51_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.33);
# }
# #T_96c51_row5_col5 {
#   background-color: rgba(215, 48, 39, 0.35);
# }
# #T_96c51_row6_col1 {
#   background-color: rgba(215, 48, 39, 0.67);
# }
# #T_96c51_row6_col2 {
#   background-color: rgba(215, 48, 39, 0.49);
# }
# #T_96c51_row6_col5, #T_96c51_row10_col5 {
#   background-color: rgba(215, 48, 39, 0.54);
# }
# #T_96c51_row7_col1 {
#   background-color: rgba(215, 48, 39, 0.65);
# }
# #T_96c51_row7_col2 {
#   background-color: rgba(215, 48, 39, 0.22);
#   border: 2px solid black;
# }
# #T_96c51_row7_col5, #T_96c51_row10_col2 {
#   background-color: rgba(215, 48, 39, 0.42);
# }
# #T_96c51_row8_col0 {
#   background-color: rgba(215, 48, 39, 0.67);
#   border: 2px solid black;
# }
# #T_96c51_row8_col2 {
#   background-color: rgba(215, 48, 39, 0.20);
#   border: 2px solid black;
# }
# #T_96c51_row8_col5 {
#   background-color: rgba(215, 48, 39, 0.51);
# }
# #T_96c51_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.62);
#   border: 2px solid black;
# }
# #T_96c51_row9_col2 {
#   background-color: rgba(215, 48, 39, 0.25);
# }
# #T_96c51_row9_col5 {
#   background-color: rgba(215, 48, 39, 0.19);
#   border: 2px solid black;
# }
# </style>
# <table id="T_96c51">
#   <thead>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th id="T_96c51_level0_col0" class="col_heading level0 col0" >axis-200-900 | pretrained</th>
#       <th id="T_96c51_level0_col1" class="col_heading level0 col1" >axis-200-900 | frozen_head</th>
#       <th id="T_96c51_level0_col2" class="col_heading level0 col2" >axis-200-900 | unfrozen_head</th>
#       <th id="T_96c51_level0_col3" class="col_heading level0 col3" >axis-100-3000 | pretrained</th>
#       <th id="T_96c51_level0_col4" class="col_heading level0 col4" >axis-100-3000 | frozen_head</th>
#       <th id="T_96c51_level0_col5" class="col_heading level0 col5" >axis-100-3000 | unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96c51_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_96c51_row0_col0" class="data row0 col0" >0.697 +/- 0.008</td>
#       <td id="T_96c51_row0_col1" class="data row0 col1" >0.697 +/- 0.008</td>
#       <td id="T_96c51_row0_col2" class="data row0 col2" >0.697 +/- 0.008</td>
#       <td id="T_96c51_row0_col3" class="data row0 col3" >0.716 +/- 0.012</td>
#       <td id="T_96c51_row0_col4" class="data row0 col4" >0.716 +/- 0.012</td>
#       <td id="T_96c51_row0_col5" class="data row0 col5" >0.716 +/- 0.012</td>
#     </tr>
#     <tr>
#       <th id="T_96c51_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_96c51_row1_col0" class="data row1 col0" >0.522 +/- 0.043</td>
#       <td id="T_96c51_row1_col1" class="data row1 col1" >0.479 +/- 0.034</td>
#       <td id="T_96c51_row1_col2" class="data row1 col2" >0.694 +/- 0.010</td>
#       <td id="T_96c51_row1_col3" class="data row1 col3" >0.478 +/- 0.026</td>
#       <td id="T_96c51_row1_col4" class="data row1 col4" >0.464 +/- 0.042</td>
#       <td id="T_96c51_row1_col5" class="data row1 col5" >0.704 +/- 0.004</td>
#     </tr>
#     <tr>
#       <th id="T_96c51_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_96c51_row2_col0" class="data row2 col0" >0.493 +/- 0.013</td>
#       <td id="T_96c51_row2_col1" class="data row2 col1" >0.464 +/- 0.013</td>
#       <td id="T_96c51_row2_col2" class="data row2 col2" >0.693 +/- 0.012</td>
#       <td id="T_96c51_row2_col3" class="data row2 col3" >0.526 +/- 0.017</td>
#       <td id="T_96c51_row2_col4" class="data row2 col4" >0.532 +/- 0.041</td>
#       <td id="T_96c51_row2_col5" class="data row2 col5" >0.715 +/- 0.009</td>
#     </tr>
#     <tr>
#       <th id="T_96c51_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_96c51_row3_col0" class="data row3 col0" >0.485 +/- 0.016</td>
#       <td id="T_96c51_row3_col1" class="data row3 col1" >0.475 +/- 0.055</td>
#       <td id="T_96c51_row3_col2" class="data row3 col2" >0.694 +/- 0.015</td>
#       <td id="T_96c51_row3_col3" class="data row3 col3" >0.498 +/- 0.004</td>
#       <td id="T_96c51_row3_col4" class="data row3 col4" >0.490 +/- 0.025</td>
#       <td id="T_96c51_row3_col5" class="data row3 col5" >0.714 +/- 0.019</td>
#     </tr>
#     <tr>
#       <th id="T_96c51_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_96c51_row4_col0" class="data row4 col0" >0.491 +/- 0.011</td>
#       <td id="T_96c51_row4_col1" class="data row4 col1" >0.475 +/- 0.035</td>
#       <td id="T_96c51_row4_col2" class="data row4 col2" >0.681 +/- 0.012</td>
#       <td id="T_96c51_row4_col3" class="data row4 col3" >0.501 +/- 0.025</td>
#       <td id="T_96c51_row4_col4" class="data row4 col4" >0.489 +/- 0.035</td>
#       <td id="T_96c51_row4_col5" class="data row4 col5" >0.711 +/- 0.012</td>
#     </tr>
#     <tr>
#       <th id="T_96c51_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_96c51_row5_col0" class="data row5 col0" >0.499 +/- 0.013</td>
#       <td id="T_96c51_row5_col1" class="data row5 col1" >0.517 +/- 0.050</td>
#       <td id="T_96c51_row5_col2" class="data row5 col2" >0.692 +/- 0.011</td>
#       <td id="T_96c51_row5_col3" class="data row5 col3" >0.507 +/- 0.017</td>
#       <td id="T_96c51_row5_col4" class="data row5 col4" >0.474 +/- 0.025</td>
#       <td id="T_96c51_row5_col5" class="data row5 col5" >0.712 +/- 0.012</td>
#     </tr>
#     <tr>
#       <th id="T_96c51_level0_row6" class="row_heading level0 row6
# roc_auc | test_combined
# <style type="text/css">
# #T_90eab_row0_col0, #T_90eab_row0_col1, #T_90eab_row0_col2, #T_90eab_row0_col3, #T_90eab_row0_col4, #T_90eab_row0_col5 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_90eab_row1_col0, #T_90eab_row7_col0 {
#   background-color: rgba(215, 48, 39, 0.68);
#   border: 2px solid black;
# }
# #T_90eab_row1_col1 {
#   background-color: rgba(215, 48, 39, 0.65);
# }
# #T_90eab_row1_col2 {
#   background-color: rgba(26, 152, 80, 0.24);
#   border: 2px solid black;
# }
# #T_90eab_row1_col3 {
#   background-color: rgba(215, 48, 39, 0.65);
#   border: 2px solid black;
# }
# #T_90eab_row1_col4, #T_90eab_row2_col2, #T_90eab_row3_col1 {
#   background-color: rgba(215, 48, 39, 0.60);
# }
# #T_90eab_row1_col5 {
#   background-color: rgba(26, 152, 80, 0.16);
#   border: 2px solid black;
# }
# #T_90eab_row2_col0, #T_90eab_row3_col4, #T_90eab_row7_col1 {
#   background-color: rgba(215, 48, 39, 0.57);
#   border: 2px solid black;
# }
# #T_90eab_row2_col1, #T_90eab_row4_col0, #T_90eab_row4_col3, #T_90eab_row4_col5, #T_90eab_row5_col3, #T_90eab_row8_col0, #T_90eab_row8_col4, #T_90eab_row9_col2, #T_90eab_row10_col4 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_90eab_row2_col3 {
#   background-color: rgba(215, 48, 39, 0.56);
#   border: 2px solid black;
# }
# #T_90eab_row2_col4, #T_90eab_row3_col2, #T_90eab_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.63);
# }
# #T_90eab_row2_col5 {
#   background-color: rgba(215, 48, 39, 0.38);
# }
# #T_90eab_row3_col0, #T_90eab_row4_col4, #T_90eab_row9_col0 {
#   background-color: rgba(215, 48, 39, 0.71);
# }
# #T_90eab_row3_col3, #T_90eab_row7_col3, #T_90eab_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.73);
# }
# #T_90eab_row3_col5, #T_90eab_row9_col4 {
#   background-color: rgba(215, 48, 39, 0.59);
# }
# #T_90eab_row4_col1, #T_90eab_row8_col1 {
#   background-color: rgba(215, 48, 39, 0.64);
# }
# #T_90eab_row4_col2 {
#   background-color: rgba(26, 152, 80, 0.19);
#   border: 2px solid black;
# }
# #T_90eab_row5_col0 {
#   background-color: rgba(215, 48, 39, 0.70);
# }
# #T_90eab_row5_col1, #T_90eab_row5_col4, #T_90eab_row7_col4 {
#   background-color: rgba(215, 48, 39, 0.55);
#   border: 2px solid black;
# }
# #T_90eab_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.22);
# }
# #T_90eab_row5_col5 {
#   background-color: rgba(215, 48, 39, 0.24);
#   border: 2px solid black;
# }
# #T_90eab_row6_col0, #T_90eab_row8_col3, #T_90eab_row9_col3 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_90eab_row6_col1 {
#   background-color: rgba(215, 48, 39, 0.62);
# }
# #T_90eab_row6_col2 {
#   background-color: rgba(26, 152, 80, 0.34);
#   border: 2px solid black;
# }
# #T_90eab_row6_col3 {
#   background-color: rgba(215, 48, 39, 0.72);
# }
# #T_90eab_row6_col4, #T_90eab_row6_col5 {
#   background-color: rgba(215, 48, 39, 0.66);
# }
# #T_90eab_row7_col2, #T_90eab_row8_col5 {
#   background-color: rgba(215, 48, 39, 0.55);
# }
# #T_90eab_row7_col5 {
#   background-color: rgba(215, 48, 39, 0.37);
# }
# #T_90eab_row8_col2, #T_90eab_row10_col2 {
#   background-color: rgba(26, 152, 80, 0.18);
# }
# #T_90eab_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.60);
#   border: 2px solid black;
# }
# #T_90eab_row9_col5 {
#   background-color: rgba(215, 48, 39, 0.34);
#   border: 2px solid black;
# }
# #T_90eab_row10_col3 {
#   background-color: rgba(215, 48, 39, 0.72);
#   border: 2px solid black;
# }
# #T_90eab_row10_col5 {
#   background-color: rgba(215, 48, 39, 0.46);
# }
# </style>
# <table id="T_90eab">
#   <thead>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th id="T_90eab_level0_col0" class="col_heading level0 col0" >axis-200-900 | pretrained</th>
#       <th id="T_90eab_level0_col1" class="col_heading level0 col1" >axis-200-900 | frozen_head</th>
#       <th id="T_90eab_level0_col2" class="col_heading level0 col2" >axis-200-900 | unfrozen_head</th>
#       <th id="T_90eab_level0_col3" class="col_heading level0 col3" >axis-100-3000 | pretrained</th>
#       <th id="T_90eab_level0_col4" class="col_heading level0 col4" >axis-100-3000 | frozen_head</th>
#       <th id="T_90eab_level0_col5" class="col_heading level0 col5" >axis-100-3000 | unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90eab_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_90eab_row0_col0" class="data row0 col0" >0.987 +/- 0.000</td>
#       <td id="T_90eab_row0_col1" class="data row0 col1" >0.987 +/- 0.000</td>
#       <td id="T_90eab_row0_col2" class="data row0 col2" >0.987 +/- 0.000</td>
#       <td id="T_90eab_row0_col3" class="data row0 col3" >0.987 +/- 0.001</td>
#       <td id="T_90eab_row0_col4" class="data row0 col4" >0.987 +/- 0.001</td>
#       <td id="T_90eab_row0_col5" class="data row0 col5" >0.987 +/- 0.001</td>
#     </tr>
#     <tr>
#       <th id="T_90eab_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_90eab_row1_col0" class="data row1 col0" >0.499 +/- 0.086</td>
#       <td id="T_90eab_row1_col1" class="data row1 col1" >0.752 +/- 0.024</td>
#       <td id="T_90eab_row1_col2" class="data row1 col2" >0.987 +/- 0.000</td>
#       <td id="T_90eab_row1_col3" class="data row1 col3" >0.512 +/- 0.079</td>
#       <td id="T_90eab_row1_col4" class="data row1 col4" >0.732 +/- 0.043</td>
#       <td id="T_90eab_row1_col5" class="data row1 col5" >0.987 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_90eab_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_90eab_row2_col0" class="data row2 col0" >0.596 +/- 0.019</td>
#       <td id="T_90eab_row2_col1" class="data row2 col1" >0.705 +/- 0.020</td>
#       <td id="T_90eab_row2_col2" class="data row2 col2" >0.986 +/- 0.000</td>
#       <td id="T_90eab_row2_col3" class="data row2 col3" >0.595 +/- 0.023</td>
#       <td id="T_90eab_row2_col4" class="data row2 col4" >0.712 +/- 0.047</td>
#       <td id="T_90eab_row2_col5" class="data row2 col5" >0.987 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_90eab_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_90eab_row3_col0" class="data row3 col0" >0.468 +/- 0.026</td>
#       <td id="T_90eab_row3_col1" class="data row3 col1" >0.775 +/- 0.013</td>
#       <td id="T_90eab_row3_col2" class="data row3 col2" >0.986 +/- 0.001</td>
#       <td id="T_90eab_row3_col3" class="data row3 col3" >0.433 +/- 0.014</td>
#       <td id="T_90eab_row3_col4" class="data row3 col4" >0.747 +/- 0.031</td>
#       <td id="T_90eab_row3_col5" class="data row3 col5" >0.986 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_90eab_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_90eab_row4_col0" class="data row4 col0" >0.429 +/- 0.019</td>
#       <td id="T_90eab_row4_col1" class="data row4 col1" >0.755 +/- 0.035</td>
#       <td id="T_90eab_row4_col2" class="data row4 col2" >0.987 +/- 0.000</td>
#       <td id="T_90eab_row4_col3" class="data row4 col3" >0.419 +/- 0.024</td>
#       <td id="T_90eab_row4_col4" class="data row4 col4" >0.670 +/- 0.103</td>
#       <td id="T_90eab_row4_col5" class="data row4 col5" >0.986 +/- 0.001</td>
#     </tr>
#     <tr>
#       <th id="T_90eab_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_90eab_row5_col0" class="data row5 col0" >0.471 +/- 0.045</td>
#       <td id="T_90eab_row5_col1" class="data row5 col1" >0.800 +/- 0.019</td>
#       <td id="T_90eab_row5_col2" class="data row5 col2" >0.987 +/- 0.000</td>
#       <td id="T_90eab_row5_col3" class="data row5 col3" >0.417 +/- 0.013</td>
#       <td id="T_90eab_row5_col4" class="data row5 col4" >0.761 +/- 0.011</td>
#       <td id="T_90eab_row5_col5" class="data row5 col5" >0.987 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_90eab_level0_row6" class="row_heading level0 row6" >P3_staged_overlap</th>
#       <td id="T_90eab_row6_col0" class="data row6 col0" >0.439 +/- 0.013</td>
#       <td id="T_90e
# contribution | heldout_image
# <style type="text/css">
# #T_930a0_row0_col0, #T_930a0_row0_col1, #T_930a0_row0_col2, #T_930a0_row0_col3, #T_930a0_row0_col4, #T_930a0_row0_col5 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_930a0_row1_col0, #T_930a0_row1_col1, #T_930a0_row1_col2, #T_930a0_row1_col3 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_930a0_row1_col4 {
#   background-color: rgba(215, 48, 39, 0.40);
# }
# #T_930a0_row1_col5 {
#   background-color: rgba(26, 152, 80, 0.57);
# }
# #T_930a0_row2_col0 {
#   background-color: rgba(215, 48, 39, 0.22);
#   border: 2px solid black;
# }
# #T_930a0_row2_col1 {
#   background-color: rgba(26, 152, 80, 0.25);
#   border: 2px solid black;
# }
# #T_930a0_row2_col2 {
#   background-color: rgba(215, 48, 39, 0.20);
#   border: 2px solid black;
# }
# #T_930a0_row2_col3 {
#   background-color: rgba(215, 48, 39, 0.23);
#   border: 2px solid black;
# }
# #T_930a0_row2_col4 {
#   background-color: rgba(26, 152, 80, 0.64);
#   border: 2px solid black;
# }
# #T_930a0_row2_col5 {
#   background-color: rgba(26, 152, 80, 0.74);
#   border: 2px solid black;
# }
# #T_930a0_row3_col0, #T_930a0_row4_col0, #T_930a0_row5_col0 {
#   background-color: rgba(215, 48, 39, 0.25);
# }
# #T_930a0_row3_col1 {
#   background-color: rgba(215, 48, 39, 0.52);
# }
# #T_930a0_row3_col2, #T_930a0_row4_col4 {
#   background-color: rgba(215, 48, 39, 0.39);
# }
# #T_930a0_row3_col3, #T_930a0_row9_col2 {
#   background-color: rgba(215, 48, 39, 0.28);
#   border: 2px solid black;
# }
# #T_930a0_row3_col4, #T_930a0_row9_col5 {
#   background-color: rgba(26, 152, 80, 0.75);
#   border: 2px solid black;
# }
# #T_930a0_row3_col5 {
#   background-color: rgba(26, 152, 80, 0.65);
#   border: 2px solid black;
# }
# #T_930a0_row4_col1 {
#   background-color: rgba(215, 48, 39, 0.36);
#   border: 2px solid black;
# }
# #T_930a0_row4_col2 {
#   background-color: rgba(215, 48, 39, 0.29);
#   border: 2px solid black;
# }
# #T_930a0_row4_col3 {
#   background-color: rgba(215, 48, 39, 0.29);
# }
# #T_930a0_row4_col5 {
#   background-color: rgba(26, 152, 80, 0.41);
# }
# #T_930a0_row5_col1 {
#   background-color: rgba(215, 48, 39, 0.49);
# }
# #T_930a0_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.57);
# }
# #T_930a0_row5_col3 {
#   background-color: rgba(215, 48, 39, 0.26);
#   border: 2px solid black;
# }
# #T_930a0_row5_col4 {
#   background-color: rgba(26, 152, 80, 0.73);
#   border: 2px solid black;
# }
# #T_930a0_row5_col5 {
#   background-color: rgba(26, 152, 80, 0.56);
# }
# #T_930a0_row6_col0, #T_930a0_row7_col0 {
#   background-color: rgba(215, 48, 39, 0.25);
#   border: 2px solid black;
# }
# #T_930a0_row6_col1 {
#   background-color: rgba(215, 48, 39, 0.27);
#   border: 2px solid black;
# }
# #T_930a0_row6_col2 {
#   background-color: rgba(215, 48, 39, 0.50);
# }
# #T_930a0_row6_col3, #T_930a0_row7_col3 {
#   background-color: rgba(215, 48, 39, 0.30);
# }
# #T_930a0_row6_col4 {
#   background-color: rgba(215, 48, 39, 0.34);
# }
# #T_930a0_row6_col5, #T_930a0_row8_col4, #T_930a0_row10_col5 {
#   background-color: rgba(26, 152, 80, 0.27);
# }
# #T_930a0_row7_col1, #T_930a0_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.53);
# }
# #T_930a0_row7_col2, #T_930a0_row8_col1 {
#   background-color: rgba(215, 48, 39, 0.45);
# }
# #T_930a0_row7_col4 {
#   background-color: rgba(26, 152, 80, 0.35);
# }
# #T_930a0_row7_col5 {
#   background-color: rgba(26, 152, 80, 0.44);
# }
# #T_930a0_row8_col0, #T_930a0_row9_col0 {
#   background-color: rgba(215, 48, 39, 0.27);
# }
# #T_930a0_row8_col2 {
#   background-color: rgba(215, 48, 39, 0.67);
# }
# #T_930a0_row8_col3 {
#   background-color: rgba(215, 48, 39, 0.32);
# }
# #T_930a0_row8_col5 {
#   background-color: rgba(215, 48, 39, 0.15);
# }
# #T_930a0_row9_col3, #T_930a0_row10_col3 {
#   background-color: rgba(215, 48, 39, 0.28);
# }
# #T_930a0_row9_col4 {
#   background-color: rgba(26, 152, 80, 0.33);
# }
# #T_930a0_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.26);
# }
# #T_930a0_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.59);
# }
# #T_930a0_row10_col2 {
#   background-color: rgba(215, 48, 39, 0.72);
# }
# #T_930a0_row10_col4 {
#   background-color: rgba(215, 48, 39, 0.31);
# }
# </style>
# <table id="T_930a0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th id="T_930a0_level0_col0" class="col_heading level0 col0" >axis-200-900 | pretrained</th>
#       <th id="T_930a0_level0_col1" class="col_heading level0 col1" >axis-200-900 | frozen_head</th>
#       <th id="T_930a0_level0_col2" class="col_heading level0 col2" >axis-200-900 | unfrozen_head</th>
#       <th id="T_930a0_level0_col3" class="col_heading level0 col3" >axis-100-3000 | pretrained</th>
#       <th id="T_930a0_level0_col4" class="col_heading level0 col4" >axis-100-3000 | frozen_head</th>
#       <th id="T_930a0_level0_col5" class="col_heading level0 col5" >axis-100-3000 | unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_930a0_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_930a0_row0_col0" class="data row0 col0" >3.076 +/- 0.143</td>
#       <td id="T_930a0_row0_col1" class="data row0 col1" >3.076 +/- 0.143</td>
#       <td id="T_930a0_row0_col2" class="data row0 col2" >3.076 +/- 0.143</td>
#       <td id="T_930a0_row0_col3" class="data row0 col3" >3.885 +/- 0.263</td>
#       <td id="T_930a0_row0_col4" class="data row0 col4" >3.885 +/- 0.263</td>
#       <td id="T_930a0_row0_col5" class="data row0 col5" >3.885 +/- 0.263</td>
#     </tr>
#     <tr>
#       <th id="T_930a0_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_930a0_row1_col0" class="data row1 col0" >185.632 +/- 24.787</td>
#       <td id="T_930a0_row1_col1" class="data row1 col1" >3.715 +/- 0.525</td>
#       <td id="T_930a0_row1_col2" class="data row1 col2" >3.678 +/- 0.191</td>
#       <td id="T_930a0_row1_col3" class="data row1 col3" >215.306 +/- 8.557</td>
#       <td id="T_930a0_row1_col4" class="data row1 col4" >4.053 +/- 0.156</td>
#       <td id="T_930a0_row1_col5" class="data row1 col5" >3.476 +/- 0.280</td>
#     </tr>
#     <tr>
#       <th id="T_930a0_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_930a0_row2_col0" class="data row2 col0" >25.799 +/- 2.581</td>
#       <td id="T_930a0_row2_col1" class="data row2 col1" >2.966 +/- 0.114</td>
#       <td id="T_930a0_row2_col2" class="data row2 col2" >3.123 +/- 0.337</td>
#       <td id="T_930a0_row2_col3" class="data row2 col3" >31.710 +/- 3.011</td>
#       <td id="T_930a0_row2_col4" class="data row2 col4" >3.548 +/- 0.122</td>
#       <td id="T_930a0_row2_col5" class="data row2 col5" >3.313 +/- 0.312</td>
#     </tr>
#     <tr>
#       <th id="T_930a0_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_930a0_row3_col0" class="data row3 col0" >34.328 +/- 5.988</td>
#       <td id="T_930a0_row3_col1" class="data row3 col1" >3.475 +/- 0.353</td>
#       <td id="T_930a0_row3_col2" class="data row3 col2" >3.320 +/- 0.277</td>
#       <td id="T_930a0_row3_col3" class="data row3 col3" >47.952 +/- 3.841</td>
#       <td id="T_930a0_row3_col4" class="data row3 col4" >3.472 +/- 0.240</td>
#       <td id="T_930a0_row3_col5" class="data row3 col5" >3.407 +/- 0.347</td>
#     </tr>
#     <tr>
#       <th id="T_930a0_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_930a0_row4_col0" class="data row4 col0" >34.137 +/- 6.829</td>
#       <td id="T_930a0_row4_col1" class="data row4 col1" >3.297 +/- 0.289</td>
#       <td id="T_930a0_row4_col2" class="data row4 col2" >3.213 +/- 0.245</td>
#       <td id="T_930a0_row4_col3" class="data row4 col3" >52.992 +/- 12.992</td>
#       <td id="T_930a0_row4_col4" class="data row4 col4" >4.052 +/- 0.397</td>
#       <td id="T_930a0_row4_col5" class="data row4 col5" >3.634 +/- 0.145</td>
#     </tr>
#     <tr>
#       <th id="T_930a0_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_930a0_row5_col0"
# contribution | test
# <style type="text/css">
# #T_26a7d_row0_col0, #T_26a7d_row0_col1, #T_26a7d_row0_col2, #T_26a7d_row0_col3, #T_26a7d_row0_col4, #T_26a7d_row0_col5 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_26a7d_row1_col0, #T_26a7d_row1_col3, #T_26a7d_row1_col4, #T_26a7d_row5_col1, #T_26a7d_row7_col2, #T_26a7d_row8_col5 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_26a7d_row1_col1, #T_26a7d_row8_col2, #T_26a7d_row10_col1, #T_26a7d_row10_col2 {
#   background-color: rgba(215, 48, 39, 0.66);
# }
# #T_26a7d_row1_col2 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_26a7d_row1_col5 {
#   background-color: rgba(215, 48, 39, 0.48);
# }
# #T_26a7d_row2_col0, #T_26a7d_row3_col4, #T_26a7d_row4_col0 {
#   background-color: rgba(215, 48, 39, 0.28);
#   border: 2px solid black;
# }
# #T_26a7d_row2_col1 {
#   background-color: rgba(26, 152, 80, 0.41);
#   border: 2px solid black;
# }
# #T_26a7d_row2_col2 {
#   background-color: rgba(26, 152, 80, 0.30);
#   border: 2px solid black;
# }
# #T_26a7d_row2_col3, #T_26a7d_row9_col5, #T_26a7d_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.29);
#   border: 2px solid black;
# }
# #T_26a7d_row2_col4 {
#   background-color: rgba(26, 152, 80, 0.22);
#   border: 2px solid black;
# }
# #T_26a7d_row2_col5 {
#   background-color: rgba(26, 152, 80, 0.36);
#   border: 2px solid black;
# }
# #T_26a7d_row3_col0, #T_26a7d_row6_col0, #T_26a7d_row7_col5, #T_26a7d_row8_col0 {
#   background-color: rgba(215, 48, 39, 0.29);
# }
# #T_26a7d_row3_col1 {
#   background-color: rgba(215, 48, 39, 0.68);
# }
# #T_26a7d_row3_col2 {
#   background-color: rgba(215, 48, 39, 0.65);
# }
# #T_26a7d_row3_col3, #T_26a7d_row7_col3, #T_26a7d_row8_col3 {
#   background-color: rgba(215, 48, 39, 0.34);
# }
# #T_26a7d_row3_col5 {
#   background-color: rgba(215, 48, 39, 0.16);
#   border: 2px solid black;
# }
# #T_26a7d_row4_col1, #T_26a7d_row7_col4 {
#   background-color: rgba(215, 48, 39, 0.44);
# }
# #T_26a7d_row4_col2 {
#   background-color: rgba(215, 48, 39, 0.24);
#   border: 2px solid black;
# }
# #T_26a7d_row4_col3 {
#   background-color: rgba(215, 48, 39, 0.32);
#   border: 2px solid black;
# }
# #T_26a7d_row4_col4, #T_26a7d_row6_col4 {
#   background-color: rgba(215, 48, 39, 0.46);
# }
# #T_26a7d_row4_col5 {
#   background-color: rgba(215, 48, 39, 0.69);
# }
# #T_26a7d_row5_col0, #T_26a7d_row7_col0 {
#   background-color: rgba(215, 48, 39, 0.30);
# }
# #T_26a7d_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.71);
# }
# #T_26a7d_row5_col3, #T_26a7d_row6_col1 {
#   background-color: rgba(215, 48, 39, 0.30);
#   border: 2px solid black;
# }
# #T_26a7d_row5_col4 {
#   background-color: rgba(215, 48, 39, 0.40);
# }
# #T_26a7d_row5_col5 {
#   background-color: rgba(215, 48, 39, 0.37);
# }
# #T_26a7d_row6_col2 {
#   background-color: rgba(215, 48, 39, 0.36);
#   border: 2px solid black;
# }
# #T_26a7d_row6_col3, #T_26a7d_row9_col3 {
#   background-color: rgba(215, 48, 39, 0.33);
# }
# #T_26a7d_row6_col5 {
#   background-color: rgba(215, 48, 39, 0.35);
# }
# #T_26a7d_row7_col1 {
#   background-color: rgba(215, 48, 39, 0.59);
# }
# #T_26a7d_row8_col1 {
#   background-color: rgba(215, 48, 39, 0.40);
#   border: 2px solid black;
# }
# #T_26a7d_row8_col4 {
#   background-color: rgba(215, 48, 39, 0.47);
# }
# #T_26a7d_row9_col0 {
#   background-color: rgba(215, 48, 39, 0.31);
# }
# #T_26a7d_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.72);
# }
# #T_26a7d_row9_col2 {
#   background-color: rgba(215, 48, 39, 0.63);
# }
# #T_26a7d_row9_col4 {
#   background-color: rgba(215, 48, 39, 0.37);
#   border: 2px solid black;
# }
# #T_26a7d_row10_col3 {
#   background-color: rgba(215, 48, 39, 0.32);
# }
# #T_26a7d_row10_col4 {
#   background-color: rgba(215, 48, 39, 0.50);
# }
# #T_26a7d_row10_col5 {
#   background-color: rgba(215, 48, 39, 0.41);
# }
# </style>
# <table id="T_26a7d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th id="T_26a7d_level0_col0" class="col_heading level0 col0" >axis-200-900 | pretrained</th>
#       <th id="T_26a7d_level0_col1" class="col_heading level0 col1" >axis-200-900 | frozen_head</th>
#       <th id="T_26a7d_level0_col2" class="col_heading level0 col2" >axis-200-900 | unfrozen_head</th>
#       <th id="T_26a7d_level0_col3" class="col_heading level0 col3" >axis-100-3000 | pretrained</th>
#       <th id="T_26a7d_level0_col4" class="col_heading level0 col4" >axis-100-3000 | frozen_head</th>
#       <th id="T_26a7d_level0_col5" class="col_heading level0 col5" >axis-100-3000 | unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26a7d_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_26a7d_row0_col0" class="data row0 col0" >3.117 +/- 0.109</td>
#       <td id="T_26a7d_row0_col1" class="data row0 col1" >3.117 +/- 0.109</td>
#       <td id="T_26a7d_row0_col2" class="data row0 col2" >3.117 +/- 0.109</td>
#       <td id="T_26a7d_row0_col3" class="data row0 col3" >3.087 +/- 0.120</td>
#       <td id="T_26a7d_row0_col4" class="data row0 col4" >3.087 +/- 0.120</td>
#       <td id="T_26a7d_row0_col5" class="data row0 col5" >3.087 +/- 0.120</td>
#     </tr>
#     <tr>
#       <th id="T_26a7d_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_26a7d_row1_col0" class="data row1 col0" >197.775 +/- 26.938</td>
#       <td id="T_26a7d_row1_col1" class="data row1 col1" >3.479 +/- 0.409</td>
#       <td id="T_26a7d_row1_col2" class="data row1 col2" >3.486 +/- 0.119</td>
#       <td id="T_26a7d_row1_col3" class="data row1 col3" >218.981 +/- 12.989</td>
#       <td id="T_26a7d_row1_col4" class="data row1 col4" >3.843 +/- 0.265</td>
#       <td id="T_26a7d_row1_col5" class="data row1 col5" >3.323 +/- 0.301</td>
#     </tr>
#     <tr>
#       <th id="T_26a7d_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_26a7d_row2_col0" class="data row2 col0" >46.056 +/- 2.657</td>
#       <td id="T_26a7d_row2_col1" class="data row2 col1" >2.938 +/- 0.062</td>
#       <td id="T_26a7d_row2_col2" class="data row2 col2" >3.025 +/- 0.142</td>
#       <td id="T_26a7d_row2_col3" class="data row2 col3" >53.388 +/- 4.786</td>
#       <td id="T_26a7d_row2_col4" class="data row2 col4" >3.004 +/- 0.080</td>
#       <td id="T_26a7d_row2_col5" class="data row2 col5" >2.940 +/- 0.125</td>
#     </tr>
#     <tr>
#       <th id="T_26a7d_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_26a7d_row3_col0" class="data row3 col0" >50.160 +/- 6.343</td>
#       <td id="T_26a7d_row3_col1" class="data row3 col1" >3.493 +/- 0.256</td>
#       <td id="T_26a7d_row3_col2" class="data row3 col2" >3.427 +/- 0.086</td>
#       <td id="T_26a7d_row3_col3" class="data row3 col3" >71.499 +/- 5.118</td>
#       <td id="T_26a7d_row3_col4" class="data row3 col4" >3.252 +/- 0.311</td>
#       <td id="T_26a7d_row3_col5" class="data row3 col5" >3.097 +/- 0.207</td>
#     </tr>
#     <tr>
#       <th id="T_26a7d_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_26a7d_row4_col0" class="data row4 col0" >45.214 +/- 2.680</td>
#       <td id="T_26a7d_row4_col1" class="data row4 col1" >3.318 +/- 0.220</td>
#       <td id="T_26a7d_row4_col2" class="data row4 col2" >3.175 +/- 0.186</td>
#       <td id="T_26a7d_row4_col3" class="data row4 col3" >64.284 +/- 11.166</td>
#       <td id="T_26a7d_row4_col4" class="data row4 col4" >3.480 +/- 0.280</td>
#       <td id="T_26a7d_row4_col5" class="data row4 col5" >3.470 +/- 0.284</td>
#     </tr>
#     <tr>
#       <th id="T_26a7d_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_26a7d_row5_col0" class="data row5 col0" >52.983 +/- 2.360</td>
#       <td id="T_26a7d_row5_col1" class="data row5 col1" >3.540 +/- 0.352</td>
# ...
# #T_de4ac_row0_col0, #T_de4ac_row0_col1, #T_de4ac_row0_col2, #T_de4ac_row0_col3, #T_de4ac_row0_col4, #T_de4ac_row0_col5 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_de4ac_row1_col0, #T_de4ac_row3_col0 {
#   background-color: rgba(215, 48, 39, 0.70);
# }
# #T_de4ac_row1_col1, #T_de4ac_row1_col2, #T_de4ac_row1_col3, #T_de4ac_row7_col0 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_de4ac_row1_col4, #T_de4ac_row7_col2 {
#   background-color: rgba(215, 48, 39, 0.39);
# }
# #T_de4ac_row1_col5, #T_de4ac_row6_col4 {
#   background-color: rgba(26, 152, 80, 0.37);
# }
# #T_de4ac_row2_col0 {
#   background-color: rgba(215, 48, 39, 0.47);
#   border: 2px solid black;
# }
# #T_de4ac_row2_col1, #T_de4ac_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.27);
# }
# #T_de4ac_row2_col2, #T_de4ac_row3_col4 {
#   background-color: rgba(215, 48, 39, 0.26);
# }
# #T_de4ac_row2_col3 {
#   background-color: rgba(215, 48, 39, 0.53);
#   border: 2px solid black;
# }
# #T_de4ac_row2_col4, #T_de4ac_row2_col5 {
#   background-color: rgba(26, 152, 80, 0.75);
#   border: 2px solid black;
# }
# #T_de4ac_row3_col1 {
#   background-color: rgba(26, 152, 80, 0.31);
#   border: 2px solid black;
# }
# #T_de4ac_row3_col2 {
#   background-color: rgba(26, 152, 80, 0.17);
#   border: 2px solid black;
# }
# #T_de4ac_row3_col3 {
#   background-color: rgba(215, 48, 39, 0.65);
# }
# #T_de4ac_row3_col5 {
#   background-color: rgba(26, 152, 80, 0.64);
# }
# #T_de4ac_row4_col0 {
#   background-color: rgba(215, 48, 39, 0.45);
#   border: 2px solid black;
# }
# #T_de4ac_row4_col1 {
#   background-color: rgba(215, 48, 39, 0.21);
#   border: 2px solid black;
# }
# #T_de4ac_row4_col2 {
#   background-color: rgba(26, 152, 80, 0.37);
#   border: 2px solid black;
# }
# #T_de4ac_row4_col3, #T_de4ac_row5_col2, #T_de4ac_row9_col0 {
#   background-color: rgba(215, 48, 39, 0.62);
# }
# #T_de4ac_row4_col4 {
#   background-color: rgba(26, 152, 80, 0.21);
# }
# #T_de4ac_row4_col5 {
#   background-color: rgba(26, 152, 80, 0.41);
# }
# #T_de4ac_row5_col0 {
#   background-color: rgba(215, 48, 39, 0.71);
# }
# #T_de4ac_row5_col1, #T_de4ac_row7_col3 {
#   background-color: rgba(215, 48, 39, 0.73);
# }
# #T_de4ac_row5_col3 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_de4ac_row5_col4 {
#   background-color: rgba(26, 152, 80, 0.30);
# }
# #T_de4ac_row5_col5 {
#   background-color: rgba(26, 152, 80, 0.68);
#   border: 2px solid black;
# }
# #T_de4ac_row6_col0, #T_de4ac_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.48);
# }
# #T_de4ac_row6_col1 {
#   background-color: rgba(215, 48, 39, 0.28);
# }
# #T_de4ac_row6_col2 {
#   background-color: rgba(215, 48, 39, 0.42);
# }
# #T_de4ac_row6_col3 {
#   background-color: rgba(215, 48, 39, 0.50);
#   border: 2px solid black;
# }
# #T_de4ac_row6_col5 {
#   background-color: rgba(26, 152, 80, 0.44);
# }
# #T_de4ac_row7_col1 {
#   background-color: rgba(215, 48, 39, 0.18);
#   border: 2px solid black;
# }
# #T_de4ac_row7_col4 {
#   background-color: rgba(26, 152, 80, 0.45);
#   border: 2px solid black;
# }
# #T_de4ac_row7_col5 {
#   background-color: rgba(26, 152, 80, 0.29);
# }
# #T_de4ac_row8_col0 {
#   background-color: rgba(215, 48, 39, 0.48);
#   border: 2px solid black;
# }
# #T_de4ac_row8_col1 {
#   background-color: rgba(215, 48, 39, 0.49);
# }
# #T_de4ac_row8_col2 {
#   background-color: rgba(215, 48, 39, 0.52);
# }
# #T_de4ac_row8_col3 {
#   background-color: rgba(215, 48, 39, 0.56);
#   border: 2px solid black;
# }
# #T_de4ac_row8_col4 {
#   background-color: rgba(215, 48, 39, 0.35);
# }
# #T_de4ac_row8_col5 {
#   background-color: rgba(215, 48, 39, 0.22);
# }
# #T_de4ac_row9_col2 {
#   background-color: rgba(26, 152, 80, 0.22);
#   border: 2px solid black;
# }
# #T_de4ac_row9_col3 {
#   background-color: rgba(215, 48, 39, 0.68);
# }
# #T_de4ac_row9_col4 {
#   background-color: rgba(26, 152, 80, 0.44);
#   border: 2px solid black;
# }
# #T_de4ac_row9_col5 {
#   background-color: rgba(26, 152, 80, 0.66);
#   border: 2px solid black;
# }
# #T_de4ac_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.38);
# }
# #T_de4ac_row10_col2 {
#   background-color: rgba(215, 48, 39, 0.33);
# }
# #T_de4ac_row10_col3 {
#   background-color: rgba(215, 48, 39, 0.60);
# }
# #T_de4ac_row10_col4 {
#   background-color: rgba(26, 152, 80, 0.33);
# }
# #T_de4ac_row10_col5 {
#   background-color: rgba(26, 152, 80, 0.54);
# }
# </style>
# <table id="T_de4ac">
#   <thead>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th id="T_de4ac_level0_col0" class="col_heading level0 col0" >axis-200-900 | pretrained</th>
#       <th id="T_de4ac_level0_col1" class="col_heading level0 col1" >axis-200-900 | frozen_head</th>
#       <th id="T_de4ac_level0_col2" class="col_heading level0 col2" >axis-200-900 | unfrozen_head</th>
#       <th id="T_de4ac_level0_col3" class="col_heading level0 col3" >axis-100-3000 | pretrained</th>
#       <th id="T_de4ac_level0_col4" class="col_heading level0 col4" >axis-100-3000 | frozen_head</th>
#       <th id="T_de4ac_level0_col5" class="col_heading level0 col5" >axis-100-3000 | unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de4ac_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_de4ac_row0_col0" class="data row0 col0" >5.222 +/- 0.130</td>
#       <td id="T_de4ac_row0_col1" class="data row0 col1" >5.222 +/- 0.130</td>
#       <td id="T_de4ac_row0_col2" class="data row0 col2" >5.222 +/- 0.130</td>
#       <td id="T_de4ac_row0_col3" class="data row0 col3" >6.468 +/- 1.180</td>
#       <td id="T_de4ac_row0_col4" class="data row0 col4" >6.468 +/- 1.180</td>
#       <td id="T_de4ac_row0_col5" class="data row0 col5" >6.468 +/- 1.180</td>
#     </tr>
#     <tr>
#       <th id="T_de4ac_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_de4ac_row1_col0" class="data row1 col0" >27.245 +/- 2.094</td>
#       <td id="T_de4ac_row1_col1" class="data row1 col1" >5.852 +/- 0.597</td>
#       <td id="T_de4ac_row1_col2" class="data row1 col2" >5.791 +/- 0.429</td>
#       <td id="T_de4ac_row1_col3" class="data row1 col3" >23.030 +/- 3.553</td>
#       <td id="T_de4ac_row1_col4" class="data row1 col4" >6.783 +/- 0.840</td>
#       <td id="T_de4ac_row1_col5" class="data row1 col5" >6.167 +/- 0.450</td>
#     </tr>
#     <tr>
#       <th id="T_de4ac_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_de4ac_row2_col0" class="data row2 col0" >18.280 +/- 2.112</td>
#       <td id="T_de4ac_row2_col1" class="data row2 col1" >5.344 +/- 0.261</td>
#       <td id="T_de4ac_row2_col2" class="data row2 col2" >5.330 +/- 0.411</td>
#       <td id="T_de4ac_row2_col3" class="data row2 col3" >16.866 +/- 1.597</td>
#       <td id="T_de4ac_row2_col4" class="data row2 col4" >5.681 +/- 0.774</td>
#       <td id="T_de4ac_row2_col5" class="data row2 col5" >5.651 +/- 0.849</td>
#     </tr>
#     <tr>
#       <th id="T_de4ac_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_de4ac_row3_col0" class="data row3 col0" >27.399 +/- 5.167</td>
#       <td id="T_de4ac_row3_col1" class="data row3 col1" >5.051 +/- 0.488</td>
#       <td id="T_de4ac_row3_col2" class="data row3 col2" >5.206 +/- 0.738</td>
#       <td id="T_de4ac_row3_col3" class="data row3 col3" >20.294 +/- 2.342</td>
#       <td id="T_de4ac_row3_col4" class="data row3 col4" >6.608 +/- 1.267</td>
#       <td id="T_de4ac_row3_col5" class="data row3 col5" >5.801 +/- 0.462</td>
#     </tr>
#     <tr>
#       <th id="T_de4ac_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_de4ac_row4_col0" class="data row4 col0" >17.270 +/- 2.341</td>
#       <td id="T_de4ac_row4_col1" class="data row4 col1" >5.285 +/- 0.738</td>
#       <td id="T_de4ac_row4_col2" class="data row4 col2" >5.011 +/- 0.320</td>
#       <td id="T_de4ac_row4_col3" class="data row4 col3" >19.531 +/- 2.010</td>
#       <td id="T_de4ac_row4_col4" class="data row4 col4" >6.392 +/- 0.784</td>
#       <td id="T_de4ac_row4
# within | test
# <style type="text/css">
# #T_9caf5_row0_col0, #T_9caf5_row0_col1, #T_9caf5_row0_col2, #T_9caf5_row0_col3, #T_9caf5_row0_col4, #T_9caf5_row0_col5 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_9caf5_row1_col0, #T_9caf5_row1_col3, #T_9caf5_row5_col1, #T_9caf5_row7_col2, #T_9caf5_row7_col5, #T_9caf5_row9_col4 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_9caf5_row1_col1, #T_9caf5_row7_col4 {
#   background-color: rgba(215, 48, 39, 0.46);
# }
# #T_9caf5_row1_col2 {
#   background-color: rgba(215, 48, 39, 0.47);
# }
# #T_9caf5_row1_col4, #T_9caf5_row5_col3, #T_9caf5_row7_col0, #T_9caf5_row9_col3 {
#   background-color: rgba(215, 48, 39, 0.73);
# }
# #T_9caf5_row1_col5 {
#   background-color: rgba(215, 48, 39, 0.57);
# }
# #T_9caf5_row2_col0, #T_9caf5_row4_col0 {
#   background-color: rgba(215, 48, 39, 0.39);
#   border: 2px solid black;
# }
# #T_9caf5_row2_col1 {
#   background-color: rgba(215, 48, 39, 0.15);
#   border: 2px solid black;
# }
# #T_9caf5_row2_col2, #T_9caf5_row2_col5 {
#   background-color: rgba(26, 152, 80, 0.22);
#   border: 2px solid black;
# }
# #T_9caf5_row2_col3 {
#   background-color: rgba(215, 48, 39, 0.49);
#   border: 2px solid black;
# }
# #T_9caf5_row2_col4 {
#   background-color: rgba(26, 152, 80, 0.20);
#   border: 2px solid black;
# }
# #T_9caf5_row3_col0, #T_9caf5_row5_col4, #T_9caf5_row9_col0 {
#   background-color: rgba(215, 48, 39, 0.66);
# }
# #T_9caf5_row3_col1 {
#   background-color: rgba(215, 48, 39, 0.68);
# }
# #T_9caf5_row3_col2, #T_9caf5_row5_col2, #T_9caf5_row9_col1, #T_9caf5_row9_col5 {
#   background-color: rgba(215, 48, 39, 0.61);
# }
# #T_9caf5_row3_col3 {
#   background-color: rgba(215, 48, 39, 0.69);
# }
# #T_9caf5_row3_col4 {
#   background-color: rgba(215, 48, 39, 0.64);
# }
# #T_9caf5_row3_col5, #T_9caf5_row8_col3 {
#   background-color: rgba(215, 48, 39, 0.52);
# }
# #T_9caf5_row4_col1, #T_9caf5_row10_col4 {
#   background-color: rgba(215, 48, 39, 0.32);
#   border: 2px solid black;
# }
# #T_9caf5_row4_col2 {
#   background-color: rgba(215, 48, 39, 0.17);
#   border: 2px solid black;
# }
# #T_9caf5_row4_col3 {
#   background-color: rgba(215, 48, 39, 0.52);
#   border: 2px solid black;
# }
# #T_9caf5_row4_col4 {
#   background-color: rgba(215, 48, 39, 0.41);
# }
# #T_9caf5_row4_col5 {
#   background-color: rgba(215, 48, 39, 0.36);
# }
# #T_9caf5_row5_col0 {
#   background-color: rgba(215, 48, 39, 0.70);
# }
# #T_9caf5_row5_col5 {
#   background-color: rgba(215, 48, 39, 0.49);
# }
# #T_9caf5_row6_col0, #T_9caf5_row8_col0 {
#   background-color: rgba(215, 48, 39, 0.42);
# }
# #T_9caf5_row6_col1 {
#   background-color: rgba(215, 48, 39, 0.34);
#   border: 2px solid black;
# }
# #T_9caf5_row6_col2 {
#   background-color: rgba(215, 48, 39, 0.29);
# }
# #T_9caf5_row6_col3 {
#   background-color: rgba(215, 48, 39, 0.48);
#   border: 2px solid black;
# }
# #T_9caf5_row6_col4 {
#   background-color: rgba(215, 48, 39, 0.29);
#   border: 2px solid black;
# }
# #T_9caf5_row6_col5 {
#   background-color: rgba(215, 48, 39, 0.24);
#   border: 2px solid black;
# }
# #T_9caf5_row7_col1 {
#   background-color: rgba(215, 48, 39, 0.67);
# }
# #T_9caf5_row7_col3 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_9caf5_row8_col1, #T_9caf5_row10_col3 {
#   background-color: rgba(215, 48, 39, 0.53);
# }
# #T_9caf5_row8_col2 {
#   background-color: rgba(215, 48, 39, 0.48);
# }
# #T_9caf5_row8_col4 {
#   background-color: rgba(215, 48, 39, 0.44);
# }
# #T_9caf5_row8_col5 {
#   background-color: rgba(215, 48, 39, 0.43);
# }
# #T_9caf5_row9_col2, #T_9caf5_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.54);
# }
# #T_9caf5_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.42);
#   border: 2px solid black;
# }
# #T_9caf5_row10_col2 {
#   background-color: rgba(215, 48, 39, 0.28);
#   border: 2px solid black;
# }
# #T_9caf5_row10_col5 {
#   background-color: rgba(215, 48, 39, 0.26);
#   border: 2px solid black;
# }
# </style>
# <table id="T_9caf5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th id="T_9caf5_level0_col0" class="col_heading level0 col0" >axis-200-900 | pretrained</th>
#       <th id="T_9caf5_level0_col1" class="col_heading level0 col1" >axis-200-900 | frozen_head</th>
#       <th id="T_9caf5_level0_col2" class="col_heading level0 col2" >axis-200-900 | unfrozen_head</th>
#       <th id="T_9caf5_level0_col3" class="col_heading level0 col3" >axis-100-3000 | pretrained</th>
#       <th id="T_9caf5_level0_col4" class="col_heading level0 col4" >axis-100-3000 | frozen_head</th>
#       <th id="T_9caf5_level0_col5" class="col_heading level0 col5" >axis-100-3000 | unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9caf5_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_9caf5_row0_col0" class="data row0 col0" >4.747 +/- 0.186</td>
#       <td id="T_9caf5_row0_col1" class="data row0 col1" >4.747 +/- 0.186</td>
#       <td id="T_9caf5_row0_col2" class="data row0 col2" >4.747 +/- 0.186</td>
#       <td id="T_9caf5_row0_col3" class="data row0 col3" >5.460 +/- 0.489</td>
#       <td id="T_9caf5_row0_col4" class="data row0 col4" >5.460 +/- 0.489</td>
#       <td id="T_9caf5_row0_col5" class="data row0 col5" >5.460 +/- 0.489</td>
#     </tr>
#     <tr>
#       <th id="T_9caf5_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_9caf5_row1_col0" class="data row1 col0" >28.541 +/- 2.346</td>
#       <td id="T_9caf5_row1_col1" class="data row1 col1" >5.117 +/- 0.254</td>
#       <td id="T_9caf5_row1_col2" class="data row1 col2" >5.188 +/- 0.325</td>
#       <td id="T_9caf5_row1_col3" class="data row1 col3" >24.501 +/- 2.080</td>
#       <td id="T_9caf5_row1_col4" class="data row1 col4" >6.842 +/- 0.597</td>
#       <td id="T_9caf5_row1_col5" class="data row1 col5" >6.416 +/- 0.587</td>
#     </tr>
#     <tr>
#       <th id="T_9caf5_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_9caf5_row2_col0" class="data row2 col0" >14.180 +/- 1.254</td>
#       <td id="T_9caf5_row2_col1" class="data row2 col1" >4.748 +/- 0.185</td>
#       <td id="T_9caf5_row2_col2" class="data row2 col2" >4.652 +/- 0.136</td>
#       <td id="T_9caf5_row2_col3" class="data row2 col3" >16.199 +/- 1.107</td>
#       <td id="T_9caf5_row2_col4" class="data row2 col4" >5.329 +/- 0.392</td>
#       <td id="T_9caf5_row2_col5" class="data row2 col5" >5.298 +/- 0.427</td>
#     </tr>
#     <tr>
#       <th id="T_9caf5_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_9caf5_row3_col0" class="data row3 col0" >25.051 +/- 2.970</td>
#       <td id="T_9caf5_row3_col1" class="data row3 col1" >5.368 +/- 0.764</td>
#       <td id="T_9caf5_row3_col2" class="data row3 col2" >5.386 +/- 0.504</td>
#       <td id="T_9caf5_row3_col3" class="data row3 col3" >22.473 +/- 2.296</td>
#       <td id="T_9caf5_row3_col4" class="data row3 col4" >6.627 +/- 0.821</td>
#       <td id="T_9caf5_row3_col5" class="data row3 col5" >6.316 +/- 0.294</td>
#     </tr>
#     <tr>
#       <th id="T_9caf5_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_9caf5_row4_col0" class="data row4 col0" >14.462 +/- 1.638</td>
#       <td id="T_9caf5_row4_col1" class="data row4 col1" >4.943 +/- 0.407</td>
#       <td id="T_9caf5_row4_col2" class="data row4 col2" >4.777 +/- 0.323</td>
#       <td id="T_9caf5_row4_col3" class="data row4 col3" >17.197 +/- 1.261</td>
#       <td id="T_9caf5_row4_col4" class="data row4 col4" >6.080 +/- 0.431</td>
#       <td id="T_9caf5_row4_col5" class="data row4 col5" >5.941 +/- 0.349</td>
#     </tr>
#     <tr>
#       <th id="T_9caf5_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_9caf5_row5_col0" class="data row5 col0" >26.638 +/- 2.901</td>
#       <td id="T_9caf5_row5_col1" class="data row5 col1" >5.454 +/- 0.269</td>
#       <td id="T_9caf5_row5_col2" class="data row5 col2" >5.383 +/- 0.502</td>
#       <td id="T_9caf5_row5_col3" class="da

# %%
## Unfrozen-head stage per variant (the pooled figure above mixes variants with different effects)
unfrozen = frame_abs[frame_abs.stage.isin(['real_only', 'unfrozen_head'])] if 'frame_abs' in globals() else metrics_abs[metrics_abs.stage.isin(['real_only', 'unfrozen_head'])]
figures.metric_panels(unfrozen, panels=[(f'{label}, unfrozen head', selector, direction) for label, selector, direction in SELECTORS_ABS],
                      group='variant', order=ABS_ORDER, labels=LABELS_ABS, baseline=BASELINE, columns=3, theme=theme);

# %% [markdown]
# ### Remarks
#
# - axis-200-900: window contribution to W1, test (by stage): baseline 3.117; others 3.36-64.55; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (3.36), worst pretrained (64.55).
# - axis-200-900: window contribution to W1, test (unfrozen head, per variant): baseline 3.117; others 3.025-3.49; 1 of 10 better than the baseline; best P1 permutations (3.025), worst P4 joint + rare (3.49).
# - axis-200-900: within-window W1, test (by stage): baseline 4.747; others 5.134-20.81; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (5.134), worst pretrained (20.81).
# - axis-200-900: within-window W1, test (unfrozen head, per variant): baseline 4.747; others 4.652-5.584; 1 of 10 better than the baseline; best P1 permutations (4.652), worst P4 joint + rare (5.584).
# - axis-200-900: window contribution to W1, heldout_image (by stage): baseline 3.076; others 3.401-49.63; 0 of 3 better than the baseline; best fine-tuned, frozen head (3.401), worst pretrained (49.63).
# - axis-200-900: window contribution to W1, heldout_image (unfrozen head, per variant): baseline 3.076; others 3.123-3.678; 0 of 10 better than the baseline; best P1 permutations (3.123), worst P0 single bins (3.678).
# - axis-200-900: within-window W1, heldout_image (by stage): baseline 5.222; others 5.406-22.68; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (5.406), worst pretrained (22.68).
# - axis-200-900: within-window W1, heldout_image (unfrozen head, per variant): baseline 5.222; others 5.011-5.791; 3 of 10 better than the baseline; best P2 staged (5.011), worst P0 single bins (5.791).
# - axis-200-900: macro AP, heldout_image (by stage): baseline 0.3557; others 0.2456-0.347; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.347), worst fine-tuned, frozen head (0.2456).
# - axis-200-900: macro AP, heldout_image (unfrozen head, per variant): baseline 0.3557; others 0.3413-0.3527; 0 of 10 better than the baseline; best P1 permutations (0.3527), worst P2 staged (0.3413).
# - axis-200-900: macro AP, test_combined (by stage): baseline 0.7088; others 0.09429-0.7094; 1 of 3 better than the baseline; best fine-tuned, unfrozen head (0.7094), worst pretrained (0.09429).
# - axis-200-900: macro AP, test_combined (unfrozen head, per variant): baseline 0.7088; others 0.7063-0.7124; 6 of 10 better than the baseline; best P3 staged + overlap (0.7124), worst P1 permutations (0.7063).
# - axis-200-900: macro ROC AUC, heldout_image (by stage): baseline 0.6966; others 0.4909-0.6917; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.6917), worst fine-tuned, frozen head (0.4909).
# - axis-200-900: macro ROC AUC, heldout_image (unfrozen head, per variant): baseline 0.6966; others 0.6814-0.6954; 0 of 10 better than the baseline; best P4 staged + rare (0.6954), worst P2 staged (0.6814).
# - axis-200-900: macro ROC AUC, test_combined (by stage): baseline 0.9866; others 0.4743-0.9865; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.9865), worst pretrained (0.4743).
# - axis-200-900: macro ROC AUC, test_combined (unfrozen head, per variant): baseline 0.9866; others 0.9862-0.9868; 5 of 10 better than the baseline; best P3 staged + overlap (0.9868), worst P5 joint + overlap + rare (0.9862).
# - axis-100-3000: window contribution to W1, test (by stage): baseline 3.087; others 3.247-81; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (3.247), worst pretrained (81).
# - axis-100-3000: window contribution to W1, test (unfrozen head, per variant): baseline 3.087; others 2.94-3.517; 1 of 10 better than the baseline; best P1 permutations (2.94), worst P4 staged + rare (3.517).
# - axis-100-3000: within-window W1, test (by stage): baseline 5.46; others 6.105-20.28; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (6.105), worst pretrained (20.28).
# - axis-100-3000: within-window W1, test (unfrozen head, per variant): baseline 5.46; others 5.298-6.84; 1 of 10 better than the baseline; best P1 permutations (5.298), worst P4 joint + rare (6.84).
# - axis-100-3000: window contribution to W1, heldout_image (by stage): baseline 3.885; others 3.566-66.8; 2 of 3 better than the baseline; best fine-tuned, unfrozen head (3.566), worst pretrained (66.8).
# - axis-100-3000: window contribution to W1, heldout_image (unfrozen head, per variant): baseline 3.885; others 3.307-3.885; 9 of 10 better than the baseline; best P5 joint + overlap + rare (3.307), worst P4 staged + rare (3.885).
# - axis-100-3000: within-window W1, heldout_image (by stage): baseline 6.468; others 6.009-19.88; 2 of 3 better than the baseline; best fine-tuned, unfrozen head (6.009), worst pretrained (19.88).
# - axis-100-3000: within-window W1, heldout_image (unfrozen head, per variant): baseline 6.468; others 5.651-6.564; 9 of 10 better than the baseline; best P1 permutations (5.651), worst P4 staged + rare (6.564).
# - axis-100-3000: macro AP, heldout_image (by stage): baseline 0.3722; others 0.2488-0.3656; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.3656), worst fine-tuned, frozen head (0.2488).
# - axis-100-3000: macro AP, heldout_image (unfrozen head, per variant): baseline 0.3722; others 0.3559-0.3744; 2 of 10 better than the baseline; best P3 joint + overlap (0.3744), worst P3 staged + overlap (0.3559).
# - axis-100-3000: macro AP, test_combined (by stage): baseline 0.7048; others 0.06727-0.704; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.704), worst pretrained (0.06727).
# - axis-100-3000: macro AP, test_combined (unfrozen head, per variant): baseline 0.7048; others 0.7008-0.7102; 3 of 10 better than the baseline; best P0 single bins (0.7102), worst P2 staged (0.7008).
# - axis-100-3000: macro ROC AUC, heldout_image (by stage): baseline 0.7157; others 0.4871-0.7105; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.7105), worst fine-tuned, frozen head (0.4871).
# - axis-100-3000: macro ROC AUC, heldout_image (unfrozen head, per variant): baseline 0.7157; others 0.704-0.715; 0 of 10 better than the baseline; best P5 joint + overlap + rare (0.715), worst P0 single bins (0.704).
# - axis-100-3000: macro ROC AUC, test_combined (by stage): baseline 0.9869; others 0.4552-0.9866; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.9866), worst pretrained (0.4552).
# - axis-100-3000: macro ROC AUC, test_combined (unfrozen head, per variant): baseline 0.9869; others 0.9862-0.9869; 1 of 10 better than the baseline; best P0 single bins (0.9869), worst P2 staged (0.9862).

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Improvement over the own baseline: wide minus narrow

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# Positive: the wide axis gains more (or loses less) relative to its baseline than the narrow axis.

# %% [markdown]
# #### Implementation
#
# `interaction`.

# %% [markdown]
# #### Figure descriptions
#
# Forest plot: rows = variants, panels = stage x quantity.

# %%
panels = [(f"{STAGE_LABELS[stage]}: {title}", {**selector, 'stage': stage}) for stage in STAGES for title, selector in QUANTITIES]
figures.improvement_forest(interaction, panels=panels, variants=VARIANTS, labels=VARIANT_LABELS, colors=VARIANT_COLORS, columns=4,
                           xlabel='wide improvement - narrow improvement', theme=theme);

# %% [markdown]
# ### Remarks
#
# - unfrozen head, common_classes average_precision, held-out: wide gains more for 0, less for 0 of 10 variants.
# - unfrozen head, common_classes average_precision, test+ext: wide gains more for 0, less for 0 of 10 variants.
# - unfrozen head, common_classes roc_auc, held-out: wide gains more for 0, less for 0 of 10 variants.
# - unfrozen head, common_classes roc_auc, test+ext: wide gains more for 0, less for 0 of 10 variants.
# - unfrozen head, common_windows contribution, held-out: wide gains more for 6, less for 0 of 10 variants.
# - unfrozen head, common_windows contribution, test: wide gains more for 0, less for 1 of 10 variants.
# - unfrozen head, common_windows within, held-out: wide gains more for 1, less for 0 of 10 variants.
# - unfrozen head, common_windows within, test: wide gains more for 0, less for 1 of 10 variants.

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Stage transitions: wide minus narrow

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# Positive: the fine-tuning step improves the wide axis more than the narrow axis.

# %% [markdown]
# #### Implementation
#
# `transition_interaction`.

# %% [markdown]
# #### Figure descriptions
#
# Forest plot: rows = variants, panels = transition x quantity.

# %%
panels = [(f"{name.replace('_minus_', ' - ')}: {title}", {**selector, 'transition': name}) for name in TRANSITIONS for title, selector in QUANTITIES]
figures.improvement_forest(transition_interaction, panels=panels, variants=VARIANTS, labels=VARIANT_LABELS, colors=VARIANT_COLORS, columns=4,
                           xlabel='wide change - narrow change', theme=theme);

# %% [markdown]
# ### Remarks
#
# - frozen - pretrained: 13 cells favour the wide axis, 9 the narrow, of 80.
# - unfrozen - frozen: 8 cells favour the wide axis, 1 the narrow, of 80.
# - unfrozen - pretrained: 23 cells favour the wide axis, 7 the narrow, of 80.

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Results / Summary
#
# ### LLM
#
# - **Observed:** the only consistent axis-dependent benefit is the held-out W1 contribution in 200-900 at the unfrozen stage (6 of 10 variants gain more on the wide axis); head quantities show no interaction.
# - **Interpretation:** pretraining helps reconstruction on the wide axis more than on the narrow axis, and helps the head on neither.
#
# **Absolute levels against the real-only baseline** (means over repetitions; 'better' compares means only, without a test; the intervals are in the improvement sections):
#
# - axis-200-900: window contribution to W1, test (by stage): baseline 3.117; others 3.36-64.55; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (3.36), worst pretrained (64.55).
# - axis-200-900: window contribution to W1, test (unfrozen head, per variant): baseline 3.117; others 3.025-3.49; 1 of 10 better than the baseline; best P1 permutations (3.025), worst P4 joint + rare (3.49).
# - axis-200-900: within-window W1, test (by stage): baseline 4.747; others 5.134-20.81; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (5.134), worst pretrained (20.81).
# - axis-200-900: within-window W1, test (unfrozen head, per variant): baseline 4.747; others 4.652-5.584; 1 of 10 better than the baseline; best P1 permutations (4.652), worst P4 joint + rare (5.584).
# - axis-200-900: window contribution to W1, heldout_image (by stage): baseline 3.076; others 3.401-49.63; 0 of 3 better than the baseline; best fine-tuned, frozen head (3.401), worst pretrained (49.63).
# - axis-200-900: window contribution to W1, heldout_image (unfrozen head, per variant): baseline 3.076; others 3.123-3.678; 0 of 10 better than the baseline; best P1 permutations (3.123), worst P0 single bins (3.678).
# - axis-200-900: within-window W1, heldout_image (by stage): baseline 5.222; others 5.406-22.68; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (5.406), worst pretrained (22.68).
# - axis-200-900: within-window W1, heldout_image (unfrozen head, per variant): baseline 5.222; others 5.011-5.791; 3 of 10 better than the baseline; best P2 staged (5.011), worst P0 single bins (5.791).
# - axis-200-900: macro AP, heldout_image (by stage): baseline 0.3557; others 0.2456-0.347; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.347), worst fine-tuned, frozen head (0.2456).
# - axis-200-900: macro AP, heldout_image (unfrozen head, per variant): baseline 0.3557; others 0.3413-0.3527; 0 of 10 better than the baseline; best P1 permutations (0.3527), worst P2 staged (0.3413).
# - axis-200-900: macro AP, test_combined (by stage): baseline 0.7088; others 0.09429-0.7094; 1 of 3 better than the baseline; best fine-tuned, unfrozen head (0.7094), worst pretrained (0.09429).
# - axis-200-900: macro AP, test_combined (unfrozen head, per variant): baseline 0.7088; others 0.7063-0.7124; 6 of 10 better than the baseline; best P3 staged + overlap (0.7124), worst P1 permutations (0.7063).
# - axis-200-900: macro ROC AUC, heldout_image (by stage): baseline 0.6966; others 0.4909-0.6917; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.6917), worst fine-tuned, frozen head (0.4909).
# - axis-200-900: macro ROC AUC, heldout_image (unfrozen head, per variant): baseline 0.6966; others 0.6814-0.6954; 0 of 10 better than the baseline; best P4 staged + rare (0.6954), worst P2 staged (0.6814).
# - axis-200-900: macro ROC AUC, test_combined (by stage): baseline 0.9866; others 0.4743-0.9865; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.9865), worst pretrained (0.4743).
# - axis-200-900: macro ROC AUC, test_combined (unfrozen head, per variant): baseline 0.9866; others 0.9862-0.9868; 5 of 10 better than the baseline; best P3 staged + overlap (0.9868), worst P5 joint + overlap + rare (0.9862).
# - axis-100-3000: window contribution to W1, test (by stage): baseline 3.087; others 3.247-81; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (3.247), worst pretrained (81).
# - axis-100-3000: window contribution to W1, test (unfrozen head, per variant): baseline 3.087; others 2.94-3.517; 1 of 10 better than the baseline; best P1 permutations (2.94), worst P4 staged + rare (3.517).
# - axis-100-3000: within-window W1, test (by stage): baseline 5.46; others 6.105-20.28; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (6.105), worst pretrained (20.28).
# - axis-100-3000: within-window W1, test (unfrozen head, per variant): baseline 5.46; others 5.298-6.84; 1 of 10 better than the baseline; best P1 permutations (5.298), worst P4 joint + rare (6.84).
# - axis-100-3000: window contribution to W1, heldout_image (by stage): baseline 3.885; others 3.566-66.8; 2 of 3 better than the baseline; best fine-tuned, unfrozen head (3.566), worst pretrained (66.8).
# - axis-100-3000: window contribution to W1, heldout_image (unfrozen head, per variant): baseline 3.885; others 3.307-3.885; 9 of 10 better than the baseline; best P5 joint + overlap + rare (3.307), worst P4 staged + rare (3.885).
# - axis-100-3000: within-window W1, heldout_image (by stage): baseline 6.468; others 6.009-19.88; 2 of 3 better than the baseline; best fine-tuned, unfrozen head (6.009), worst pretrained (19.88).
# - axis-100-3000: within-window W1, heldout_image (unfrozen head, per variant): baseline 6.468; others 5.651-6.564; 9 of 10 better than the baseline; best P1 permutations (5.651), worst P4 staged + rare (6.564).
# - axis-100-3000: macro AP, heldout_image (by stage): baseline 0.3722; others 0.2488-0.3656; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.3656), worst fine-tuned, frozen head (0.2488).
# - axis-100-3000: macro AP, heldout_image (unfrozen head, per variant): baseline 0.3722; others 0.3559-0.3744; 2 of 10 better than the baseline; best P3 joint + overlap (0.3744), worst P3 staged + overlap (0.3559).
# - axis-100-3000: macro AP, test_combined (by stage): baseline 0.7048; others 0.06727-0.704; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.704), worst pretrained (0.06727).
# - axis-100-3000: macro AP, test_combined (unfrozen head, per variant): baseline 0.7048; others 0.7008-0.7102; 3 of 10 better than the baseline; best P0 single bins (0.7102), worst P2 staged (0.7008).
# - axis-100-3000: macro ROC AUC, heldout_image (by stage): baseline 0.7157; others 0.4871-0.7105; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.7105), worst fine-tuned, frozen head (0.4871).
# - axis-100-3000: macro ROC AUC, heldout_image (unfrozen head, per variant): baseline 0.7157; others 0.704-0.715; 0 of 10 better than the baseline; best P5 joint + overlap + rare (0.715), worst P0 single bins (0.704).
# - axis-100-3000: macro ROC AUC, test_combined (by stage): baseline 0.9869; others 0.4552-0.9866; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.9866), worst pretrained (0.4552).
# - axis-100-3000: macro ROC AUC, test_combined (unfrozen head, per variant): baseline 0.9869; others 0.9862-0.9869; 1 of 10 better than the baseline; best P0 single bins (0.9869), worst P2 staged (0.9862).

# %% [markdown]
# ### Person
