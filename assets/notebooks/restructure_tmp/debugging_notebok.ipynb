# %%
import matplotlib.pyplot as plt
import numpy as np
import os 
from pathlib import Path
import torch 

import m2aia as m2



# seting global dir
cwd=Path.cwd()
if cwd.parent.name == "notebooks":
    # os.chdir(cwd.parent.parent) 
    os.chdir(cwd.parent.parent.parent) 
os.getcwd()
# Out:
# '/home/maxi7524/repositories/MSIAutoEncoderWrapper'

# %%
from msi_autoencoder_wrapper import MSIAutoEncoderWrapper

# %%
# instantiate wrapper object
debug_path = 'data/restructurization_tests/mouse_bladder'
wrapper = MSIAutoEncoderWrapper(debug_path)
# Out:
# 2026-07-07 22:01:00,356 | INFO     | msi_autoencoder_wrapper.core.mixins.reader_manager_mixin:37 | Enforcing automatic module discovery for reader and binner registries.
# 2026-07-07 22:01:00,359 | INFO     | msi_autoencoder_wrapper.readers.readers_manager:66 | ReaderManager successfully auto-discovered and registered strategy drivers.
# 2026-07-07 22:01:01,133 | INFO     | msi_autoencoder_wrapper.binners.binners_manager:115 | BinnerManager successfully auto-discovered and registered compression drivers.
# 2026-07-07 22:01:01,223 | INFO     | msi_autoencoder_wrapper.core.wrapper:104 | MSI AutoEncoder Facade workspace initialized on device: None

# %% [markdown]
# ## Workspace manager

# %%
# create project dir 
wrapper.workspace.create_required_directories()
# meanwhile move ims there (it is not necessary)

# %%
## default image settiing 
wrapper.workspace.set_default_image('mouse_urinary_bladder.imzML')
print(wrapper.workspace.default_img_name)
wrapper.workspace.set_active_image()
print(wrapper.workspace.active_img_name)
print(wrapper.workspace.get_active_image_file_path())
print('WITHOUT EXTENSION')
wrapper.workspace.set_default_image('mouse_urinary_bladder')
print(wrapper.workspace.default_img_name)
wrapper.workspace.set_active_image()
print(wrapper.workspace.active_img_name)
print(wrapper.workspace.get_active_image_file_path())
# Out:
# mouse_urinary_bladder.imzML
# 2026-07-07 22:01:01,264 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:158 | No image name provided. Falling back to default workspace image configuration.
# 2026-07-07 22:01:01,265 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:184 | Mapping relative image handle against workspace repository path: mouse_urinary_bladder.imzML
# mouse_urinary_bladder
# data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML
# WITHOUT EXTENSION
# mouse_urinary_bladder
# 2026-07-07 22:01:01,266 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:158 | No image name provided. Falling back to default workspace image configuration.
# 2026-07-07 22:01:01,267 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:184 | Mapping relative image handle against workspace repository path: mouse_urinary_bladder
# mouse_urinary_bladder
# data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML

# %%
## setting by path 
wrapper.workspace.set_active_image('data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML')
print(wrapper.workspace.active_img_name)
print(wrapper.workspace.get_active_image_file_path())
print('WITHOUT EXTENSION')
wrapper.workspace.set_active_image('data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder')
print(wrapper.workspace.active_img_name)
print(wrapper.workspace.get_active_image_file_path())
# Out:
# 2026-07-07 11:18:24,086 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:171 | Resolving direct filesystem path context for image: data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML
# 2026-07-07 11:18:24,088 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:177 | Image path successfully validated inside active workspace root.
# mouse_urinary_bladder
# data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML
# WITHOUT EXTENSION
# 2026-07-07 11:18:24,090 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:171 | Resolving direct filesystem path context for image: data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder
# 2026-07-07 11:18:24,092 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:177 | Image path successfully validated inside active workspace root.
# mouse_urinary_bladder
# data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML

# %%
## setting by external path 
wrapper.workspace.set_active_image('data/bladder_data/bladder_data/mouse_urinary_bladder.imzML')
print(wrapper.workspace.active_img_name)
print(wrapper.workspace.get_active_image_file_path())
print('WITHOUT EXTENSION')
wrapper.workspace.set_active_image('data/bladder_data/bladder_data/mouse_urinary_bladder')
print(wrapper.workspace.active_img_name)
print(wrapper.workspace.get_active_image_file_path())
# Out:
# 2026-07-07 11:18:25,764 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:171 | Resolving direct filesystem path context for image: data/bladder_data/bladder_data/mouse_urinary_bladder.imzML
# 2026-07-07 11:18:25,767 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:181 | External filesystem path detected. Image context mapped outside of workspace.
# mouse_urinary_bladder
# data/bladder_data/bladder_data/mouse_urinary_bladder.imzML
# WITHOUT EXTENSION
# 2026-07-07 11:18:25,769 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:171 | Resolving direct filesystem path context for image: data/bladder_data/bladder_data/mouse_urinary_bladder
# 2026-07-07 11:18:25,770 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:181 | External filesystem path detected. Image context mapped outside of workspace.
# mouse_urinary_bladder
# data/bladder_data/bladder_data/mouse_urinary_bladder.imzML

# %% [markdown]
# ## Readers and binners

# %%
# checking available methods
## params
print_return = True
## results 
wrapper.reader_manager.get_available_readers(print_return)
wrapper.reader_manager.get_available_binners(print_return)
wrapper.reader_manager.get_available_inverse_binners(print_return)
print(wrapper.reader_manager.print_setup_summary())
# Out:
# ================================================================================
#  REGISTERED MSI READERS & PARAMETERS
# ================================================================================
#
# [Reader Key]: 'M2aiaReader'
#  Description: Concrete data loader adapter linking native binary C++ M2aia bindings to the library ecosystem.
#
#     This strategy handles file initialization, raw binary buffer parsing, and spatial tracking
#     for standard imzML structures wrapped by the M2aia processing API.
#  Parameters (kwargs):
#    - file_path: Required
# ================================================================================
#
#
# ================================================================================
#  REGISTERED MSI FORWARD BINNERS & PARAMETERS
# ================================================================================
#
# [Binner Key]: 'LinearBinning'
#  Description: Concrete processing strategy executing fast linear quantization via equidistant mass-to-charge bins.
#  Parameters (kwargs):
#    - x_min: Required
#    - x_max: Required
#    - bin_step: Required
# ================================================================================
#
#
# ================================================================================
#  REGISTERED MSI INVERSE BINNERS & PARAMETERS
# ================================================================================
#
# [Inverse Binner Key]: 'TopPeaksInverseBinner'
#  Description: Resolution reduction algorithm tracking top peak heights across non-overlapping contextual coordinate masks.
#  Parameters (kwargs):
#    - binner: Required
#    - max_bins: 500
#    - window_size: 3
# ================================================================================
#
# 2026-07-07 22:06:19,385 | INFO     | msi_autoencoder_wrapper.core.mixins.reader_manager_mixin:251 | === ReadersManagerProxy Configuration Ledger Trace ===
# {}
# None

# %%
wrapper.reader_manager.set_reader('data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder', 'M2aiaReader')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 wrapper.reader_manager.set_reader('data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder', 'M2aiaReader')
#
# File ~/repositories/MSIAutoEncoderWrapper/src/msi_autoencoder_wrapper/core/mixins/reader_manager_mixin.py:88, in ReadersManagerProxy.set_reader(self, img_name, reader_or_name, **kwargs)
#      82     raise ValueError(
#      83         f"Unknown reader strategy identifier '{reader_or_name}'. "
#      84         f"Available strategies in REGISTRY are: {list(ReaderManager.REGISTRY.keys())}."
#      85     )
#      87 reader_cls = ReaderManager.REGISTRY[reader_or_name]
# ---> 88 validate_constructor_kwargs(cls=reader_cls, name=reader_or_name, kwargs=kwargs)
#      90 self.config_ledger[img_name]["reader"] = {
#      91     "instance_name": reader_or_name,
#      92     "instance_params": kwargs
#      93 }
#      94 logger.info("Committed dataset reader configuration setup under image token context: %s", img_name)
#
# File ~/repositories/MSIAutoEncoderWrapper/src/msi_autoencoder_wrapper/utils/validators.py:48, in validate_constructor_kwargs(cls, name, kwargs)
#      45             missing_args.append(param_name)
#      47 if missing_args:
# ---> 48     raise ValueError(
#      49         f"Cannot initialize configuration for '{name}' using class '{cls.__name__}'. "
#      50         f"Missing required keyword argument(s): {', '.join([repr(a) for a in missing_args])}. "
#      51         f"Provided arguments: {list(kwargs.keys())}."
#      52     )
#
# ValueError: Cannot initialize configuration for 'M2aiaReader' using class 'M2aiaReader'. Missing required keyword argument(s): 'file_path'. Provided arguments: [].
