# %%
import matplotlib.pyplot as plt
import numpy as np
import os 
from pathlib import Path
import torch 

import m2aia as m2



# seting global dir
cwd=Path.cwd()
if cwd.parent.name == "notebooks":
    # os.chdir(cwd.parent.parent) 
    os.chdir(cwd.parent.parent.parent) 
os.getcwd()
# Out:
# '/home/maxi7524/repositories/MSIAutoEncoderWrapper'

# %%
from msi_autoencoder_wrapper import MSIAutoEncoderWrapper

# %%
# instantiate wrapper object
debug_path = 'data/restructurization_tests/mouse_bladder'
wrapper = MSIAutoEncoderWrapper(debug_path)
# Out:
# 2026-07-08 11:10:02,281 | INFO     | msi_autoencoder_wrapper.core.mixins.reader_manager_mixin:41 | Enforcing automatic module discovery for reader and binner registries.
# 2026-07-08 11:10:02,293 | INFO     | msi_autoencoder_wrapper.readers.readers_manager:66 | ReaderManager successfully auto-discovered and registered strategy drivers.
# 2026-07-08 11:10:02,964 | INFO     | msi_autoencoder_wrapper.binners.binners_manager:115 | BinnerManager successfully auto-discovered and registered compression drivers.
# 2026-07-08 11:10:03,096 | INFO     | msi_autoencoder_wrapper.core.wrapper:104 | MSI AutoEncoder Facade workspace initialized on device: None

# %% [markdown]
# ## Workspace manager

# %%
# create project dir 
wrapper.workspace.create_required_directories()
# meanwhile move ims there (it is not necessary)

# %%
## default image settiing 
wrapper.workspace.set_default_image_path('mouse_urinary_bladder.imzML')
print(wrapper.workspace.default_img_name)
wrapper.workspace.set_active_image()
print(wrapper.workspace.active_img_name)
print(wrapper.workspace.get_active_image_file_path())
print('WITHOUT EXTENSION')
wrapper.workspace.set_default_image_path('mouse_urinary_bladder')
print(wrapper.workspace.default_img_name)
wrapper.workspace.set_active_image()
print(wrapper.workspace.active_img_name)
print(wrapper.workspace.get_active_image_file_path())
# Out:
# 2026-07-08 11:10:03,137 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:137 | Default image context successfully established: mouse_urinary_bladder
# mouse_urinary_bladder
# 2026-07-08 11:10:03,139 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:99 | No image name provided. Falling back to default workspace image configuration.
# mouse_urinary_bladder
# data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML
# WITHOUT EXTENSION
# 2026-07-08 11:10:03,141 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:137 | Default image context successfully established: mouse_urinary_bladder
# mouse_urinary_bladder
# 2026-07-08 11:10:03,142 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:99 | No image name provided. Falling back to default workspace image configuration.
# mouse_urinary_bladder
# data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML

# %%
## setting by path 
wrapper.workspace.set_active_image('data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML')
print(wrapper.workspace.active_img_name)
print(wrapper.workspace.get_active_image_file_path())
print('WITHOUT EXTENSION')
wrapper.workspace.set_active_image('data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder')
print(wrapper.workspace.active_img_name)
print(wrapper.workspace.get_active_image_file_path())
# Out:
# 2026-07-08 11:10:03,164 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:112 | Active image context successfully established: mouse_urinary_bladder
# mouse_urinary_bladder
# data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML
# WITHOUT EXTENSION
# 2026-07-08 11:10:03,167 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:112 | Active image context successfully established: mouse_urinary_bladder
# mouse_urinary_bladder
# data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML

# %%
## setting by external path 
wrapper.workspace.set_active_image('data/bladder_data/bladder_data/mouse_urinary_bladder.imzML')
print(wrapper.workspace.active_img_name)
print(wrapper.workspace.get_active_image_file_path())
print('WITHOUT EXTENSION')
wrapper.workspace.set_active_image('data/bladder_data/bladder_data/mouse_urinary_bladder')
print(wrapper.workspace.active_img_name)
print(wrapper.workspace.get_active_image_file_path())
# Out:
# 2026-07-08 11:10:03,196 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:112 | Active image context successfully established: mouse_urinary_bladder
# mouse_urinary_bladder
# data/bladder_data/bladder_data/mouse_urinary_bladder.imzML
# WITHOUT EXTENSION
# 2026-07-08 11:10:03,198 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:112 | Active image context successfully established: mouse_urinary_bladder
# mouse_urinary_bladder
# data/bladder_data/bladder_data/mouse_urinary_bladder.imzML

# %% [markdown]
# ## Readers and binners

# %%
# checking available methods
## params
print_return = True
## results 
wrapper.reader_manager.get_available_readers(print_return)
wrapper.reader_manager.get_available_binners(print_return)
wrapper.reader_manager.get_available_inverse_binners(print_return)
print(wrapper.reader_manager.print_setup_summary())
# Out:
# ================================================================================
#  REGISTERED MSI READERS & PARAMETERS
# ================================================================================
#
# [Reader Key]: 'M2aiaReader'
#  Description: Concrete data loader adapter linking native binary C++ M2aia bindings to the library ecosystem.
#
#     This strategy handles file initialization, raw binary buffer parsing, and spatial tracking
#     for standard imzML structures wrapped by the M2aia processing API.
#  Parameters (kwargs):
#    - file_path: Required
# ================================================================================
#
#
# ================================================================================
#  REGISTERED MSI FORWARD BINNERS & PARAMETERS
# ================================================================================
#
# [Binner Key]: 'LinearBinning'
#  Description: Concrete processing strategy executing fast linear quantization via equidistant mass-to-charge bins.
#  Parameters (kwargs):
#    - x_min: Required
#    - x_max: Required
#    - bin_step: Required
# ================================================================================
#
#
# ================================================================================
#  REGISTERED MSI INVERSE BINNERS & PARAMETERS
# ================================================================================
#
# [Inverse Binner Key]: 'TopPeaksInverseBinner'
#  Description: Resolution reduction algorithm tracking top peak heights across non-overlapping contextual coordinate masks.
#  Parameters (kwargs):
#    - binner: Required
#    - max_bins: 500
#    - window_size: 3
# ================================================================================
#
# 2026-07-08 11:10:04,189 | INFO     | msi_autoencoder_wrapper.core.mixins.reader_manager_mixin:341 | ReadersManagerProxy Configuration Ledger Trace
# {}
# None

# %%
wrapper.workspace.get_default_image_path()
# Out:
# PosixPath('data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML')

# %%
wrapper.reader_manager.get_available_readers()
# Out:
# ================================================================================
#  REGISTERED MSI READERS & PARAMETERS
# ================================================================================
#
# [Reader Key]: 'M2aiaReader'
#  Description: Concrete data loader adapter linking native binary C++ M2aia bindings to the library ecosystem.
#
#     This strategy handles file initialization, raw binary buffer parsing, and spatial tracking
#     for standard imzML structures wrapped by the M2aia processing API.
#  Parameters (kwargs):
#    - file_path: Required
# ================================================================================

# %%
# reader management 
## text
wrapper.reader_manager.set_reader('M2aiaReader')
## instance
## REMARK: we need pass str (i manage this automatically in method) 
wrapper.reader_manager.set_reader(m2.ImzMLReader(str(wrapper.workspace.get_active_image_file_path())))
# Out:
# 2026-07-08 11:20:14,740 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:99 | No image name provided. Falling back to default workspace image configuration.
# 2026-07-08 11:20:14,742 | INFO     | msi_autoencoder_wrapper.core.mixins.reader_manager_mixin:298 | Resolving system component 'reader' under image context 'mouse_urinary_bladder'
# 2026-07-08 11:20:14,743 | INFO     | msi_autoencoder_wrapper.readers.strategies.m2aia_readers:32 | Initializing M2aia native image reader on file target: data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML
# !26.570! WARNING: No pixel size found, set x and y spacing to 50 microns!
# !28.880! WARNING: Processed profile spectrum is not fully supported! Check the ImzML file.
# [29.512] [imzML]: data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML
# 	[pixel size (mm)]: 0.050000x0.050000x0.010000
# 	[image dimension]: 260x134x1
# 	[num spectra]: 34840
# 	[spec. type]: ProcessedProfile
# 	[mass range]: 400.259620 to 999.795899 with #1500 measurements
# !29.513! WARNING: No pixel size found, set x and y spacing to 50 microns!
# !31.820! WARNING: Processed profile spectrum is not fully supported! Check the ImzML file.
# [2026-07-08 11:20:16,564 | INFO     | msi_autoencoder_wrapper.core.mixins.reader_manager_mixin:316 | Successfully registered component 'reader' into ledger for image 'mouse_urinary_bladder'
# 32.496] [imzML]: data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML
# 	[pixel size (mm)]: 0.050000x0.050000x0.010000
# 	[image dimension]: 260x134x1
# 	[num spectra]: 34840
# 	[spec. type]: ProcessedProfile
# 	[mass range]: 400.259620 to 999.795899 with #1500 measurements
# !32.500! WARNING: No pixel size found, set x and y spacing to 50 microns!
# !34.855! WARNING: Processed profile spectrum is not fully supported! Check the ImzML file.
# [2026-07-08 11:20:17,440 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:99 | No image name provided. Falling back to default workspace image configuration.
# 35.461] [imzML]: data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML
# 	[pixel size (mm)]: 0.050000x0.050000x0.010000
# 	[image dimension]: 260x134x1
# 	[num spectra]: 34840
# 	[spec. type]: ProcessedProfile
# 	[mass range]: 400.259620 to 999.795899 with #1500 measurements
# 2026-07-08 11:20:17,441 | INFO     | msi_autoencoder_wrapper.core.mixins.reader_manager_mixin:298 | Resolving system component 'reader' under image context 'mouse_urinary_bladder'
# 2026-07-08 11:20:17,443 | INFO     | msi_autoencoder_wrapper.core.mixins.reader_manager_mixin:316 | Successfully registered component 'reader' into ledger for image 'mouse_urinary_bladder'

# %%
wrapper.reader_manager.get_available_binners()
# Out:
# ================================================================================
#  REGISTERED MSI FORWARD BINNERS & PARAMETERS
# ================================================================================
#
# [Binner Key]: 'LinearBinning'
#  Description: Concrete processing strategy executing fast linear quantization via equidistant mass-to-charge bins.
#  Parameters (kwargs):
#    - x_min: Required
#    - x_max: Required
#    - bin_step: Required
# ================================================================================

# %%
wrapper.reader_manager.set_binner('LinearBinning', wrapper.)
# Out:
# 2026-07-08 11:20:53,663 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace_mixin:99 | No image name provided. Falling back to default workspace image configuration.
# 2026-07-08 11:20:53,667 | ERROR    | msi_autoencoder_wrapper.utils.validators:76 | Validation failed for constructor setup of: LinearBinning
# 2026-07-08 11:20:53,669 | ERROR    | msi_autoencoder_wrapper.core.utils.decorators:66 | Exception intercepted in '_set_component'. Triggering active reader context reset.
# Traceback (most recent call last):
#   File "/home/maxi7524/repositories/MSIAutoEncoderWrapper/src/msi_autoencoder_wrapper/core/utils/decorators.py", line 63, in wrapper
#     return func(instance, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/maxi7524/repositories/MSIAutoEncoderWrapper/src/msi_autoencoder_wrapper/core/mixins/reader_manager_mixin.py", line 294, in _set_component
#     validate_constructor_kwargs(target_registry[target], target, kwargs)
#   File "/home/maxi7524/repositories/MSIAutoEncoderWrapper/src/msi_autoencoder_wrapper/utils/validators.py", line 77, in validate_constructor_kwargs
#     raise ValueError(error_message)
# ValueError: Cannot initialize configuration for 'LinearBinning' using class 'LinearBinning'. Missing required keyword argument(s): 'x_min', 'x_max', 'bin_step'. Provided arguments: [].
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/repositories/MSIAutoEncoderWrapper/src/msi_autoencoder_wrapper/core/utils/decorators.py:63, in manage_image_context.<locals>.wrapper(instance, *args, **kwargs)
#      62     logger.debug("Executing method '%s' under verified context: %s", func.__name__, workspace.active_img_name)
# ---> 63     return func(instance, *args, **kwargs)
#      64 except Exception as error:
#      65     ### Capture runtime system exceptions to initiate emergency pipeline state cleanup
#
# File ~/repositories/MSIAutoEncoderWrapper/src/msi_autoencoder_wrapper/core/mixins/reader_manager_mixin.py:294, in ReadersManagerProxy._set_component(self, component_type, target, img_name_or_path, **kwargs)
#     293     logger.debug("Executing static reflection analysis against constructor of class: %s", target)
# --> 294     validate_constructor_kwargs(target_registry[target], target, kwargs)
#     296 # Strategy compilation block
#     297 ## Delegate strategy selection to the unified validation framework factory
#
# File ~/repositories/MSIAutoEncoderWrapper/src/msi_autoencoder_wrapper/utils/validators.py:77, in validate_constructor_kwargs(cls, name, kwargs)
#      76 logger.error("Validation failed for constructor setup of: %s", name)
# ---> 77 raise ValueError(error_message)
#
# ValueError: Cannot initialize configuration for 'LinearBinning' using class 'LinearBinning'. Missing required keyword argument(s): 'x_min', 'x_max', 'bin_step'. Provided arguments: [].
#
# During handling of the above exception, another exception occurred:
#
# ValidationError                           Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 wrapper.reader_manager.set_binner('LinearBinning')
#
# File ~/repositories/MSIAutoEncoderWrapper/src/msi_autoencoder_wrapper/core/mixins/reader_manager_mixin.py:96, in ReadersManagerProxy.set_binner(self, binner_name_or_instance, img_name_or_path, **kwargs)
#      83 """
#      84 Registers a forward spectral binning compression configuration into the project ledger.
#      85
#    (...)     92 :rtype: Any
#      93 """
#      94 # Strategy routing block
#      95 ## Forward execution properties directly to the unified driver registration manager
# ---> 96 return self._set_component(
#      97     component_type="binner",
#      98     target=binner_name_or_instance,
#      99     img_name_or_path=img_name_or_path,
#     100     **kwargs
#     101 )
#
# File ~/repositories/MSIAutoEncoderWrapper/src/msi_autoencoder_wrapper/core/utils/decorators.py:70, in manage_image_context.<locals>.wrapper(instance, *args, **kwargs)
#      68 ### Access active lazy-loading drivers to clear cached filesystem file handles
#      69 active_reader = getattr(wrapper_ref, "active_reader", None)
# ---> 70 if active_reader:
#      71     if hasattr(active_reader, "clear_active_context"):
#      72         active_reader.clear_active_context()
#
# File ~/repositories/MSIAutoEncoderWrapper/src/msi_autoencoder_wrapper/core/mixins/active_reader_mixin.py:183, in ActiveReaderProxy.__len__(self)
#     181 self._sync_active_pipeline()
#     182 if self._active_reader is None:
# --> 183     raise ValidationError(["Active reader initialization failed. Length is unresolved."])
#     184 return len(self._active_reader)
#
# ValidationError: Validation failed. Missing required components/files: Active reader initialization failed. Length is unresolved.

# %%
wrapper.workspace.get_active_image_file_path()
wrapper.workspace.clear_active_context()
# Out:
# PosixPath('data/restructurization_tests/mouse_bladder/imgs/mouse_urinary_bladder.imzML')
