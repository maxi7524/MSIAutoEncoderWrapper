# %%
import matplotlib.pyplot as plt
import numpy as np
import os 
from pathlib import Path

# seting global dir
current_path = Path.cwd().resolve()
repository_root = next(
    path for path in (current_path, *current_path.parents)
    if (path / 'pyproject.toml').is_file()
)
os.chdir(repository_root)
repository_root
# Out:
# PosixPath('/home/maxi7524/repositories/MSIAutoEncoderWrapper')

# %%
# Creating wrapper 

## imports 
from msi_autoencoder_wrapper import MSIAutoEncoderWrapper

## setting workspace
workspace_path = 'workspace'

wrapper = MSIAutoEncoderWrapper(
    project_path='workspace',
)
# Out:
# 2026-07-29 23:52:58,180 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.models.architectures.types.autoencoders.presets'.
# 2026-07-29 23:52:58,183 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 15 implementation module(s) in package 'msi_autoencoder_wrapper.models.architectures.types.autoencoders'.
# 2026-07-29 23:52:58,187 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 0 implementation module(s) in package 'msi_autoencoder_wrapper.models.architectures.types.schema'.
# 2026-07-29 23:52:58,188 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 21 implementation module(s) in package 'msi_autoencoder_wrapper.models.architectures'.
# 2026-07-29 23:52:58,210 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 9 implementation module(s) in package 'msi_autoencoder_wrapper.training.criterions.autoencoder'.
# 2026-07-29 23:52:58,212 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 13 implementation module(s) in package 'msi_autoencoder_wrapper.training.criterions'.
# 2026-07-29 23:52:58,333 | INFO     | msi_autoencoder_wrapper.core.wrapper:71 | MSIAutoEncoderWrapper: Anchoring processing device state: cuda
# 2026-07-29 23:52:58,334 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:49 | Enforcing automatic module discovery for reader and binner registries.
# 2026-07-29 23:53:02,395 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 2 implementation module(s) in package 'msi_autoencoder_wrapper.readers.strategies'.
# 2026-07-29 23:53:02,399 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.binners.binners_strategies'.
# 2026-07-29 23:53:02,401 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.binners.binners_strategies'.
# 2026-07-29 23:53:02,405 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.binners.inverse_strategies'.
# 2026-07-29 23:53:02,406 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.binners.inverse_strategies'.
# 2026-07-29 23:53:02,408 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 13 implementation module(s) in package 'msi_autoencoder_wrapper.training.criterions'.
# 2026-07-29 23:53:02,416 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.models.datasets.strategies'.
# 2026-07-29 23:53:02,417 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.models.datasets.strategies'.
# 2026-07-29 23:53:02,419 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 21 implementation module(s) in package 'msi_autoencoder_wrapper.models.architectures'.
# 2026-07-29 23:53:02,420 | INFO     | msi_autoencoder_wrapper.core.wrapper:86 | MSIAutoEncoderWrapper facade successfully initialized and bound.

# %%
# Reader setup
wrapper.workspace.set_default_image_path('kidney-pilot-v2')
wrapper.context_manager.set_reader('PyImzMLReader') 
wrapper.context_manager.set_binner('LinearBinning', bin_step= 0.01)
wrapper.context_manager.set_inverse_binner('TopPeaksInverseBinner')
# Out:
# 2026-07-29 23:53:05,101 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.getters_and_setters_proxy:93 | Default fallback image anchored: kidney-pilot-v2
# 2026-07-29 23:53:05,102 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.getters_and_setters_proxy:53 | No image name provided. Falling back to default workspace image configuration.
# 2026-07-29 23:53:05,103 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:462 | Resolving system component 'reader' under image context 'kidney-pilot-v2'
# 2026-07-29 23:53:05,725 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:481 | Successfully registered component 'reader' into ledger for image 'kidney-pilot-v2'
# 2026-07-29 23:53:05,729 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.getters_and_setters_proxy:69 | Active image set via direct filesystem path: kidney-pilot-v2 (Location: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/datasets/kidney-pilot-v2)
# 2026-07-29 23:53:05,730 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:462 | Resolving system component 'annotation_reader' under image context 'kidney-pilot-v2'
# 2026-07-29 23:53:05,732 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:481 | Successfully registered component 'annotation_reader' into ledger for image 'kidney-pilot-v2'
# 2026-07-29 23:53:05,733 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.getters_and_setters_proxy:53 | No image name provided. Falling back to default workspace image configuration.
# 2026-07-29 23:53:05,734 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:462 | Resolving system component 'binner' under image context 'kidney-pilot-v2'
# 2026-07-29 23:53:05,735 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.active_context_mixin:111 | Successfully bound active context memory maps for: kidney-pilot-v2
# 2026-07-29 23:53:05,757 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:481 | Successfully registered component 'binner' into ledger for image 'kidney-pilot-v2'
# 2026-07-29 23:53:05,757 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.getters_and_setters_proxy:53 | No image name provided. Falling back to default workspace image configuration.
# 2026-07-29 23:53:05,759 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:462 | Resolving system component 'inverse_binner' under image context 'kidney-pilot-v2'
# 2026-07-29 23:53:05,759 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:481 | Successfully registered component 'inverse_binner' into ledger for image 'kidney-pilot-v2'

# %%
# obtain annotation information\
print('Metadata', wrapper.active_context.annotation_reader.get_dataset_metadata())
print('Spectra:', wrapper.active_context.reader.GetNumberOfSpectra())
print('Molecular annotations:', len(wrapper.active_context.annotation_reader.get_annotations()))
print('Annotated spectrum 449 length:', len(wrapper.active_context.annotation_reader.get_spectrum_annotations(449)))
print('Annotated spectrum 449:', wrapper.active_context.annotation_reader.get_spectrum_annotations(449))
# Out:
# 2026-07-29 23:53:05,773 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.active_context_mixin:70 | No active image set. Automatically resolving default workspace context: kidney-pilot-v2
# 2026-07-29 23:53:05,774 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.getters_and_setters_proxy:53 | No image name provided. Falling back to default workspace image configuration.
# 2026-07-29 23:53:05,775 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.active_context_mixin:111 | Successfully bound active context memory maps for: kidney-pilot-v2
# Metadata {'merged_dataset_id': 'kidney-pilot-v2', 'sources': [{'source': 'metaspace', 'dataset_id': '2026-07-27_08h49m39s', 'name': 'C57BL6_Kidney_02-pos', 'local_path': 'workspace/datasets/C57BL6_Kidney_02-pos', 'status': 'materialized', 'updated_at': '2026-07-28T09:47:27.479315+00:00', 'metadata': {'organ': 'kidney', 'organism': 'mouse'}}]}
# Spectra: 5959
# Molecular annotations: 22
# Annotated spectrum 449 length: 22
# Annotated spectrum 449: [{'adduct': 'M+Na', 'annotation_id': '0', 'chemMod': '', 'datasetId': '2026-07-27_08h49m39s', 'datasetName': 'C57BL6_Kidney_02-pos', 'fdr': 0.05, 'formula': 'C27H20O12', 'group': '', 'ion': 'C27H20O12+Na+', 'isobarIons': 'C24H24O13+K+, C22H20F3N3O9S+', 'isobaric_ions_count': '2', 'isomeric_ions_count': '0', 'isomeric_mols_count': '1', 'massError': '6.834860963934858', 'maxIntensity': '1400.379150390625', 'minIntensity': '0', 'moleculeIds': 'HMDB0034035', 'moleculeNames': 'Sagecoumarin', 'msm': '0.83674395', 'mz': 559.084696763, 'offSample': 'false', 'rawOffSampleProb': '0.00015931409143377095', 'rhoChaos': '0.998367770544391', 'rhoSpatial': '0.8894151943004499', 'rhoSpectral': '0.9423180196984413', 'totalIntensity': '2688485.25', 'spectrum_id': 449, 'intensity': 571.135009765625, 'source': 'metaspace', 'source_dataset_id': '2026-07-27_08h49m39s', 'source_spectrum_id': 449}, {'adduct': 'M+H', 'annotation_id': '10', 'chemMod': '', 'datasetId': '2026-07-27_08h49m39s', 'datasetName': 'C57BL6_Kidney_02-pos', 'fdr': 0.05, 'formula': 'C19H20O3', 'group': '', 'ion': 'C19H20O3+H+', 'isobarIons': '', 'isobaric_ions_count': '0', 'isomeric_ions_count': '0', 'isomeric_mols_count': '7', 'massError': '5.426459464601315', 'maxIntensity': '901', 'minIntensity': '0', 'moleculeIds': 'HMDB0038784, HMDB0030599, HMDB0033950, HMDB0035220, HMDB0039071, HMDB0138206, HMDB0141090', 'moleculeNames': '(E)-Arachidin II, 5-[(4-Hydroxypheny)ethenyl]-2-(3-methyl-1-butenyl)-1,3-benzenediol, Parakmerin A, Cryptotanshinone, exo-Dehydrochalepin, (4E)-1,7-bis(4-hydroxyphenyl)hept-4-en-3-one, 1-(4-hydroxyphenyl)-7-phenylheptane-3,5-dione', 'msm': '0.71065813', 'mz': 297.148520935, 'offSample': 'false', 'rawOffSampleProb': '0.00017550360644236207', 'rhoChaos': '0.9982922917256345', 'rhoSpatial': '0.7238195540836116', 'rhoSpectral': '0.9834962702754538', 'totalIntensity': '1725364', 'spectrum_id': 449, 'intensity': 229.6666717529297, 'source': 'metaspace', 'source_dataset_id': '2026-07-27_08h49m39s', 'source_spectrum_id': 449}, {'adduct': 'M[M]+', 'annotation_id': '11', 'chemMod': '', 'datasetId': '2026-07-27_08h49m39s', 'datasetName': 'C57BL6_Kidney_02-pos', 'fdr': 0.05, 'formula': 'C30H46O7', 'group': '', 'ion': 'C30H46O7+', 'isobarIons': 'C24H50NO7P+Na+, C26H48NO7P+H+', 'isobaric_ions_count': '2', 'isomeric_ions_count': '0', 'isomeric_mols_count': '4', 'massError': '5.659414025633079', 'maxIntensity': '1580', 'minIntensity': '0', 'moleculeIds': 'HMDB0034392, HMDB0035304, HMDB0035699, HMDB0039691', 'moleculeNames': 'Perulactone, Ganoderic acid C2, Corosin, Ganolucidic acid C', 'msm': '0.7084589', 'mz': 518.323805215, 'offSample': 'false', 'rawOffSampleProb': '0.000020184152162983082', 'rhoChaos': '0.9986413812623832', 'rhoSpatial': '0.7250033490140805', 'rhoSpectral': '0.9785095907654087', 'totalIntensity': '1803349', 'spectrum_id': 449, 'intensity': 254.03921508789062, 'source': 'metaspace', 'source_dataset_id': '2026-07-27_08h49m39s', 'source_spectrum_id': 449}, {'adduct': 'M+Na', 'annotation_id': '12', 'chemMod': '', 'datasetId': '2026-07-27_08h49m39s', 'datasetName': 'C57BL6_Kidney_02-pos', 'fdr': 0.05, 'formula': 'C46H86NO7P', 'group': '', 'ion': 'C46H86NO7P+Na+', 'isobarIons': 'C48H84NO7P+H+', 'isobaric_ions_count': '1', 'isomeric_ions_count': '0', 'isomeric_mols_count': '9', 'massError': '9.095517132901346', 'maxIntensity': '10067', 'minIntensity': '0', 'moleculeIds': 'HMDB0008359, HMDB0008360, HMDB0008391, HMDB0008423, HMDB0011251, HMDB0011252, HMDB0011283, HMDB0011316, HMDB0013420', 'moleculeNames': 'PC(20:2(11Z,14Z)/P-18:1(11Z)), PC(20:2(11Z,14Z)/P-18:1(9Z)), PC(20:3(5Z,8Z,11Z)/P-18:0), PC(20:3(8Z,11Z,14Z)/P-18:0), PC(P-18:0/20:3(5Z,8Z,11Z)), PC(P-18:0/20:3(8Z,11Z,14Z)), PC(P-18:1(11Z)/20:2(11Z,14Z)), PC(P-18:1(9Z)/20:2(11Z,14Z)), PC(o-18:0/20:4(8Z,11Z,14Z,17Z))', 'msm': '0.7018402', 'mz': 818.6034117749999, 'offSample': 'false', 'rawOffSampleProb': '0.000002447339511491009', 'rhoChaos': '0.9988206434569299', 'rhoSpatial': '0.74714 ...

# %%
# import helpers for creating annotation
from msi_autoencoder_wrapper.models.datasets.class_assignment import (
    build_class_mapping, molecule_key,
)

# create annotation
##  here we iterate through all filter we have so it contains 
molecule_mapping = build_class_mapping(
    molecule_key(item) for item in wrapper.active_context.annotation_reader.get_annotations()
)

## Here we iterate through names to obtain only names (for print purpose only)
molecule_labels = [None] * len(molecule_mapping)
for label, class_index in molecule_mapping.items():
    molecule_labels[class_index] = label

print('Molecular classes:', len(molecule_mapping))
molecule_mapping
# Out:
# Molecular classes: 22
# {'C14H19N3O5|M[M]+': 0,
#  'C15H32O6|M+Na': 1,
#  'C16H20O6|M+H': 2,
#  'C17H18F3NO|M[M]+': 3,
#  'C17H23NO2|M[M]+': 4,
#  'C18H18O3|M+H': 5,
#  'C19H20O3|M+H': 6,
#  'C20H18O14|M+H': 7,
#  'C23H37NO5S|M+NH4': 8,
#  'C24H50NO7P|M+Na': 9,
#  'C25H49NO4|M+H': 10,
#  'C26H42O4|M+K': 11,
#  'C26H48NO7P|M+H': 12,
#  'C27H20O12|M+Na': 13,
#  'C27H45NO4|M+H': 14,
#  'C30H46O7|M[M]+': 15,
#  'C41H74NO8P|M+H': 16,
#  'C42H76NO8P|M+H': 17,
#  'C43H78NO7P|M+H': 18,
#  'C45H74NO8P|M+H': 19,
#  'C46H86NO7P|M+Na': 20,
#  'C48H84NO7P|M+H': 21}

# %% [markdown]
# Model creation

# %%
latent_dim = 128
model_name = 'kidney-annotation-mse-autoencoder'

wrapper.models_manager.set_model_type('autoencoder', model_name)
wrapper.models_manager.set_model_preset(
    'GradualReduction', latent_dim=latent_dim, projection_dim=64
)
wrapper.models_manager.set_head(
    head_id='molecule_primary',
    target_field='molecule',
    strategy='LinearClassificationHead',
    latent_dim=latent_dim,
    output_dim=len(molecule_mapping), # 22 classes for this example
    hidden_dim=64,
    dropout=0.1,
)
wrapper.models_manager.set_dataset(
    'PixelDataset',
    normalization='tic',
    target_specs={
        'molecule': {
            'type': 'multi_label',
            'class_mapping': molecule_mapping,
        },
    },
)
model = wrapper.models_manager.compile_model(run_validation_pass=True)
model
# Out:
# 2026-07-29 23:53:32,520 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:329 | Initiating model preset configuration layout lookup for family: autoencoder, preset: GradualReduction
# 2026-07-29 23:53:32,521 | INFO     | msi_autoencoder_wrapper.models.architectures.types.autoencoders.presets.gradual_reduction_preset:46 | Preset builder initiating hyperparameter execution pipeline analysis.
# 2026-07-29 23:53:49,303 | INFO     | msi_autoencoder_wrapper.models.architectures.utils.presets_utils:88 | Statistical reflection completed. Suggested baseline kernel width: 3 bins
# 2026-07-29 23:53:49,304 | INFO     | msi_autoencoder_wrapper.models.architectures.types.autoencoders.presets.gradual_reduction_preset:86 | Gradual Reduction layout synthesis finalized. Mapped feature width roadmaps: [110007, 36669, 9166, 2291, 763, 381]
# 2026-07-29 23:53:49,305 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:365 | Preset parsing operational trace: Automatically routing component category 'encoder' using strategy 'CNNEncoder'.
# 2026-07-29 23:53:49,305 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:365 | Preset parsing operational trace: Automatically routing component category 'decoder' using strategy 'CNNDecoder'.
# 2026-07-29 23:53:49,306 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:365 | Preset parsing operational trace: Automatically routing component category 'projector' using strategy 'LinearProjector'.
# 2026-07-29 23:53:49,307 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:377 | Model preset layout 'GradualReduction' successfully staged into the configurations buffer. Graph compilation deferred for user modifications.
# 2026-07-29 23:53:49,308 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:296 | Configured head 'molecule_primary' for target 'molecule'.
# 2026-07-29 23:53:49,311 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:401 | Initializing PyTorch network compilation sequences from buffered blueprints.
# 2026-07-29 23:53:49,312 | INFO     | msi_autoencoder_wrapper.models.architectures.architectures_manager:125 | Initializing multi-component sub-graph resolution phase for model family: autoencoder
# 2026-07-29 23:53:49,313 | INFO     | msi_autoencoder_wrapper.models.architectures.architectures_manager:144 | Instantiating standard component sub-module: Category='encoder' using Strategy='CNNEncoder'.
# 2026-07-29 23:53:49,370 | INFO     | msi_autoencoder_wrapper.models.architectures.architectures_manager:144 | Instantiating standard component sub-module: Category='decoder' using Strategy='CNNDecoder'.
# 2026-07-29 23:53:49,379 | INFO     | msi_autoencoder_wrapper.models.architectures.architectures_manager:144 | Instantiating standard component sub-module: Category='projector' using Strategy='LinearProjector'.
# 2026-07-29 23:53:49,382 | INFO     | msi_autoencoder_wrapper.models.architectures.architectures_manager:155 | Nested layout schema detected for category: 'heads'. Traversing sub-components branch...
# 2026-07-29 23:53:49,383 | INFO     | msi_autoencoder_wrapper.models.architectures.architectures_manager:169 | Instantiating nested sub-module: Collection='heads', Key='molecule_primary' using Strategy='LinearClassificationHead'.
# 2026-07-29 23:53:49,384 | INFO     | msi_autoencoder_wrapper.models.architectures.architectures_manager:184 | Injecting resolved computational components ledger dictionary into the master architecture graph.
# 2026-07-29 23:53:49,385 | INFO     | msi_autoencoder_wrapper.models.architectures.types.autoencoders.base_architecture_autoencoder:49 | MSIBaseAutoencoderArchitecture master network graph successfully assembled.
# 2026-07-29 23:53:49,386 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:461 | Compiling and binding dataset target: PixelDataset to the active model graph.
# 2026-07-29 23:53:49,386 | INFO     | msi_autoencoder_wrapper.models.datasets.dataset_manager:62 | Resolving and instantiating dataset strategy 'PixelDataset' from global registry.
# 2026-07-29 23:53:49,990 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:540 | MSI Network master graph successfully compiled and migrated onto execution hardware: cuda
# 2026-07-29 23:53:49,993 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 21 implementation module(s) in package 'msi_autoencoder_wrapper.models.architectures'.
# 2026-07-29 23:53:49,995 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.model_runtime_proxy:189 | Bound loaded model functionality to image context 'kidney-pilot-v2'.
# 2026-07-29 23:53:49,996 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.model_runtime_proxy:107 | Attached loaded model 'kidney-annotation-mse-autoencoder' as family 'autoencoder'.
# MSIBaseAutoencoderArchitecture(
#   (encoder): CNNEncoder(
#     (conv_blocks): ModuleList(
#       (0): Sequential(
#         (0): Conv1d(1, 64, kernel_size=(3,), stride=(3,))
#         (1): LayerNorm((36669,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (1): Sequential(
#         (0): Conv1d(64, 32, kernel_size=(7,), stride=(4,))
#         (1): LayerNorm((9166,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (2): Sequential(
#         (0): Conv1d(32, 16, kernel_size=(5,), stride=(4,))
#         (1): LayerNorm((2291,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (3): Sequential(
#         (0): Conv1d(16, 8, kernel_size=(3,), stride=(3,))
#         (1): LayerNorm((763,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (4): Sequential(
#         (0): Conv1d(8, 8, kernel_size=(3,), stride=(2,))
#         (1): LayerNorm((381,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#     )
#     (bottleneck_layer): Sequential(
#       (0): Flatten(start_dim=1, end_dim=-1)
#       (1): Linear(in_features=3048, out_features=128, bias=True)
#       (2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (decoder): CNNDecoder(
#     (initial_expansion): Sequential(
#       (0): Linear(in_features=128, out_features=3048, bias=True)
#       (1): LayerNorm((3048,), eps=1e-05, elementwise_affine=True)
#       (2): ReshapeLayer()
#     )
#     (deconv_blocks): ModuleList(
#       (0): Sequential(
#         (0): ConvTranspose1d(8, 8, kernel_size=(3,), stride=(2,))
#         (1): LayerNorm((763,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (1): Sequential(
#         (0): ConvTranspose1d(8, 16, kernel_size=(3,), stride=(3,), output_padding=(2,))
#         (1): LayerNorm((2291,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (2): Sequential(
#         (0): ConvTranspose1d(16, 32, kernel_size=(5,), stride=(4,), output_padding=(1,))
#         (1): LayerNorm((9166,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (3): Sequential(
#         (0): ConvTranspose1d(32, 64, kernel_size=(7,), stride=(4,), output_padding=(2,))
#         (1): LayerNorm((36669,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (4): Sequential(
#         (0): ConvTranspose1d(64, 1, kernel_size=(3,), stride=(3,))
#         (1): Identity()
#         (2): Identity()
#       )
#     )
#   )
#   (projector): LinearProjector(
#     (projection_network): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (2): ReLU()
#       (3): Linear(in_features=128, out_features=64, bias=True)
#     )
#   )
#   (heads): ModuleDict(
#     (molecule_primary): LinearClassificationHead(
#       (network): Sequential(
#         (0): Linear(in_features=128, out_features=64, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=64, out_features=22, bias=True)
#       )
#     )
#   )
# )

# %%
# 

## import 
import torch 

## example run to see model dimensions
dataset = wrapper.active_dataset
spectrum_id, spectrum, targets, target_masks = dataset[449]
with torch.no_grad():
    outputs = model(spectrum.unsqueeze(0).to(wrapper.device))
print('Dataset size:', len(dataset))
print('Spectrum shape:', tuple(spectrum.shape))
print('Positive molecule targets:', int(targets['molecule'].sum().item()))
print('Latent shape:', tuple(outputs['latent_space'].shape))
print('Molecule logits shape:', tuple(outputs['head_molecule_primary'].shape))

## check how many pixel are without molecular label
#TODO - during merge tehre should be opotion for "how many unlabbelled molecules" - be default we should take only annoated pixel (write new imzML and ibd file so it would be clear), for background information we should include unannotataed data. it is imprtant as it is says which label are unresgisterd and how to encode "noise" to retrive similiar values.  
target_counts = torch.stack([dataset[index][2]['molecule'] for index in range(len(dataset))]).sum(0)
print('Pixels without a molecular label:', sum(dataset[index][2]['molecule'].sum() == 0 for index in range(len(dataset))))
print('Positive pixels per class:')
for label, count in zip(molecule_labels, target_counts.tolist()):
    print(f'{count:6.0f}  {label}')
# Out:
# Dataset size: 5959
# Spectrum shape: (110007,)
# Positive molecule targets: 22
# Latent shape: (1, 128)
# Molecule logits shape: (1, 22)
# Pixels without a molecular label: tensor(2426)
# Positive pixels per class:
#   3533  C14H19N3O5|M[M]+
#   3533  C15H32O6|M+Na
#   3533  C16H20O6|M+H
#   3533  C17H18F3NO|M[M]+
#   3533  C17H23NO2|M[M]+
#   3533  C18H18O3|M+H
#   3533  C19H20O3|M+H
#   3533  C20H18O14|M+H
#   3533  C23H37NO5S|M+NH4
#   3533  C24H50NO7P|M+Na
#   3533  C25H49NO4|M+H
#   3533  C26H42O4|M+K
#   3533  C26H48NO7P|M+H
#   3533  C27H20O12|M+Na
#   3532  C27H45NO4|M+H
#   3533  C30H46O7|M[M]+
#   3533  C41H74NO8P|M+H
#   3533  C42H76NO8P|M+H
#   3533  C43H78NO7P|M+H
#   3533  C45H74NO8P|M+H
#   3525  C46H86NO7P|M+Na
#   3525  C48H84NO7P|M+H

# %%
wrapper.models_manager.get_available_criterions()
# Out:
# 2026-07-29 23:54:41,146 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.training_proxy:69 | Ferrying database capabilities ledger for active model family target: autoencoder
#
# ================================================================================
#  Available Contrastive Criterions for 'autoencoder'
# ================================================================================
#
# [Criterion]: 'InfoNCELoss'
#  Description: InfoNCE Contrastive Loss using automated chemical peak profiling noise caches.
#  Parameters (kwargs):
#    - temperature: 0.07
#    - noise_level: 0.05
#    - max_peaks_per_spectrum: 2
#    - peak_sample_size: 1000
#    - peak_sample_seed: 0
#    - max_noise_peaks: 8
# ================================================================================
#
#
# ================================================================================
#  Available Head Criterions for 'autoencoder'
# ================================================================================
#
# [Criterion]: 'MaskedCrossEntropyLoss'
#  Description: Evaluate a named head only where its dataset target is available.
#  Parameters (kwargs):
#    - head_id: Required
#    - target_field: Required
#    - reduction: mean
#
# [Criterion]: 'MultiLabelBCELoss'
#  Description: Compare molecular logits with a multi-hot dataset target.
#
# :param head_id: Model head identifier used in the output mapping.
# :type head_id: str
# :param target_field: Dataset target dictionary key.
# :type target_field: str
# :param reduction: PyTorch BCE reduction mode.
# :type reduction: str
#  Parameters (kwargs):
#    - head_id: Required
#    - target_field: Required
#    - reduction: mean
# ================================================================================
#
#
# ================================================================================
#  Available Reconstruction Criterions for 'autoencoder'
# ================================================================================
#
# [Criterion]: 'MSELoss'
#  Description: Mean Squared Error (MSE) loss strategy evaluating raw profile reconstruction accuracy.
#  Parameters (kwargs):
#    - reduction: mean
#
# [Criterion]: 'MassersteinLoss'
#  Description: Compare spectra by robust optimal transport with an auxiliary sink.
#
# This loss is a differentiable reconstruction adaptation of the Masserstein
# regression described by Ciach et al. (2021), DOI ``10.1002/rcm.8956``.
# The paper augments the mass axis with an auxiliary point :math:`\omega`.
# Signal may be transported to that point for a fixed cost :math:`\kappa`
# instead of being moved an implausibly long distance in the m/z domain.
#
# For autoencoder reconstruction, both the input and prediction may contain
# unmatched signal. The implementation therefore uses the symmetric extension
# with an auxiliary point on both sides. The real-to-real ground cost is the
# m/z distance, transport between a real bin and :math:`\omega` costs
# ``denoising_penalty``, and auxiliary-to-auxiliary transport is free. Thus,
# moving one unit through the auxiliary point costs :math:`2\kappa` and is
# preferred over direct transport only for sufficiently distant signal.
#
# The two spectra are divided by their joint maximum total ion current. This
# preserves their relative mass difference, unlike independent TIC
# normalization. Each measure is then augmented with the other measure's
# total mass, which balances the transport problem while retaining the amount
# of created or destroyed signal. A stabilized Sinkhorn solver computes a
# differentiable transport plan. The optional Sinkhorn divergence subtracts
# self-transport bias introduced by entropy regularization.
#
# A dense Sinkhorn matrix is quadratic in the number of m/z bins and is not
# practical for training on MSI grids. For a regular axis this implementation
# applies the exponentially decaying transport kernel as a one-dimensional
# convolution and evaluates the whole batch together. Terms smaller than
# ``kernel_tolerance`` are omitted. The resulting complexity is
# :math:`O(BNRI)`, where :math:`B` is batch size, :math:`N` is the number of
# bins, :math:`R` is the retained kernel radius, and :math:`I` is the number
# of Sinkhorn iterations. An irregular axis uses a bounded-memory chunked
# fallback with quadratic runtime.
#
# ``axis_step`` must use the same unit as ``denoising_penalty``. When a
# dataset binner exposes ``GetXAxis()``, :meth:`on_phase_start` automatically
# uses that physical m/z grid instead of the fallback uniform axis.
#  Parameters (kwargs):
#    - denoising_penalty: 0.5
#    - entropy_regularization: 0.02
#    - sinkhorn_iterations: 50
#    - axis_step: 1.0
#    - reduction: mean
#    - debias: True
#    - epsilon: 1e-12
#    - kernel_tolerance: 1e-07
#    - chunk_size: 512
#
# [Criterion]: 'SobolevLoss'
#  Description: Weighted RMSE Sobolev loss strategy calculating spectral derivative deviations.
#  Parameters (kwargs):
#    - sobolev_weight: 0.5
#    - eps: 1e-06
# ================================================================================

# %%
training_config = {
    'seed': 1912,
    'checkpoint': {'enabled': True, 'restore_best': True},
    'phases': [
        {
            'phase_name': 'reconstruction_and_molecule_classification',
            'epochs': 10,
            'batch_size': 16,
            'dataloader': {'num_workers': 0, 'pin_memory': wrapper.device == 'cuda'},
            'gradient_clip_norm': 1.0,
            'freeze': [],
            'optimizer': {
                'type': 'AdamW',
                'params': {'lr': 1e-3, 'weight_decay': 1e-4},
            },
            'criterions': {
                'reconstruction': {
                    # 'mse': {'target': 'MSELoss', 'weight': 1.0, 'params': {}}, # to na ten moment pomijamy 
                    'mse': {
                        'target': 'MSELoss',
                        'weight': 1.0
                    },
                },
                'heads': {
                    'molecule_primary': {
                        'molecule_bce': {
                            'target': 'MultiLabelBCELoss',
                            'weight': 0.25,
                            'params': {},
                        },
                    },
                },
            },
        },
    ],
}
training_config
# Out:
# {'seed': 1912,
#  'checkpoint': {'enabled': True, 'restore_best': True},
#  'phases': [{'phase_name': 'reconstruction_and_molecule_classification',
#    'epochs': 10,
#    'batch_size': 16,
#    'dataloader': {'num_workers': 0, 'pin_memory': False},
#    'gradient_clip_norm': 1.0,
#    'freeze': [],
#    'optimizer': {'type': 'AdamW',
#     'params': {'lr': 0.001, 'weight_decay': 0.0001}},
#    'criterions': {'reconstruction': {'mse': {'target': 'MSELoss',
#       'weight': 1.0}},
#     'heads': {'molecule_primary': {'molecule_bce': {'target': 'MultiLabelBCELoss',
#        'weight': 0.25,
#        'params': {}}}}}}]}

# %%
## apply train setup 
resource_report = wrapper.models_manager.estimate_training_resources(
    training_config,
    resource_limits={'ram': 0.65, 'vram': 0.80, 'disk': 1.00},
    auto_adjust_batch_size=True,
)
safe_training_config = resource_report['recommended_training_config']
resource_report
# Out:
# 2026-07-29 23:55:22,195 | INFO     | msi_autoencoder_wrapper.training.resource_estimator:148 | Training resource estimation completed for 1 phase(s).
# Training resource estimate
# - reconstruction_and_molecule_classification: batch 16 -> 16, RAM 8.39 MiB, VRAM 3.33 GiB, fits limits: True
# - disk: 4.30 MiB, fits limit: True
# {'method': 'probe_forward_plus_static_training_state',
#  'safety_factor': 1.25,
#  'available_bytes': {'ram': 2283311104,
#   'vram': 5369757696,
#   'disk': 827904462848},
#  'limit_bytes': {'ram': 1484152217, 'vram': 4295806156, 'disk': 827904462848},
#  'model_bytes': 4225684,
#  'estimated_disk_bytes': 4508308,
#  'disk_fits_limit': True,
#  'phases': [{'phase': 'reconstruction_and_molecule_classification',
#    'configured_batch_size': 16,
#    'recommended_batch_size': 16,
#    'estimated_ram_bytes': 8800560,
#    'estimated_vram_bytes': 3574271060,
#    'fits_limits': True}],
#  'recommended_training_config': {'seed': 1912,
#   'checkpoint': {'enabled': True, 'restore_best': True},
#   'phases': [{'phase_name': 'reconstruction_and_molecule_classification',
#     'epochs': 10,
#     'batch_size': 16,
#     'dataloader': {'num_workers': 0, 'pin_memory': False},
#     'gradient_clip_norm': 1.0,
#     'freeze': [],
#     'optimizer': {'type': 'AdamW',
#      'params': {'lr': 0.001, 'weight_decay': 0.0001}},
#     'criterions': {'reconstruction': {'mse': {'target': 'MSELoss',
#        'weight': 1.0}},
#      'heads': {'molecule_primary': {'molecule_bce': {'target': 'MultiLabelBCELoss',
#         'weight': 0.25,
#         'params': {}}}}}}]},
#  'limitations': ['Reader-native caches and operating-system activity are not measured.',
#   'CUDA allocator fragmentation can increase actual peak VRAM.',
#   'The estimate is not a substitute for monitoring the first training epoch.']}

# %%
history = wrapper.models_manager.fit(safe_training_config)
# Out:
# 2026-07-29 23:55:26,128 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.training_proxy:133 | Instantiating execution training manager instance.
# 2026-07-29 23:55:26,129 | INFO     | msi_autoencoder_wrapper.training.training_manager:78 | Training lifecycle orchestration triggered. Dispatching execution parameters for model family: autoencoder
# 2026-07-29 23:55:26,130 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:544 | Pre-flight validation successful. Training environment maps verified.
# 2026-07-29 23:55:26,132 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:63 | Enforcing global deterministic execution pipeline using seed token: 1912
# 2026-07-29 23:55:26,155 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:92 | Initiating sequential training loop phase: reconstruction_and_molecule_classification (1/1)
# 2026-07-29 23:55:26,157 | INFO     | msi_autoencoder_wrapper.training.criterions.criterions_manager:298 | Assembling 'reconstruction' objective 'mse' with weight 1.0.
# 2026-07-29 23:55:26,158 | INFO     | msi_autoencoder_wrapper.training.criterions.criterions_manager:298 | Assembling 'head' objective 'molecule_primary__molecule_bce' with weight 0.25.
# 2026-07-29 23:55:30,114 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 1/10 | Batch 1/373 | Loss: 2.8225 | Elapsed: 1.8 s | ETA: 10:54
# 2026-07-29 23:55:41,051 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 1/10 | Batch 75/373 | Loss: 0.0009 | Elapsed: 12.7 s | ETA: 00:50
# 2026-07-29 23:55:53,514 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 1/10 | Batch 149/373 | Loss: 0.0003 | Elapsed: 25.2 s | ETA: 00:37
# 2026-07-29 23:56:05,237 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 1/10 | Batch 223/373 | Loss: 0.0002 | Elapsed: 36.9 s | ETA: 00:24
# 2026-07-29 23:56:16,137 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 1/10 | Batch 297/373 | Loss: 0.0002 | Elapsed: 47.8 s | ETA: 00:12
# 2026-07-29 23:56:29,140 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 1/10 | Batch 371/373 | Loss: 0.0001 | Elapsed: 60.8 s | ETA: 00:00
# 2026-07-29 23:56:29,388 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 1/10 | Batch 373/373 | Loss: 0.0001 | Elapsed: 61.0 s | ETA: 00:00
# 2026-07-29 23:56:29,391 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-29 23:56:29,394 | INFO     | msi_autoencoder_wrapper.workspace.model_store:84 | Model configuration saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/config.json
# 2026-07-29 23:56:29,460 | INFO     | msi_autoencoder_wrapper.workspace.model_store:157 | Model weights saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/weights.pt
# 2026-07-29 23:56:29,462 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-29 23:56:29,463 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.io_models_proxy:194 | Active model 'kidney-annotation-mse-autoencoder' saved under context 'kidney-pilot-v2'.
# 2026-07-29 23:56:29,463 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:298 | Saved new best checkpoint for phase 'reconstruction_and_molecule_classification' at epoch 1.
# 2026-07-29 23:56:29,464 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:304 | === Epoch Summary [reconstruction_and_molecule_classification] 001/010 | Avg Loss: 0.0348 | Patience: 0/10 | Duration: 61.04 s ===
# 2026-07-29 23:56:29,630 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 2/10 | Batch 1/373 | Loss: 0.0001 | Elapsed: 0.2 s | ETA: 01:01
# 2026-07-29 23:56:41,062 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 2/10 | Batch 75/373 | Loss: 0.0001 | Elapsed: 11.6 s | ETA: 00:46
# 2026-07-29 23:56:55,072 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 2/10 | Batch 149/373 | Loss: 0.0006 | Elapsed: 25.6 s | ETA: 00:38
# 2026-07-29 23:57:06,646 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 2/10 | Batch 223/373 | Loss: 0.0002 | Elapsed: 37.2 s | ETA: 00:25
# 2026-07-29 23:57:17,724 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 2/10 | Batch 297/373 | Loss: 0.0003 | Elapsed: 48.3 s | ETA: 00:12
# 2026-07-29 23:57:30,069 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 2/10 | Batch 371/373 | Loss: 0.0006 | Elapsed: 60.6 s | ETA: 00:00
# 2026-07-29 23:57:30,311 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 2/10 | Batch 373/373 | Loss: 0.0243 | Elapsed: 60.8 s | ETA: 00:00
# 2026-07-29 23:57:30,313 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-29 23:57:30,316 | INFO     | msi_autoencoder_wrapper.workspace.model_store:84 | Model configuration saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/config.json
# 2026-07-29 23:57:30,342 | INFO     | msi_autoencoder_wrapper.workspace.model_store:157 | Model weights saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/weights.pt
# 2026-07-29 23:57:30,344 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-29 23:57:30,345 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.io_models_proxy:194 | Active model 'kidney-annotation-mse-autoencoder' saved under context 'kidney-pilot-v2'.
# 2026-07-29 23:57:30,346 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:298 | Saved new best checkpoint for phase 'reconstruction_and_molecule_classification' at epoch 2.
# 2026-07-29 23:57:30,347 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:304 | === Epoch Summary [reconstruction_and_molecule_classification] 002/010 | Avg Loss: 0.0004 | Patience: 0/10 | Duration: 60.85 s ===
# 2026-07-29 23:57:30,571 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 3/10 | Batch 1/373 | Loss: 0.0067 | Elapsed: 0.2 s | ETA: 01:22
# 2026-07-29 23:57:41,768 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 3/10 | Batch 75/373 | Loss: 0.0001 | Elapsed: 11.4 s | ETA: 00:45
# 2026-07-29 23:57:54,339 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 3/10 | Batch 149/373 | Loss: 0.0000 | Elapsed: 24.0 s | ETA: 00:36
# 2026-07-29 23:58:06,797 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 3/10 | Batch 223/373 | Loss: 0.0000 | Elapsed: 36.4 s | ETA: 00:24
# 2026-07-29 23:58:18,591 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 3/10 | Batch 297/373 | Loss: 0.0000 | Elapsed: 48.2 s | ETA: 00:12
# 2026-07-29 23:58:31,836 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 3/10 | Batch 371/373 | Loss: 0.0003 | Elapsed: 61.5 s | ETA: 00:00
# 2026-07-29 23:58:32,079 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 3/10 | Batch 373/373 | Loss: 0.0003 | Elapsed: 61.7 s | ETA: 00:00
# 2026-07-29 23:58:32,081 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-29 23:58:32,085 | INFO     | msi_autoencoder_wrapper.workspace.model_store:84 | Model configuration saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/config.json
# 2026-07-29 23:58:32,109 | INFO     | msi_autoencoder_wrapper.workspace.model_store:157 | Model weights saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/weights.pt
# 2026-07-29 23:58:32,111 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-29 23:58:32,112 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.io_models_proxy:194 | Active model 'kidney-annotation-mse-autoencoder' saved under context 'kidney-pilot-v2'.
# 2026-07-29 23:58:32,112 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:298 | Saved new best checkpoint for phase 'reconstruction_and_molecule_classification' at epoch 3.
# 2026-07-29 23:58:32,113 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:304 | === Epoch Summary [reconstruction_and_molecule_classification] 003/010 | Avg Loss: 0.0003 | Patience: 0/10 | Duration: 61.73 s ===
# 2026-07-29 23:58:32,282 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 4/10 | Batch 1/373 | Loss: 0.0002 | Elapsed: 0.2 s | ETA: 01:02
# 2026-07-29 23:58:44,248 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 4/10 | Batch 75/373 | Loss: 0.0002 | Elapsed: 12.1 s | ETA: 00:48
# 2026-07-29 23:58:54,914 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 4/10 | Batch 149/373 | Loss: 0.0000 | Elapsed: 22.8 s | ETA: 00:34
# 2026-07-29 23:59:09,945 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 4/10 | Batch 223/373 | Loss: 0.0006 | Elapsed: 37.8 s | ETA: 00:25
# 2026-07-29 23:59:24,141 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 4/10 | Batch 297/373 | Loss: 0.0000 | Elapsed: 52.0 s | ETA: 00:13
# 2026-07-29 23:59:36,054 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 4/10 | Batch 371/373 | Loss: 0.0028 | Elapsed: 63.9 s | ETA: 00:00
# 2026-07-29 23:59:36,321 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 4/10 | Batch 373/373 | Loss: 0.0001 | Elapsed: 64.2 s | ETA: 00:00
# 2026-07-29 23:59:36,323 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-29 23:59:36,331 | INFO     | msi_autoencoder_wrapper.workspace.model_store:84 | Model configuration saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/config.json
# 2026-07-29 23:59:36,357 | INFO     | msi_autoencoder_wrapper.workspace.model_store:157 | Model weights saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/weights.pt
# 2026-07-29 23:59:36,359 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-29 23:59:36,361 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.io_models_proxy:194 | Active model 'kidney-annotation-mse-autoencoder' saved under context 'kidney-pilot-v2'.
# 2026-07-29 23:59:36,361 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:298 | Saved new best checkpoint for phase 'reconstruction_and_molecule_classification' at epoch 4.
# 2026-07-29 23:59:36,362 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:304 | === Epoch Summary [reconstruction_and_molecule_classification] 004/010 | Avg Loss: 0.0002 | Patience: 0/10 | Duration: 64.21 s ===
# 2026-07-29 23:59:36,571 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 5/10 | Batch 1/373 | Loss: 0.0000 | Elapsed: 0.2 s | ETA: 01:17
# 2026-07-29 23:59:47,577 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 5/10 | Batch 75/373 | Loss: 0.0000 | Elapsed: 11.2 s | ETA: 00:44
# 2026-07-30 00:00:03,092 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 5/10 | Batch 149/373 | Loss: 0.0000 | Elapsed: 26.7 s | ETA: 00:40
# 2026-07-30 00:00:15,538 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 5/10 | Batch 223/373 | Loss: 0.0000 | Elapsed: 39.2 s | ETA: 00:26
# 2026-07-30 00:00:27,015 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 5/10 | Batch 297/373 | Loss: 0.0000 | Elapsed: 50.7 s | ETA: 00:12
# 2026-07-30 00:00:39,566 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 5/10 | Batch 371/373 | Loss: 0.0000 | Elapsed: 63.2 s | ETA: 00:00
# 2026-07-30 00:00:39,930 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 5/10 | Batch 373/373 | Loss: 0.0000 | Elapsed: 63.6 s | ETA: 00:00
# 2026-07-30 00:00:39,933 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-30 00:00:39,936 | INFO     | msi_autoencoder_wrapper.workspace.model_store:84 | Model configuration saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/config.json
# 2026-07-30 00:00:39,961 | INFO     | msi_autoencoder_wrapper.workspace.model_store:157 | Model weights saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/weights.pt
# 2026-07-30 00:00:39,963 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-30 00:00:39,964 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.io_models_proxy:194 | Active model 'kidney-annotation-mse-autoencoder' saved under context 'kidney-pilot-v2'.
# 2026-07-30 00:00:39,965 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:298 | Saved new best checkpoint for phase 'reconstruction_and_molecule_classification' at epoch 5.
# 2026-07-30 00:00:39,966 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:304 | === Epoch Summary [reconstruction_and_molecule_classification] 005/010 | Avg Loss: 0.0001 | Patience: 0/10 | Duration: 63.57 s ===
# 2026-07-30 00:00:40,141 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 6/10 | Batch 1/373 | Loss: 0.0000 | Elapsed: 0.2 s | ETA: 01:04
# 2026-07-30 00:00:52,092 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 6/10 | Batch 75/373 | Loss: 0.0001 | Elapsed: 12.1 s | ETA: 00:48
# 2026-07-30 00:01:04,992 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 6/10 | Batch 149/373 | Loss: 0.0000 | Elapsed: 25.0 s | ETA: 00:37
# 2026-07-30 00:01:16,827 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 6/10 | Batch 223/373 | Loss: 0.0000 | Elapsed: 36.9 s | ETA: 00:24
# 2026-07-30 00:01:27,071 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 6/10 | Batch 297/373 | Loss: 0.0000 | Elapsed: 47.1 s | ETA: 00:12
# 2026-07-30 00:01:38,943 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 6/10 | Batch 371/373 | Loss: 0.0000 | Elapsed: 59.0 s | ETA: 00:00
# 2026-07-30 00:01:39,189 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 6/10 | Batch 373/373 | Loss: 0.0000 | Elapsed: 59.2 s | ETA: 00:00
# 2026-07-30 00:01:39,193 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-30 00:01:39,198 | INFO     | msi_autoencoder_wrapper.workspace.model_store:84 | Model configuration saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/config.json
# 2026-07-30 00:01:39,219 | INFO     | msi_autoencoder_wrapper.workspace.model_store:157 | Model weights saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/weights.pt
# 2026-07-30 00:01:39,221 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-30 00:01:39,222 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.io_models_proxy:194 | Active model 'kidney-annotation-mse-autoencoder' saved under context 'kidney-pilot-v2'.
# 2026-07-30 00:01:39,223 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:298 | Saved new best checkpoint for phase 'reconstruction_and_molecule_classification' at epoch 6.
# 2026-07-30 00:01:39,225 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:304 | === Epoch Summary [reconstruction_and_molecule_classification] 006/010 | Avg Loss: 0.0001 | Patience: 0/10 | Duration: 59.22 s ===
# 2026-07-30 00:01:39,398 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 7/10 | Batch 1/373 | Loss: 0.0000 | Elapsed: 0.2 s | ETA: 01:04
# 2026-07-30 00:01:50,209 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 7/10 | Batch 75/373 | Loss: 0.0000 | Elapsed: 11.0 s | ETA: 00:43
# 2026-07-30 00:02:02,194 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 7/10 | Batch 149/373 | Loss: 0.0001 | Elapsed: 23.0 s | ETA: 00:34
# 2026-07-30 00:02:14,443 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 7/10 | Batch 223/373 | Loss: 0.0000 | Elapsed: 35.2 s | ETA: 00:23
# 2026-07-30 00:02:25,189 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 7/10 | Batch 297/373 | Loss: 0.0000 | Elapsed: 46.0 s | ETA: 00:11
# 2026-07-30 00:02:36,986 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 7/10 | Batch 371/373 | Loss: 0.0000 | Elapsed: 57.8 s | ETA: 00:00
# 2026-07-30 00:02:37,230 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 7/10 | Batch 373/373 | Loss: 0.0000 | Elapsed: 58.0 s | ETA: 00:00
# 2026-07-30 00:02:37,232 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-30 00:02:37,237 | INFO     | msi_autoencoder_wrapper.workspace.model_store:84 | Model configuration saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/config.json
# 2026-07-30 00:02:37,255 | INFO     | msi_autoencoder_wrapper.workspace.model_store:157 | Model weights saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/weights.pt
# 2026-07-30 00:02:37,258 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-30 00:02:37,259 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.io_models_proxy:194 | Active model 'kidney-annotation-mse-autoencoder' saved under context 'kidney-pilot-v2'.
# 2026-07-30 00:02:37,260 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:298 | Saved new best checkpoint for phase 'reconstruction_and_molecule_classification' at epoch 7.
# 2026-07-30 00:02:37,260 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:304 | === Epoch Summary [reconstruction_and_molecule_classification] 007/010 | Avg Loss: 0.0001 | Patience: 0/10 | Duration: 58.01 s ===
# 2026-07-30 00:02:37,428 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 8/10 | Batch 1/373 | Loss: 0.0000 | Elapsed: 0.2 s | ETA: 01:01
# 2026-07-30 00:02:49,316 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 8/10 | Batch 75/373 | Loss: 0.0000 | Elapsed: 12.1 s | ETA: 00:47
# 2026-07-30 00:03:00,333 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 8/10 | Batch 149/373 | Loss: 0.0000 | Elapsed: 23.1 s | ETA: 00:34
# 2026-07-30 00:03:12,134 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 8/10 | Batch 223/373 | Loss: 0.0000 | Elapsed: 34.9 s | ETA: 00:23
# 2026-07-30 00:03:22,800 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 8/10 | Batch 297/373 | Loss: 0.0000 | Elapsed: 45.5 s | ETA: 00:11
# 2026-07-30 00:03:34,822 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 8/10 | Batch 371/373 | Loss: 0.0000 | Elapsed: 57.6 s | ETA: 00:00
# 2026-07-30 00:03:35,065 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 8/10 | Batch 373/373 | Loss: 0.0000 | Elapsed: 57.8 s | ETA: 00:00
# 2026-07-30 00:03:35,067 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-30 00:03:35,071 | INFO     | msi_autoencoder_wrapper.workspace.model_store:84 | Model configuration saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/config.json
# 2026-07-30 00:03:35,090 | INFO     | msi_autoencoder_wrapper.workspace.model_store:157 | Model weights saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/weights.pt
# 2026-07-30 00:03:35,092 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-30 00:03:35,093 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.io_models_proxy:194 | Active model 'kidney-annotation-mse-autoencoder' saved under context 'kidney-pilot-v2'.
# 2026-07-30 00:03:35,094 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:298 | Saved new best checkpoint for phase 'reconstruction_and_molecule_classification' at epoch 8.
# 2026-07-30 00:03:35,094 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:304 | === Epoch Summary [reconstruction_and_molecule_classification] 008/010 | Avg Loss: 0.0001 | Patience: 0/10 | Duration: 57.80 s ===
# 2026-07-30 00:03:35,306 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 9/10 | Batch 1/373 | Loss: 0.0000 | Elapsed: 0.2 s | ETA: 01:18
# 2026-07-30 00:03:47,467 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 9/10 | Batch 75/373 | Loss: 0.0000 | Elapsed: 12.4 s | ETA: 00:49
# 2026-07-30 00:03:58,270 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 9/10 | Batch 149/373 | Loss: 0.0000 | Elapsed: 23.2 s | ETA: 00:34
# 2026-07-30 00:04:10,284 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 9/10 | Batch 223/373 | Loss: 0.0001 | Elapsed: 35.2 s | ETA: 00:23
# 2026-07-30 00:04:22,998 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 9/10 | Batch 297/373 | Loss: 0.0000 | Elapsed: 47.9 s | ETA: 00:12
# 2026-07-30 00:04:34,125 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 9/10 | Batch 371/373 | Loss: 0.0000 | Elapsed: 59.0 s | ETA: 00:00
# 2026-07-30 00:04:34,361 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 9/10 | Batch 373/373 | Loss: 0.0000 | Elapsed: 59.3 s | ETA: 00:00
# 2026-07-30 00:04:34,363 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-30 00:04:34,367 | INFO     | msi_autoencoder_wrapper.workspace.model_store:84 | Model configuration saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/config.json
# 2026-07-30 00:04:34,384 | INFO     | msi_autoencoder_wrapper.workspace.model_store:157 | Model weights saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/weights.pt
# 2026-07-30 00:04:34,386 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-30 00:04:34,387 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.io_models_proxy:194 | Active model 'kidney-annotation-mse-autoencoder' saved under context 'kidney-pilot-v2'.
# 2026-07-30 00:04:34,387 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:298 | Saved new best checkpoint for phase 'reconstruction_and_molecule_classification' at epoch 9.
# 2026-07-30 00:04:34,388 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:304 | === Epoch Summary [reconstruction_and_molecule_classification] 009/010 | Avg Loss: 0.0001 | Patience: 0/10 | Duration: 59.27 s ===
# 2026-07-30 00:04:34,549 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 10/10 | Batch 1/373 | Loss: 0.0000 | Elapsed: 0.2 s | ETA: 00:59
# 2026-07-30 00:04:46,114 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 10/10 | Batch 75/373 | Loss: 0.0000 | Elapsed: 11.7 s | ETA: 00:46
# 2026-07-30 00:04:56,476 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 10/10 | Batch 149/373 | Loss: 0.0000 | Elapsed: 22.1 s | ETA: 00:33
# 2026-07-30 00:05:10,247 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 10/10 | Batch 223/373 | Loss: 0.0000 | Elapsed: 35.9 s | ETA: 00:24
# 2026-07-30 00:05:22,517 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 10/10 | Batch 297/373 | Loss: 0.0000 | Elapsed: 48.1 s | ETA: 00:12
# 2026-07-30 00:05:32,961 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 10/10 | Batch 371/373 | Loss: 0.0000 | Elapsed: 58.6 s | ETA: 00:00
# 2026-07-30 00:05:33,201 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:248 | [reconstruction_and_molecule_classification] Epoch 10/10 | Batch 373/373 | Loss: 0.0000 | Elapsed: 58.8 s | ETA: 00:00
# 2026-07-30 00:05:33,203 | INFO     | msi_autoencoder_wrapper.workspace.model_store:210 | Training history saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/config/history.json
# 2026-07-30 00:05:33,204 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:304 | === Epoch Summary [reconstruction_and_molecule_classification] 010/010 | Avg Loss: 0.0001 | Patience: 1/10 | Duration: 58.81 s ===
# 2026-07-30 00:05:33,224 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:325 | Restored the best checkpoint after phase 'reconstruction_and_molecule_classification'.
# 2026-07-30 00:05:33,225 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:330 | All configured sequential multi-phase training loops successfully completed.

# %%
# TODO - plot history 
history
# Out:
# [{'phase': 'reconstruction_and_molecule_classification',
#   'metrics': {'epoch': 1,
#    'duration': 61.035380840301514,
#    'mse': 0.025474590512522998,
#    'molecule_primary__molecule_bce': 0.0371913411595427,
#    'total_loss': 0.034772426002268306,
#    'is_best': True,
#    'best_loss': 0.034772426002268306}},
#  {'phase': 'reconstruction_and_molecule_classification',
#   'metrics': {'epoch': 2,
#    'duration': 60.84721755981445,
#    'mse': 0.00013004547560591584,
#    'molecule_primary__molecule_bce': 0.0009745850929500776,
#    'total_loss': 0.0003736917528316183,
#    'is_best': True,
#    'best_loss': 0.0003736917528316183}},
#  {'phase': 'reconstruction_and_molecule_classification',
#   'metrics': {'epoch': 3,
#    'duration': 61.732335329055786,
#    'mse': 0.000101078319480121,
#    'molecule_primary__molecule_bce': 0.0006080646807698765,
#    'total_loss': 0.00025309448923430144,
#    'is_best': True,
#    'best_loss': 0.00025309448923430144}},
#  {'phase': 'reconstruction_and_molecule_classification',
#   'metrics': {'epoch': 4,
#    'duration': 64.20750761032104,
#    'mse': 8.710490699780072e-05,
#    'molecule_primary__molecule_bce': 0.00042549598966581286,
#    'total_loss': 0.00019347890471649177,
#    'is_best': True,
#    'best_loss': 0.00019347890471649177}},
#  {'phase': 'reconstruction_and_molecule_classification',
#   'metrics': {'epoch': 5,
#    'duration': 63.56872606277466,
#    'mse': 4.590776981161683e-05,
#    'molecule_primary__molecule_bce': 0.0003499963485749037,
#    'total_loss': 0.00013340685757858207,
#    'is_best': True,
#    'best_loss': 0.00013340685757858207}},
#  {'phase': 'reconstruction_and_molecule_classification',
#   'metrics': {'epoch': 6,
#    'duration': 59.22358179092407,
#    'mse': 3.5961023585594805e-05,
#    'molecule_primary__molecule_bce': 0.00034845858583710057,
#    'total_loss': 0.00012307567007199629,
#    'is_best': True,
#    'best_loss': 0.00012307567007199629}},
#  {'phase': 'reconstruction_and_molecule_classification',
#   'metrics': {'epoch': 7,
#    'duration': 58.00511312484741,
#    'mse': 1.973493099578005e-05,
#    'molecule_primary__molecule_bce': 0.00027672281087881215,
#    'total_loss': 8.891563411440616e-05,
#    'is_best': True,
#    'best_loss': 8.891563411440616e-05}},
#  {'phase': 'reconstruction_and_molecule_classification',
#   'metrics': {'epoch': 8,
#    'duration': 57.804375410079956,
#    'mse': 1.2051644987807096e-05,
#    'molecule_primary__molecule_bce': 0.00029218837041681807,
#    'total_loss': 8.509873738244913e-05,
#    'is_best': True,
#    'best_loss': 8.509873738244913e-05}},
#  {'phase': 'reconstruction_and_molecule_classification',
#   'metrics': {'epoch': 9,
#    'duration': 59.266114234924316,
#    'mse': 1.0153105991025097e-05,
#    'molecule_primary__molecule_bce': 0.00023657264851661527,
#    'total_loss': 6.92962678931386e-05,
#    'is_best': True,
#    'best_loss': 6.92962678931386e-05}},
#  {'phase': 'reconstruction_and_molecule_classification',
#   'metrics': {'epoch': 10,
#    'duration': 58.81361532211304,
#    'mse': 3.0655277244943194e-06,
#    'molecule_primary__molecule_bce': 0.000328500095876417,
#    'total_loss': 8.519055167144887e-05,
#    'is_best': False,
#    'best_loss': 6.92962678931386e-05}}]

# %% [markdown]
# Saving results

# %%
latent_path = wrapper.active_context.save_latent(
    loader_config={'batch_size': 64, 'num_workers': 0, 'pin_memory': wrapper.device == 'cuda'},
    activate=False,
)
print('Latent dataset:', latent_path)
# Out:
# 2026-07-30 00:05:33,369 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.autoencoder_context_manager:165 | Initiating sequential image feature mapping over active data stream channels.
# 2026-07-30 00:05:59,258 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.autoencoder_context_manager:171 | Sequential structural image data translation complete.
# 2026-07-30 00:05:59,900 | INFO     | msi_autoencoder_wrapper.latent.imzml_store:94 | Latent imzML/ibd pair saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/latent/kidney-pilot-v2.latent.imzML
# Latent dataset: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-mse-autoencoder/latent/kidney-pilot-v2.latent.imzML

# %%
latents = wrapper.models_manager.autoencoder.transform(
    {'batch_size': 64, 'num_workers': 0, 'pin_memory': wrapper.device == 'cuda'}
)
with torch.no_grad():
    logits = model.heads['molecule_primary'](torch.from_numpy(latents).float().to(wrapper.device))
    probabilities = torch.sigmoid(logits).cpu().numpy()
print('Latents:', latents.shape)
print('Molecule probabilities:', probabilities.shape)
print('Finite:', np.isfinite(latents).all() and np.isfinite(probabilities).all())
# Out:
# 2026-07-30 00:05:59,956 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.autoencoder_context_manager:165 | Initiating sequential image feature mapping over active data stream channels.
# 2026-07-30 00:06:27,220 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.autoencoder_context_manager:171 | Sequential structural image data translation complete.
# Latents: (5959, 128)
# Molecule probabilities: (5959, 22)
# Finite: True

# %% [markdown]
# Calculating predictions

# %%
spectrum_id = 449
top_indices = np.argsort(probabilities[spectrum_id])[::-1][:5]
predictions = [
    {
        'molecule': molecule_labels[index],
        'probability': float(probabilities[spectrum_id, index]),
        'target': int(dataset[spectrum_id][2]['molecule'][index].item()),
    }
    for index in top_indices
]
predictions
# Out:
# [{'molecule': 'C42H76NO8P|M+H', 'probability': 1.0, 'target': 1},
#  {'molecule': 'C43H78NO7P|M+H', 'probability': 1.0, 'target': 1},
#  {'molecule': 'C41H74NO8P|M+H', 'probability': 1.0, 'target': 1},
#  {'molecule': 'C26H48NO7P|M+H', 'probability': 1.0, 'target': 1},
#  {'molecule': 'C27H20O12|M+Na', 'probability': 1.0, 'target': 1}]

# %% [markdown]
# Load model after training
