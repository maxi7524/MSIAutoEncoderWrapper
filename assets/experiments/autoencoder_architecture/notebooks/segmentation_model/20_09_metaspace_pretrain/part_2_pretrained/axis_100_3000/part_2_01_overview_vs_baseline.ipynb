# %% [markdown]
# # Overview: pretrained variants against the baseline (axis-100-3000)
#
# Does any pretraining variant improve on the real-only baseline on the key reconstruction and head metrics, and which variant is best? Stage shown: **pretrained**, i.e. the model right after the synthetic phases, evaluated on real data without any real-data training (0 real epochs); its head was trained with BCE on complete synthetic targets.

# %% [markdown]
# ## Introduction
#
# The thesis tested in parts 2-6 is that synthetic pretraining improves on the model trained on real data only.
# Every table therefore contains the **real-only baseline** of the same axis (10 real epochs from the same
# initialization) and every comparison is a **paired difference to that baseline**.
#
# The ten pretraining variants differ only in the synthetic data seen before real data (campaign methodology,
# `pretraining_campaign_methodology.md`):
#
# | Variant | Synthetic phases | Construction |
# | --- | --- | --- |
# | P0 single bins | 1 x 10 epochs | ten spectra per axis bin; annotated bins carry their labels, blank bins are known negatives |
# | P1 permutations | 1 x 10 epochs | component-token bag (30 per class and per blank bin) packed into mixed spectra |
# | P2 joint / staged | 1 x 10 / 2 x 10 epochs | P0 and P1 rows shuffled together / P0 first, then P1 |
# | P3 joint / staged | as P2 | P2 + overlap quota (30 extra tokens per class that shares a bin with another class in a training pixel) |
# | P4 joint / staged | as P2 | P2 + rare quota (30 extra tokens per class of the least-annotated quarter) |
# | P5 joint / staged | as P2 | P2 + both quotas |
#
# Every variant yields three models along one lineage (stages): `pretrained`, `frozen_head` and `unfrozen_head`.
# The staged schedules train twice as many synthetic epochs as the joint ones, so schedule and budget are
# confounded (methodology, "Pretraining ablation").
#
# ### Assumptions
#
# * **Pairing.** Repetition $r$ uses one initialization seed for the baseline and for every variant and stage
#   (verified for all 310 models in the campaign-plan verification). The difference between a variant and the
#   baseline of the same repetition removes the initialization effect; the five repetitions are the independent
#   units. Pixels are not independent units and never enter a test as such.
# * **Data.** Every model is evaluated on identical pixels: the same `train`, `test`, `test_extended` and
#   `heldout_image` populations as in part 1, decoded once in the shared cache.
# * **Objectives.** Synthetic phases: Masserstein (1.0) + BCE (0.2) on complete synthetic targets. Real phases
#   (baseline and both fine-tuning stages): Masserstein (1.0) + VPU (0.2) + contractive (2e-3) + InfoNCE (1e-3,
#   multilabel-Jaccard negatives, added by mistake and kept because every model used it).
# * **Threshold metrics.** Precision, recall and F1 use $\hat Y \ge 0.5$, as in part 1. A head whose
#   probabilities never reach 0.5 on real data has F1 = 0 although its ranking may still carry information;
#   average precision is threshold free and is the primary head metric.
# * **Uncertainty.** With five repetitions the Student-t interval has 4 degrees of freedom
#   ($t_{0.975,4} = 2.78$); an interval that excludes zero is a strong statement, one that includes zero is not
#   evidence of no effect.
#
# ### Notation
#
# * $b_r$, $v_r$: value of a metric for the baseline and for a variant (at one stage) in repetition $r$.
# * $s_m \in \{-1, +1\}$: direction of metric $m$; $-1$ for lower-is-better metrics (Masserstein $W_1$,
#   spectral angle, MSE, Hamming loss, window contribution and within-window $W_1$, absolute mass imbalance, ECE,
#   Brier score, true-label rank, false-positive rate and lift, losses), $+1$ otherwise.
# * **Improvement** $\Delta_r = s_m (v_r - b_r)$: positive is always better than the baseline.
#   **Relative improvement** $\Delta_r / |b_r|$.
# * Summary over repetitions: mean $\bar\Delta$, SD $s$, interval $\bar\Delta \pm t_{0.975, n-1}\, s / \sqrt{n}$,
#   and the numbers of repetitions with $\Delta_r > 0$ (`+k`) and $\Delta_r < 0$ (`-m`).
# * Evaluations: `test` (withheld pixels of training images), `test_combined` (test + rare-class extension, the
#   main per-class estimate), `heldout_image` (three images never seen; pooled), `heldout_image_per_image` (mean of
#   the per-image values; pooled held-out values understate the ranking because annotations are incomplete across
#   images, part 1_08).
# * $W_1$: exact one-dimensional Wasserstein-1 distance between TIC-normalized input and reconstruction (m/z
#   units); $u$: canonical latent code (LayerNorm affine removed).

# %% [markdown]
# ## Configuration

# %%
import logging
import os
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display

# Library modules log INFO to stdout; warnings stay visible, progress messages do not.
logging.disable(logging.INFO)
current_path = Path.cwd().resolve()
repository_root = next(path for path in (current_path, *current_path.parents) if (path / "pyproject.toml").is_file())
os.chdir(repository_root)

from msi_autoencoder_wrapper.analysis.autoencoder.experiments import pretraining_campaign as campaign
from msi_autoencoder_wrapper.analysis.autoencoder.experiments.pretraining_campaign_precompute import (
    load_metadata, load_table, run_command,
)
from msi_autoencoder_wrapper.analysis.precompute.notebook_inputs import load_model_catalog, load_visualization_theme
from msi_autoencoder_wrapper.visualization import pretraining as figures

SETTINGS_PATH = Path("assets/experiments/autoencoder_architecture/notebooks/segmentation_model/20_09_metaspace_pretrain/analysis_settings.yaml")
ANALYSIS = "stage_overview"
AXIS = "axis-100-3000"
STAGE = "pretrained"

settings = campaign.load_settings(SETTINGS_PATH)
theme = load_visualization_theme(settings).with_overrides(figure_dpi=100)
catalog = load_model_catalog(settings)
metadata = load_metadata(settings, ANALYSIS, AXIS, STAGE)
pd.set_option("display.precision", 4)
pd.set_option("display.width", 200)
pd.set_option("display.max_columns", 40)
pd.set_option("display.max_rows", 80)


def table(name: str) -> pd.DataFrame:
    """Load one canonical table written for this notebook by the precompute."""
    return load_table(settings, ANALYSIS, name, AXIS, STAGE)


def mean_sd(frame: pd.DataFrame, keys: list, columns: list) -> pd.DataFrame:
    """Mean and SD over repetitions of the given columns (presentation helper)."""
    long = frame.melt(id_vars=keys, value_vars=columns, var_name="quantity", value_name="value")
    return long.groupby([*keys, "quantity"]).value.agg(["mean", "std"]).unstack("quantity")


POPULATION_COLORS = {name: figures.population_color(name, theme) for name in figures.POPULATION_ORDER}
print("Analysis:", ANALYSIS, "| axis:", AXIS, "| stage:", STAGE, "| models:", metadata["models"] if isinstance(metadata["models"], int) else len(metadata["models"]))
print("Cache keys:", metadata["cache_keys"])

BASELINE = "baseline"
VARIANTS = list(settings["variants"])
VARIANT_LABELS = {BASELINE: "real-only baseline", **{name: value["label"] for name, value in settings["variants"].items()}}
## The baseline keeps its catalog colour (the dark theme baseline colour is reserved for reference lines)
BASELINE_COLOR = next(value["visualization"]["color"] for value in settings["models"].values()
                      if value.get("select", {}).get("role") == settings["baseline_role"])
VARIANT_COLORS = {BASELINE: BASELINE_COLOR, **{name: value["color"] for name, value in settings["variants"].items()}}
STAGES = list(settings["stages"])
STAGE_LABELS = {"real_only": "real-only baseline", **{name: value["label"] for name, value in settings["stages"].items()}}
KEY_METRICS = settings["comparison"]["key_metrics"]
AXES = list(settings["axes"])
AXIS_LABELS = {name: value["label"] for name, value in settings["axes"].items()}
SHORT = {"masserstein": "W1", "spectral_angle": "spectral angle", "average_precision": "macro AP",
         "micro_average_precision": "micro AP", "f1": "macro F1 at 0.5"}
EVALUATION_NAMES = {**figures.DISPLAY_NAMES, "heldout_image_per_image": "held-out, per image"}


def key_panels(reconstruction=("test", "heldout_image"), prediction=("test_combined", "heldout_image_per_image")):
    """Forest-plot panels of the key metrics: (title, row selector)."""
    panels = []
    for spec in KEY_METRICS:
        for evaluation in (reconstruction if spec["family"] == "reconstruction" else prediction):
            selector = {"family": spec["family"], "metric": spec["metric"], "evaluation": evaluation,
                        "ranking": spec.get("ranking", "none")}
            panels.append((f"{SHORT.get(spec['metric'], spec['metric'])}, {EVALUATION_NAMES.get(evaluation, evaluation)}", selector))
    return panels


def interval(frame, digits=3):
    """'mean [ci_low, ci_high] (+k/-m)' strings of a summary table."""
    form = "{:." + str(digits) + "g}"
    return (frame["mean"].map(form.format) + " [" + frame.ci_low.map(form.format) + ", "
            + frame.ci_high.map(form.format) + "] (+" + frame.positive.astype(int).astype(str) + "/-"
            + frame.negative.astype(int).astype(str) + ")")

from msi_autoencoder_wrapper.analysis.autoencoder.experiments.pretraining_campaign_comparison import summarize

ORDER = [BASELINE, *VARIANTS]
EVALUATIONS = ['test', 'test_combined', 'heldout_image', 'heldout_image_per_image']

metrics = table('model_metrics')
paired = table('improvements')
improvement_summary = table('improvement_summary')
values = table('value_summary')
print('Best variant on the test pixels:', metadata['best_variant'])
# Out:
# Analysis: stage_overview | axis: axis-100-3000 | stage: pretrained | models: 55
# Cache keys: {'plan': 'f34a92a8f6f7833f', 'populations': '513690bdd78a83ce', 'synthetic_reference': '6ba5bc1e0839ba0e', 'inference': '0243c1efb93b9c4c'}
# Best variant on the test pixels: P1_permutation

# %% [markdown]
# ## Producing the tables this notebook reads
#
# ### Methodology
#
# #### Implementation
#
# `stage_overview` reads, per model, the population means of the per-pixel reconstruction metrics and the
# whole-axis head ranking table (scope `train_supported`, group `all`) written by the `inference` level,
# plus the per-image held-out head metrics. It pairs every variant model with the baseline of the same
# repetition, summarizes the improvements over repetitions and ranks the variants.
#
# The command below is generated by the precompute entry point itself; if a table is missing, `load_table` raises with the same command.

# %%
print(run_command(settings, ANALYSIS))
# Out:
# nohup uv run --extra cu118 python -m msi_autoencoder_wrapper.analysis.precompute --settings /home/max/repositories/MSIAutoEncoderWrapper/assets/experiments/autoencoder_architecture/notebooks/segmentation_model/20_09_metaspace_pretrain/analysis_settings.yaml --analysis stage_overview > /home/max/repositories/MSIAutoEncoderWrapper/assets/experiments/autoencoder_architecture/notebooks/segmentation_model/20_09_metaspace_pretrain/shared_precompute.log 2>&1 &

# %% [markdown]
# ### Remarks

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Absolute results of every variant and of the real-only baseline

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# The paired improvements below answer *whether* a variant differs from the baseline; this section shows *what
# every model reaches*: the absolute value of every key metric for the real-only baseline and for every variant,
# so that a difference can be read against the level at which it happens.

# %% [markdown]
# #### Implementation
#
# `model_metrics` holds one value per model, metric and evaluation population (repetitions of a variant = its five models).

# %% [markdown]
# #### Figure descriptions
#
#         First figure: one panel per key metric and evaluation; x = baseline and variants, violin and points = the five
#         repetitions, bar = mean. Tables: the reconstruction metrics on test and held-out pixels, then the complete
#         prediction metric set (annotation retrieval, training-supported classes) per evaluation population.
#
# Colours: in the figures the baseline is grey (its mean is the dashed line) and every other group is green when its
# mean is better than the baseline mean and red when it is worse. In the tables every cell is mean +/- SD over the
# repetitions; green / red cells are better / worse than the baseline cell of the same column (stronger colour = larger
# difference within the column), the black frame marks the three best rows of the column and the grey bold row is the
# real-only baseline.

# %%
LOWER_IS_BETTER = {'masserstein', 'spectral_angle', 'mse', 'hamming_loss', 'expected_calibration_error', 'brier_score',
                   'within', 'contribution', 'absolute_mass_imbalance', 'bic'}
METRIC_ORDER = ['average_precision', 'micro_average_precision', 'roc_auc', 'micro_roc_auc', 'ap_above_prevalence',
                'precision', 'recall', 'f1', 'micro_precision', 'micro_recall', 'micro_f1', 'micro_prevalence',
                'hamming_loss']
ABS_ORDER = [BASELINE, *VARIANTS]
LABELS_ABS = {**VARIANT_LABELS, **{name: VARIANT_LABELS.get(name, name) for name in ABS_ORDER}}


def better(metric):
    """Direction of a metric: 'lower' or 'higher' is better."""
    return 'lower' if metric in LOWER_IS_BETTER else 'higher'

# %%
metrics_abs = table('model_metrics')

panels = []
for spec in KEY_METRICS:
    evaluations = ['test', 'heldout_image'] if spec['family'] == 'reconstruction' else ['test_combined', 'heldout_image_per_image']
    for evaluation in evaluations:
        panels.append((f"{SHORT[spec['metric']]}, {EVALUATION_NAMES.get(evaluation, evaluation)}",
                       {'family': spec['family'], 'metric': spec['metric'], 'evaluation': evaluation,
                        'ranking': spec.get('ranking', 'none')}, better(spec['metric'])))
figures.metric_panels(metrics_abs, panels=panels, group='variant', order=ABS_ORDER, labels=LABELS_ABS, baseline=BASELINE, columns=4, theme=theme);

# %%
recon = metrics_abs[(metrics_abs.family == 'reconstruction') & metrics_abs.evaluation.isin(['test', 'heldout_image'])]
recon = recon.assign(column=recon.metric + ' | ' + recon.evaluation)
columns = [f'{metric} | {evaluation}' for evaluation in ('test', 'heldout_image') for metric in ('masserstein', 'spectral_angle', 'cosine_similarity', 'mse')]
display(figures.comparison_table(recon, index='variant', columns='column', baseline=BASELINE, order=ABS_ORDER, column_order=columns,
                                 direction={column: better(column.split(' | ')[0]) for column in columns}))
prediction_abs = metrics_abs[(metrics_abs.family == 'prediction') & (metrics_abs.ranking == 'annotation_retrieval')]
for evaluation in ('test_combined', 'heldout_image', 'heldout_image_per_image'):
    rows = prediction_abs[prediction_abs.evaluation == evaluation]
    if rows.empty:
        continue
    print(EVALUATION_NAMES.get(evaluation, evaluation))
    display(figures.comparison_table(rows, index='variant', columns='metric', baseline=BASELINE, order=ABS_ORDER,
                                     column_order=METRIC_ORDER, direction={metric: better(metric) for metric in rows.metric.unique()}))
# Out:
# <style type="text/css">
# #T_6ef7e_row0_col0, #T_6ef7e_row0_col1, #T_6ef7e_row0_col2, #T_6ef7e_row0_col3, #T_6ef7e_row0_col4, #T_6ef7e_row0_col5, #T_6ef7e_row0_col6, #T_6ef7e_row0_col7 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_6ef7e_row1_col0, #T_6ef7e_row1_col3, #T_6ef7e_row1_col4, #T_6ef7e_row1_col7, #T_6ef7e_row4_col5, #T_6ef7e_row4_col6, #T_6ef7e_row6_col1, #T_6ef7e_row6_col2, #T_6ef7e_row6_col5, #T_6ef7e_row6_col6 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_6ef7e_row1_col1 {
#   background-color: rgba(215, 48, 39, 0.49);
#   border: 2px solid black;
# }
# #T_6ef7e_row1_col2, #T_6ef7e_row2_col6 {
#   background-color: rgba(215, 48, 39, 0.56);
#   border: 2px solid black;
# }
# #T_6ef7e_row1_col5, #T_6ef7e_row5_col5, #T_6ef7e_row5_col6, #T_6ef7e_row9_col6 {
#   background-color: rgba(215, 48, 39, 0.72);
#   border: 2px solid black;
# }
# #T_6ef7e_row1_col6, #T_6ef7e_row7_col1, #T_6ef7e_row7_col2, #T_6ef7e_row9_col1, #T_6ef7e_row9_col2, #T_6ef7e_row10_col5, #T_6ef7e_row10_col6 {
#   background-color: rgba(215, 48, 39, 0.73);
# }
# #T_6ef7e_row2_col0 {
#   background-color: rgba(215, 48, 39, 0.45);
#   border: 2px solid black;
# }
# #T_6ef7e_row2_col1 {
#   background-color: rgba(215, 48, 39, 0.59);
#   border: 2px solid black;
# }
# #T_6ef7e_row2_col2 {
#   background-color: rgba(215, 48, 39, 0.58);
#   border: 2px solid black;
# }
# #T_6ef7e_row2_col3, #T_6ef7e_row5_col7, #T_6ef7e_row7_col7 {
#   background-color: rgba(215, 48, 39, 0.16);
#   border: 2px solid black;
# }
# #T_6ef7e_row2_col4 {
#   background-color: rgba(215, 48, 39, 0.39);
#   border: 2px solid black;
# }
# #T_6ef7e_row2_col5, #T_6ef7e_row9_col0 {
#   background-color: rgba(215, 48, 39, 0.57);
#   border: 2px solid black;
# }
# #T_6ef7e_row2_col7 {
#   background-color: rgba(215, 48, 39, 0.15);
#   border: 2px solid black;
# }
# #T_6ef7e_row3_col0, #T_6ef7e_row4_col4, #T_6ef7e_row6_col4 {
#   background-color: rgba(215, 48, 39, 0.57);
# }
# #T_6ef7e_row3_col1, #T_6ef7e_row3_col2, #T_6ef7e_row4_col1, #T_6ef7e_row4_col2, #T_6ef7e_row8_col1, #T_6ef7e_row8_col2, #T_6ef7e_row8_col5, #T_6ef7e_row8_col6, #T_6ef7e_row10_col1, #T_6ef7e_row10_col2 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_6ef7e_row3_col3, #T_6ef7e_row4_col7, #T_6ef7e_row9_col3 {
#   background-color: rgba(215, 48, 39, 0.17);
# }
# #T_6ef7e_row3_col4 {
#   background-color: rgba(215, 48, 39, 0.51);
#   border: 2px solid black;
# }
# #T_6ef7e_row3_col5, #T_6ef7e_row3_col6, #T_6ef7e_row7_col5, #T_6ef7e_row7_col6, #T_6ef7e_row9_col5 {
#   background-color: rgba(215, 48, 39, 0.72);
# }
# #T_6ef7e_row3_col7, #T_6ef7e_row9_col7 {
#   background-color: rgba(215, 48, 39, 0.16);
# }
# #T_6ef7e_row4_col0, #T_6ef7e_row6_col0 {
#   background-color: rgba(215, 48, 39, 0.62);
# }
# #T_6ef7e_row4_col3, #T_6ef7e_row6_col7, #T_6ef7e_row8_col3, #T_6ef7e_row8_col7, #T_6ef7e_row10_col3, #T_6ef7e_row10_col7 {
#   background-color: rgba(215, 48, 39, 0.18);
# }
# #T_6ef7e_row5_col0 {
#   background-color: rgba(215, 48, 39, 0.54);
#   border: 2px solid black;
# }
# #T_6ef7e_row5_col1, #T_6ef7e_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.73);
#   border: 2px solid black;
# }
# #T_6ef7e_row5_col3, #T_6ef7e_row7_col3 {
#   background-color: rgba(215, 48, 39, 0.17);
#   border: 2px solid black;
# }
# #T_6ef7e_row5_col4 {
#   background-color: rgba(215, 48, 39, 0.48);
#   border: 2px solid black;
# }
# #T_6ef7e_row6_col3 {
#   background-color: rgba(215, 48, 39, 0.19);
# }
# #T_6ef7e_row7_col0 {
#   background-color: rgba(215, 48, 39, 0.59);
# }
# #T_6ef7e_row7_col4 {
#   background-color: rgba(215, 48, 39, 0.54);
# }
# #T_6ef7e_row8_col0 {
#   background-color: rgba(215, 48, 39, 0.60);
# }
# #T_6ef7e_row8_col4, #T_6ef7e_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.58);
# }
# #T_6ef7e_row9_col4, #T_6ef7e_row10_col4 {
#   background-color: rgba(215, 48, 39, 0.52);
# }
# </style>
# <table id="T_6ef7e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th id="T_6ef7e_level0_col0" class="col_heading level0 col0" >masserstein | test</th>
#       <th id="T_6ef7e_level0_col1" class="col_heading level0 col1" >spectral_angle | test</th>
#       <th id="T_6ef7e_level0_col2" class="col_heading level0 col2" >cosine_similarity | test</th>
#       <th id="T_6ef7e_level0_col3" class="col_heading level0 col3" >mse | test</th>
#       <th id="T_6ef7e_level0_col4" class="col_heading level0 col4" >masserstein | heldout_image</th>
#       <th id="T_6ef7e_level0_col5" class="col_heading level0 col5" >spectral_angle | heldout_image</th>
#       <th id="T_6ef7e_level0_col6" class="col_heading level0 col6" >cosine_similarity | heldout_image</th>
#       <th id="T_6ef7e_level0_col7" class="col_heading level0 col7" >mse | heldout_image</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ef7e_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_6ef7e_row0_col0" class="data row0 col0" >3.988 +/- 0.155</td>
#       <td id="T_6ef7e_row0_col1" class="data row0 col1" >1.094 +/- 0.026</td>
#       <td id="T_6ef7e_row0_col2" class="data row0 col2" >0.457 +/- 0.023</td>
#       <td id="T_6ef7e_row0_col3" class="data row0 col3" >0.000 +/- 0.000</td>
#       <td id="T_6ef7e_row0_col4" class="data row0 col4" >4.467 +/- 0.290</td>
#       <td id="T_6ef7e_row0_col5" class="data row0 col5" >1.058 +/- 0.035</td>
#       <td id="T_6ef7e_row0_col6" class="data row0 col6" >0.490 +/- 0.030</td>
#       <td id="T_6ef7e_row0_col7" class="data row0 col7" >0.000 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_6ef7e_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_6ef7e_row1_col0" class="data row1 col0" >315.305 +/- 145.532</td>
#       <td id="T_6ef7e_row1_col1" class="data row1 col1" >1.345 +/- 0.179</td>
#       <td id="T_6ef7e_row1_col2" class="data row1 col2" >0.168 +/- 0.128</td>
#       <td id="T_6ef7e_row1_col3" class="data row1 col3" >0.000 +/- 0.000</td>
#       <td id="T_6ef7e_row1_col4" class="data row1 col4" >315.899 +/- 205.774</td>
#       <td id="T_6ef7e_row1_col5" class="data row1 col5" >1.511 +/- 0.069</td>
#       <td id="T_6ef7e_row1_col6" class="data row1 col6" >0.055 +/- 0.062</td>
#       <td id="T_6ef7e_row1_col7" class="data row1 col7" >0.000 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_6ef7e_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_6ef7e_row2_col0" class="data row2 col0" >159.301 +/- 5.736</td>
#       <td id="T_6ef7e_row2_col1" class="data row2 col1" >1.417 +/- 0.023</td>
#       <td id="T_6ef7e_row2_col2" class="data row2 col2" >0.153 +/- 0.023</td>
#       <td id="T_6ef7e_row2_col3" class="data row2 col3" >0.000 +/- 0.000</td>
#       <td id="T_6ef7e_row2_col4" class="data row2 col4" >129.610 +/- 7.120</td>
#       <td id="T_6ef7e_row2_col5" class="data row2 col5" >1.389 +/- 0.024</td>
#       <td id="T_6ef7e_row2_col6" class="data row2 col6" >0.181 +/- 0.023</td>
#       <td id="T_6ef7e_row2_col7" class="data row2 col7" >0.000 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_6ef7e_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_6ef7e_row3_col0" class="data row3 col0" >222.697 +/- 14.241</td>
#       <td id="T_6ef7e_row3_col1" class="data row3 col1" >1.525 +/- 0.015</td>
#       <td id="T_6ef7e_row3_col2" class="data row3 col2" >0.046 +/- 0.015</td>
#       <td id="T_6ef7e_row3_col3" class="data row3 col3" >0.000 +/- 0.000</td>
#       <td id="T_6ef7e_row3_col4" class="data row3 col4" >191.777 +/- 14.635</td>
#       <td id="T_6ef7e_row3_col5" class="data row3 col5" >1.514 +/- 0.030</td>
#       <td id="T_6ef7e_row3_col6" class="data row3 col6" >0.057 +/- 0.030</td>
#       <td id="T_6ef7e_row3_col7" class="data row3 col7" >0.000 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_6ef7e_level0_row4" class="row
# test + extension
# <style type="text/css">
# #T_453c6_row0_col0, #T_453c6_row0_col1, #T_453c6_row0_col2, #T_453c6_row0_col3, #T_453c6_row0_col4, #T_453c6_row0_col5, #T_453c6_row0_col6, #T_453c6_row0_col7, #T_453c6_row0_col8 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_453c6_row1_col0, #T_453c6_row1_col3, #T_453c6_row3_col0, #T_453c6_row3_col3 {
#   background-color: rgba(215, 48, 39, 0.74);
#   border: 2px solid black;
# }
# #T_453c6_row1_col1, #T_453c6_row1_col4, #T_453c6_row1_col5, #T_453c6_row1_col6, #T_453c6_row1_col7, #T_453c6_row1_col8, #T_453c6_row2_col4, #T_453c6_row2_col5, #T_453c6_row2_col6, #T_453c6_row2_col7, #T_453c6_row2_col8, #T_453c6_row3_col4, #T_453c6_row3_col5, #T_453c6_row3_col6, #T_453c6_row3_col7, #T_453c6_row3_col8, #T_453c6_row4_col0, #T_453c6_row4_col3, #T_453c6_row4_col5, #T_453c6_row4_col6, #T_453c6_row4_col7, #T_453c6_row4_col8, #T_453c6_row5_col0, #T_453c6_row5_col2, #T_453c6_row5_col3, #T_453c6_row5_col4, #T_453c6_row5_col5, #T_453c6_row5_col6, #T_453c6_row5_col7, #T_453c6_row5_col8, #T_453c6_row6_col0, #T_453c6_row6_col1, #T_453c6_row6_col3, #T_453c6_row7_col0, #T_453c6_row7_col3, #T_453c6_row7_col4, #T_453c6_row7_col5, #T_453c6_row7_col6, #T_453c6_row7_col7, #T_453c6_row7_col8, #T_453c6_row8_col0, #T_453c6_row8_col1, #T_453c6_row8_col3, #T_453c6_row8_col4, #T_453c6_row9_col0, #T_453c6_row9_col3, #T_453c6_row9_col4, #T_453c6_row9_col5, #T_453c6_row9_col6, #T_453c6_row9_col7, #T_453c6_row9_col8, #T_453c6_row10_col0, #T_453c6_row10_col1, #T_453c6_row10_col3 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_453c6_row1_col2 {
#   background-color: rgba(215, 48, 39, 0.65);
#   border: 2px solid black;
# }
# #T_453c6_row2_col0, #T_453c6_row2_col3 {
#   background-color: rgba(215, 48, 39, 0.67);
#   border: 2px solid black;
# }
# #T_453c6_row2_col1 {
#   background-color: rgba(215, 48, 39, 0.66);
#   border: 2px solid black;
# }
# #T_453c6_row2_col2 {
#   background-color: rgba(215, 48, 39, 0.55);
#   border: 2px solid black;
# }
# #T_453c6_row3_col1, #T_453c6_row6_col2, #T_453c6_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.72);
# }
# #T_453c6_row3_col2, #T_453c6_row7_col2, #T_453c6_row8_col2 {
#   background-color: rgba(215, 48, 39, 0.73);
# }
# #T_453c6_row4_col1, #T_453c6_row4_col2, #T_453c6_row9_col2 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_453c6_row4_col4, #T_453c6_row6_col4, #T_453c6_row6_col5, #T_453c6_row6_col6, #T_453c6_row6_col7, #T_453c6_row6_col8, #T_453c6_row8_col5, #T_453c6_row8_col6, #T_453c6_row8_col7, #T_453c6_row8_col8, #T_453c6_row10_col4, #T_453c6_row10_col5, #T_453c6_row10_col6, #T_453c6_row10_col7, #T_453c6_row10_col8 {
#   background-color: rgba(215, 48, 39, 0.75);
#   border: 2px solid black;
# }
# #T_453c6_row5_col1, #T_453c6_row7_col1, #T_453c6_row10_col2 {
#   background-color: rgba(215, 48, 39, 0.72);
#   border: 2px solid black;
# }
# </style>
# <table id="T_453c6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >metric</th>
#       <th id="T_453c6_level0_col0" class="col_heading level0 col0" >average_precision</th>
#       <th id="T_453c6_level0_col1" class="col_heading level0 col1" >micro_average_precision</th>
#       <th id="T_453c6_level0_col2" class="col_heading level0 col2" >roc_auc</th>
#       <th id="T_453c6_level0_col3" class="col_heading level0 col3" >ap_above_prevalence</th>
#       <th id="T_453c6_level0_col4" class="col_heading level0 col4" >precision</th>
#       <th id="T_453c6_level0_col5" class="col_heading level0 col5" >recall</th>
#       <th id="T_453c6_level0_col6" class="col_heading level0 col6" >f1</th>
#       <th id="T_453c6_level0_col7" class="col_heading level0 col7" >micro_f1</th>
#       <th id="T_453c6_level0_col8" class="col_heading level0 col8" >hamming_loss</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_453c6_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_453c6_row0_col0" class="data row0 col0" >0.708 +/- 0.008</td>
#       <td id="T_453c6_row0_col1" class="data row0 col1" >0.870 +/- 0.007</td>
#       <td id="T_453c6_row0_col2" class="data row0 col2" >0.987 +/- 0.001</td>
#       <td id="T_453c6_row0_col3" class="data row0 col3" >0.651 +/- 0.008</td>
#       <td id="T_453c6_row0_col4" class="data row0 col4" >0.588 +/- 0.010</td>
#       <td id="T_453c6_row0_col5" class="data row0 col5" >0.529 +/- 0.017</td>
#       <td id="T_453c6_row0_col6" class="data row0 col6" >0.508 +/- 0.015</td>
#       <td id="T_453c6_row0_col7" class="data row0 col7" >0.826 +/- 0.005</td>
#       <td id="T_453c6_row0_col8" class="data row0 col8" >0.020 +/- 0.001</td>
#     </tr>
#     <tr>
#       <th id="T_453c6_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_453c6_row1_col0" class="data row1 col0" >0.071 +/- 0.018</td>
#       <td id="T_453c6_row1_col1" class="data row1 col1" >0.055 +/- 0.011</td>
#       <td id="T_453c6_row1_col2" class="data row1 col2" >0.511 +/- 0.077</td>
#       <td id="T_453c6_row1_col3" class="data row1 col3" >0.013 +/- 0.018</td>
#       <td id="T_453c6_row1_col4" class="data row1 col4" >0.000 +/- 0.000</td>
#       <td id="T_453c6_row1_col5" class="data row1 col5" >0.000 +/- 0.000</td>
#       <td id="T_453c6_row1_col6" class="data row1 col6" >0.000 +/- 0.000</td>
#       <td id="T_453c6_row1_col7" class="data row1 col7" >0.000 +/- 0.000</td>
#       <td id="T_453c6_row1_col8" class="data row1 col8" >0.057 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_453c6_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_453c6_row2_col0" class="data row2 col0" >0.144 +/- 0.006</td>
#       <td id="T_453c6_row2_col1" class="data row2 col1" >0.172 +/- 0.029</td>
#       <td id="T_453c6_row2_col2" class="data row2 col2" >0.602 +/- 0.022</td>
#       <td id="T_453c6_row2_col3" class="data row2 col3" >0.087 +/- 0.006</td>
#       <td id="T_453c6_row2_col4" class="data row2 col4" >0.000 +/- 0.000</td>
#       <td id="T_453c6_row2_col5" class="data row2 col5" >0.000 +/- 0.000</td>
#       <td id="T_453c6_row2_col6" class="data row2 col6" >0.000 +/- 0.000</td>
#       <td id="T_453c6_row2_col7" class="data row2 col7" >0.000 +/- 0.000</td>
#       <td id="T_453c6_row2_col8" class="data row2 col8" >0.057 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_453c6_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_453c6_row3_col0" class="data row3 col0" >0.065 +/- 0.017</td>
#       <td id="T_453c6_row3_col1" class="data row3 col1" >0.089 +/- 0.015</td>
#       <td id="T_453c6_row3_col2" class="data row3 col2" >0.429 +/- 0.012</td>
#       <td id="T_453c6_row3_col3" class="data row3 col3" >0.007 +/- 0.017</td>
#       <td id="T_453c6_row3_col4" class="data row3 col4" >0.000 +/- 0.001</td>
#       <td id="T_453c6_row3_col5" class="data row3 col5" >0.000 +/- 0.000</td>
#       <td id="T_453c6_row3_col6" class="data row3 col6" >0.000 +/- 0.000</td>
#       <td id="T_453c6_row3_col7" class="data row3 col7" >0.000 +/- 0.000</td>
#       <td id="T_453c6_row3_col8" class="data row3 col8" >0.057 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_453c6_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_453c6_row4_col0" class="data row4 col0" >0.055 +/- 0.005</td>
#       <td id="T_453c6_row4_col1" class="data row4 col1" >0.064 +/- 0.009</td>
#       <td id="T_453c6_row4_col2" class="data row4 col2" >0.417 +/- 0.024</td>
#       <td id="T_453c6_row4_col3" class="data row4 col3" >-0.003 +/- 0.005</td>
#       <td id="T_453c6_row4_col4" class="data row4 col4" >0.002 +/- 0.002</td>
#       <td id="T_453c6_row4_col5" class="data row4 col5" >0.001 +/- 0.001</td>
#       <td id="T_453c6_row4_col6" class="data row4 col6" >0.000 +
# held-out images
# <style type="text/css">
# #T_9e085_row0_col0, #T_9e085_row0_col1, #T_9e085_row0_col2, #T_9e085_row0_col3, #T_9e085_row0_col4, #T_9e085_row0_col5, #T_9e085_row0_col6, #T_9e085_row0_col7, #T_9e085_row0_col8 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_9e085_row1_col0, #T_9e085_row1_col3, #T_9e085_row3_col0, #T_9e085_row3_col3, #T_9e085_row6_col2, #T_9e085_row7_col0, #T_9e085_row7_col3 {
#   background-color: rgba(215, 48, 39, 0.70);
# }
# #T_9e085_row1_col1, #T_9e085_row8_col2 {
#   background-color: rgba(215, 48, 39, 0.69);
#   border: 2px solid black;
# }
# #T_9e085_row1_col2, #T_9e085_row2_col1, #T_9e085_row4_col4, #T_9e085_row4_col5, #T_9e085_row4_col6, #T_9e085_row4_col7, #T_9e085_row4_col8, #T_9e085_row5_col1, #T_9e085_row5_col4, #T_9e085_row5_col5, #T_9e085_row5_col6, #T_9e085_row5_col7, #T_9e085_row5_col8, #T_9e085_row6_col0, #T_9e085_row6_col3, #T_9e085_row6_col4, #T_9e085_row6_col5, #T_9e085_row6_col6, #T_9e085_row6_col7, #T_9e085_row6_col8, #T_9e085_row7_col1, #T_9e085_row7_col4, #T_9e085_row7_col5, #T_9e085_row7_col6, #T_9e085_row7_col7, #T_9e085_row7_col8, #T_9e085_row8_col4, #T_9e085_row8_col5, #T_9e085_row8_col6, #T_9e085_row8_col7, #T_9e085_row8_col8, #T_9e085_row9_col1, #T_9e085_row9_col4, #T_9e085_row9_col5, #T_9e085_row9_col6, #T_9e085_row9_col7, #T_9e085_row9_col8, #T_9e085_row10_col4, #T_9e085_row10_col5, #T_9e085_row10_col6, #T_9e085_row10_col7, #T_9e085_row10_col8 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_9e085_row1_col4, #T_9e085_row1_col5, #T_9e085_row1_col6, #T_9e085_row1_col7, #T_9e085_row1_col8, #T_9e085_row2_col4, #T_9e085_row2_col5, #T_9e085_row2_col6, #T_9e085_row2_col7, #T_9e085_row2_col8, #T_9e085_row3_col4, #T_9e085_row3_col5, #T_9e085_row3_col6, #T_9e085_row3_col7, #T_9e085_row3_col8 {
#   background-color: rgba(215, 48, 39, 0.75);
#   border: 2px solid black;
# }
# #T_9e085_row2_col0, #T_9e085_row2_col3 {
#   background-color: rgba(215, 48, 39, 0.64);
#   border: 2px solid black;
# }
# #T_9e085_row2_col2 {
#   background-color: rgba(215, 48, 39, 0.55);
#   border: 2px solid black;
# }
# #T_9e085_row3_col1 {
#   background-color: rgba(215, 48, 39, 0.74);
#   border: 2px solid black;
# }
# #T_9e085_row3_col2, #T_9e085_row9_col2, #T_9e085_row10_col0, #T_9e085_row10_col2, #T_9e085_row10_col3 {
#   background-color: rgba(215, 48, 39, 0.72);
# }
# #T_9e085_row4_col0, #T_9e085_row4_col3, #T_9e085_row7_col2 {
#   background-color: rgba(215, 48, 39, 0.73);
# }
# #T_9e085_row4_col1 {
#   background-color: rgba(215, 48, 39, 0.72);
#   border: 2px solid black;
# }
# #T_9e085_row4_col2 {
#   background-color: rgba(215, 48, 39, 0.71);
# }
# #T_9e085_row5_col0, #T_9e085_row5_col3 {
#   background-color: rgba(215, 48, 39, 0.66);
#   border: 2px solid black;
# }
# #T_9e085_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.70);
#   border: 2px solid black;
# }
# #T_9e085_row6_col1, #T_9e085_row8_col1, #T_9e085_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_9e085_row8_col0, #T_9e085_row8_col3 {
#   background-color: rgba(215, 48, 39, 0.68);
#   border: 2px solid black;
# }
# #T_9e085_row9_col0, #T_9e085_row9_col3 {
#   background-color: rgba(215, 48, 39, 0.68);
# }
# </style>
# <table id="T_9e085">
#   <thead>
#     <tr>
#       <th class="index_name level0" >metric</th>
#       <th id="T_9e085_level0_col0" class="col_heading level0 col0" >average_precision</th>
#       <th id="T_9e085_level0_col1" class="col_heading level0 col1" >micro_average_precision</th>
#       <th id="T_9e085_level0_col2" class="col_heading level0 col2" >roc_auc</th>
#       <th id="T_9e085_level0_col3" class="col_heading level0 col3" >ap_above_prevalence</th>
#       <th id="T_9e085_level0_col4" class="col_heading level0 col4" >precision</th>
#       <th id="T_9e085_level0_col5" class="col_heading level0 col5" >recall</th>
#       <th id="T_9e085_level0_col6" class="col_heading level0 col6" >f1</th>
#       <th id="T_9e085_level0_col7" class="col_heading level0 col7" >micro_f1</th>
#       <th id="T_9e085_level0_col8" class="col_heading level0 col8" >hamming_loss</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e085_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_9e085_row0_col0" class="data row0 col0" >0.376 +/- 0.016</td>
#       <td id="T_9e085_row0_col1" class="data row0 col1" >0.581 +/- 0.019</td>
#       <td id="T_9e085_row0_col2" class="data row0 col2" >0.726 +/- 0.013</td>
#       <td id="T_9e085_row0_col3" class="data row0 col3" >0.154 +/- 0.016</td>
#       <td id="T_9e085_row0_col4" class="data row0 col4" >0.360 +/- 0.044</td>
#       <td id="T_9e085_row0_col5" class="data row0 col5" >0.119 +/- 0.012</td>
#       <td id="T_9e085_row0_col6" class="data row0 col6" >0.128 +/- 0.016</td>
#       <td id="T_9e085_row0_col7" class="data row0 col7" >0.381 +/- 0.030</td>
#       <td id="T_9e085_row0_col8" class="data row0 col8" >0.191 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_9e085_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_9e085_row1_col0" class="data row1 col0" >0.249 +/- 0.013</td>
#       <td id="T_9e085_row1_col1" class="data row1 col1" >0.233 +/- 0.023</td>
#       <td id="T_9e085_row1_col2" class="data row1 col2" >0.456 +/- 0.022</td>
#       <td id="T_9e085_row1_col3" class="data row1 col3" >0.027 +/- 0.013</td>
#       <td id="T_9e085_row1_col4" class="data row1 col4" >0.000 +/- 0.000</td>
#       <td id="T_9e085_row1_col5" class="data row1 col5" >0.000 +/- 0.000</td>
#       <td id="T_9e085_row1_col6" class="data row1 col6" >0.000 +/- 0.000</td>
#       <td id="T_9e085_row1_col7" class="data row1 col7" >0.000 +/- 0.000</td>
#       <td id="T_9e085_row1_col8" class="data row1 col8" >0.222 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_9e085_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_9e085_row2_col0" class="data row2 col0" >0.263 +/- 0.008</td>
#       <td id="T_9e085_row2_col1" class="data row2 col1" >0.195 +/- 0.022</td>
#       <td id="T_9e085_row2_col2" class="data row2 col2" >0.548 +/- 0.016</td>
#       <td id="T_9e085_row2_col3" class="data row2 col3" >0.040 +/- 0.008</td>
#       <td id="T_9e085_row2_col4" class="data row2 col4" >0.000 +/- 0.000</td>
#       <td id="T_9e085_row2_col5" class="data row2 col5" >0.000 +/- 0.000</td>
#       <td id="T_9e085_row2_col6" class="data row2 col6" >0.000 +/- 0.000</td>
#       <td id="T_9e085_row2_col7" class="data row2 col7" >0.000 +/- 0.000</td>
#       <td id="T_9e085_row2_col8" class="data row2 col8" >0.222 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_9e085_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_9e085_row3_col0" class="data row3 col0" >0.249 +/- 0.010</td>
#       <td id="T_9e085_row3_col1" class="data row3 col1" >0.202 +/- 0.021</td>
#       <td id="T_9e085_row3_col2" class="data row3 col2" >0.469 +/- 0.004</td>
#       <td id="T_9e085_row3_col3" class="data row3 col3" >0.027 +/- 0.010</td>
#       <td id="T_9e085_row3_col4" class="data row3 col4" >0.000 +/- 0.000</td>
#       <td id="T_9e085_row3_col5" class="data row3 col5" >0.000 +/- 0.000</td>
#       <td id="T_9e085_row3_col6" class="data row3 col6" >0.000 +/- 0.000</td>
#       <td id="T_9e085_row3_col7" class="data row3 col7" >0.000 +/- 0.000</td>
#       <td id="T_9e085_row3_col8" class="data row3 col8" >0.222 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_9e085_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_9e085_row4_col0" class="data row4 col0" >0.242 +/- 0.009</td>
#       <td id="T_9e085_row4_col1" class="data row4 col1" >0.212 +/- 0.016</td>
#       <td id="T_9e085_row4_col2" class="data row4 col2" >0.475 +/- 0.021</td>
# held-out, per image
# <style type="text/css">
# #T_5818c_row0_col0, #T_5818c_row0_col1, #T_5818c_row0_col2, #T_5818c_row0_col3, #T_5818c_row0_col4, #T_5818c_row0_col5, #T_5818c_row0_col6, #T_5818c_row0_col7, #T_5818c_row0_col8 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_5818c_row1_col0, #T_5818c_row1_col3 {
#   background-color: rgba(215, 48, 39, 0.69);
# }
# #T_5818c_row1_col1 {
#   background-color: rgba(215, 48, 39, 0.61);
#   border: 2px solid black;
# }
# #T_5818c_row1_col2, #T_5818c_row2_col1, #T_5818c_row4_col4, #T_5818c_row4_col5, #T_5818c_row4_col6, #T_5818c_row4_col7, #T_5818c_row4_col8, #T_5818c_row5_col4, #T_5818c_row5_col5, #T_5818c_row5_col6, #T_5818c_row5_col7, #T_5818c_row5_col8, #T_5818c_row6_col0, #T_5818c_row6_col3, #T_5818c_row6_col4, #T_5818c_row6_col5, #T_5818c_row6_col6, #T_5818c_row6_col7, #T_5818c_row6_col8, #T_5818c_row7_col4, #T_5818c_row7_col5, #T_5818c_row7_col6, #T_5818c_row7_col7, #T_5818c_row7_col8, #T_5818c_row8_col4, #T_5818c_row8_col5, #T_5818c_row8_col6, #T_5818c_row8_col7, #T_5818c_row8_col8, #T_5818c_row9_col4, #T_5818c_row9_col5, #T_5818c_row9_col6, #T_5818c_row9_col7, #T_5818c_row9_col8, #T_5818c_row10_col4, #T_5818c_row10_col5, #T_5818c_row10_col6, #T_5818c_row10_col7, #T_5818c_row10_col8 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_5818c_row1_col4, #T_5818c_row1_col5, #T_5818c_row1_col6, #T_5818c_row1_col7, #T_5818c_row1_col8, #T_5818c_row2_col4, #T_5818c_row2_col5, #T_5818c_row2_col6, #T_5818c_row2_col7, #T_5818c_row2_col8, #T_5818c_row3_col4, #T_5818c_row3_col5, #T_5818c_row3_col6, #T_5818c_row3_col7, #T_5818c_row3_col8 {
#   background-color: rgba(215, 48, 39, 0.75);
#   border: 2px solid black;
# }
# #T_5818c_row2_col0, #T_5818c_row2_col3 {
#   background-color: rgba(215, 48, 39, 0.57);
#   border: 2px solid black;
# }
# #T_5818c_row2_col2, #T_5818c_row3_col2, #T_5818c_row8_col1 {
#   background-color: rgba(215, 48, 39, 0.70);
#   border: 2px solid black;
# }
# #T_5818c_row3_col0, #T_5818c_row3_col3, #T_5818c_row7_col0, #T_5818c_row7_col3 {
#   background-color: rgba(215, 48, 39, 0.66);
#   border: 2px solid black;
# }
# #T_5818c_row3_col1, #T_5818c_row4_col2, #T_5818c_row6_col1, #T_5818c_row6_col2, #T_5818c_row8_col2, #T_5818c_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.71);
# }
# #T_5818c_row4_col0, #T_5818c_row4_col3, #T_5818c_row5_col1, #T_5818c_row8_col0, #T_5818c_row8_col3, #T_5818c_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.73);
# }
# #T_5818c_row4_col1 {
#   background-color: rgba(215, 48, 39, 0.68);
#   border: 2px solid black;
# }
# #T_5818c_row5_col0, #T_5818c_row5_col3 {
#   background-color: rgba(215, 48, 39, 0.67);
# }
# #T_5818c_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.69);
#   border: 2px solid black;
# }
# #T_5818c_row7_col1, #T_5818c_row9_col2, #T_5818c_row10_col0, #T_5818c_row10_col2, #T_5818c_row10_col3 {
#   background-color: rgba(215, 48, 39, 0.72);
# }
# #T_5818c_row7_col2 {
#   background-color: rgba(215, 48, 39, 0.70);
# }
# #T_5818c_row9_col0, #T_5818c_row9_col3 {
#   background-color: rgba(215, 48, 39, 0.68);
# }
# </style>
# <table id="T_5818c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >metric</th>
#       <th id="T_5818c_level0_col0" class="col_heading level0 col0" >average_precision</th>
#       <th id="T_5818c_level0_col1" class="col_heading level0 col1" >micro_average_precision</th>
#       <th id="T_5818c_level0_col2" class="col_heading level0 col2" >roc_auc</th>
#       <th id="T_5818c_level0_col3" class="col_heading level0 col3" >ap_above_prevalence</th>
#       <th id="T_5818c_level0_col4" class="col_heading level0 col4" >precision</th>
#       <th id="T_5818c_level0_col5" class="col_heading level0 col5" >recall</th>
#       <th id="T_5818c_level0_col6" class="col_heading level0 col6" >f1</th>
#       <th id="T_5818c_level0_col7" class="col_heading level0 col7" >micro_f1</th>
#       <th id="T_5818c_level0_col8" class="col_heading level0 col8" >hamming_loss</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5818c_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_5818c_row0_col0" class="data row0 col0" >0.610 +/- 0.008</td>
#       <td id="T_5818c_row0_col1" class="data row0 col1" >0.797 +/- 0.007</td>
#       <td id="T_5818c_row0_col2" class="data row0 col2" >0.770 +/- 0.007</td>
#       <td id="T_5818c_row0_col3" class="data row0 col3" >0.201 +/- 0.008</td>
#       <td id="T_5818c_row0_col4" class="data row0 col4" >0.470 +/- 0.048</td>
#       <td id="T_5818c_row0_col5" class="data row0 col5" >0.140 +/- 0.010</td>
#       <td id="T_5818c_row0_col6" class="data row0 col6" >0.158 +/- 0.016</td>
#       <td id="T_5818c_row0_col7" class="data row0 col7" >0.410 +/- 0.034</td>
#       <td id="T_5818c_row0_col8" class="data row0 col8" >0.314 +/- 0.011</td>
#     </tr>
#     <tr>
#       <th id="T_5818c_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_5818c_row1_col0" class="data row1 col0" >0.456 +/- 0.010</td>
#       <td id="T_5818c_row1_col1" class="data row1 col1" >0.447 +/- 0.067</td>
#       <td id="T_5818c_row1_col2" class="data row1 col2" >0.492 +/- 0.017</td>
#       <td id="T_5818c_row1_col3" class="data row1 col3" >0.046 +/- 0.010</td>
#       <td id="T_5818c_row1_col4" class="data row1 col4" >0.000 +/- 0.000</td>
#       <td id="T_5818c_row1_col5" class="data row1 col5" >0.000 +/- 0.000</td>
#       <td id="T_5818c_row1_col6" class="data row1 col6" >0.000 +/- 0.000</td>
#       <td id="T_5818c_row1_col7" class="data row1 col7" >0.000 +/- 0.000</td>
#       <td id="T_5818c_row1_col8" class="data row1 col8" >0.410 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_5818c_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_5818c_row2_col0" class="data row2 col0" >0.490 +/- 0.010</td>
#       <td id="T_5818c_row2_col1" class="data row2 col1" >0.342 +/- 0.025</td>
#       <td id="T_5818c_row2_col2" class="data row2 col2" >0.515 +/- 0.010</td>
#       <td id="T_5818c_row2_col3" class="data row2 col3" >0.080 +/- 0.010</td>
#       <td id="T_5818c_row2_col4" class="data row2 col4" >0.000 +/- 0.000</td>
#       <td id="T_5818c_row2_col5" class="data row2 col5" >0.000 +/- 0.000</td>
#       <td id="T_5818c_row2_col6" class="data row2 col6" >0.000 +/- 0.000</td>
#       <td id="T_5818c_row2_col7" class="data row2 col7" >0.000 +/- 0.000</td>
#       <td id="T_5818c_row2_col8" class="data row2 col8" >0.410 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_5818c_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_5818c_row3_col0" class="data row3 col0" >0.464 +/- 0.013</td>
#       <td id="T_5818c_row3_col1" class="data row3 col1" >0.372 +/- 0.018</td>
#       <td id="T_5818c_row3_col2" class="data row3 col2" >0.513 +/- 0.010</td>
#       <td id="T_5818c_row3_col3" class="data row3 col3" >0.054 +/- 0.013</td>
#       <td id="T_5818c_row3_col4" class="data row3 col4" >0.000 +/- 0.000</td>
#       <td id="T_5818c_row3_col5" class="data row3 col5" >0.000 +/- 0.000</td>
#       <td id="T_5818c_row3_col6" class="data row3 col6" >0.000 +/- 0.000</td>
#       <td id="T_5818c_row3_col7" class="data row3 col7" >0.000 +/- 0.000</td>
#       <td id="T_5818c_row3_col8" class="data row3 col8" >0.410 +/- 0.000</td>
#     </tr>
#     <tr>
#       <th id="T_5818c_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_5818c_row4_col0" class="data row4 col0" >0.447 +/- 0.015</td>
#       <td id="T_5818c_row4_col1" class="data row4 col1" >0.396 +/- 0.055</td>
#       <td id="T_5818c_row4_col2" class="data row4 col2" >0.510 +/- 0.016</td>
#       <td id="T_5818c_row4_col3" class="data row4 col3" >0.037 +/- 0.015</td>
#       <td id="T_5818c_row4_co

# %% [markdown]
# ### Remarks
#
# - W1, test: baseline 3.988; others 159.3-315.3; 0 of 10 better than the baseline; best P1 permutations (159.3), worst P0 single bins (315.3).
# - W1, heldout_image: baseline 4.467; others 129.6-315.9; 0 of 10 better than the baseline; best P1 permutations (129.6), worst P0 single bins (315.9).
# - spectral angle, test: baseline 1.094; others 1.345-1.534; 0 of 10 better than the baseline; best P0 single bins (1.345), worst P3 staged + overlap (1.534).
# - spectral angle, heldout_image: baseline 1.058; others 1.389-1.534; 0 of 10 better than the baseline; best P1 permutations (1.389), worst P3 staged + overlap (1.534).
# - macro AP, test_combined: baseline 0.7084; others 0.05439-0.1444; 0 of 10 better than the baseline; best P1 permutations (0.1444), worst P4 staged + rare (0.05439).
# - macro AP, heldout_image_per_image: baseline 0.6105; others 0.4394-0.4902; 0 of 10 better than the baseline; best P1 permutations (0.4902), worst P3 staged + overlap (0.4394).
# - micro AP, test_combined: baseline 0.8696; others 0.05473-0.1723; 0 of 10 better than the baseline; best P1 permutations (0.1723), worst P0 single bins (0.05473).
# - micro AP, heldout_image_per_image: baseline 0.7966; others 0.3418-0.4469; 0 of 10 better than the baseline; best P0 single bins (0.4469), worst P1 permutations (0.3418).
# - macro F1 at 0.5, test_combined: baseline 0.508; others 0-0.0012; 0 of 10 better than the baseline; best P4 staged + rare (0.0012), worst P0 single bins (0).
# - macro F1 at 0.5, heldout_image_per_image: baseline 0.1583; others 0-0; 0 of 10 better than the baseline; best P0 single bins (0), worst P0 single bins (0).

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Key metrics of every variant and of the baseline

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# The five key metrics are those of the part 1 representative choice: Masserstein $W_1$ and spectral angle of
# the reconstruction, macro AP, micro AP and macro F1 at 0.5 of the head (annotation retrieval, classes
# observed in training). Reconstruction is shown on the withheld test pixels and on the held-out images, the
# head on test + extension and per held-out image.

# %% [markdown]
# #### Implementation
#
# `model_metrics` (one row per model, metric and evaluation); the table gives mean +/- SD over the five
# repetitions from `value_summary`.

# %% [markdown]
# #### Figure descriptions
#
# One panel per key metric; x = variant (baseline first), colour = evaluation, one point per repetition, bar =
# mean. $W_1$ is drawn on a log scale because untrained-on-real models can be two orders of magnitude worse.

# %%
figure, axes = plt.subplots(2, 3, figsize=(20, 9), dpi=theme.figure_dpi)
for ax, spec in zip(axes.flat, KEY_METRICS):
    evaluations = ['test', 'heldout_image'] if spec['family'] == 'reconstruction' else ['test_combined', 'heldout_image_per_image']
    rows = metrics[(metrics.family == spec['family']) & (metrics.metric == spec['metric'])
                   & (metrics.ranking == spec.get('ranking', 'none')) & metrics.evaluation.isin(evaluations)]
    figures.repetition_points(rows, value='value', group='variant', hue='evaluation', order=ORDER, hue_order=evaluations,
                              colors={name: POPULATION_COLORS.get(name, theme.model_palette[5]) for name in evaluations},
                              ylabel=SHORT[spec['metric']], title=SHORT[spec['metric']], ax=ax, theme=theme)
    if spec['metric'] == 'masserstein':
        ax.set_yscale('log')
axes.flat[-1].set_visible(False)
figure.tight_layout()
key = pd.concat([values[(values.family == spec['family']) & (values.metric == spec['metric'])
                        & (values.ranking == spec.get('ranking', 'none'))] for spec in KEY_METRICS])
key = key[key.evaluation.isin(EVALUATIONS)]
cells = key.assign(cell=key['mean'].map('{:.4g}'.format) + ' +/- ' + key.sd.map('{:.2g}'.format),
                   column=key.metric.map(SHORT) + ' | ' + key.evaluation)
display(cells.pivot_table(index='variant', columns='column', values='cell', aggfunc='first').reindex(ORDER))
# Out:
# column            W1 | heldout_image          W1 | test macro AP | heldout_image macro AP | heldout_image_per_image     macro AP | test macro AP | test_combined macro F1 at 0.5 | heldout_image  \
# variant
# baseline              4.467 +/- 0.29     3.988 +/- 0.16         0.3761 +/- 0.016                  0.6105 +/- 0.0084   0.6973 +/- 0.0089        0.7084 +/- 0.0079                0.1276 +/- 0.016
# P0_single          315.9 +/- 2.1e+02  315.3 +/- 1.5e+02         0.2488 +/- 0.013                   0.456 +/- 0.0099   0.06053 +/- 0.014        0.07062 +/- 0.018                         0 +/- 0
# P1_permutation         129.6 +/- 7.1      159.3 +/- 5.7        0.2627 +/- 0.0077                  0.4902 +/- 0.0099   0.1393 +/- 0.0054        0.1444 +/- 0.0064                         0 +/- 0
# P2_joint_base           191.8 +/- 15       222.7 +/- 14          0.2492 +/- 0.01                   0.4641 +/- 0.013   0.05351 +/- 0.011        0.06459 +/- 0.017                         0 +/- 0
# P2_staged_base          221.1 +/- 44       247.9 +/- 36        0.2423 +/- 0.0094                   0.4465 +/- 0.015  0.04736 +/- 0.0043       0.05454 +/- 0.0049                         0 +/- 0
# P3_joint_overlap          175 +/- 10       203.9 +/- 20         0.2587 +/- 0.022                  0.4633 +/- 0.0085   0.04993 +/- 0.003       0.05722 +/- 0.0035                         0 +/- 0
# P3_staged_overlap       220.7 +/- 50       245.7 +/- 45        0.2381 +/- 0.0038                  0.4394 +/- 0.0063  0.04738 +/- 0.0024       0.05642 +/- 0.0046                         0 +/- 0
# P4_joint_rare           206.1 +/- 39       231.8 +/- 37        0.2498 +/- 0.0049                  0.4637 +/- 0.0091  0.04932 +/- 0.0032       0.05666 +/- 0.0028                         0 +/- 0
# P4_staged_rare          226.2 +/- 38       239.2 +/- 29          0.254 +/- 0.021                   0.4463 +/- 0.013  0.04683 +/- 0.0028       0.05439 +/- 0.0023                         0 +/- 0
# P5_joint_all            195.6 +/- 23       219.9 +/- 27         0.2537 +/- 0.011                  0.4588 +/- 0.0034  0.04943 +/- 0.0062       0.05648 +/- 0.0055                         0 +/- 0
# P5_staged_all           196.5 +/- 19       225.2 +/- 15        0.2448 +/- 0.0045                   0.4473 +/- 0.011   0.0483 +/- 0.0034        0.0583 +/- 0.0076                         0 +/- 0
#
# column            macro F1 at 0.5 | heldout_image_per_image macro F1 at 0.5 | test macro F1 at 0.5 | test_combined micro AP | heldout_image micro AP | heldout_image_per_image     micro AP | test  \
# variant
# baseline                                   0.1583 +/- 0.016       0.5047 +/- 0.015                 0.508 +/- 0.015         0.5809 +/- 0.019                  0.7966 +/- 0.0068   0.8774 +/- 0.0074
# P0_single                                           0 +/- 0                0 +/- 0                         0 +/- 0         0.2326 +/- 0.023                   0.4469 +/- 0.067  0.04561 +/- 0.0094
# P1_permutation                                      0 +/- 0                0 +/- 0                         0 +/- 0         0.1951 +/- 0.022                   0.3418 +/- 0.025    0.2176 +/- 0.049
# P2_joint_base                                       0 +/- 0   3.22e-05 +/- 7.2e-05           3.633e-05 +/- 8.1e-05         0.2016 +/- 0.021                   0.3717 +/- 0.018   0.09794 +/- 0.025
# P2_staged_base                                      0 +/- 0  0.0003853 +/- 0.00052            0.0003722 +/- 0.0005         0.2123 +/- 0.016                   0.3961 +/- 0.055   0.06285 +/- 0.013
# P3_joint_overlap                                    0 +/- 0                0 +/- 0                         0 +/- 0         0.1939 +/- 0.016                   0.3607 +/- 0.031    0.1129 +/- 0.011
# P3_staged_overlap                                   0 +/- 0    0.001116 +/- 0.0012             0.001099 +/- 0.0012         0.1997 +/- 0.015                     0.37 +/- 0.024   0.05586 +/- 0.006
# P4_joint_rare                                       0 +/- 0  0.0002794 +/- 0.00057           0.0002779 +/- 0.00056         0.1964 +/- 0.011                   0.3625 +/- 0.025    0.1093 +/- 0.013
# P4_staged_rare                                      0 +/- 0   0.001207 +/- 0.00018              0.0012 +/- 0.00017         0.1997 +/- 0.016                   0.3759 +/- 0.025   0.05531 +/- 0.012
# P5_joint_all                                        0 +/- 0  0.0004853 +/- 0.00066           0.0004827 +/- 0.00066        0.1936 +/- 0.0056                  0.3583 +/- 0.0084    0.1093 +/- 0.015
# P5_staged_all                                       0 +/- 0   0.001169 +/- 8.5e-05             0.00116 +/- 8.6e-05        0.2003 +/- 0.0082                   0.3755 +/- 0.025  0.05535 +/- 0.0072
#
# column            micro AP | test_combined spectral angle | heldout_image spectral angle | test
# variant
# baseline                 0.8696 +/- 0.0066                1.058 +/- 0.035       1.094 +/- 0.026
# P0_single                0.05473 +/- 0.011                1.511 +/- 0.069        1.345 +/- 0.18
# P1_permutation            0.1723 +/- 0.029                1.389 +/- 0.024       1.417 +/- 0.023
# P2_joint_base             0.0888 +/- 0.015                 1.514 +/- 0.03       1.525 +/- 0.015
# P2_staged_base          0.06436 +/- 0.0086                1.531 +/- 0.026       1.527 +/- 0.022
# P3_joint_overlap        0.09619 +/- 0.0071                 1.51 +/- 0.037       1.521 +/- 0.018
# P3_staged_overlap       0.05994 +/- 0.0046                1.534 +/- 0.015       1.534 +/- 0.011
# P4_joint_rare           0.09387 +/- 0.0081                1.512 +/- 0.038       1.523 +/- 0.019
# P4_staged_rare          0.05821 +/- 0.0088                1.528 +/- 0.022       1.529 +/- 0.019
# P5_joint_all            0.09364 +/- 0.0098                1.511 +/- 0.028       1.522 +/- 0.012
# P5_staged_all           0.05895 +/- 0.0046                1.521 +/- 0.026        1.529 +/- 0.02

# %% [markdown]
# ### Remarks
#
# - Baseline: W1 test 3.988 +/- 0.16; W1 held-out 4.467 +/- 0.29; spectral angle test 1.094 +/- 0.026; spectral angle held-out 1.058 +/- 0.035; macro AP held-out 0.3761 +/- 0.016; macro AP test+ext 0.7084 +/- 0.0079; macro AP held-out per image 0.6105 +/- 0.0084; micro AP held-out 0.5809 +/- 0.019; micro AP test+ext 0.8696 +/- 0.0066; micro AP held-out per image 0.7966 +/- 0.0068; macro F1@0.5 held-out 0.1276 +/- 0.016; macro F1@0.5 test+ext 0.508 +/- 0.015; macro F1@0.5 held-out per image 0.1583 +/- 0.016.
# - W1, test: variants 159.3 to 315.3 (baseline 3.988).
# - W1, held-out: variants 129.6 to 315.9 (baseline 4.467).
# - spectral angle, test: variants 1.345 to 1.534 (baseline 1.094).
# - spectral angle, held-out: variants 1.389 to 1.534 (baseline 1.058).
# - macro AP, held-out: variants 0.2381 to 0.2627 (baseline 0.3761).
# - macro AP, test+ext: variants 0.05439 to 0.1444 (baseline 0.7084).
# - macro AP, held-out per image: variants 0.4394 to 0.4902 (baseline 0.6105).
# - micro AP, held-out: variants 0.1936 to 0.2326 (baseline 0.5809).
# - micro AP, test+ext: variants 0.05473 to 0.1723 (baseline 0.8696).
# - micro AP, held-out per image: variants 0.3418 to 0.4469 (baseline 0.7966).
# - macro F1@0.5, held-out: variants 0 to 0 (baseline 0.1276).
# - macro F1@0.5, test+ext: variants 0 to 0.0012 (baseline 0.508).
# - macro F1@0.5, held-out per image: variants 0 to 0 (baseline 0.1583).

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Paired improvement over the baseline

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# The improvement $\Delta_r = s_m (v_r - b_r)$ of every repetition and its summary over repetitions answer
# the main question directly: an interval entirely above zero means the variant is better than the baseline
# in this stage, entirely below zero means worse.

# %% [markdown]
# #### Implementation
#
# `improvements` (per repetition) and `improvement_summary` (mean, SD, 95 % t interval, sign counts).

# %% [markdown]
# #### Figure descriptions
#
# Forest plot: one panel per key metric and evaluation; rows = variants; diamond = mean improvement, bar = 95 %
# interval, small dots = the five repetitions; the dashed vertical line is the baseline. The table gives
# `mean [interval] (+improving/-worsening repetitions)`.

# %%
figures.improvement_forest(improvement_summary, panels=key_panels(), variants=VARIANTS, labels=VARIANT_LABELS,
                           colors=VARIANT_COLORS, paired=paired, columns=4, theme=theme);
rows = pd.concat([improvement_summary[(improvement_summary.family == spec['family']) & (improvement_summary.metric == spec['metric'])
                                      & (improvement_summary.ranking == spec.get('ranking', 'none'))] for spec in KEY_METRICS])
rows = rows[rows.evaluation.isin(EVALUATIONS)]
display(rows.assign(result=interval(rows), column=rows.metric.map(SHORT) + ' | ' + rows.evaluation)
        .pivot_table(index='variant', columns='column', values='result', aggfunc='first').reindex(VARIANTS))
# Out:
# column                     W1 | heldout_image                  W1 | test          macro AP | heldout_image macro AP | heldout_image_per_image                  macro AP | test  \
# variant
# P0_single          -311 [-567, -56.1] (+0/-5)  -311 [-492, -131] (+0/-5)  -0.127 [-0.158, -0.0965] (+0/-5)    -0.154 [-0.166, -0.143] (+0/-5)   -0.637 [-0.664, -0.61] (+0/-5)
# P1_permutation      -125 [-134, -117] (+0/-5)  -155 [-162, -148] (+0/-5)  -0.113 [-0.133, -0.0942] (+0/-5)    -0.12 [-0.141, -0.0999] (+0/-5)  -0.558 [-0.565, -0.551] (+0/-5)
# P2_joint_base       -187 [-206, -169] (+0/-5)  -219 [-237, -201] (+0/-5)  -0.127 [-0.154, -0.0999] (+0/-5)    -0.146 [-0.159, -0.134] (+0/-5)  -0.644 [-0.664, -0.623] (+0/-5)
# P2_staged_base      -217 [-271, -162] (+0/-5)  -244 [-289, -199] (+0/-5)   -0.134 [-0.151, -0.116] (+0/-5)    -0.164 [-0.183, -0.145] (+0/-5)   -0.65 [-0.663, -0.636] (+0/-5)
# P3_joint_overlap    -171 [-183, -158] (+0/-5)  -200 [-225, -174] (+0/-5)  -0.117 [-0.143, -0.0914] (+0/-5)     -0.147 [-0.16, -0.135] (+0/-5)  -0.647 [-0.659, -0.636] (+0/-5)
# P3_staged_overlap   -216 [-278, -154] (+0/-5)  -242 [-297, -186] (+0/-5)   -0.138 [-0.158, -0.117] (+0/-5)    -0.171 [-0.187, -0.155] (+0/-5)   -0.65 [-0.662, -0.638] (+0/-5)
# P4_joint_rare       -202 [-250, -154] (+0/-5)  -228 [-274, -182] (+0/-5)   -0.126 [-0.144, -0.109] (+0/-5)    -0.147 [-0.156, -0.137] (+0/-5)  -0.648 [-0.661, -0.635] (+0/-5)
# P4_staged_rare      -222 [-269, -174] (+0/-5)  -235 [-272, -199] (+0/-5)  -0.122 [-0.167, -0.0768] (+0/-5)    -0.164 [-0.189, -0.139] (+0/-5)   -0.65 [-0.665, -0.636] (+0/-5)
# P5_joint_all        -191 [-220, -162] (+0/-5)  -216 [-250, -182] (+0/-5)  -0.122 [-0.153, -0.0922] (+0/-5)    -0.152 [-0.163, -0.141] (+0/-5)  -0.648 [-0.662, -0.634] (+0/-5)
# P5_staged_all       -192 [-216, -168] (+0/-5)  -221 [-239, -203] (+0/-5)   -0.131 [-0.151, -0.111] (+0/-5)     -0.163 [-0.18, -0.147] (+0/-5)  -0.649 [-0.661, -0.637] (+0/-5)
#
# column                    macro AP | test_combined  macro F1 at 0.5 | heldout_image macro F1 at 0.5 | heldout_image_per_image           macro F1 at 0.5 | test  macro F1 at 0.5 | test_combined  \
# variant
# P0_single          -0.638 [-0.668, -0.607] (+0/-5)  -0.128 [-0.147, -0.108] (+0/-5)           -0.158 [-0.178, -0.139] (+0/-5)  -0.505 [-0.523, -0.486] (+0/-5)  -0.508 [-0.527, -0.489] (+0/-5)
# P1_permutation     -0.564 [-0.569, -0.559] (+0/-5)  -0.128 [-0.147, -0.108] (+0/-5)           -0.158 [-0.178, -0.139] (+0/-5)  -0.505 [-0.523, -0.486] (+0/-5)  -0.508 [-0.527, -0.489] (+0/-5)
# P2_joint_base      -0.644 [-0.667, -0.621] (+0/-5)  -0.128 [-0.147, -0.108] (+0/-5)           -0.158 [-0.178, -0.139] (+0/-5)  -0.505 [-0.523, -0.486] (+0/-5)  -0.508 [-0.527, -0.489] (+0/-5)
# P2_staged_base     -0.654 [-0.663, -0.644] (+0/-5)  -0.128 [-0.147, -0.108] (+0/-5)           -0.158 [-0.178, -0.139] (+0/-5)  -0.504 [-0.524, -0.485] (+0/-5)  -0.508 [-0.527, -0.488] (+0/-5)
# P3_joint_overlap   -0.651 [-0.661, -0.641] (+0/-5)  -0.128 [-0.147, -0.108] (+0/-5)           -0.158 [-0.178, -0.139] (+0/-5)  -0.505 [-0.523, -0.486] (+0/-5)  -0.508 [-0.527, -0.489] (+0/-5)
# P3_staged_overlap  -0.652 [-0.665, -0.639] (+0/-5)  -0.128 [-0.147, -0.108] (+0/-5)           -0.158 [-0.178, -0.139] (+0/-5)  -0.504 [-0.523, -0.485] (+0/-5)  -0.507 [-0.526, -0.488] (+0/-5)
# P4_joint_rare      -0.652 [-0.662, -0.641] (+0/-5)  -0.128 [-0.147, -0.108] (+0/-5)           -0.158 [-0.178, -0.139] (+0/-5)  -0.504 [-0.523, -0.486] (+0/-5)  -0.508 [-0.527, -0.489] (+0/-5)
# P4_staged_rare     -0.654 [-0.666, -0.642] (+0/-5)  -0.128 [-0.147, -0.108] (+0/-5)           -0.158 [-0.178, -0.139] (+0/-5)  -0.503 [-0.522, -0.485] (+0/-5)  -0.507 [-0.526, -0.488] (+0/-5)
# P5_joint_all       -0.652 [-0.661, -0.643] (+0/-5)  -0.128 [-0.147, -0.108] (+0/-5)           -0.158 [-0.178, -0.139] (+0/-5)  -0.504 [-0.523, -0.486] (+0/-5)  -0.507 [-0.526, -0.489] (+0/-5)
# P5_staged_all       -0.65 [-0.664, -0.636] (+0/-5)  -0.128 [-0.147, -0.108] (+0/-5)           -0.158 [-0.178, -0.139] (+0/-5)  -0.503 [-0.522, -0.485] (+0/-5)  -0.507 [-0.526, -0.488] (+0/-5)
#
# column                    micro AP | heldout_image micro AP | heldout_image_per_image                  micro AP | test         micro AP | test_combined   spectral angle | heldout_image  \
# variant
# P0_single          -0.348 [-0.372, -0.325] (+0/-5)     -0.35 [-0.431, -0.268] (+0/-5)   -0.832 [-0.85, -0.814] (+0/-5)  -0.815 [-0.836, -0.794] (+0/-5)  -0.452 [-0.569, -0.336] (+0/-5)
# P1_permutation     -0.386 [-0.426, -0.346] (+0/-5)    -0.455 [-0.492, -0.417] (+0/-5)   -0.66 [-0.717, -0.602] (+0/-5)  -0.697 [-0.729, -0.665] (+0/-5)  -0.331 [-0.377, -0.284] (+0/-5)
# P2_joint_base      -0.379 [-0.411, -0.348] (+0/-5)    -0.425 [-0.447, -0.403] (+0/-5)  -0.779 [-0.815, -0.744] (+0/-5)  -0.781 [-0.805, -0.756] (+0/-5)  -0.456 [-0.527, -0.384] (+0/-5)
# P2_staged_base     -0.369 [-0.382, -0.355] (+0/-5)    -0.401 [-0.471, -0.331] (+0/-5)    -0.815 [-0.829, -0.8] (+0/-5)  -0.805 [-0.816, -0.795] (+0/-5)   -0.473 [-0.53, -0.416] (+0/-5)
# P3_joint_overlap   -0.387 [-0.425, -0.349] (+0/-5)    -0.436 [-0.474, -0.398] (+0/-5)  -0.765 [-0.778, -0.751] (+0/-5)  -0.773 [-0.785, -0.761] (+0/-5)  -0.452 [-0.518, -0.385] (+0/-5)
# P3_staged_overlap  -0.381 [-0.408, -0.355] (+0/-5)    -0.427 [-0.457, -0.396] (+0/-5)  -0.822 [-0.834, -0.809] (+0/-5)   -0.81 [-0.821, -0.798] (+0/-5)   -0.476 [-0.52, -0.432] (+0/-5)
# P4_joint_rare      -0.385 [-0.417, -0.352] (+0/-5)    -0.434 [-0.469, -0.399] (+0/-5)  -0.768 [-0.788, -0.748] (+0/-5)   -0.776 [-0.79, -0.761] (+0/-5)  -0.454 [-0.511, -0.396] (+0/-5)
# P4_staged_rare     -0.381 [-0.411, -0.352] (+0/-5)    -0.421 [-0.448, -0.393] (+0/-5)  -0.822 [-0.838, -0.807] (+0/-5)  -0.811 [-0.825, -0.798] (+0/-5)   -0.47 [-0.506, -0.435] (+0/-5)
# P5_joint_all       -0.387 [-0.412, -0.363] (+0/-5)     -0.438 [-0.456, -0.42] (+0/-5)  -0.768 [-0.787, -0.749] (+0/-5)   -0.776 [-0.79, -0.762] (+0/-5)  -0.453 [-0.514, -0.393] (+0/-5)
# P5_staged_all      -0.381 [-0.403, -0.358] (+0/-5)    -0.421 [-0.449, -0.393] (+0/-5)   -0.822 [-0.834, -0.81] (+0/-5)  -0.811 [-0.819, -0.802] (+0/-5)  -0.463 [-0.509, -0.417] (+0/-5)
#
# column                         spectral angle | test
# variant
# P0_single          -0.251 [-0.493, -0.00917] (+0/-5)
# P1_permutation       -0.322 [-0.355, -0.289] (+0/-5)
# P2_joint_base        -0.431 [-0.477, -0.384] (+0/-5)
# P2_staged_base       -0.433 [-0.483, -0.383] (+0/-5)
# P3_joint_overlap     -0.427 [-0.465, -0.389] (+0/-5)
# P3_staged_overlap    -0.439 [-0.478, -0.401] (+0/-5)
# P4_joint_rare        -0.428 [-0.459, -0.398] (+0/-5)
# P4_staged_rare       -0.434 [-0.464, -0.405] (+0/-5)
# P5_joint_all         -0.427 [-0.462, -0.393] (+0/-5)
# P5_staged_all        -0.434 [-0.465, -0.403] (+0/-5)

# %% [markdown]
# ### Remarks
#
# - Of 130 variant x key-metric cells, 0 improve (interval above zero), 130 worsen and 0 are inconclusive.
# - W1, test: mean improvement -311 to -155 (best P1 permutations); interval above zero: none; below zero: P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare.
# - W1, held-out: mean improvement -311 to -125 (best P1 permutations); interval above zero: none; below zero: P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare.
# - spectral angle, test: mean improvement -0.439 to -0.251 (best P0 single bins); interval above zero: none; below zero: P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare.
# - spectral angle, held-out: mean improvement -0.476 to -0.331 (best P1 permutations); interval above zero: none; below zero: P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare.
# - macro AP, held-out: mean improvement -0.138 to -0.113 (best P1 permutations); interval above zero: none; below zero: P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare.
# - macro AP, test+ext: mean improvement -0.654 to -0.564 (best P1 permutations); interval above zero: none; below zero: P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare.
# - macro AP, held-out per image: mean improvement -0.171 to -0.12 (best P1 permutations); interval above zero: none; below zero: P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare.
# - micro AP, held-out: mean improvement -0.387 to -0.348 (best P0 single bins); interval above zero: none; below zero: P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare.
# - micro AP, test+ext: mean improvement -0.815 to -0.697 (best P1 permutations); interval above zero: none; below zero: P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare.
# - micro AP, held-out per image: mean improvement -0.455 to -0.35 (best P0 single bins); interval above zero: none; below zero: P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare.
# - macro F1@0.5, held-out: mean improvement -0.128 to -0.128 (best P0 single bins); interval above zero: none; below zero: P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare.
# - macro F1@0.5, test+ext: mean improvement -0.508 to -0.507 (best P4 staged + rare); interval above zero: none; below zero: P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare.
# - macro F1@0.5, held-out per image: mean improvement -0.158 to -0.158 (best P0 single bins); interval above zero: none; below zero: P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare.

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Relative improvement over the complete metric set

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# The key metrics may hide a trade-off. The relative improvement $\Delta_r / |b_r|$ puts every
# reconstruction and head metric on one scale (fraction of the baseline value).

# %% [markdown]
# #### Implementation
#
# Mean over repetitions of `relative_improvement` from `improvements`; reconstruction on test and held-out,
# head (annotation retrieval) on test, test + extension and held-out.

# %% [markdown]
# #### Figure descriptions
#
# Heat map: rows = variants, columns = metric | evaluation, colour = mean relative improvement clipped to
# [-1, 1], diverging around 0 = baseline: red = better than the baseline, blue = worse; the colour range is
# symmetric around the largest absolute value shown. Values beyond the clip are listed below the figure.

# %%
full = paired[paired.evaluation.isin(['test', 'test_combined', 'heldout_image']) & paired.ranking.isin(['none', 'annotation_retrieval'])]
matrix = (full.assign(column=full.metric + ' | ' + full.evaluation)
          .pivot_table(index='variant', columns='column', values='relative_improvement', aggfunc='mean').reindex(VARIANTS))
figures.matrix_heatmap(matrix.clip(-1, 1), title='Mean relative improvement over the baseline (clipped to [-1, 1])',
                       colorbar_label='improvement / |baseline|', diverging=True, theme=theme);
beyond = matrix.stack()
beyond = beyond[beyond.abs() > 1]
if beyond.empty:
    print('No mean relative improvement beyond [-1, 1].')
else:
    display(beyond.rename('relative_improvement').round(2).to_frame())
# Out:
#                                                        relative_improvement
# variant           column
# P0_single         hamming_loss | test                                 -2.30
#                   hamming_loss | test_combined                        -1.89
#                   masserstein | heldout_image                        -68.50
#                   masserstein | test                                 -77.45
#                   mse | heldout_image                                -44.40
#                   mse | test                                         -21.42
# P1_permutation    hamming_loss | test                                 -2.30
#                   hamming_loss | test_combined                        -1.89
#                   masserstein | heldout_image                        -28.04
#                   masserstein | test                                 -38.97
# P2_joint_base     hamming_loss | test                                 -2.30
#                   hamming_loss | test_combined                        -1.89
#                   masserstein | heldout_image                        -42.16
#                   masserstein | test                                 -54.99
#                   mse | heldout_image                                 -1.01
# P2_staged_base    ap_above_prevalence | test                          -1.01
#                   ap_above_prevalence | test_combined                 -1.00
#                   hamming_loss | test                                 -2.31
#                   hamming_loss | test_combined                        -1.89
#                   masserstein | heldout_image                        -49.11
#                   masserstein | test                                 -61.52
#                   mse | heldout_image                                 -1.82
#                   mse | test                                          -1.19
# P3_joint_overlap  ap_above_prevalence | test                          -1.00
#                   ap_above_prevalence | test_combined                 -1.00
#                   hamming_loss | test                                 -2.30
#                   hamming_loss | test_combined                        -1.89
#                   masserstein | heldout_image                        -38.41
#                   masserstein | test                                 -50.35
# P3_staged_overlap ap_above_prevalence | test                          -1.01
#                   ap_above_prevalence | test_combined                 -1.00
#                   hamming_loss | test                                 -2.30
#                   hamming_loss | test_combined                        -1.89
#                   masserstein | heldout_image                        -49.05
#                   masserstein | test                                 -61.04
#                   mse | heldout_image                                 -1.90
#                   mse | test                                          -1.25
# P4_joint_rare     ap_above_prevalence | test                          -1.00
#                   ap_above_prevalence | test_combined                 -1.00
#                   hamming_loss | test                                 -2.30
#                   hamming_loss | test_combined                        -1.89
#                   masserstein | heldout_image                        -45.32
#                   masserstein | test                                 -57.25
# P4_staged_rare    ap_above_prevalence | test                          -1.01
#                   ap_above_prevalence | test_combined                 -1.00
#                   hamming_loss | test                                 -2.30
#                   hamming_loss | test_combined                        -1.89
#                   masserstein | heldout_image                        -49.96
#                   masserstein | test                                 -59.19
#                   mse | heldout_image                                 -1.86
#                   mse | test                                          -1.21
# P5_joint_all      ap_above_prevalence | test                          -1.00
#                   ap_above_prevalence | test_combined                 -1.00
#                   hamming_loss | test                                 -2.30
#                   hamming_loss | test_combined                        -1.89
#                   masserstein | heldout_image                        -43.14
#                   masserstein | test                                 -54.40
#                   mse | heldout_image                                 -1.08
# P5_staged_all     ap_above_prevalence | test                          -1.01
#                   hamming_loss | test                                 -2.30
#                   hamming_loss | test_combined                        -1.89
#                   masserstein | heldout_image                        -43.23
#                   masserstein | test                                 -55.57
#                   mse | heldout_image                                 -1.97
#                   mse | test                                          -1.23

# %% [markdown]
# ### Remarks
#
# - Largest mean relative improvements: P0 single bins hamming_loss held-out -0.162; P1 permutations hamming_loss held-out -0.162; P2 joint hamming_loss held-out -0.162.
# - Largest mean relative losses: P0 single bins masserstein test -77.5; P0 single bins masserstein held-out -68.5; P2 staged masserstein test -61.5.

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Generalization gap to new images

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# The gap $g = v^{\mathrm{heldout}} - v^{\mathrm{test}}$ measures how much a model loses from new pixels
# of seen images to new images. Its improvement $s_m (g^{v}_r - g^{b}_r)$ is positive when the variant
# loses less than the baseline (for lower-is-better metrics: when its held-out error grows less).

# %% [markdown]
# #### Implementation
#
# `generalization_gap` holds the gap per model and its paired improvement; summarized here with the
# library's `summarize` (same t interval).

# %% [markdown]
# #### Figure descriptions
#
# Forest plot as above, one panel per key metric; the table gives the interval strings.

# %%
gap = table('generalization_gap')
gap_summary = summarize(gap, ['variant', 'family', 'metric', 'ranking'])
panels = [(SHORT[spec['metric']], {'family': spec['family'], 'metric': spec['metric'], 'ranking': spec.get('ranking', 'none')})
          for spec in KEY_METRICS]
figures.improvement_forest(gap_summary, panels=panels, variants=VARIANTS, labels=VARIANT_LABELS, colors=VARIANT_COLORS,
                           paired=gap, columns=5, theme=theme);
shown = gap_summary[gap_summary.metric.isin(SHORT) & gap_summary.ranking.isin(['none', 'annotation_retrieval'])]
display(shown.assign(result=interval(shown)).pivot_table(index='variant', columns='metric', values='result', aggfunc='first').reindex(VARIANTS))
# Out:
# metric                        average_precision                            f1                   masserstein       micro_average_precision                       spectral_angle
# variant
# P0_single            0.51 [0.49, 0.529] (+5/-0)  0.377 [0.356, 0.398] (+5/-0)  -0.114 [-79.9, 79.7] (+4/-1)  0.483 [0.461, 0.506] (+5/-0)     -0.201 [-0.362, -0.0403] (+0/-5)
# P1_permutation     0.445 [0.428, 0.461] (+5/-0)  0.377 [0.356, 0.398] (+5/-0)     30.2 [23.6, 36.8] (+5/-0)  0.274 [0.203, 0.345] (+5/-0)   -0.00868 [-0.025, 0.00764] (+1/-4)
# P2_joint_base      0.517 [0.488, 0.546] (+5/-0)  0.377 [0.356, 0.398] (+5/-0)       31.4 [24.8, 38] (+5/-0)    0.4 [0.368, 0.432] (+5/-0)   -0.0251 [-0.0539, 0.00363] (+1/-4)
# P2_staged_base     0.516 [0.496, 0.537] (+5/-0)  0.377 [0.355, 0.399] (+5/-0)       27.4 [12, 42.7] (+5/-0)   0.446 [0.432, 0.46] (+5/-0)  -0.0404 [-0.0731, -0.00766] (+0/-5)
# P3_joint_overlap    0.53 [0.505, 0.555] (+5/-0)  0.377 [0.356, 0.398] (+5/-0)       29.3 [12, 46.7] (+5/-0)  0.378 [0.348, 0.407] (+5/-0)   -0.0249 [-0.0569, 0.00714] (+1/-4)
# P3_staged_overlap  0.512 [0.501, 0.523] (+5/-0)  0.376 [0.354, 0.398] (+5/-0)     25.5 [3.35, 47.6] (+5/-0)   0.44 [0.417, 0.463] (+5/-0)   -0.0362 [-0.0612, -0.0113] (+0/-5)
# P4_joint_rare       0.522 [0.51, 0.534] (+5/-0)  0.377 [0.356, 0.398] (+5/-0)     26.2 [9.06, 43.4] (+5/-0)  0.384 [0.366, 0.401] (+5/-0)   -0.0252 [-0.0547, 0.00422] (+1/-4)
# P4_staged_rare     0.528 [0.494, 0.563] (+5/-0)  0.376 [0.354, 0.397] (+5/-0)    13.4 [-13.7, 40.6] (+3/-2)  0.441 [0.412, 0.469] (+5/-0)   -0.0357 [-0.0468, -0.0246] (+0/-5)
# P5_joint_all       0.526 [0.502, 0.549] (+5/-0)  0.377 [0.355, 0.398] (+5/-0)     24.8 [11.5, 38.1] (+5/-0)  0.381 [0.359, 0.403] (+5/-0)    -0.0259 [-0.0571, 0.0053] (+1/-4)
# P5_staged_all      0.518 [0.504, 0.532] (+5/-0)  0.376 [0.354, 0.397] (+5/-0)     29.1 [21.4, 36.8] (+5/-0)  0.441 [0.419, 0.464] (+5/-0)  -0.0289 [-0.0506, -0.00714] (+0/-5)

# %% [markdown]
# ### Remarks
#
# - macro AP: smaller loss to new images than the baseline for P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare; larger loss for no variant.
# - macro F1@0.5: smaller loss to new images than the baseline for P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare; larger loss for no variant.
# - micro AP: smaller loss to new images than the baseline for P0 single bins, P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P4 staged + rare, P5 joint + overlap + rare, P5 staged + overlap + rare; larger loss for no variant.
# - W1: smaller loss to new images than the baseline for P1 permutations, P2 joint, P2 staged, P3 joint + overlap, P3 staged + overlap, P4 joint + rare, P5 joint + overlap + rare, P5 staged + overlap + rare; larger loss for no variant.
# - spectral angle: smaller loss to new images than the baseline for no variant; larger loss for P0 single bins, P2 staged, P3 staged + overlap, P4 staged + rare, P5 staged + overlap + rare.
# - Caveat: at this stage the variants are far below the baseline (on every metric), so a smaller loss to new images is a level artefact, not better generalization: a model near chance on both populations has nothing to lose (e.g. its held-out macro AP is close to the prevalence of the few held-out classes, see the prediction notebook).

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Variant ranking used to pick the displayed variant

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# Images and representatives in later notebooks show the best variant of each stage. It is the variant with
# the lowest mean rank of its mean improvement over the five key metrics on the withheld **test** pixels
# (never on the held-out images that are displayed); equal mean ranks are decided by the macro-AP improvement.

# %% [markdown]
# #### Implementation
#
# `variant_ranking` (mean rank, tie-break rank, final rank).

# %% [markdown]
# #### Figure descriptions
#
# No figure.

# %%
display(table('variant_ranking').drop(columns=['axis']))
# Out:
#              variant  mean_rank  tie_rank  rank       stage
# 0     P1_permutation        2.8       1.0     1  pretrained
# 1       P5_joint_all        3.8       5.0     2  pretrained
# 2   P3_joint_overlap        4.0       4.0     3  pretrained
# 3      P2_joint_base        5.0       3.0     4  pretrained
# 4      P4_joint_rare        5.4       6.0     5  pretrained
# 5      P5_staged_all        6.0       7.0     6  pretrained
# 6          P0_single        6.4       2.0     7  pretrained
# 7  P3_staged_overlap        7.2       8.0     8  pretrained
# 8     P2_staged_base        7.2       9.0     9  pretrained
# 9     P4_staged_rare        7.2      10.0    10  pretrained

# %% [markdown]
# ### Remarks
#
# - Best variant on the test pixels: P1 permutations (mean rank 2.8 of 10); last: P4 staged + rare (7.2). Mean ranks span 2.8-7.2. The spread is small, so the choice of the displayed variant is weakly determined.

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Results / Summary
#
# ### LLM
#
# - **Observed:** 0 of 130 variant x key-metric cells improve on the baseline, 130 worsen, 0 are inconclusive (95 % t interval, five paired repetitions).
# - **Observed:** test W1 159-315 against 3.99 for the baseline; macro AP (test + extension) 0.0544-0.144 against 0.708.
# - **Interpretation:** without real-data training no variant is usable on real spectra: the reconstruction is an order of magnitude worse and the synthetic head never reaches p = 0.5 on real data (F1 = 0, part 2_03). The pretrained model is a starting point, not a competitor of the baseline; the thesis can only be decided at the fine-tuned stages.
#
# **Absolute levels against the real-only baseline** (means over repetitions; 'better' compares means only, without a test; the intervals are in the improvement sections):
#
# - W1, test: baseline 3.988; others 159.3-315.3; 0 of 10 better than the baseline; best P1 permutations (159.3), worst P0 single bins (315.3).
# - W1, heldout_image: baseline 4.467; others 129.6-315.9; 0 of 10 better than the baseline; best P1 permutations (129.6), worst P0 single bins (315.9).
# - spectral angle, test: baseline 1.094; others 1.345-1.534; 0 of 10 better than the baseline; best P0 single bins (1.345), worst P3 staged + overlap (1.534).
# - spectral angle, heldout_image: baseline 1.058; others 1.389-1.534; 0 of 10 better than the baseline; best P1 permutations (1.389), worst P3 staged + overlap (1.534).
# - macro AP, test_combined: baseline 0.7084; others 0.05439-0.1444; 0 of 10 better than the baseline; best P1 permutations (0.1444), worst P4 staged + rare (0.05439).
# - macro AP, heldout_image_per_image: baseline 0.6105; others 0.4394-0.4902; 0 of 10 better than the baseline; best P1 permutations (0.4902), worst P3 staged + overlap (0.4394).
# - micro AP, test_combined: baseline 0.8696; others 0.05473-0.1723; 0 of 10 better than the baseline; best P1 permutations (0.1723), worst P0 single bins (0.05473).
# - micro AP, heldout_image_per_image: baseline 0.7966; others 0.3418-0.4469; 0 of 10 better than the baseline; best P0 single bins (0.4469), worst P1 permutations (0.3418).
# - macro F1 at 0.5, test_combined: baseline 0.508; others 0-0.0012; 0 of 10 better than the baseline; best P4 staged + rare (0.0012), worst P0 single bins (0).
# - macro F1 at 0.5, heldout_image_per_image: baseline 0.1583; others 0-0; 0 of 10 better than the baseline; best P0 single bins (0), worst P0 single bins (0).

# %% [markdown]
# ### Person
