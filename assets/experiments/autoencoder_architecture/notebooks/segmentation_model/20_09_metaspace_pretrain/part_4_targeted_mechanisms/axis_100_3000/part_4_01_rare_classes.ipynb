# %% [markdown]
# # Rare-class quota: does it improve the classes it targets? (axis-100-3000)
#
# The rare quota adds 30 synthetic tokens for every class of the least-annotated quarter of the generator-eligible classes. If the mechanism works, exactly those classes should gain, and they should gain more than the other eligible classes and more than in the matched variant without the quota.

# %% [markdown]
# ## Introduction
#
# The thesis tested in parts 2-6 is that synthetic pretraining improves on the model trained on real data only.
# Every table therefore contains the **real-only baseline** of the same axis (10 real epochs from the same
# initialization) and every comparison is a **paired difference to that baseline**.
#
# The ten pretraining variants differ only in the synthetic data seen before real data (campaign methodology,
# `pretraining_campaign_methodology.md`):
#
# | Variant | Synthetic phases | Construction |
# | --- | --- | --- |
# | P0 single bins | 1 x 10 epochs | ten spectra per axis bin; annotated bins carry their labels, blank bins are known negatives |
# | P1 permutations | 1 x 10 epochs | component-token bag (30 per class and per blank bin) packed into mixed spectra |
# | P2 joint / staged | 1 x 10 / 2 x 10 epochs | P0 and P1 rows shuffled together / P0 first, then P1 |
# | P3 joint / staged | as P2 | P2 + overlap quota (30 extra tokens per class that shares a bin with another class in a training pixel) |
# | P4 joint / staged | as P2 | P2 + rare quota (30 extra tokens per class of the least-annotated quarter) |
# | P5 joint / staged | as P2 | P2 + both quotas |
#
# Every variant yields three models along one lineage (stages): `pretrained`, `frozen_head` and `unfrozen_head`.
# The staged schedules train twice as many synthetic epochs as the joint ones, so schedule and budget are
# confounded (methodology, "Pretraining ablation").
#
# ### Assumptions
#
# * **Pairing.** Repetition $r$ uses one initialization seed for the baseline and for every variant and stage
#   (verified for all 310 models in the campaign-plan verification). The difference between a variant and the
#   baseline of the same repetition removes the initialization effect; the five repetitions are the independent
#   units. Pixels are not independent units and never enter a test as such.
# * **Data.** Every model is evaluated on identical pixels: the same `train`, `test`, `test_extended` and
#   `heldout_image` populations as in part 1, decoded once in the shared cache.
# * **Objectives.** Synthetic phases: Masserstein (1.0) + BCE (0.2) on complete synthetic targets. Real phases
#   (baseline and both fine-tuning stages): Masserstein (1.0) + VPU (0.2) + contractive (2e-3) + InfoNCE (1e-3,
#   multilabel-Jaccard negatives, added by mistake and kept because every model used it).
# * **Threshold metrics.** Precision, recall and F1 use $\hat Y \ge 0.5$, as in part 1. A head whose
#   probabilities never reach 0.5 on real data has F1 = 0 although its ranking may still carry information;
#   average precision is threshold free and is the primary head metric.
# * **Uncertainty.** With five repetitions the Student-t interval has 4 degrees of freedom
#   ($t_{0.975,4} = 2.78$); an interval that excludes zero is a strong statement, one that includes zero is not
#   evidence of no effect.
#
# * **Matched controls.** P4 joint vs P2 joint, P4 staged vs P2 staged, P5 joint vs P3 joint and P5 staged vs P3
#   staged differ only in the rare quota; paired by stage and repetition.
# * **Class sets.** `rare`: generator-eligible classes that received rare-bonus tokens; `other_eligible`: the
#   remaining generator-eligible classes. Classes the generator cannot synthesize are excluded from both.
#
# ### Notation
#
# * $b_r$, $v_r$: value of a metric for the baseline and for a variant (at one stage) in repetition $r$.
# * $s_m \in \{-1, +1\}$: direction of metric $m$; $-1$ for lower-is-better metrics (Masserstein $W_1$,
#   spectral angle, MSE, Hamming loss, window contribution and within-window $W_1$, absolute mass imbalance, ECE,
#   Brier score, true-label rank, false-positive rate and lift, losses), $+1$ otherwise.
# * **Improvement** $\Delta_r = s_m (v_r - b_r)$: positive is always better than the baseline.
#   **Relative improvement** $\Delta_r / |b_r|$.
# * Summary over repetitions: mean $\bar\Delta$, SD $s$, interval $\bar\Delta \pm t_{0.975, n-1}\, s / \sqrt{n}$,
#   and the numbers of repetitions with $\Delta_r > 0$ (`+k`) and $\Delta_r < 0$ (`-m`).
# * Evaluations: `test` (withheld pixels of training images), `test_combined` (test + rare-class extension, the
#   main per-class estimate), `heldout_image` (three images never seen; pooled), `heldout_image_per_image` (mean of
#   the per-image values; pooled held-out values understate the ranking because annotations are incomplete across
#   images, part 1_08).
# * $W_1$: exact one-dimensional Wasserstein-1 distance between TIC-normalized input and reconstruction (m/z
#   units); $u$: canonical latent code (LayerNorm affine removed).
#
# * $n_c$: training annotation count of class $c$; eligible classes are ranked by $n_c$ (ties by class index) and the
#   lowest $\lceil 0.25 \cdot |\mathrm{eligible}| \rceil$ are rare.

# %% [markdown]
# ## Configuration

# %%
import logging
import os
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display

# Library modules log INFO to stdout; warnings stay visible, progress messages do not.
logging.disable(logging.INFO)
current_path = Path.cwd().resolve()
repository_root = next(path for path in (current_path, *current_path.parents) if (path / "pyproject.toml").is_file())
os.chdir(repository_root)

from msi_autoencoder_wrapper.analysis.autoencoder.experiments import pretraining_campaign as campaign
from msi_autoencoder_wrapper.analysis.autoencoder.experiments.pretraining_campaign_precompute import (
    load_metadata, load_table, run_command,
)
from msi_autoencoder_wrapper.analysis.precompute.notebook_inputs import load_model_catalog, load_visualization_theme
from msi_autoencoder_wrapper.visualization import pretraining as figures

SETTINGS_PATH = Path("assets/experiments/autoencoder_architecture/notebooks/segmentation_model/20_09_metaspace_pretrain/analysis_settings.yaml")
ANALYSIS = "rare_classes"
AXIS = "axis-100-3000"
STAGE = None

settings = campaign.load_settings(SETTINGS_PATH)
theme = load_visualization_theme(settings).with_overrides(figure_dpi=100)
catalog = load_model_catalog(settings)
metadata = load_metadata(settings, ANALYSIS, AXIS, STAGE)
pd.set_option("display.precision", 4)
pd.set_option("display.width", 200)
pd.set_option("display.max_columns", 40)
pd.set_option("display.max_rows", 80)


def table(name: str) -> pd.DataFrame:
    """Load one canonical table written for this notebook by the precompute."""
    return load_table(settings, ANALYSIS, name, AXIS, STAGE)


def mean_sd(frame: pd.DataFrame, keys: list, columns: list) -> pd.DataFrame:
    """Mean and SD over repetitions of the given columns (presentation helper)."""
    long = frame.melt(id_vars=keys, value_vars=columns, var_name="quantity", value_name="value")
    return long.groupby([*keys, "quantity"]).value.agg(["mean", "std"]).unstack("quantity")


POPULATION_COLORS = {name: figures.population_color(name, theme) for name in figures.POPULATION_ORDER}
print("Analysis:", ANALYSIS, "| axis:", AXIS, "| stage:", STAGE, "| models:", metadata["models"] if isinstance(metadata["models"], int) else len(metadata["models"]))
print("Cache keys:", metadata["cache_keys"])

BASELINE = "baseline"
VARIANTS = list(settings["variants"])
VARIANT_LABELS = {BASELINE: "real-only baseline", **{name: value["label"] for name, value in settings["variants"].items()}}
## The baseline keeps its catalog colour (the dark theme baseline colour is reserved for reference lines)
BASELINE_COLOR = next(value["visualization"]["color"] for value in settings["models"].values()
                      if value.get("select", {}).get("role") == settings["baseline_role"])
VARIANT_COLORS = {BASELINE: BASELINE_COLOR, **{name: value["color"] for name, value in settings["variants"].items()}}
STAGES = list(settings["stages"])
STAGE_LABELS = {"real_only": "real-only baseline", **{name: value["label"] for name, value in settings["stages"].items()}}
KEY_METRICS = settings["comparison"]["key_metrics"]
AXES = list(settings["axes"])
AXIS_LABELS = {name: value["label"] for name, value in settings["axes"].items()}
SHORT = {"masserstein": "W1", "spectral_angle": "spectral angle", "average_precision": "macro AP",
         "micro_average_precision": "micro AP", "f1": "macro F1 at 0.5"}
EVALUATION_NAMES = {**figures.DISPLAY_NAMES, "heldout_image_per_image": "held-out, per image"}


def key_panels(reconstruction=("test", "heldout_image"), prediction=("test_combined", "heldout_image_per_image")):
    """Forest-plot panels of the key metrics: (title, row selector)."""
    panels = []
    for spec in KEY_METRICS:
        for evaluation in (reconstruction if spec["family"] == "reconstruction" else prediction):
            selector = {"family": spec["family"], "metric": spec["metric"], "evaluation": evaluation,
                        "ranking": spec.get("ranking", "none")}
            panels.append((f"{SHORT.get(spec['metric'], spec['metric'])}, {EVALUATION_NAMES.get(evaluation, evaluation)}", selector))
    return panels


def interval(frame, digits=3):
    """'mean [ci_low, ci_high] (+k/-m)' strings of a summary table."""
    form = "{:." + str(digits) + "g}"
    return (frame["mean"].map(form.format) + " [" + frame.ci_low.map(form.format) + ", "
            + frame.ci_high.map(form.format) + "] (+" + frame.positive.astype(int).astype(str) + "/-"
            + frame.negative.astype(int).astype(str) + ")")

from msi_autoencoder_wrapper.analysis.autoencoder.experiments.pretraining_campaign_comparison import summarize

ORDER = [BASELINE, *VARIANTS]

classes = table('classes')
baseline_summary = table('baseline_summary')
control_summary = table('control_summary')
PAIRS = settings['targeted']['rare']['pairs']
TREATED = list(PAIRS)
PAIR_LABELS = {treated: f"{VARIANT_LABELS[treated]} - {VARIANT_LABELS[control]}" for treated, control in PAIRS.items()}
print('Rare classes:', metadata['rare_classes'], '| eligible:', metadata['eligible_classes'], '| cutoff rank:', metadata['cutoff_rank'])
# Out:
# Analysis: rare_classes | axis: axis-100-3000 | stage: None | models: 155
# Cache keys: {'plan': 'f34a92a8f6f7833f', 'populations': '513690bdd78a83ce', 'synthetic_reference': '6ba5bc1e0839ba0e', 'inference': '0243c1efb93b9c4c'}
# Rare classes: 26 | eligible: 103 | cutoff rank: 26.0

# %% [markdown]
# ## Producing the tables this notebook reads
#
# ### Methodology
#
# #### Implementation
#
# `rare_classes` reads the class flags of the regenerated synthetic artifact (`synthetic_reference` level: the
# rare set is read from the rare-bonus tokens of the manifest and checked against the configured rule), the
# per-class head tables of every model and the stored logits for the true-label ranks.
#
# The command below is generated by the precompute entry point itself; if a table is missing, `load_table` raises with the same command.

# %%
print(run_command(settings, ANALYSIS))
# Out:
# nohup uv run --extra cu118 python -m msi_autoencoder_wrapper.analysis.precompute --settings /home/max/repositories/MSIAutoEncoderWrapper/assets/experiments/autoencoder_architecture/notebooks/segmentation_model/20_09_metaspace_pretrain/analysis_settings.yaml --analysis rare_classes > /home/max/repositories/MSIAutoEncoderWrapper/assets/experiments/autoencoder_architecture/notebooks/segmentation_model/20_09_metaspace_pretrain/shared_precompute.log 2>&1 &

# %% [markdown]
# ### Remarks

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Absolute metrics of the targeted class sets against the real-only baseline

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# The improvements and matched controls below are differences; this section shows the level of every
# targeted class-set metric for the real-only baseline and every variant at every stage.

# %% [markdown]
# #### Implementation
#
# `set_metrics` holds one value per model, class set, metric and evaluation population.

# %% [markdown]
# #### Figure descriptions
#
#         Figure: one panel per metric; x = real-only baseline and the stages (every variant's repetitions pooled per
#         stage; 50 models per stage against 5 baseline models), violin and points = models. Tables (one per metric): rows
#         = baseline and variants, columns = stages; the baseline row repeats the baseline value in every stage column so
#         that each cell is compared with it.
#         Last figure: the unfrozen-head stage only, split by variant (x = real-only baseline and every variant, five
#         repetitions each), because pooling the variants of a stage mixes variants with very different effects.
#
# Colours: in the figures the baseline is grey (its mean is the dashed line) and every other group is green when its
# mean is better than the baseline mean and red when it is worse. In the tables every cell is mean +/- SD over the
# repetitions; green / red cells are better / worse than the baseline cell of the same column (stronger colour = larger
# difference within the column), the black frame marks the three best rows of the column and the grey bold row is the
# real-only baseline.

# %%
LOWER_IS_BETTER = {'masserstein', 'spectral_angle', 'mse', 'hamming_loss', 'expected_calibration_error', 'brier_score',
                   'within', 'contribution', 'absolute_mass_imbalance', 'bic'}
METRIC_ORDER = ['average_precision', 'micro_average_precision', 'roc_auc', 'micro_roc_auc', 'ap_above_prevalence',
                'precision', 'recall', 'f1', 'micro_precision', 'micro_recall', 'micro_f1', 'micro_prevalence',
                'hamming_loss']
ABS_ORDER = [BASELINE, *VARIANTS]
LABELS_ABS = {**VARIANT_LABELS, **{name: VARIANT_LABELS.get(name, name) for name in ABS_ORDER}}


def better(metric):
    """Direction of a metric: 'lower' or 'higher' is better."""
    return 'lower' if metric in LOWER_IS_BETTER else 'higher'

# %%
frame_abs = table('set_metrics')

SELECTORS_ABS = [["test_combined | average_precision | rare", {"evaluation": "test_combined", "metric": "average_precision", "class_set": "rare"}, "higher"], ["test_extended | average_precision | rare", {"evaluation": "test_extended", "metric": "average_precision", "class_set": "rare"}, "higher"], ["test_combined | recall | rare", {"evaluation": "test_combined", "metric": "recall", "class_set": "rare"}, "higher"], ["test_extended | recall | rare", {"evaluation": "test_extended", "metric": "recall", "class_set": "rare"}, "higher"], ["heldout_image | average_precision | other_eligible", {"evaluation": "heldout_image", "metric": "average_precision", "class_set": "other_eligible"}, "higher"], ["test_combined | average_precision | other_eligible", {"evaluation": "test_combined", "metric": "average_precision", "class_set": "other_eligible"}, "higher"], ["test_extended | average_precision | other_eligible", {"evaluation": "test_extended", "metric": "average_precision", "class_set": "other_eligible"}, "higher"], ["heldout_image | recall | other_eligible", {"evaluation": "heldout_image", "metric": "recall", "class_set": "other_eligible"}, "higher"], ["test_combined | recall | other_eligible", {"evaluation": "test_combined", "metric": "recall", "class_set": "other_eligible"}, "higher"], ["test_extended | recall | other_eligible", {"evaluation": "test_extended", "metric": "recall", "class_set": "other_eligible"}, "higher"]]
STAGE_ORDER = ['real_only', *STAGES]
figures.metric_panels(frame_abs, panels=[(label, selector, direction) for label, selector, direction in SELECTORS_ABS], group='stage',
                      order=STAGE_ORDER, labels=STAGE_LABELS, baseline='real_only', columns=4, theme=theme);
plt.show()
for label, selector, direction in SELECTORS_ABS:
    rows = frame_abs
    for column, value in selector.items():
        rows = rows[rows[column] == value]
    base = rows[rows.stage == 'real_only']
    grid = pd.concat([rows[rows.stage != 'real_only'], *[base.assign(stage=stage) for stage in STAGES]])
    print(label)
    display(figures.comparison_table(grid, index='variant', columns='stage', baseline=BASELINE, order=ABS_ORDER,
                                     column_order=STAGES, direction={stage: direction for stage in STAGES}))
# Out:
# test_combined | average_precision | rare
# <style type="text/css">
# #T_2484e_row0_col0, #T_2484e_row0_col1, #T_2484e_row0_col2 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_2484e_row1_col0 {
#   background-color: rgba(215, 48, 39, 0.71);
#   border: 2px solid black;
# }
# #T_2484e_row1_col1 {
#   background-color: rgba(215, 48, 39, 0.64);
# }
# #T_2484e_row1_col2 {
#   background-color: rgba(26, 152, 80, 0.75);
#   border: 2px solid black;
# }
# #T_2484e_row2_col0 {
#   background-color: rgba(215, 48, 39, 0.63);
#   border: 2px solid black;
# }
# #T_2484e_row2_col1, #T_2484e_row3_col0, #T_2484e_row4_col0, #T_2484e_row6_col0 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_2484e_row2_col2 {
#   background-color: rgba(215, 48, 39, 0.27);
#   border: 2px solid black;
# }
# #T_2484e_row3_col1, #T_2484e_row6_col1, #T_2484e_row7_col2 {
#   background-color: rgba(215, 48, 39, 0.65);
# }
# #T_2484e_row3_col2 {
#   background-color: rgba(215, 48, 39, 0.55);
# }
# #T_2484e_row4_col1 {
#   background-color: rgba(215, 48, 39, 0.67);
# }
# #T_2484e_row4_col2 {
#   background-color: rgba(215, 48, 39, 0.44);
# }
# #T_2484e_row5_col0, #T_2484e_row7_col0, #T_2484e_row8_col0, #T_2484e_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_2484e_row5_col1 {
#   background-color: rgba(215, 48, 39, 0.60);
#   border: 2px solid black;
# }
# #T_2484e_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.34);
# }
# #T_2484e_row6_col2 {
#   background-color: rgba(215, 48, 39, 0.31);
# }
# #T_2484e_row7_col1, #T_2484e_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.62);
#   border: 2px solid black;
# }
# #T_2484e_row8_col1 {
#   background-color: rgba(215, 48, 39, 0.69);
# }
# #T_2484e_row8_col2 {
#   background-color: rgba(215, 48, 39, 0.25);
#   border: 2px solid black;
# }
# #T_2484e_row9_col0 {
#   background-color: rgba(215, 48, 39, 0.73);
#   border: 2px solid black;
# }
# #T_2484e_row9_col2 {
#   background-color: rgba(215, 48, 39, 0.48);
# }
# #T_2484e_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.72);
# }
# #T_2484e_row10_col2 {
#   background-color: rgba(215, 48, 39, 0.32);
# }
# </style>
# <table id="T_2484e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >stage</th>
#       <th id="T_2484e_level0_col0" class="col_heading level0 col0" >pretrained</th>
#       <th id="T_2484e_level0_col1" class="col_heading level0 col1" >frozen_head</th>
#       <th id="T_2484e_level0_col2" class="col_heading level0 col2" >unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2484e_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_2484e_row0_col0" class="data row0 col0" >0.644 +/- 0.007</td>
#       <td id="T_2484e_row0_col1" class="data row0 col1" >0.644 +/- 0.007</td>
#       <td id="T_2484e_row0_col2" class="data row0 col2" >0.644 +/- 0.007</td>
#     </tr>
#     <tr>
#       <th id="T_2484e_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_2484e_row1_col0" class="data row1 col0" >0.121 +/- 0.045</td>
#       <td id="T_2484e_row1_col1" class="data row1 col1" >0.219 +/- 0.018</td>
#       <td id="T_2484e_row1_col2" class="data row1 col2" >0.654 +/- 0.002</td>
#     </tr>
#     <tr>
#       <th id="T_2484e_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_2484e_row2_col0" class="data row2 col0" >0.188 +/- 0.133</td>
#       <td id="T_2484e_row2_col1" class="data row2 col1" >0.121 +/- 0.035</td>
#       <td id="T_2484e_row2_col2" class="data row2 col2" >0.643 +/- 0.009</td>
#     </tr>
#     <tr>
#       <th id="T_2484e_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_2484e_row3_col0" class="data row3 col0" >0.082 +/- 0.008</td>
#       <td id="T_2484e_row3_col1" class="data row3 col1" >0.205 +/- 0.055</td>
#       <td id="T_2484e_row3_col2" class="data row3 col2" >0.638 +/- 0.007</td>
#     </tr>
#     <tr>
#       <th id="T_2484e_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_2484e_row4_col0" class="data row4 col0" >0.084 +/- 0.020</td>
#       <td id="T_2484e_row4_col1" class="data row4 col1" >0.194 +/- 0.032</td>
#       <td id="T_2484e_row4_col2" class="data row4 col2" >0.640 +/- 0.009</td>
#     </tr>
#     <tr>
#       <th id="T_2484e_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_2484e_row5_col0" class="data row5 col0" >0.092 +/- 0.011</td>
#       <td id="T_2484e_row5_col1" class="data row5 col1" >0.253 +/- 0.063</td>
#       <td id="T_2484e_row5_col2" class="data row5 col2" >0.641 +/- 0.008</td>
#     </tr>
#     <tr>
#       <th id="T_2484e_level0_row6" class="row_heading level0 row6" >P3_staged_overlap</th>
#       <td id="T_2484e_row6_col0" class="data row6 col0" >0.080 +/- 0.006</td>
#       <td id="T_2484e_row6_col1" class="data row6 col1" >0.206 +/- 0.022</td>
#       <td id="T_2484e_row6_col2" class="data row6 col2" >0.642 +/- 0.007</td>
#     </tr>
#     <tr>
#       <th id="T_2484e_level0_row7" class="row_heading level0 row7" >P4_joint_rare</th>
#       <td id="T_2484e_row7_col0" class="data row7 col0" >0.086 +/- 0.018</td>
#       <td id="T_2484e_row7_col1" class="data row7 col1" >0.233 +/- 0.046</td>
#       <td id="T_2484e_row7_col2" class="data row7 col2" >0.637 +/- 0.011</td>
#     </tr>
#     <tr>
#       <th id="T_2484e_level0_row8" class="row_heading level0 row8" >P4_staged_rare</th>
#       <td id="T_2484e_row8_col0" class="data row8 col0" >0.086 +/- 0.013</td>
#       <td id="T_2484e_row8_col1" class="data row8 col1" >0.170 +/- 0.030</td>
#       <td id="T_2484e_row8_col2" class="data row8 col2" >0.643 +/- 0.009</td>
#     </tr>
#     <tr>
#       <th id="T_2484e_level0_row9" class="row_heading level0 row9" >P5_joint_all</th>
#       <td id="T_2484e_row9_col0" class="data row9 col0" >0.094 +/- 0.030</td>
#       <td id="T_2484e_row9_col1" class="data row9 col1" >0.235 +/- 0.057</td>
#       <td id="T_2484e_row9_col2" class="data row9 col2" >0.639 +/- 0.010</td>
#     </tr>
#     <tr>
#       <th id="T_2484e_level0_row10" class="row_heading level0 row10" >P5_staged_all</th>
#       <td id="T_2484e_row10_col0" class="data row10 col0" >0.085 +/- 0.012</td>
#       <td id="T_2484e_row10_col1" class="data row10 col1" >0.144 +/- 0.058</td>
#       <td id="T_2484e_row10_col2" class="data row10 col2" >0.642 +/- 0.005</td>
#     </tr>
#   </tbody>
# </table>
# test_extended | average_precision | rare
# <style type="text/css">
# #T_9c8af_row0_col0, #T_9c8af_row0_col1, #T_9c8af_row0_col2 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_9c8af_row1_col0, #T_9c8af_row2_col0, #T_9c8af_row2_col1, #T_9c8af_row3_col2 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_9c8af_row1_col1, #T_9c8af_row4_col1 {
#   background-color: rgba(215, 48, 39, 0.57);
# }
# #T_9c8af_row1_col2 {
#   background-color: rgba(26, 152, 80, 0.41);
#   border: 2px solid black;
# }
# #T_9c8af_row2_col2 {
#   background-color: rgba(26, 152, 80, 0.15);
#   border: 2px solid black;
# }
# #T_9c8af_row3_col0 {
#   background-color: rgba(215, 48, 39, 0.66);
#   border: 2px solid black;
# }
# #T_9c8af_row3_col1 {
#   background-color: rgba(215, 48, 39, 0.43);
#   border: 2px solid black;
# }
# #T_9c8af_row4_col0, #T_9c8af_row7_col0 {
#   background-color: rgba(215, 48, 39, 0.73);
# }
# #T_9c8af_row4_col2 {
#   background-color: rgba(215, 48, 39, 0.38);
# }
# #T_9c8af_row5_col0 {
#   background-color: rgba(215, 48, 39, 0.72);
# }
# #T_9c8af_row5_col1 {
#   background-color: rgba(215, 48, 39, 0.41);
#   border: 2px solid black;
# }
# #T_9c8af_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.49);
# }
# #T_9c8af_row6_col0, #T_9c8af_row8_col0 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_9c8af_row6_col1 {
#   background-color: rgba(215, 48, 39, 0.64);
# }
# #T_9c8af_row6_col2 {
#   background-color: rgba(215, 48, 39, 0.46);
# }
# #T_9c8af_row7_col1, #T_9c8af_row8_col2 {
#   background-color: rgba(215, 48, 39, 0.48);
# }
# #T_9c8af_row7_col2 {
#   background-color: rgba(215, 48, 39, 0.34);
# }
# #T_9c8af_row8_col1 {
#   background-color: rgba(215, 48, 39, 0.58);
# }
# #T_9c8af_row9_col0 {
#   background-color: rgba(215, 48, 39, 0.71);
#   border: 2px solid black;
# }
# #T_9c8af_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.46);
#   border: 2px solid black;
# }
# #T_9c8af_row9_col2 {
#   background-color: rgba(215, 48, 39, 0.24);
#   border: 2px solid black;
# }
# #T_9c8af_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.72);
#   border: 2px solid black;
# }
# #T_9c8af_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.70);
# }
# #T_9c8af_row10_col2 {
#   background-color: rgba(215, 48, 39, 0.27);
# }
# </style>
# <table id="T_9c8af">
#   <thead>
#     <tr>
#       <th class="index_name level0" >stage</th>
#       <th id="T_9c8af_level0_col0" class="col_heading level0 col0" >pretrained</th>
#       <th id="T_9c8af_level0_col1" class="col_heading level0 col1" >frozen_head</th>
#       <th id="T_9c8af_level0_col2" class="col_heading level0 col2" >unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c8af_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_9c8af_row0_col0" class="data row0 col0" >0.702 +/- 0.010</td>
#       <td id="T_9c8af_row0_col1" class="data row0 col1" >0.702 +/- 0.010</td>
#       <td id="T_9c8af_row0_col2" class="data row0 col2" >0.702 +/- 0.010</td>
#     </tr>
#     <tr>
#       <th id="T_9c8af_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_9c8af_row1_col0" class="data row1 col0" >0.148 +/- 0.058</td>
#       <td id="T_9c8af_row1_col1" class="data row1 col1" >0.380 +/- 0.094</td>
#       <td id="T_9c8af_row1_col2" class="data row1 col2" >0.709 +/- 0.008</td>
#     </tr>
#     <tr>
#       <th id="T_9c8af_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_9c8af_row2_col0" class="data row2 col0" >0.153 +/- 0.038</td>
#       <td id="T_9c8af_row2_col1" class="data row2 col1" >0.238 +/- 0.153</td>
#       <td id="T_9c8af_row2_col2" class="data row2 col2" >0.703 +/- 0.014</td>
#     </tr>
#     <tr>
#       <th id="T_9c8af_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_9c8af_row3_col0" class="data row3 col0" >0.232 +/- 0.071</td>
#       <td id="T_9c8af_row3_col1" class="data row3 col1" >0.483 +/- 0.034</td>
#       <td id="T_9c8af_row3_col2" class="data row3 col2" >0.687 +/- 0.015</td>
#     </tr>
#     <tr>
#       <th id="T_9c8af_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_9c8af_row4_col0" class="data row4 col0" >0.171 +/- 0.060</td>
#       <td id="T_9c8af_row4_col1" class="data row4 col1" >0.381 +/- 0.090</td>
#       <td id="T_9c8af_row4_col2" class="data row4 col2" >0.697 +/- 0.014</td>
#     </tr>
#     <tr>
#       <th id="T_9c8af_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_9c8af_row5_col0" class="data row5 col0" >0.176 +/- 0.025</td>
#       <td id="T_9c8af_row5_col1" class="data row5 col1" >0.503 +/- 0.036</td>
#       <td id="T_9c8af_row5_col2" class="data row5 col2" >0.694 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_9c8af_level0_row6" class="row_heading level0 row6" >P3_staged_overlap</th>
#       <td id="T_9c8af_row6_col0" class="data row6 col0" >0.156 +/- 0.022</td>
#       <td id="T_9c8af_row6_col1" class="data row6 col1" >0.325 +/- 0.062</td>
#       <td id="T_9c8af_row6_col2" class="data row6 col2" >0.694 +/- 0.020</td>
#     </tr>
#     <tr>
#       <th id="T_9c8af_level0_row7" class="row_heading level0 row7" >P4_joint_rare</th>
#       <td id="T_9c8af_row7_col0" class="data row7 col0" >0.167 +/- 0.030</td>
#       <td id="T_9c8af_row7_col1" class="data row7 col1" >0.449 +/- 0.065</td>
#       <td id="T_9c8af_row7_col2" class="data row7 col2" >0.698 +/- 0.023</td>
#     </tr>
#     <tr>
#       <th id="T_9c8af_level0_row8" class="row_heading level0 row8" >P4_staged_rare</th>
#       <td id="T_9c8af_row8_col0" class="data row8 col0" >0.159 +/- 0.038</td>
#       <td id="T_9c8af_row8_col1" class="data row8 col1" >0.366 +/- 0.096</td>
#       <td id="T_9c8af_row8_col2" class="data row8 col2" >0.694 +/- 0.022</td>
#     </tr>
#     <tr>
#       <th id="T_9c8af_level0_row9" class="row_heading level0 row9" >P5_joint_all</th>
#       <td id="T_9c8af_row9_col0" class="data row9 col0" >0.189 +/- 0.061</td>
#       <td id="T_9c8af_row9_col1" class="data row9 col1" >0.459 +/- 0.041</td>
#       <td id="T_9c8af_row9_col2" class="data row9 col2" >0.700 +/- 0.024</td>
#     </tr>
#     <tr>
#       <th id="T_9c8af_level0_row10" class="row_heading level0 row10" >P5_staged_all</th>
#       <td id="T_9c8af_row10_col0" class="data row10 col0" >0.178 +/- 0.034</td>
#       <td id="T_9c8af_row10_col1" class="data row10 col1" >0.275 +/- 0.124</td>
#       <td id="T_9c8af_row10_col2" class="data row10 col2" >0.699 +/- 0.015</td>
#     </tr>
#   </tbody>
# </table>
# test_combined | recall | rare
# <style type="text/css">
# #T_a4107_row0_col0, #T_a4107_row0_col1, #T_a4107_row0_col2 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_a4107_row1_col0, #T_a4107_row1_col1, #T_a4107_row2_col0, #T_a4107_row2_col1, #T_a4107_row3_col0, #T_a4107_row3_col1, #T_a4107_row5_col0, #T_a4107_row5_col1, #T_a4107_row7_col1 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_a4107_row1_col2 {
#   background-color: rgba(215, 48, 39, 0.71);
# }
# #T_a4107_row2_col2 {
#   background-color: rgba(215, 48, 39, 0.45);
# }
# #T_a4107_row3_col2 {
#   background-color: rgba(26, 152, 80, 0.28);
# }
# #T_a4107_row4_col0, #T_a4107_row6_col1, #T_a4107_row7_col0, #T_a4107_row9_col0, #T_a4107_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_a4107_row4_col1, #T_a4107_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.74);
#   border: 2px solid black;
# }
# #T_a4107_row4_col2 {
#   background-color: rgba(26, 152, 80, 0.49);
# }
# #T_a4107_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.26);
# }
# #T_a4107_row6_col0, #T_a4107_row8_col1 {
#   background-color: rgba(215, 48, 39, 0.73);
#   border: 2px solid black;
# }
# #T_a4107_row6_col2 {
#   background-color: rgba(26, 152, 80, 0.55);
#   border: 2px solid black;
# }
# #T_a4107_row7_col2 {
#   background-color: rgba(26, 152, 80, 0.45);
# }
# #T_a4107_row8_col0, #T_a4107_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.72);
#   border: 2px solid black;
# }
# #T_a4107_row8_col2 {
#   background-color: rgba(26, 152, 80, 0.75);
#   border: 2px solid black;
# }
# #T_a4107_row9_col2 {
#   background-color: rgba(26, 152, 80, 0.34);
# }
# #T_a4107_row10_col2 {
#   background-color: rgba(26, 152, 80, 0.51);
#   border: 2px solid black;
# }
# </style>
# <table id="T_a4107">
#   <thead>
#     <tr>
#       <th class="index_name level0" >stage</th>
#       <th id="T_a4107_level0_col0" class="col_heading level0 col0" >pretrained</th>
#       <th id="T_a4107_level0_col1" class="col_heading level0 col1" >frozen_head</th>
#       <th id="T_a4107_level0_col2" class="col_heading level0 col2" >unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4107_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_a4107_row0_col0" class="data row0 col0" >0.664 +/- 0.036</td>
#       <td id="T_a4107_row0_col1" class="data row0 col1" >0.664 +/- 0.036</td>
#       <td id="T_a4107_row0_col2" class="data row0 col2" >0.664 +/- 0.036</td>
#     </tr>
#     <tr>
#       <th id="T_a4107_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_a4107_row1_col0" class="data row1 col0" >0.000 +/- 0.000</td>
#       <td id="T_a4107_row1_col1" class="data row1 col1" >0.000 +/- 0.000</td>
#       <td id="T_a4107_row1_col2" class="data row1 col2" >0.624 +/- 0.026</td>
#     </tr>
#     <tr>
#       <th id="T_a4107_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_a4107_row2_col0" class="data row2 col0" >0.000 +/- 0.000</td>
#       <td id="T_a4107_row2_col1" class="data row2 col1" >0.000 +/- 0.000</td>
#       <td id="T_a4107_row2_col2" class="data row2 col2" >0.643 +/- 0.078</td>
#     </tr>
#     <tr>
#       <th id="T_a4107_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_a4107_row3_col0" class="data row3 col0" >0.000 +/- 0.000</td>
#       <td id="T_a4107_row3_col1" class="data row3 col1" >0.000 +/- 0.000</td>
#       <td id="T_a4107_row3_col2" class="data row3 col2" >0.673 +/- 0.041</td>
#     </tr>
#     <tr>
#       <th id="T_a4107_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_a4107_row4_col0" class="data row4 col0" >0.010 +/- 0.017</td>
#       <td id="T_a4107_row4_col1" class="data row4 col1" >0.009 +/- 0.013</td>
#       <td id="T_a4107_row4_col2" class="data row4 col2" >0.688 +/- 0.024</td>
#     </tr>
#     <tr>
#       <th id="T_a4107_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_a4107_row5_col0" class="data row5 col0" >0.000 +/- 0.000</td>
#       <td id="T_a4107_row5_col1" class="data row5 col1" >0.001 +/- 0.002</td>
#       <td id="T_a4107_row5_col2" class="data row5 col2" >0.656 +/- 0.050</td>
#     </tr>
#     <tr>
#       <th id="T_a4107_level0_row6" class="row_heading level0 row6" >P3_staged_overlap</th>
#       <td id="T_a4107_row6_col0" class="data row6 col0" >0.022 +/- 0.020</td>
#       <td id="T_a4107_row6_col1" class="data row6 col1" >0.006 +/- 0.011</td>
#       <td id="T_a4107_row6_col2" class="data row6 col2" >0.692 +/- 0.021</td>
#     </tr>
#     <tr>
#       <th id="T_a4107_level0_row7" class="row_heading level0 row7" >P4_joint_rare</th>
#       <td id="T_a4107_row7_col0" class="data row7 col0" >0.008 +/- 0.017</td>
#       <td id="T_a4107_row7_col1" class="data row7 col1" >0.005 +/- 0.010</td>
#       <td id="T_a4107_row7_col2" class="data row7 col2" >0.685 +/- 0.038</td>
#     </tr>
#     <tr>
#       <th id="T_a4107_level0_row8" class="row_heading level0 row8" >P4_staged_rare</th>
#       <td id="T_a4107_row8_col0" class="data row8 col0" >0.034 +/- 0.009</td>
#       <td id="T_a4107_row8_col1" class="data row8 col1" >0.018 +/- 0.018</td>
#       <td id="T_a4107_row8_col2" class="data row8 col2" >0.706 +/- 0.037</td>
#     </tr>
#     <tr>
#       <th id="T_a4107_level0_row9" class="row_heading level0 row9" >P5_joint_all</th>
#       <td id="T_a4107_row9_col0" class="data row9 col0" >0.013 +/- 0.018</td>
#       <td id="T_a4107_row9_col1" class="data row9 col1" >0.007 +/- 0.016</td>
#       <td id="T_a4107_row9_col2" class="data row9 col2" >0.678 +/- 0.031</td>
#     </tr>
#     <tr>
#       <th id="T_a4107_level0_row10" class="row_heading level0 row10" >P5_staged_all</th>
#       <td id="T_a4107_row10_col0" class="data row10 col0" >0.033 +/- 0.006</td>
#       <td id="T_a4107_row10_col1" class="data row10 col1" >0.007 +/- 0.010</td>
#       <td id="T_a4107_row10_col2" class="data row10 col2" >0.690 +/- 0.010</td>
#     </tr>
#   </tbody>
# </table>
# test_extended | recall | rare
# <style type="text/css">
# #T_ac3ef_row0_col0, #T_ac3ef_row0_col1, #T_ac3ef_row0_col2 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_ac3ef_row1_col0, #T_ac3ef_row2_col0, #T_ac3ef_row2_col1, #T_ac3ef_row3_col0 {
#   background-color: rgba(215, 48, 39, 0.75);
#   border: 2px solid black;
# }
# #T_ac3ef_row1_col1, #T_ac3ef_row3_col1, #T_ac3ef_row4_col0, #T_ac3ef_row4_col1, #T_ac3ef_row5_col0, #T_ac3ef_row5_col1, #T_ac3ef_row6_col0, #T_ac3ef_row7_col0, #T_ac3ef_row7_col1, #T_ac3ef_row8_col0, #T_ac3ef_row8_col1, #T_ac3ef_row9_col0, #T_ac3ef_row9_col1, #T_ac3ef_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_ac3ef_row1_col2 {
#   background-color: rgba(26, 152, 80, 0.23);
# }
# #T_ac3ef_row2_col2 {
#   background-color: rgba(215, 48, 39, 0.52);
# }
# #T_ac3ef_row3_col2 {
#   background-color: rgba(26, 152, 80, 0.51);
# }
# #T_ac3ef_row4_col2 {
#   background-color: rgba(26, 152, 80, 0.39);
# }
# #T_ac3ef_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.49);
# }
# #T_ac3ef_row6_col1, #T_ac3ef_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.74);
#   border: 2px solid black;
# }
# #T_ac3ef_row6_col2 {
#   background-color: rgba(26, 152, 80, 0.65);
#   border: 2px solid black;
# }
# #T_ac3ef_row7_col2 {
#   background-color: rgba(26, 152, 80, 0.36);
# }
# #T_ac3ef_row8_col2 {
#   background-color: rgba(26, 152, 80, 0.75);
#   border: 2px solid black;
# }
# #T_ac3ef_row9_col2 {
#   background-color: rgba(215, 48, 39, 0.46);
# }
# #T_ac3ef_row10_col2 {
#   background-color: rgba(26, 152, 80, 0.58);
#   border: 2px solid black;
# }
# </style>
# <table id="T_ac3ef">
#   <thead>
#     <tr>
#       <th class="index_name level0" >stage</th>
#       <th id="T_ac3ef_level0_col0" class="col_heading level0 col0" >pretrained</th>
#       <th id="T_ac3ef_level0_col1" class="col_heading level0 col1" >frozen_head</th>
#       <th id="T_ac3ef_level0_col2" class="col_heading level0 col2" >unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac3ef_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_ac3ef_row0_col0" class="data row0 col0" >0.497 +/- 0.029</td>
#       <td id="T_ac3ef_row0_col1" class="data row0 col1" >0.497 +/- 0.029</td>
#       <td id="T_ac3ef_row0_col2" class="data row0 col2" >0.497 +/- 0.029</td>
#     </tr>
#     <tr>
#       <th id="T_ac3ef_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_ac3ef_row1_col0" class="data row1 col0" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row1_col1" class="data row1 col1" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row1_col2" class="data row1 col2" >0.500 +/- 0.013</td>
#     </tr>
#     <tr>
#       <th id="T_ac3ef_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_ac3ef_row2_col0" class="data row2 col0" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row2_col1" class="data row2 col1" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row2_col2" class="data row2 col2" >0.481 +/- 0.073</td>
#     </tr>
#     <tr>
#       <th id="T_ac3ef_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_ac3ef_row3_col0" class="data row3 col0" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row3_col1" class="data row3 col1" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row3_col2" class="data row3 col2" >0.512 +/- 0.062</td>
#     </tr>
#     <tr>
#       <th id="T_ac3ef_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_ac3ef_row4_col0" class="data row4 col0" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row4_col1" class="data row4 col1" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row4_col2" class="data row4 col2" >0.507 +/- 0.022</td>
#     </tr>
#     <tr>
#       <th id="T_ac3ef_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_ac3ef_row5_col0" class="data row5 col0" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row5_col1" class="data row5 col1" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row5_col2" class="data row5 col2" >0.482 +/- 0.025</td>
#     </tr>
#     <tr>
#       <th id="T_ac3ef_level0_row6" class="row_heading level0 row6" >P3_staged_overlap</th>
#       <td id="T_ac3ef_row6_col0" class="data row6 col0" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row6_col1" class="data row6 col1" >0.007 +/- 0.008</td>
#       <td id="T_ac3ef_row6_col2" class="data row6 col2" >0.518 +/- 0.030</td>
#     </tr>
#     <tr>
#       <th id="T_ac3ef_level0_row7" class="row_heading level0 row7" >P4_joint_rare</th>
#       <td id="T_ac3ef_row7_col0" class="data row7 col0" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row7_col1" class="data row7 col1" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row7_col2" class="data row7 col2" >0.506 +/- 0.028</td>
#     </tr>
#     <tr>
#       <th id="T_ac3ef_level0_row8" class="row_heading level0 row8" >P4_staged_rare</th>
#       <td id="T_ac3ef_row8_col0" class="data row8 col0" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row8_col1" class="data row8 col1" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row8_col2" class="data row8 col2" >0.523 +/- 0.012</td>
#     </tr>
#     <tr>
#       <th id="T_ac3ef_level0_row9" class="row_heading level0 row9" >P5_joint_all</th>
#       <td id="T_ac3ef_row9_col0" class="data row9 col0" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row9_col1" class="data row9 col1" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row9_col2" class="data row9 col2" >0.483 +/- 0.015</td>
#     </tr>
#     <tr>
#       <th id="T_ac3ef_level0_row10" class="row_heading level0 row10" >P5_staged_all</th>
#       <td id="T_ac3ef_row10_col0" class="data row10 col0" >0.000 +/- 0.000</td>
#       <td id="T_ac3ef_row10_col1" class="data row10 col1" >0.008 +/- 0.019</td>
#       <td id="T_ac3ef_row10_col2" class="data row10 col2" >0.515 +/- 0.022</td>
#     </tr>
#   </tbody>
# </table>
# heldout_image | average_precision | other_eligible
# <style type="text/css">
# #T_d47ce_row0_col0, #T_d47ce_row0_col1, #T_d47ce_row0_col2 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_d47ce_row1_col0 {
#   background-color: rgba(215, 48, 39, 0.46);
# }
# #T_d47ce_row1_col1 {
#   background-color: rgba(215, 48, 39, 0.67);
# }
# #T_d47ce_row1_col2 {
#   background-color: rgba(26, 152, 80, 0.52);
# }
# #T_d47ce_row2_col0, #T_d47ce_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_d47ce_row2_col1 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_d47ce_row2_col2, #T_d47ce_row7_col0 {
#   background-color: rgba(215, 48, 39, 0.32);
# }
# #T_d47ce_row3_col0 {
#   background-color: rgba(215, 48, 39, 0.29);
#   border: 2px solid black;
# }
# #T_d47ce_row3_col1 {
#   background-color: rgba(215, 48, 39, 0.53);
#   border: 2px solid black;
# }
# #T_d47ce_row3_col2 {
#   background-color: rgba(26, 152, 80, 0.68);
#   border: 2px solid black;
# }
# #T_d47ce_row4_col0 {
#   background-color: rgba(215, 48, 39, 0.37);
# }
# #T_d47ce_row4_col1 {
#   background-color: rgba(215, 48, 39, 0.64);
# }
# #T_d47ce_row4_col2 {
#   background-color: rgba(215, 48, 39, 0.20);
# }
# #T_d47ce_row5_col0 {
#   background-color: rgba(215, 48, 39, 0.21);
#   border: 2px solid black;
# }
# #T_d47ce_row5_col1 {
#   background-color: rgba(215, 48, 39, 0.60);
# }
# #T_d47ce_row5_col2 {
#   background-color: rgba(26, 152, 80, 0.45);
# }
# #T_d47ce_row6_col0 {
#   background-color: rgba(215, 48, 39, 0.25);
#   border: 2px solid black;
# }
# #T_d47ce_row6_col1 {
#   background-color: rgba(215, 48, 39, 0.59);
#   border: 2px solid black;
# }
# #T_d47ce_row6_col2 {
#   background-color: rgba(26, 152, 80, 0.34);
# }
# #T_d47ce_row7_col1 {
#   background-color: rgba(215, 48, 39, 0.66);
# }
# #T_d47ce_row7_col2 {
#   background-color: rgba(26, 152, 80, 0.32);
# }
# #T_d47ce_row8_col0 {
#   background-color: rgba(215, 48, 39, 0.42);
# }
# #T_d47ce_row8_col1 {
#   background-color: rgba(215, 48, 39, 0.56);
#   border: 2px solid black;
# }
# #T_d47ce_row8_col2 {
#   background-color: rgba(26, 152, 80, 0.75);
#   border: 2px solid black;
# }
# #T_d47ce_row9_col0 {
#   background-color: rgba(215, 48, 39, 0.30);
# }
# #T_d47ce_row9_col2 {
#   background-color: rgba(26, 152, 80, 0.66);
#   border: 2px solid black;
# }
# #T_d47ce_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.47);
# }
# #T_d47ce_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.59);
# }
# #T_d47ce_row10_col2 {
#   background-color: rgba(26, 152, 80, 0.65);
# }
# </style>
# <table id="T_d47ce">
#   <thead>
#     <tr>
#       <th class="index_name level0" >stage</th>
#       <th id="T_d47ce_level0_col0" class="col_heading level0 col0" >pretrained</th>
#       <th id="T_d47ce_level0_col1" class="col_heading level0 col1" >frozen_head</th>
#       <th id="T_d47ce_level0_col2" class="col_heading level0 col2" >unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d47ce_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_d47ce_row0_col0" class="data row0 col0" >0.087 +/- 0.009</td>
#       <td id="T_d47ce_row0_col1" class="data row0 col1" >0.087 +/- 0.009</td>
#       <td id="T_d47ce_row0_col2" class="data row0 col2" >0.087 +/- 0.009</td>
#     </tr>
#     <tr>
#       <th id="T_d47ce_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_d47ce_row1_col0" class="data row1 col0" >0.066 +/- 0.017</td>
#       <td id="T_d47ce_row1_col1" class="data row1 col1" >0.056 +/- 0.016</td>
#       <td id="T_d47ce_row1_col2" class="data row1 col2" >0.092 +/- 0.006</td>
#     </tr>
#     <tr>
#       <th id="T_d47ce_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_d47ce_row2_col0" class="data row2 col0" >0.047 +/- 0.006</td>
#       <td id="T_d47ce_row2_col1" class="data row2 col1" >0.051 +/- 0.004</td>
#       <td id="T_d47ce_row2_col2" class="data row2 col2" >0.085 +/- 0.008</td>
#     </tr>
#     <tr>
#       <th id="T_d47ce_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_d47ce_row3_col0" class="data row3 col0" >0.078 +/- 0.008</td>
#       <td id="T_d47ce_row3_col1" class="data row3 col1" >0.064 +/- 0.022</td>
#       <td id="T_d47ce_row3_col2" class="data row3 col2" >0.094 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_d47ce_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_d47ce_row4_col0" class="data row4 col0" >0.073 +/- 0.007</td>
#       <td id="T_d47ce_row4_col1" class="data row4 col1" >0.057 +/- 0.026</td>
#       <td id="T_d47ce_row4_col2" class="data row4 col2" >0.087 +/- 0.006</td>
#     </tr>
#     <tr>
#       <th id="T_d47ce_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_d47ce_row5_col0" class="data row5 col0" >0.083 +/- 0.009</td>
#       <td id="T_d47ce_row5_col1" class="data row5 col1" >0.060 +/- 0.022</td>
#       <td id="T_d47ce_row5_col2" class="data row5 col2" >0.091 +/- 0.006</td>
#     </tr>
#     <tr>
#       <th id="T_d47ce_level0_row6" class="row_heading level0 row6" >P3_staged_overlap</th>
#       <td id="T_d47ce_row6_col0" class="data row6 col0" >0.080 +/- 0.013</td>
#       <td id="T_d47ce_row6_col1" class="data row6 col1" >0.060 +/- 0.020</td>
#       <td id="T_d47ce_row6_col2" class="data row6 col2" >0.090 +/- 0.007</td>
#     </tr>
#     <tr>
#       <th id="T_d47ce_level0_row7" class="row_heading level0 row7" >P4_joint_rare</th>
#       <td id="T_d47ce_row7_col0" class="data row7 col0" >0.076 +/- 0.009</td>
#       <td id="T_d47ce_row7_col1" class="data row7 col1" >0.056 +/- 0.016</td>
#       <td id="T_d47ce_row7_col2" class="data row7 col2" >0.089 +/- 0.008</td>
#     </tr>
#     <tr>
#       <th id="T_d47ce_level0_row8" class="row_heading level0 row8" >P4_staged_rare</th>
#       <td id="T_d47ce_row8_col0" class="data row8 col0" >0.069 +/- 0.016</td>
#       <td id="T_d47ce_row8_col1" class="data row8 col1" >0.062 +/- 0.019</td>
#       <td id="T_d47ce_row8_col2" class="data row8 col2" >0.095 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_d47ce_level0_row9" class="row_heading level0 row9" >P5_joint_all</th>
#       <td id="T_d47ce_row9_col0" class="data row9 col0" >0.077 +/- 0.010</td>
#       <td id="T_d47ce_row9_col1" class="data row9 col1" >0.050 +/- 0.009</td>
#       <td id="T_d47ce_row9_col2" class="data row9 col2" >0.094 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_d47ce_level0_row10" class="row_heading level0 row10" >P5_staged_all</th>
#       <td id="T_d47ce_row10_col0" class="data row10 col0" >0.066 +/- 0.015</td>
#       <td id="T_d47ce_row10_col1" class="data row10 col1" >0.060 +/- 0.015</td>
#       <td id="T_d47ce_row10_col2" class="data row10 col2" >0.094 +/- 0.009</td>
#     </tr>
#   </tbody>
# </table>
# test_combined | average_precision | other_eligible
# <style type="text/css">
# #T_898dc_row0_col0, #T_898dc_row0_col1, #T_898dc_row0_col2 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_898dc_row1_col0 {
#   background-color: rgba(215, 48, 39, 0.72);
#   border: 2px solid black;
# }
# #T_898dc_row1_col1 {
#   background-color: rgba(215, 48, 39, 0.66);
# }
# #T_898dc_row1_col2 {
#   background-color: rgba(26, 152, 80, 0.75);
#   border: 2px solid black;
# }
# #T_898dc_row2_col0 {
#   background-color: rgba(215, 48, 39, 0.56);
#   border: 2px solid black;
# }
# #T_898dc_row2_col1, #T_898dc_row3_col0, #T_898dc_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_898dc_row2_col2 {
#   background-color: rgba(26, 152, 80, 0.32);
# }
# #T_898dc_row3_col1 {
#   background-color: rgba(215, 48, 39, 0.65);
# }
# #T_898dc_row3_col2 {
#   background-color: rgba(26, 152, 80, 0.16);
# }
# #T_898dc_row4_col0, #T_898dc_row6_col0, #T_898dc_row7_col0, #T_898dc_row8_col0 {
#   background-color: rgba(215, 48, 39, 0.74);
# }
# #T_898dc_row4_col1 {
#   background-color: rgba(215, 48, 39, 0.68);
# }
# #T_898dc_row4_col2 {
#   background-color: rgba(26, 152, 80, 0.23);
# }
# #T_898dc_row5_col0 {
#   background-color: rgba(215, 48, 39, 0.73);
#   border: 2px solid black;
# }
# #T_898dc_row5_col1, #T_898dc_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.63);
#   border: 2px solid black;
# }
# #T_898dc_row5_col2 {
#   background-color: rgba(26, 152, 80, 0.37);
# }
# #T_898dc_row6_col1 {
#   background-color: rgba(215, 48, 39, 0.67);
# }
# #T_898dc_row6_col2 {
#   background-color: rgba(26, 152, 80, 0.40);
# }
# #T_898dc_row7_col1 {
#   background-color: rgba(215, 48, 39, 0.60);
#   border: 2px solid black;
# }
# #T_898dc_row7_col2 {
#   background-color: rgba(26, 152, 80, 0.22);
# }
# #T_898dc_row8_col1 {
#   background-color: rgba(215, 48, 39, 0.71);
# }
# #T_898dc_row8_col2 {
#   background-color: rgba(26, 152, 80, 0.43);
# }
# #T_898dc_row9_col0 {
#   background-color: rgba(215, 48, 39, 0.73);
# }
# #T_898dc_row9_col2 {
#   background-color: rgba(26, 152, 80, 0.44);
#   border: 2px solid black;
# }
# #T_898dc_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.72);
# }
# #T_898dc_row10_col2 {
#   background-color: rgba(26, 152, 80, 0.47);
#   border: 2px solid black;
# }
# </style>
# <table id="T_898dc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >stage</th>
#       <th id="T_898dc_level0_col0" class="col_heading level0 col0" >pretrained</th>
#       <th id="T_898dc_level0_col1" class="col_heading level0 col1" >frozen_head</th>
#       <th id="T_898dc_level0_col2" class="col_heading level0 col2" >unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_898dc_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_898dc_row0_col0" class="data row0 col0" >0.907 +/- 0.006</td>
#       <td id="T_898dc_row0_col1" class="data row0 col1" >0.907 +/- 0.006</td>
#       <td id="T_898dc_row0_col2" class="data row0 col2" >0.907 +/- 0.006</td>
#     </tr>
#     <tr>
#       <th id="T_898dc_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_898dc_row1_col0" class="data row1 col0" >0.182 +/- 0.058</td>
#       <td id="T_898dc_row1_col1" class="data row1 col1" >0.343 +/- 0.052</td>
#       <td id="T_898dc_row1_col2" class="data row1 col2" >0.924 +/- 0.003</td>
#     </tr>
#     <tr>
#       <th id="T_898dc_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_898dc_row2_col0" class="data row2 col0" >0.383 +/- 0.244</td>
#       <td id="T_898dc_row2_col1" class="data row2 col1" >0.246 +/- 0.050</td>
#       <td id="T_898dc_row2_col2" class="data row2 col2" >0.912 +/- 0.006</td>
#     </tr>
#     <tr>
#       <th id="T_898dc_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_898dc_row3_col0" class="data row3 col0" >0.143 +/- 0.014</td>
#       <td id="T_898dc_row3_col1" class="data row3 col1" >0.354 +/- 0.078</td>
#       <td id="T_898dc_row3_col2" class="data row3 col2" >0.908 +/- 0.008</td>
#     </tr>
#     <tr>
#       <th id="T_898dc_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_898dc_row4_col0" class="data row4 col0" >0.156 +/- 0.032</td>
#       <td id="T_898dc_row4_col1" class="data row4 col1" >0.326 +/- 0.049</td>
#       <td id="T_898dc_row4_col2" class="data row4 col2" >0.909 +/- 0.006</td>
#     </tr>
#     <tr>
#       <th id="T_898dc_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_898dc_row5_col0" class="data row5 col0" >0.166 +/- 0.020</td>
#       <td id="T_898dc_row5_col1" class="data row5 col1" >0.381 +/- 0.088</td>
#       <td id="T_898dc_row5_col2" class="data row5 col2" >0.913 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_898dc_level0_row6" class="row_heading level0 row6" >P3_staged_overlap</th>
#       <td id="T_898dc_row6_col0" class="data row6 col0" >0.148 +/- 0.015</td>
#       <td id="T_898dc_row6_col1" class="data row6 col1" >0.334 +/- 0.045</td>
#       <td id="T_898dc_row6_col2" class="data row6 col2" >0.914 +/- 0.003</td>
#     </tr>
#     <tr>
#       <th id="T_898dc_level0_row7" class="row_heading level0 row7" >P4_joint_rare</th>
#       <td id="T_898dc_row7_col0" class="data row7 col0" >0.157 +/- 0.016</td>
#       <td id="T_898dc_row7_col1" class="data row7 col1" >0.415 +/- 0.034</td>
#       <td id="T_898dc_row7_col2" class="data row7 col2" >0.909 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_898dc_level0_row8" class="row_heading level0 row8" >P4_staged_rare</th>
#       <td id="T_898dc_row8_col0" class="data row8 col0" >0.148 +/- 0.017</td>
#       <td id="T_898dc_row8_col1" class="data row8 col1" >0.293 +/- 0.061</td>
#       <td id="T_898dc_row8_col2" class="data row8 col2" >0.915 +/- 0.006</td>
#     </tr>
#     <tr>
#       <th id="T_898dc_level0_row9" class="row_heading level0 row9" >P5_joint_all</th>
#       <td id="T_898dc_row9_col0" class="data row9 col0" >0.160 +/- 0.031</td>
#       <td id="T_898dc_row9_col1" class="data row9 col1" >0.382 +/- 0.102</td>
#       <td id="T_898dc_row9_col2" class="data row9 col2" >0.915 +/- 0.002</td>
#     </tr>
#     <tr>
#       <th id="T_898dc_level0_row10" class="row_heading level0 row10" >P5_staged_all</th>
#       <td id="T_898dc_row10_col0" class="data row10 col0" >0.140 +/- 0.009</td>
#       <td id="T_898dc_row10_col1" class="data row10 col1" >0.280 +/- 0.041</td>
#       <td id="T_898dc_row10_col2" class="data row10 col2" >0.916 +/- 0.003</td>
#     </tr>
#   </tbody>
# </table>
# test_extended | average_precision | other_eligible
# <style type="text/css">
# #T_84274_row0_col0, #T_84274_row0_col1, #T_84274_row0_col2 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_84274_row1_col0, #T_84274_row6_col0, #T_84274_row7_col0, #T_84274_row9_col0 {
#   background-color: rgba(215, 48, 39, 0.71);
# }
# #T_84274_row1_col1, #T_84274_row6_col1 {
#   background-color: rgba(215, 48, 39, 0.67);
# }
# #T_84274_row1_col2 {
#   background-color: rgba(26, 152, 80, 0.72);
#   border: 2px solid black;
# }
# #T_84274_row2_col0, #T_84274_row2_col1, #T_84274_row9_col2 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_84274_row2_col2 {
#   background-color: rgba(215, 48, 39, 0.41);
# }
# #T_84274_row3_col0 {
#   background-color: rgba(215, 48, 39, 0.65);
#   border: 2px solid black;
# }
# #T_84274_row3_col1 {
#   background-color: rgba(215, 48, 39, 0.47);
#   border: 2px solid black;
# }
# #T_84274_row3_col2 {
#   background-color: rgba(215, 48, 39, 0.43);
# }
# #T_84274_row4_col0, #T_84274_row8_col0 {
#   background-color: rgba(215, 48, 39, 0.70);
# }
# #T_84274_row4_col1, #T_84274_row8_col1 {
#   background-color: rgba(215, 48, 39, 0.64);
# }
# #T_84274_row4_col2 {
#   background-color: rgba(26, 152, 80, 0.20);
#   border: 2px solid black;
# }
# #T_84274_row5_col0, #T_84274_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.69);
#   border: 2px solid black;
# }
# #T_84274_row5_col1 {
#   background-color: rgba(215, 48, 39, 0.43);
#   border: 2px solid black;
# }
# #T_84274_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.19);
# }
# #T_84274_row6_col2 {
#   background-color: rgba(26, 152, 80, 0.16);
# }
# #T_84274_row7_col1 {
#   background-color: rgba(215, 48, 39, 0.50);
# }
# #T_84274_row7_col2 {
#   background-color: rgba(215, 48, 39, 0.59);
# }
# #T_84274_row8_col2 {
#   background-color: rgba(26, 152, 80, 0.30);
#   border: 2px solid black;
# }
# #T_84274_row9_col1 {
#   background-color: rgba(215, 48, 39, 0.46);
#   border: 2px solid black;
# }
# #T_84274_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.68);
# }
# #T_84274_row10_col2 {
#   background-color: rgba(215, 48, 39, 0.46);
# }
# </style>
# <table id="T_84274">
#   <thead>
#     <tr>
#       <th class="index_name level0" >stage</th>
#       <th id="T_84274_level0_col0" class="col_heading level0 col0" >pretrained</th>
#       <th id="T_84274_level0_col1" class="col_heading level0 col1" >frozen_head</th>
#       <th id="T_84274_level0_col2" class="col_heading level0 col2" >unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84274_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_84274_row0_col0" class="data row0 col0" >0.816 +/- 0.004</td>
#       <td id="T_84274_row0_col1" class="data row0 col1" >0.816 +/- 0.004</td>
#       <td id="T_84274_row0_col2" class="data row0 col2" >0.816 +/- 0.004</td>
#     </tr>
#     <tr>
#       <th id="T_84274_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_84274_row1_col0" class="data row1 col0" >0.248 +/- 0.067</td>
#       <td id="T_84274_row1_col1" class="data row1 col1" >0.379 +/- 0.109</td>
#       <td id="T_84274_row1_col2" class="data row1 col2" >0.826 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_84274_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_84274_row2_col0" class="data row2 col0" >0.205 +/- 0.027</td>
#       <td id="T_84274_row2_col1" class="data row2 col1" >0.309 +/- 0.146</td>
#       <td id="T_84274_row2_col2" class="data row2 col2" >0.811 +/- 0.011</td>
#     </tr>
#     <tr>
#       <th id="T_84274_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_84274_row3_col0" class="data row3 col0" >0.307 +/- 0.029</td>
#       <td id="T_84274_row3_col1" class="data row3 col1" >0.549 +/- 0.077</td>
#       <td id="T_84274_row3_col2" class="data row3 col2" >0.811 +/- 0.009</td>
#     </tr>
#     <tr>
#       <th id="T_84274_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_84274_row4_col0" class="data row4 col0" >0.254 +/- 0.028</td>
#       <td id="T_84274_row4_col1" class="data row4 col1" >0.399 +/- 0.085</td>
#       <td id="T_84274_row4_col2" class="data row4 col2" >0.817 +/- 0.009</td>
#     </tr>
#     <tr>
#       <th id="T_84274_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_84274_row5_col0" class="data row5 col0" >0.264 +/- 0.023</td>
#       <td id="T_84274_row5_col1" class="data row5 col1" >0.577 +/- 0.075</td>
#       <td id="T_84274_row5_col2" class="data row5 col2" >0.815 +/- 0.008</td>
#     </tr>
#     <tr>
#       <th id="T_84274_level0_row6" class="row_heading level0 row6" >P3_staged_overlap</th>
#       <td id="T_84274_row6_col0" class="data row6 col0" >0.244 +/- 0.021</td>
#       <td id="T_84274_row6_col1" class="data row6 col1" >0.379 +/- 0.078</td>
#       <td id="T_84274_row6_col2" class="data row6 col2" >0.816 +/- 0.009</td>
#     </tr>
#     <tr>
#       <th id="T_84274_level0_row7" class="row_heading level0 row7" >P4_joint_rare</th>
#       <td id="T_84274_row7_col0" class="data row7 col0" >0.250 +/- 0.020</td>
#       <td id="T_84274_row7_col1" class="data row7 col1" >0.519 +/- 0.090</td>
#       <td id="T_84274_row7_col2" class="data row7 col2" >0.808 +/- 0.007</td>
#     </tr>
#     <tr>
#       <th id="T_84274_level0_row8" class="row_heading level0 row8" >P4_staged_rare</th>
#       <td id="T_84274_row8_col0" class="data row8 col0" >0.259 +/- 0.021</td>
#       <td id="T_84274_row8_col1" class="data row8 col1" >0.400 +/- 0.057</td>
#       <td id="T_84274_row8_col2" class="data row8 col2" >0.818 +/- 0.008</td>
#     </tr>
#     <tr>
#       <th id="T_84274_level0_row9" class="row_heading level0 row9" >P5_joint_all</th>
#       <td id="T_84274_row9_col0" class="data row9 col0" >0.245 +/- 0.026</td>
#       <td id="T_84274_row9_col1" class="data row9 col1" >0.557 +/- 0.052</td>
#       <td id="T_84274_row9_col2" class="data row9 col2" >0.805 +/- 0.014</td>
#     </tr>
#     <tr>
#       <th id="T_84274_level0_row10" class="row_heading level0 row10" >P5_staged_all</th>
#       <td id="T_84274_row10_col0" class="data row10 col0" >0.265 +/- 0.025</td>
#       <td id="T_84274_row10_col1" class="data row10 col1" >0.366 +/- 0.046</td>
#       <td id="T_84274_row10_col2" class="data row10 col2" >0.810 +/- 0.015</td>
#     </tr>
#   </tbody>
# </table>
# heldout_image | recall | other_eligible
# <style type="text/css">
# #T_5b775_row0_col0, #T_5b775_row0_col1, #T_5b775_row0_col2 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_5b775_row1_col0, #T_5b775_row1_col1, #T_5b775_row2_col0, #T_5b775_row2_col1, #T_5b775_row3_col0, #T_5b775_row3_col1 {
#   background-color: rgba(215, 48, 39, 0.75);
#   border: 2px solid black;
# }
# #T_5b775_row1_col2 {
#   background-color: rgba(26, 152, 80, 0.68);
#   border: 2px solid black;
# }
# #T_5b775_row2_col2 {
#   background-color: rgba(215, 48, 39, 0.36);
# }
# #T_5b775_row3_col2 {
#   background-color: rgba(215, 48, 39, 0.33);
# }
# #T_5b775_row4_col0, #T_5b775_row4_col1, #T_5b775_row5_col0, #T_5b775_row5_col1, #T_5b775_row6_col0, #T_5b775_row6_col1, #T_5b775_row7_col0, #T_5b775_row7_col1, #T_5b775_row8_col0, #T_5b775_row8_col1, #T_5b775_row9_col0, #T_5b775_row9_col1, #T_5b775_row10_col0, #T_5b775_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_5b775_row4_col2 {
#   background-color: rgba(215, 48, 39, 0.42);
# }
# #T_5b775_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.58);
# }
# #T_5b775_row6_col2 {
#   background-color: rgba(26, 152, 80, 0.16);
# }
# #T_5b775_row7_col2 {
#   background-color: rgba(215, 48, 39, 0.57);
# }
# #T_5b775_row8_col2 {
#   background-color: rgba(26, 152, 80, 0.29);
# }
# #T_5b775_row9_col2 {
#   background-color: rgba(26, 152, 80, 0.75);
#   border: 2px solid black;
# }
# #T_5b775_row10_col2 {
#   background-color: rgba(26, 152, 80, 0.31);
#   border: 2px solid black;
# }
# </style>
# <table id="T_5b775">
#   <thead>
#     <tr>
#       <th class="index_name level0" >stage</th>
#       <th id="T_5b775_level0_col0" class="col_heading level0 col0" >pretrained</th>
#       <th id="T_5b775_level0_col1" class="col_heading level0 col1" >frozen_head</th>
#       <th id="T_5b775_level0_col2" class="col_heading level0 col2" >unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b775_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_5b775_row0_col0" class="data row0 col0" >0.007 +/- 0.003</td>
#       <td id="T_5b775_row0_col1" class="data row0 col1" >0.007 +/- 0.003</td>
#       <td id="T_5b775_row0_col2" class="data row0 col2" >0.007 +/- 0.003</td>
#     </tr>
#     <tr>
#       <th id="T_5b775_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_5b775_row1_col0" class="data row1 col0" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row1_col1" class="data row1 col1" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row1_col2" class="data row1 col2" >0.012 +/- 0.008</td>
#     </tr>
#     <tr>
#       <th id="T_5b775_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_5b775_row2_col0" class="data row2 col0" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row2_col1" class="data row2 col1" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row2_col2" class="data row2 col2" >0.006 +/- 0.006</td>
#     </tr>
#     <tr>
#       <th id="T_5b775_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_5b775_row3_col0" class="data row3 col0" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row3_col1" class="data row3 col1" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row3_col2" class="data row3 col2" >0.006 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_5b775_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_5b775_row4_col0" class="data row4 col0" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row4_col1" class="data row4 col1" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row4_col2" class="data row4 col2" >0.005 +/- 0.006</td>
#     </tr>
#     <tr>
#       <th id="T_5b775_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_5b775_row5_col0" class="data row5 col0" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row5_col1" class="data row5 col1" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row5_col2" class="data row5 col2" >0.004 +/- 0.002</td>
#     </tr>
#     <tr>
#       <th id="T_5b775_level0_row6" class="row_heading level0 row6" >P3_staged_overlap</th>
#       <td id="T_5b775_row6_col0" class="data row6 col0" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row6_col1" class="data row6 col1" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row6_col2" class="data row6 col2" >0.007 +/- 0.006</td>
#     </tr>
#     <tr>
#       <th id="T_5b775_level0_row7" class="row_heading level0 row7" >P4_joint_rare</th>
#       <td id="T_5b775_row7_col0" class="data row7 col0" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row7_col1" class="data row7 col1" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row7_col2" class="data row7 col2" >0.004 +/- 0.002</td>
#     </tr>
#     <tr>
#       <th id="T_5b775_level0_row8" class="row_heading level0 row8" >P4_staged_rare</th>
#       <td id="T_5b775_row8_col0" class="data row8 col0" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row8_col1" class="data row8 col1" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row8_col2" class="data row8 col2" >0.009 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_5b775_level0_row9" class="row_heading level0 row9" >P5_joint_all</th>
#       <td id="T_5b775_row9_col0" class="data row9 col0" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row9_col1" class="data row9 col1" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row9_col2" class="data row9 col2" >0.012 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_5b775_level0_row10" class="row_heading level0 row10" >P5_staged_all</th>
#       <td id="T_5b775_row10_col0" class="data row10 col0" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row10_col1" class="data row10 col1" >0.000 +/- 0.000</td>
#       <td id="T_5b775_row10_col2" class="data row10 col2" >0.009 +/- 0.007</td>
#     </tr>
#   </tbody>
# </table>
# test_combined | recall | other_eligible
# <style type="text/css">
# #T_d8e2b_row0_col0, #T_d8e2b_row0_col1, #T_d8e2b_row0_col2 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_d8e2b_row1_col0, #T_d8e2b_row1_col1, #T_d8e2b_row2_col0, #T_d8e2b_row2_col2, #T_d8e2b_row3_col1, #T_d8e2b_row4_col1, #T_d8e2b_row5_col0, #T_d8e2b_row5_col1, #T_d8e2b_row6_col1, #T_d8e2b_row7_col0, #T_d8e2b_row7_col1, #T_d8e2b_row8_col0, #T_d8e2b_row9_col0, #T_d8e2b_row9_col1, #T_d8e2b_row10_col0 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_d8e2b_row1_col2 {
#   background-color: rgba(215, 48, 39, 0.64);
# }
# #T_d8e2b_row2_col1, #T_d8e2b_row3_col0, #T_d8e2b_row4_col0, #T_d8e2b_row6_col0, #T_d8e2b_row8_col1, #T_d8e2b_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.75);
#   border: 2px solid black;
# }
# #T_d8e2b_row3_col2 {
#   background-color: rgba(26, 152, 80, 0.60);
#   border: 2px solid black;
# }
# #T_d8e2b_row4_col2 {
#   background-color: rgba(26, 152, 80, 0.58);
# }
# #T_d8e2b_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.24);
# }
# #T_d8e2b_row6_col2 {
#   background-color: rgba(26, 152, 80, 0.75);
#   border: 2px solid black;
# }
# #T_d8e2b_row7_col2 {
#   background-color: rgba(26, 152, 80, 0.56);
# }
# #T_d8e2b_row8_col2 {
#   background-color: rgba(26, 152, 80, 0.61);
#   border: 2px solid black;
# }
# #T_d8e2b_row9_col2 {
#   background-color: rgba(26, 152, 80, 0.44);
# }
# #T_d8e2b_row10_col2 {
#   background-color: rgba(26, 152, 80, 0.31);
# }
# </style>
# <table id="T_d8e2b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >stage</th>
#       <th id="T_d8e2b_level0_col0" class="col_heading level0 col0" >pretrained</th>
#       <th id="T_d8e2b_level0_col1" class="col_heading level0 col1" >frozen_head</th>
#       <th id="T_d8e2b_level0_col2" class="col_heading level0 col2" >unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8e2b_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_d8e2b_row0_col0" class="data row0 col0" >0.961 +/- 0.007</td>
#       <td id="T_d8e2b_row0_col1" class="data row0 col1" >0.961 +/- 0.007</td>
#       <td id="T_d8e2b_row0_col2" class="data row0 col2" >0.961 +/- 0.007</td>
#     </tr>
#     <tr>
#       <th id="T_d8e2b_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_d8e2b_row1_col0" class="data row1 col0" >0.000 +/- 0.000</td>
#       <td id="T_d8e2b_row1_col1" class="data row1 col1" >0.000 +/- 0.000</td>
#       <td id="T_d8e2b_row1_col2" class="data row1 col2" >0.958 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_d8e2b_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_d8e2b_row2_col0" class="data row2 col0" >0.000 +/- 0.000</td>
#       <td id="T_d8e2b_row2_col1" class="data row2 col1" >0.005 +/- 0.008</td>
#       <td id="T_d8e2b_row2_col2" class="data row2 col2" >0.957 +/- 0.015</td>
#     </tr>
#     <tr>
#       <th id="T_d8e2b_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_d8e2b_row3_col0" class="data row3 col0" >0.000 +/- 0.000</td>
#       <td id="T_d8e2b_row3_col1" class="data row3 col1" >0.000 +/- 0.000</td>
#       <td id="T_d8e2b_row3_col2" class="data row3 col2" >0.964 +/- 0.005</td>
#     </tr>
#     <tr>
#       <th id="T_d8e2b_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_d8e2b_row4_col0" class="data row4 col0" >0.000 +/- 0.001</td>
#       <td id="T_d8e2b_row4_col1" class="data row4 col1" >0.003 +/- 0.003</td>
#       <td id="T_d8e2b_row4_col2" class="data row4 col2" >0.964 +/- 0.003</td>
#     </tr>
#     <tr>
#       <th id="T_d8e2b_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_d8e2b_row5_col0" class="data row5 col0" >0.000 +/- 0.000</td>
#       <td id="T_d8e2b_row5_col1" class="data row5 col1" >0.000 +/- 0.000</td>
#       <td id="T_d8e2b_row5_col2" class="data row5 col2" >0.961 +/- 0.004</td>
#     </tr>
#     <tr>
#       <th id="T_d8e2b_level0_row6" class="row_heading level0 row6" >P3_staged_overlap</th>
#       <td id="T_d8e2b_row6_col0" class="data row6 col0" >0.002 +/- 0.004</td>
#       <td id="T_d8e2b_row6_col1" class="data row6 col1" >0.002 +/- 0.002</td>
#       <td id="T_d8e2b_row6_col2" class="data row6 col2" >0.965 +/- 0.004</td>
#     </tr>
#     <tr>
#       <th id="T_d8e2b_level0_row7" class="row_heading level0 row7" >P4_joint_rare</th>
#       <td id="T_d8e2b_row7_col0" class="data row7 col0" >0.000 +/- 0.000</td>
#       <td id="T_d8e2b_row7_col1" class="data row7 col1" >0.000 +/- 0.000</td>
#       <td id="T_d8e2b_row7_col2" class="data row7 col2" >0.964 +/- 0.004</td>
#     </tr>
#     <tr>
#       <th id="T_d8e2b_level0_row8" class="row_heading level0 row8" >P4_staged_rare</th>
#       <td id="T_d8e2b_row8_col0" class="data row8 col0" >0.000 +/- 0.000</td>
#       <td id="T_d8e2b_row8_col1" class="data row8 col1" >0.005 +/- 0.007</td>
#       <td id="T_d8e2b_row8_col2" class="data row8 col2" >0.965 +/- 0.003</td>
#     </tr>
#     <tr>
#       <th id="T_d8e2b_level0_row9" class="row_heading level0 row9" >P5_joint_all</th>
#       <td id="T_d8e2b_row9_col0" class="data row9 col0" >0.000 +/- 0.000</td>
#       <td id="T_d8e2b_row9_col1" class="data row9 col1" >0.000 +/- 0.000</td>
#       <td id="T_d8e2b_row9_col2" class="data row9 col2" >0.963 +/- 0.003</td>
#     </tr>
#     <tr>
#       <th id="T_d8e2b_level0_row10" class="row_heading level0 row10" >P5_staged_all</th>
#       <td id="T_d8e2b_row10_col0" class="data row10 col0" >0.000 +/- 0.000</td>
#       <td id="T_d8e2b_row10_col1" class="data row10 col1" >0.004 +/- 0.007</td>
#       <td id="T_d8e2b_row10_col2" class="data row10 col2" >0.962 +/- 0.003</td>
#     </tr>
#   </tbody>
# </table>
# test_extended | recall | other_eligible
# <style type="text/css">
# #T_2a043_row0_col0, #T_2a043_row0_col1, #T_2a043_row0_col2 {
#   background-color: rgba(128, 128, 128, 0.25);
#   font-weight: bold;
# }
# #T_2a043_row1_col0, #T_2a043_row1_col1, #T_2a043_row3_col1, #T_2a043_row5_col0, #T_2a043_row5_col1, #T_2a043_row6_col0, #T_2a043_row6_col1, #T_2a043_row7_col0, #T_2a043_row7_col1, #T_2a043_row8_col0, #T_2a043_row9_col0, #T_2a043_row9_col1, #T_2a043_row9_col2, #T_2a043_row10_col0, #T_2a043_row10_col1 {
#   background-color: rgba(215, 48, 39, 0.75);
# }
# #T_2a043_row1_col2 {
#   background-color: rgba(215, 48, 39, 0.21);
# }
# #T_2a043_row2_col0, #T_2a043_row3_col0, #T_2a043_row4_col0 {
#   background-color: rgba(215, 48, 39, 0.75);
#   border: 2px solid black;
# }
# #T_2a043_row2_col1 {
#   background-color: rgba(215, 48, 39, 0.73);
#   border: 2px solid black;
# }
# #T_2a043_row2_col2, #T_2a043_row5_col2 {
#   background-color: rgba(215, 48, 39, 0.47);
# }
# #T_2a043_row3_col2 {
#   background-color: rgba(215, 48, 39, 0.41);
# }
# #T_2a043_row4_col1, #T_2a043_row8_col1 {
#   background-color: rgba(215, 48, 39, 0.74);
#   border: 2px solid black;
# }
# #T_2a043_row4_col2 {
#   background-color: rgba(26, 152, 80, 0.20);
#   border: 2px solid black;
# }
# #T_2a043_row6_col2 {
#   background-color: rgba(26, 152, 80, 0.71);
#   border: 2px solid black;
# }
# #T_2a043_row7_col2 {
#   background-color: rgba(215, 48, 39, 0.32);
# }
# #T_2a043_row8_col2 {
#   background-color: rgba(26, 152, 80, 0.60);
#   border: 2px solid black;
# }
# #T_2a043_row10_col2 {
#   background-color: rgba(26, 152, 80, 0.18);
# }
# </style>
# <table id="T_2a043">
#   <thead>
#     <tr>
#       <th class="index_name level0" >stage</th>
#       <th id="T_2a043_level0_col0" class="col_heading level0 col0" >pretrained</th>
#       <th id="T_2a043_level0_col1" class="col_heading level0 col1" >frozen_head</th>
#       <th id="T_2a043_level0_col2" class="col_heading level0 col2" >unfrozen_head</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a043_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_2a043_row0_col0" class="data row0 col0" >0.722 +/- 0.008</td>
#       <td id="T_2a043_row0_col1" class="data row0 col1" >0.722 +/- 0.008</td>
#       <td id="T_2a043_row0_col2" class="data row0 col2" >0.722 +/- 0.008</td>
#     </tr>
#     <tr>
#       <th id="T_2a043_level0_row1" class="row_heading level0 row1" >P0_single</th>
#       <td id="T_2a043_row1_col0" class="data row1 col0" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row1_col1" class="data row1 col1" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row1_col2" class="data row1 col2" >0.720 +/- 0.010</td>
#     </tr>
#     <tr>
#       <th id="T_2a043_level0_row2" class="row_heading level0 row2" >P1_permutation</th>
#       <td id="T_2a043_row2_col0" class="data row2 col0" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row2_col1" class="data row2 col1" >0.019 +/- 0.027</td>
#       <td id="T_2a043_row2_col2" class="data row2 col2" >0.713 +/- 0.025</td>
#     </tr>
#     <tr>
#       <th id="T_2a043_level0_row3" class="row_heading level0 row3" >P2_joint_base</th>
#       <td id="T_2a043_row3_col0" class="data row3 col0" >0.001 +/- 0.001</td>
#       <td id="T_2a043_row3_col1" class="data row3 col1" >0.002 +/- 0.002</td>
#       <td id="T_2a043_row3_col2" class="data row3 col2" >0.714 +/- 0.025</td>
#     </tr>
#     <tr>
#       <th id="T_2a043_level0_row4" class="row_heading level0 row4" >P2_staged_base</th>
#       <td id="T_2a043_row4_col0" class="data row4 col0" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row4_col1" class="data row4 col1" >0.012 +/- 0.010</td>
#       <td id="T_2a043_row4_col2" class="data row4 col2" >0.723 +/- 0.009</td>
#     </tr>
#     <tr>
#       <th id="T_2a043_level0_row5" class="row_heading level0 row5" >P3_joint_overlap</th>
#       <td id="T_2a043_row5_col0" class="data row5 col0" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row5_col1" class="data row5 col1" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row5_col2" class="data row5 col2" >0.713 +/- 0.014</td>
#     </tr>
#     <tr>
#       <th id="T_2a043_level0_row6" class="row_heading level0 row6" >P3_staged_overlap</th>
#       <td id="T_2a043_row6_col0" class="data row6 col0" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row6_col1" class="data row6 col1" >0.005 +/- 0.005</td>
#       <td id="T_2a043_row6_col2" class="data row6 col2" >0.738 +/- 0.017</td>
#     </tr>
#     <tr>
#       <th id="T_2a043_level0_row7" class="row_heading level0 row7" >P4_joint_rare</th>
#       <td id="T_2a043_row7_col0" class="data row7 col0" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row7_col1" class="data row7 col1" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row7_col2" class="data row7 col2" >0.717 +/- 0.018</td>
#     </tr>
#     <tr>
#       <th id="T_2a043_level0_row8" class="row_heading level0 row8" >P4_staged_rare</th>
#       <td id="T_2a043_row8_col0" class="data row8 col0" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row8_col1" class="data row8 col1" >0.006 +/- 0.009</td>
#       <td id="T_2a043_row8_col2" class="data row8 col2" >0.734 +/- 0.029</td>
#     </tr>
#     <tr>
#       <th id="T_2a043_level0_row9" class="row_heading level0 row9" >P5_joint_all</th>
#       <td id="T_2a043_row9_col0" class="data row9 col0" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row9_col1" class="data row9 col1" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row9_col2" class="data row9 col2" >0.705 +/- 0.016</td>
#     </tr>
#     <tr>
#       <th id="T_2a043_level0_row10" class="row_heading level0 row10" >P5_staged_all</th>
#       <td id="T_2a043_row10_col0" class="data row10 col0" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row10_col1" class="data row10 col1" >0.000 +/- 0.000</td>
#       <td id="T_2a043_row10_col2" class="data row10 col2" >0.723 +/- 0.008</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Unfrozen-head stage per variant (the pooled figure above mixes variants with different effects)
unfrozen = frame_abs[frame_abs.stage.isin(['real_only', 'unfrozen_head'])] if 'frame_abs' in globals() else metrics_abs[metrics_abs.stage.isin(['real_only', 'unfrozen_head'])]
figures.metric_panels(unfrozen, panels=[(f'{label}, unfrozen head', selector, direction) for label, selector, direction in SELECTORS_ABS],
                      group='variant', order=ABS_ORDER, labels=LABELS_ABS, baseline=BASELINE, columns=3, theme=theme);

# %% [markdown]
# ### Remarks
#
# - test_combined | average_precision | rare (by stage, variants pooled): baseline 0.6443; others 0.09979-0.6418; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.6418), worst pretrained (0.09979).
# - test_combined | average_precision | rare (unfrozen head, per variant): baseline 0.6443; others 0.6366-0.6536; 1 of 10 better than the baseline; best P0 single bins (0.6536), worst P4 joint + rare (0.6366).
#   best single cell: P0 single bins, fine-tuned, unfrozen head (0.6536 vs baseline 0.6443).
# - test_extended | average_precision | rare (by stage, variants pooled): baseline 0.7025; others 0.1729-0.6976; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.6976), worst pretrained (0.1729).
# - test_extended | average_precision | rare (unfrozen head, per variant): baseline 0.7025; others 0.6872-0.7092; 2 of 10 better than the baseline; best P0 single bins (0.7092), worst P2 joint (0.6872).
#   best single cell: P0 single bins, fine-tuned, unfrozen head (0.7092 vs baseline 0.7025).
# - test_combined | recall | rare (by stage, variants pooled): baseline 0.6638; others 0.005274-0.6734; 1 of 3 better than the baseline; best fine-tuned, unfrozen head (0.6734), worst fine-tuned, frozen head (0.005274).
# - test_combined | recall | rare (unfrozen head, per variant): baseline 0.6638; others 0.6241-0.7063; 7 of 10 better than the baseline; best P4 staged + rare (0.7063), worst P0 single bins (0.6241).
#   best single cell: P4 staged + rare, fine-tuned, unfrozen head (0.7063 vs baseline 0.6638).
# - test_extended | recall | rare (by stage, variants pooled): baseline 0.4966; others 0-0.5026; 1 of 3 better than the baseline; best fine-tuned, unfrozen head (0.5026), worst pretrained (0).
# - test_extended | recall | rare (unfrozen head, per variant): baseline 0.4966; others 0.4806-0.5228; 7 of 10 better than the baseline; best P4 staged + rare (0.5228), worst P1 permutations (0.4806).
#   best single cell: P4 staged + rare, fine-tuned, unfrozen head (0.5228 vs baseline 0.4966).
# - heldout_image | average_precision | other_eligible (by stage, variants pooled): baseline 0.08724; others 0.05764-0.09105; 1 of 3 better than the baseline; best fine-tuned, unfrozen head (0.09105), worst fine-tuned, frozen head (0.05764).
# - heldout_image | average_precision | other_eligible (unfrozen head, per variant): baseline 0.08724; others 0.08506-0.09499; 8 of 10 better than the baseline; best P4 staged + rare (0.09499), worst P1 permutations (0.08506).
#   best single cell: P4 staged + rare, fine-tuned, unfrozen head (0.09499 vs baseline 0.08724).
# - test_combined | average_precision | other_eligible (by stage, variants pooled): baseline 0.9073; others 0.1784-0.9135; 1 of 3 better than the baseline; best fine-tuned, unfrozen head (0.9135), worst pretrained (0.1784).
# - test_combined | average_precision | other_eligible (unfrozen head, per variant): baseline 0.9073; others 0.9076-0.9237; 10 of 10 better than the baseline; best P0 single bins (0.9237), worst P2 joint (0.9076).
#   best single cell: P0 single bins, fine-tuned, unfrozen head (0.9237 vs baseline 0.9073).
# - test_extended | average_precision | other_eligible (by stage, variants pooled): baseline 0.8157; others 0.2542-0.8137; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.8137), worst pretrained (0.2542).
# - test_extended | average_precision | other_eligible (unfrozen head, per variant): baseline 0.8157; others 0.8051-0.8258; 4 of 10 better than the baseline; best P0 single bins (0.8258), worst P5 joint + overlap + rare (0.8051).
#   best single cell: P0 single bins, fine-tuned, unfrozen head (0.8258 vs baseline 0.8157).
# - heldout_image | recall | other_eligible (by stage, variants pooled): baseline 0.007415; others 0-0.007354; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.007354), worst fine-tuned, frozen head (0).
# - heldout_image | recall | other_eligible (unfrozen head, per variant): baseline 0.007415; others 0.003851-0.01237; 5 of 10 better than the baseline; best P5 joint + overlap + rare (0.01237), worst P3 joint + overlap (0.003851).
#   best single cell: P5 joint + overlap + rare, fine-tuned, unfrozen head (0.01237 vs baseline 0.007415).
# - test_combined | recall | other_eligible (by stage, variants pooled): baseline 0.9613; others 0.0002497-0.9625; 1 of 3 better than the baseline; best fine-tuned, unfrozen head (0.9625), worst pretrained (0.0002497).
# - test_combined | recall | other_eligible (unfrozen head, per variant): baseline 0.9613; others 0.9572-0.9655; 7 of 10 better than the baseline; best P3 staged + overlap (0.9655), worst P1 permutations (0.9572).
#   best single cell: P3 staged + overlap, fine-tuned, unfrozen head (0.9655 vs baseline 0.9613).
# - test_extended | recall | other_eligible (by stage, variants pooled): baseline 0.7218; others 6.391e-05-0.72; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.72), worst pretrained (6.391e-05).
# - test_extended | recall | other_eligible (unfrozen head, per variant): baseline 0.7218; others 0.7049-0.7375; 4 of 10 better than the baseline; best P3 staged + overlap (0.7375), worst P5 joint + overlap + rare (0.7049).
#   best single cell: P3 staged + overlap, fine-tuned, unfrozen head (0.7375 vs baseline 0.7218).

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Targeted classes and their synthetic exposure

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# Which classes the quota targets and how much synthetic exposure they receive. A rare class is rare in the
# real training data; its test support comes mostly from the test extension.

# %% [markdown]
# #### Implementation
#
# `classes` (flags, annotation counts, ranks) and `exposure` (tokens of the rare classes per population and kind).

# %% [markdown]
# #### Figure descriptions
#
# No figure; counts and ranges of the class sets, then the tokens per population and kind.

# %%
classes['set'] = np.where(~classes.generator_eligible.astype(bool), 'not eligible', np.where(classes.rare.astype(bool), 'rare', 'other_eligible'))
display(classes.groupby('set').agg(classes=('class_index', 'size'), min_train_positives=('train_positives', 'min'),
                                   median_train_positives=('train_positives', 'median'), max_train_positives=('train_positives', 'max')))
display(table('exposure').pivot_table(index='population', columns='kind', values='tokens', aggfunc='sum', fill_value=0))
# Out:
#                 classes  min_train_positives  median_train_positives  max_train_positives
# set
# not eligible        460                    1                   904.0                19293
# other_eligible       77                10256                 14312.0                24409
# rare                 26                  726                  7578.5                10922
# kind                 base_class  overlap_bonus  rare_bonus  single
# population
# axis                          0              0           0     260
# joint_all                   780            180         780     260
# joint_base                  780              0           0     260
# joint_overlap               780            180           0     260
# joint_rare                  780              0         780     260
# permutation_all             780            180         780       0
# permutation_base            780              0           0       0
# permutation_overlap         780            180           0       0
# permutation_rare            780              0         780       0

# %% [markdown]
# ### Remarks
#
# - 103 of 563 head classes are generator-eligible; 26 are rare. Rare classes have 726-10922 training positives (median 7578): they are the least-annotated eligible classes, not rare classes of the head (the head's rarest classes, down to 1 training positive, are not generator-eligible).

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Rare and other eligible classes against the baseline

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# Macro AP over each class set (eligible classes of the evaluation), paired against the baseline. The quota
# works if the rare-set improvement of P4/P5 exceeds that of P2/P3 and that of the other eligible classes.

# %% [markdown]
# #### Implementation
#
# `baseline_improvements` (per model) and `baseline_summary`.

# %% [markdown]
# #### Figure descriptions
#
# Forest plot: rows = variants, panels = stage x class set (test + extension).

# %%
rows = baseline_summary[(baseline_summary.metric == 'average_precision') & (baseline_summary.evaluation == 'test_combined')]
panels = [(f"{STAGE_LABELS[stage]}, {class_set}", {'stage': stage, 'class_set': class_set}) for class_set in ['rare', 'other_eligible'] for stage in STAGES]
paired = table('baseline_improvements')
figures.improvement_forest(rows, panels=panels, variants=VARIANTS, labels=VARIANT_LABELS, colors=VARIANT_COLORS,
                           paired=paired[(paired.metric == 'average_precision') & (paired.evaluation == 'test_combined')], columns=3,
                           xlabel='macro-AP improvement over the baseline', theme=theme);
shown = baseline_summary[baseline_summary.metric == 'average_precision']
display(shown.assign(result=interval(shown)).pivot_table(index='variant', columns=['evaluation', 'class_set', 'stage'], values='result', aggfunc='first').reindex(VARIANTS))
# Out:
# evaluation                               heldout_image                                                                                              test_combined                                   \
# class_set                               other_eligible                                                                                             other_eligible
# stage                                      frozen_head                           pretrained                        unfrozen_head                      frozen_head                       pretrained
# variant
# P0_single           -0.0317 [-0.0534, -0.0101] (+0/-5)    -0.0208 [-0.0524, 0.0108] (+2/-3)   0.00474 [-0.00922, 0.0187] (+4/-1)  -0.564 [-0.626, -0.503] (+0/-5)  -0.725 [-0.797, -0.653] (+0/-5)
# P1_permutation      -0.0361 [-0.0466, -0.0256] (+0/-5)   -0.0406 [-0.0576, -0.0236] (+0/-5)   -0.00218 [-0.0208, 0.0165] (+3/-2)  -0.661 [-0.719, -0.604] (+0/-5)  -0.524 [-0.823, -0.225] (+0/-5)
# P2_joint_base        -0.0231 [-0.0566, 0.0104] (+1/-4)  -0.00957 [-0.0248, 0.00562] (+1/-4)   0.00689 [-0.00543, 0.0192] (+4/-1)  -0.553 [-0.644, -0.462] (+0/-5)   -0.764 [-0.78, -0.747] (+0/-5)
# P2_staged_base     -0.0302 [-0.0528, -0.00766] (+1/-4)   -0.0146 [-0.0319, 0.00281] (+1/-4)  -0.000615 [-0.0134, 0.0122] (+2/-3)   -0.581 [-0.64, -0.523] (+0/-5)   -0.752 [-0.793, -0.71] (+0/-5)
# P3_joint_overlap    -0.0275 [-0.0437, -0.0112] (+0/-5)    -0.00392 [-0.021, 0.0132] (+2/-3)     0.00394 [-0.0051, 0.013] (+4/-1)  -0.526 [-0.637, -0.416] (+0/-5)  -0.741 [-0.769, -0.713] (+0/-5)
# P3_staged_overlap   -0.0269 [-0.0425, -0.0114] (+0/-5)  -0.00675 [-0.0213, 0.00779] (+1/-4)    0.00241 [-0.0144, 0.0192] (+3/-2)  -0.574 [-0.628, -0.519] (+0/-5)  -0.759 [-0.776, -0.742] (+0/-5)
# P4_joint_rare      -0.0312 [-0.0581, -0.00428] (+0/-5)   -0.0113 [-0.0288, 0.00616] (+1/-4)     0.00217 [-0.014, 0.0184] (+3/-2)  -0.493 [-0.537, -0.448] (+0/-5)  -0.751 [-0.765, -0.737] (+0/-5)
# P4_staged_rare      -0.0252 [-0.0507, 0.00028] (+0/-5)   -0.0184 [-0.0428, 0.00588] (+1/-4)    0.00775 [-0.00955, 0.025] (+3/-2)  -0.614 [-0.683, -0.546] (+0/-5)  -0.759 [-0.781, -0.737] (+0/-5)
# P5_joint_all        -0.0369 [-0.0568, -0.0169] (+0/-5)     -0.0101 [-0.03, 0.00973] (+2/-3)   0.00659 [-0.00847, 0.0217] (+4/-1)  -0.525 [-0.656, -0.395] (+0/-5)  -0.747 [-0.787, -0.707] (+0/-5)
# P5_staged_all        -0.0272 [-0.047, -0.0074] (+0/-5)   -0.0215 [-0.0497, 0.00679] (+1/-4)   0.00639 [-0.00488, 0.0177] (+4/-1)  -0.627 [-0.671, -0.582] (+0/-5)  -0.768 [-0.784, -0.752] (+0/-5)
#
# evaluation                                                                                                                                                                        test_extended  \
# class_set                                                                           rare                                                                                         other_eligible
# stage                                     unfrozen_head                      frozen_head                       pretrained                        unfrozen_head                      frozen_head
# variant
# P0_single              0.0164 [0.00838, 0.0244] (+5/-0)  -0.425 [-0.451, -0.399] (+0/-5)  -0.523 [-0.581, -0.465] (+0/-5)   0.00926 [-0.00114, 0.0197] (+4/-1)   -0.437 [-0.57, -0.304] (+0/-5)
# P1_permutation       0.00475 [-0.00332, 0.0128] (+4/-1)  -0.523 [-0.562, -0.485] (+0/-5)  -0.456 [-0.617, -0.296] (+0/-5)   -0.00181 [-0.0167, 0.0131] (+2/-3)  -0.507 [-0.693, -0.321] (+0/-5)
# P2_joint_base      0.000334 [-0.00749, 0.00816] (+3/-2)   -0.44 [-0.511, -0.368] (+0/-5)  -0.562 [-0.576, -0.549] (+0/-5)  -0.00617 [-0.0169, 0.00457] (+2/-3)  -0.266 [-0.364, -0.169] (+0/-5)
# P2_staged_base      0.00213 [-0.00513, 0.00938] (+3/-2)   -0.45 [-0.483, -0.417] (+0/-5)   -0.56 [-0.589, -0.531] (+0/-5)   -0.00442 [-0.0201, 0.0112] (+2/-3)  -0.417 [-0.522, -0.311] (+0/-5)
# P3_joint_overlap     0.00598 [-0.00341, 0.0154] (+4/-1)  -0.392 [-0.472, -0.311] (+0/-5)  -0.552 [-0.567, -0.538] (+0/-5)      -0.00295 [-0.02, 0.014] (+2/-3)   -0.239 [-0.33, -0.148] (+0/-5)
# P3_staged_overlap   0.00673 [-0.000188, 0.0136] (+4/-1)  -0.438 [-0.462, -0.415] (+0/-5)  -0.565 [-0.573, -0.556] (+0/-5)   -0.0024 [-0.0111, 0.00633] (+2/-3)   -0.437 [-0.53, -0.345] (+0/-5)
# P4_joint_rare         0.00198 [-0.00303, 0.007] (+3/-2)  -0.411 [-0.474, -0.348] (+0/-5)  -0.558 [-0.579, -0.538] (+0/-5)  -0.00776 [-0.0193, 0.00376] (+1/-4)  -0.297 [-0.411, -0.183] (+0/-5)
# P4_staged_rare         0.00752 [0.00308, 0.012] (+5/-0)  -0.474 [-0.508, -0.439] (+0/-5)  -0.558 [-0.582, -0.534] (+0/-5)   -0.0015 [-0.0102, 0.00722] (+2/-3)  -0.416 [-0.488, -0.345] (+0/-5)
# P5_joint_all         0.00788 [-0.00196, 0.0177] (+4/-1)   -0.41 [-0.483, -0.336] (+0/-5)   -0.55 [-0.592, -0.509] (+0/-5)    -0.00504 [-0.025, 0.0149] (+2/-3)  -0.259 [-0.324, -0.193] (+0/-5)
# P5_staged_all        0.00862 [0.000298, 0.0169] (+5/-0)     -0.5 [-0.57, -0.431] (+0/-5)   -0.56 [-0.577, -0.542] (+0/-5)  -0.00256 [-0.0102, 0.00511] (+1/-4)   -0.45 [-0.504, -0.395] (+0/-5)
#
# evaluation
# class_set                                                                                                           rare
# stage                                   pretrained                        unfrozen_head                      frozen_head                       pretrained                        unfrozen_head
# variant
# P0_single           -0.567 [-0.65, -0.485] (+0/-5)     0.0101 [0.00551, 0.0146] (+5/-0)   -0.322 [-0.44, -0.205] (+0/-5)  -0.554 [-0.632, -0.477] (+0/-5)   0.00673 [-0.00075, 0.0142] (+4/-1)
# P1_permutation     -0.611 [-0.644, -0.578] (+0/-5)  -0.00465 [-0.0165, 0.00726] (+1/-4)  -0.465 [-0.662, -0.267] (+0/-5)   -0.55 [-0.592, -0.508] (+0/-5)   7.08e-05 [-0.0271, 0.0272] (+2/-3)
# P2_joint_base      -0.508 [-0.547, -0.469] (+0/-5)  -0.00505 [-0.0184, 0.00828] (+2/-3)  -0.219 [-0.271, -0.168] (+0/-5)  -0.471 [-0.557, -0.385] (+0/-5)    -0.0152 [-0.0322, 0.0017] (+1/-4)
# P2_staged_base     -0.562 [-0.599, -0.525] (+0/-5)   0.000852 [-0.0105, 0.0122] (+2/-3)   -0.322 [-0.434, -0.21] (+0/-5)  -0.531 [-0.604, -0.458] (+0/-5)  -0.00574 [-0.0196, 0.00808] (+3/-2)
# P3_joint_overlap   -0.552 [-0.579, -0.524] (+0/-5)  -0.000641 [-0.0125, 0.0113] (+3/-2)  -0.199 [-0.242, -0.157] (+0/-5)  -0.526 [-0.559, -0.493] (+0/-5)  -0.00876 [-0.0255, 0.00797] (+1/-4)
# P3_staged_overlap  -0.572 [-0.594, -0.551] (+0/-5)   0.000183 [-0.0153, 0.0156] (+3/-2)  -0.377 [-0.452, -0.302] (+0/-5)  -0.546 [-0.575, -0.517] (+0/-5)     -0.008 [-0.0299, 0.0139] (+2/-3)
# P4_joint_rare      -0.566 [-0.594, -0.537] (+0/-5)  -0.00775 [-0.013, -0.00251] (+0/-5)   -0.254 [-0.338, -0.17] (+0/-5)  -0.535 [-0.568, -0.503] (+0/-5)   -0.00472 [-0.0403, 0.0309] (+3/-2)
# P4_staged_rare     -0.557 [-0.586, -0.528] (+0/-5)   0.00273 [-0.00791, 0.0134] (+2/-3)  -0.337 [-0.451, -0.222] (+0/-5)  -0.544 [-0.585, -0.503] (+0/-5)   -0.00839 [-0.0336, 0.0168] (+2/-3)
# P5_joint_all        -0.57 [-0.605, -0.535] (+0/-5)   -0.0107 [-0.0294, 0.00804] (+2/-3)  -0.244 [-0.303, -0.184] (+0/-5)  -0.514 [-0.581, -0.446] (+0/-5)   -0.00223 [-0.0233, 0.0188] (+3/-2)
# P5_staged_all      -0.551 [-0.579, -0.523] (+0/-5)   -0.00555 [-0.0239, 0.0128] (+2/-3)  -0.427 [-0.581, -0.273] (+0/-5)  -0.525 [-0.571, -0.479] (+0/-5)   -0.00302 [-0.0304, 0.0244] (+2/-3)

# %% [markdown]
# ### Remarks
#
# - frozen head, other_eligible: macro-AP improvement -0.661 to -0.493; above zero: none; below: 10 variants.
# - frozen head, rare: macro-AP improvement -0.523 to -0.392; above zero: none; below: 10 variants.
# - pretrained, other_eligible: macro-AP improvement -0.768 to -0.524; above zero: none; below: 10 variants.
# - pretrained, rare: macro-AP improvement -0.565 to -0.456; above zero: none; below: 10 variants.
# - unfrozen head, other_eligible: macro-AP improvement 0.000334 to 0.0164; above zero: P0 single bins, P4 staged + rare, P5 staged + overlap + rare; below: 0 variants.
# - unfrozen head, rare: macro-AP improvement -0.00776 to 0.00926; above zero: none; below: 0 variants.

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Rare quota against the matched control

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# The direct test of the mechanism: variant with the quota minus the same variant without it, paired by stage
# and repetition. A positive rare-set effect with no other-eligible effect is the signature of a working
# quota.

# %% [markdown]
# #### Implementation
#
# `control_improvements` and `control_summary`.

# %% [markdown]
# #### Figure descriptions
#
# Forest plot: rows = treated variants (label: treated - control), panels = stage x class set (test + extension).

# %%
rows = control_summary[(control_summary.metric == 'average_precision') & (control_summary.evaluation == 'test_combined')]
figures.improvement_forest(rows, panels=panels, variants=TREATED, labels=PAIR_LABELS, colors=VARIANT_COLORS, columns=3,
                           xlabel='macro-AP difference (with - without quota)', theme=theme);
shown = control_summary[control_summary.metric == 'average_precision']
display(shown.assign(result=interval(shown)).pivot_table(index='variant', columns=['evaluation', 'class_set', 'stage'], values='result', aggfunc='first').reindex(TREATED))
# Out:
# evaluation                            heldout_image                                                                                                test_combined                                      \
# class_set                            other_eligible                                                                                               other_eligible
# stage                                   frozen_head                            pretrained                        unfrozen_head                       frozen_head                          pretrained
# variant
# P4_joint_rare   -0.00811 [-0.0191, 0.00292] (+0/-5)  -0.00174 [-0.00508, 0.00159] (+2/-3)  -0.00472 [-0.0171, 0.00767] (+2/-3)   0.0604 [-0.0458, 0.167] (+4/-1)     0.0133 [-0.005, 0.0316] (+4/-1)
# P4_staged_rare    0.00505 [-0.0403, 0.0504] (+3/-2)    -0.00389 [-0.0296, 0.0219] (+2/-3)   0.00836 [-0.00489, 0.0216] (+4/-1)  -0.0332 [-0.101, 0.0349] (+2/-3)   -0.0073 [-0.0424, 0.0278] (+2/-3)
# P5_joint_all      -0.00938 [-0.045, 0.0262] (+1/-4)     -0.00623 [-0.024, 0.0115] (+2/-3)    0.00265 [-0.00566, 0.011] (+3/-2)  0.000959 [-0.206, 0.208] (+2/-3)  -0.00626 [-0.0591, 0.0465] (+1/-4)
# P5_staged_all   -0.000253 [-0.0306, 0.0301] (+3/-2)     -0.0147 [-0.0408, 0.0113] (+1/-4)       0.00399 [-0.012, 0.02] (+3/-2)  -0.0534 [-0.129, 0.0221] (+1/-4)  -0.00867 [-0.0316, 0.0143] (+1/-4)
#
# evaluation                                                                                                                                                                            test_extended  \
# class_set                                                                          rare                                                                                              other_eligible
# stage                                 unfrozen_head                         frozen_head                         pretrained                         unfrozen_head                        frozen_head
# variant
# P4_joint_rare   0.00165 [-0.00448, 0.00777] (+3/-2)    0.0288 [-0.0371, 0.0947] (+3/-2)  0.00413 [-0.0155, 0.0238] (+4/-1)    -0.00159 [-0.0173, 0.0141] (+3/-2)    -0.0306 [-0.174, 0.113] (+2/-3)
# P4_staged_rare   0.00539 [-0.00166, 0.0124] (+4/-1)  -0.0236 [-0.0551, 0.00798] (+1/-4)  0.00221 [-0.0162, 0.0206] (+2/-3)     0.00292 [-0.0141, 0.0199] (+3/-2)   0.000356 [-0.172, 0.172] (+1/-4)
# P5_joint_all       0.00189 [-0.00623, 0.01] (+4/-1)     -0.018 [-0.127, 0.0912] (+2/-3)  0.00192 [-0.0449, 0.0487] (+1/-4)  -0.00209 [-0.00625, 0.00207] (+1/-4)    -0.0196 [-0.154, 0.115] (+1/-4)
# P5_staged_all   0.00189 [-0.00242, 0.00621] (+4/-1)  -0.0619 [-0.115, -0.00844] (+1/-4)   0.00504 [-0.0159, 0.026] (+3/-2)   -0.000165 [-0.0131, 0.0127] (+3/-2)  -0.0128 [-0.0897, 0.0642] (+2/-3)
#
# evaluation
# class_set                                                                                                            rare
# stage                                   pretrained                        unfrozen_head                       frozen_head                         pretrained                       unfrozen_head
# variant
# P4_joint_rare   -0.0574 [-0.0877, -0.0272] (+0/-5)    -0.0027 [-0.0161, 0.0107] (+2/-3)  -0.0345 [-0.144, 0.0745] (+3/-2)   -0.0645 [-0.145, 0.0162] (+0/-5)      0.0105 [-0.015, 0.036] (+4/-1)
# P4_staged_rare    0.00532 [-0.0344, 0.045] (+3/-2)  0.00188 [-0.00171, 0.00547] (+4/-1)   -0.0146 [-0.195, 0.166] (+3/-2)  -0.0127 [-0.0916, 0.0662] (+1/-4)  -0.00265 [-0.0165, 0.0112] (+2/-3)
# P5_joint_all     -0.0188 [-0.0495, 0.0119] (+1/-4)     -0.01 [-0.0298, 0.00977] (+1/-4)  -0.0446 [-0.109, 0.0194] (+1/-4)   0.0125 [-0.0538, 0.0788] (+2/-3)   0.00654 [-0.0258, 0.0389] (+4/-1)
# P5_staged_all     0.0211 [0.00515, 0.0371] (+5/-0)    -0.00573 [-0.0265, 0.015] (+2/-3)   -0.0498 [-0.213, 0.113] (+1/-4)   0.0213 [-0.0127, 0.0553] (+4/-1)   0.00497 [-0.0314, 0.0414] (+3/-2)

# %% [markdown]
# ### Remarks
#
# - test+ext, frozen head, rare: with quota better for none; worse for P5 staged + overlap + rare.
# - test_extended, pretrained, other_eligible: with quota better for P5 staged + overlap + rare; worse for P4 joint + rare.
# - All other treated x stage x class-set x evaluation cells are inconclusive.

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Dose response: class improvement against annotation count

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# Per class, the mean AP improvement over the baseline against its training annotation count. If the quota
# acts, rare classes (left of the cutoff) should lie above the other eligible classes for P4/P5 but not for
# P2/P3.

# %% [markdown]
# #### Implementation
#
# `dose_response` (per class and cell; eligible classes of the evaluation).

# %% [markdown]
# #### Figure descriptions
#
# Panels = P2-P5 joint variants at the unfrozen stage (test + extension); x = annotation count (log), y = mean AP improvement, colour = class set.

# %%
dose = table('dose_response')
dose = dose[(dose.evaluation == 'test_combined') & dose.generator_eligible.astype(bool) & (dose.stage == 'unfrozen_head')].copy()
dose['set'] = np.where(dose.rare.astype(bool), 'rare', 'other eligible')
shown = ['P2_joint_base', 'P3_joint_overlap', 'P4_joint_rare', 'P5_joint_all']
figure, axes = plt.subplots(1, 4, figsize=(24, 5), dpi=theme.figure_dpi, sharey=True)
for ax, variant in zip(axes, shown):
    figures.paired_scatter(dose[dose.variant == variant], x='annotation_count', y='mean', hue='set', hue_order=['rare', 'other eligible'],
                           colors={'rare': theme.model_palette[3], 'other eligible': theme.model_palette[0]}, xlabel='training annotation count',
                           ylabel='mean AP improvement', title=VARIANT_LABELS[variant], diagonal=False, ax=ax, theme=theme)
    ax.set_xscale('log')
    ax.axhline(0.0, color=theme.baseline_color, linestyle='--', linewidth=0.8)
figure.tight_layout()

# %% [markdown]
# ### Remarks
#
# - As on 200-900: no separation of rare and other eligible classes at the unfrozen stage.

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Classes just below and just above the rare cutoff

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# Classes ranked just below the cutoff (rare, bonus tokens) and just above it (no bonus) have almost the same
# annotation count. Their improvement difference estimates the quota effect with frequency roughly held
# constant (a regression-discontinuity style comparison, descriptive).

# %% [markdown]
# #### Implementation
#
# `cutoff` (mean improvement over the baseline of the classes within the configured window of ranks).

# %% [markdown]
# #### Figure descriptions
#
# No figure; mean improvement below and above the cutoff per variant and stage (test + extension).

# %%
cutoff = table('cutoff')
cutoff = cutoff[cutoff.evaluation == 'test_combined']
display(cutoff.pivot_table(index='variant', columns=['stage', 'side'], values='mean_improvement').reindex(VARIANTS).round(4))
display(cutoff.groupby('side')[['classes', 'mean_annotation_count']].mean())
# Out:
# stage              frozen_head                     pretrained                   unfrozen_head
# side              above_cutoff rare_below_cutoff above_cutoff rare_below_cutoff  above_cutoff rare_below_cutoff
# variant
# P0_single              -0.5363           -0.4211      -0.6723           -0.5215        0.0314            0.0090
# P1_permutation         -0.6196           -0.5284      -0.5189           -0.4566        0.0081           -0.0016
# P2_joint_base          -0.5311           -0.4364      -0.7205           -0.5613        0.0026           -0.0064
# P2_staged_base         -0.5342           -0.4466      -0.7105           -0.5595        0.0064           -0.0041
# P3_joint_overlap       -0.4849           -0.3908      -0.7049           -0.5508        0.0133           -0.0028
# P3_staged_overlap      -0.5271           -0.4343      -0.7278           -0.5640        0.0142           -0.0026
# P4_joint_rare          -0.4886           -0.4079      -0.7160           -0.5570        0.0073           -0.0081
# P4_staged_rare         -0.5783           -0.4736      -0.7258           -0.5567        0.0170           -0.0016
# P5_joint_all           -0.5027           -0.4053      -0.7085           -0.5487        0.0160           -0.0047
# P5_staged_all          -0.6059           -0.5017      -0.7278           -0.5591        0.0187           -0.0026
#                    classes  mean_annotation_count
# side
# above_cutoff          25.0               52462.04
# rare_below_cutoff     25.0               32241.48

# %% [markdown]
# ### Remarks
#
# - Unfrozen head: below-minus-above-cutoff difference of the mean AP improvement -0.0224 to -0.00892; the variants with the rare quota (P4, P5) are not systematically above those without.

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Rank of the annotated classes within their pixels

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# For every annotated entry, the rank of its logit among all classes of the pixel (1 = top). A rare class that
# the model has learned from synthetic data should be ranked higher within the pixels where it occurs.

# %% [markdown]
# #### Implementation
#
# `true_rank` (per model, evaluation and class set: median and mean rank over annotated entries).

# %% [markdown]
# #### Figure descriptions
#
# No figure; repetition mean of the median rank per variant and stage (baseline in its own row).

# %%
ranks = table('true_rank')
display(ranks.pivot_table(index='variant', columns=['evaluation', 'class_set', 'stage'], values='median_true_rank', aggfunc='mean').reindex(ORDER).round(1))
# Out:
# evaluation         heldout_image                                     test_combined
# class_set         other_eligible                                    other_eligible                                           rare
# stage                frozen_head pretrained real_only unfrozen_head    frozen_head pretrained real_only unfrozen_head frozen_head pretrained real_only unfrozen_head
# variant
# baseline                     NaN        NaN      18.4           NaN            NaN        NaN      36.4           NaN         NaN        NaN      83.8           NaN
# P0_single                    4.0        8.2       NaN          17.2          509.8      509.4       NaN          35.8       511.0      509.6       NaN          82.6
# P1_permutation              61.0       89.8       NaN          18.0           48.4       49.4       NaN          36.8        49.6       52.6       NaN          82.0
# P2_joint_base               40.8       74.6       NaN          17.8           47.4       46.4       NaN          36.8        53.2       60.0       NaN          80.8
# P2_staged_base              77.8      163.4       NaN          19.2           47.2       49.2       NaN          36.8       105.0      213.0       NaN          80.6
# P3_joint_overlap            30.6       63.8       NaN          17.6           50.4       49.2       NaN          35.6        44.0       47.8       NaN          82.0
# P3_staged_overlap           87.0       49.0       NaN          18.4           48.6       69.6       NaN          36.4        48.0      100.6       NaN          80.6
# P4_joint_rare               51.8       78.8       NaN          17.2           49.6       49.6       NaN          35.8        45.0       43.8       NaN          81.2
# P4_staged_rare             115.8       72.6       NaN          18.0           50.6       86.6       NaN          36.8        52.8      149.8       NaN          80.0
# P5_joint_all                44.2       71.0       NaN          17.0           50.2       53.2       NaN          35.6        43.8       42.0       NaN          81.0
# P5_staged_all               71.6      131.8       NaN          18.4           49.8       52.6       NaN          37.2        47.6       49.4       NaN          79.4

# %% [markdown]
# ### Remarks
#
# - Median rank of annotated rare classes (test + extension): baseline 83.8; pretrained P2-P3 47.8-213, with the rare quota (P4-P5) 42-150; unfrozen head 79.4-82.6.
# - Caveat: before real fine-tuning the synthetic head only scores the generator-eligible classes highly, so eligible classes are ranked above the ~400 others by construction; ranks are comparable between variants of one stage, not between stages.

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Spectra with rarely occurring peaks: the baseline against the fine-tuned variants

# %% [markdown]
# ### Methodology
#
# #### Theoretical
#
# Class-set metrics do not show how a spectrum with rare peaks is reconstructed. A bin is rare when it carries at
# least $10^{-3}$ of the TIC in fewer than 5 % of the training pixels; the rare mass of a pixel is its TIC fraction
# in rare bins, and the candidates are the 2 % of training and of held-out pixels with the largest rare mass. For
# the representatives of the baseline and of every unfrozen-head variant, the candidates are ranked by their
# per-pixel $W_1$: the two worst candidates of the baseline (shared by every variant), the two with the largest
# paired improvement of each variant and the variant's worst candidate. The spectra are reconstructed by the
# representatives themselves (full axis) and zoomed on the pixel's strongest rare peak.

# %% [markdown]
# #### Implementation
#
# `rare_spectra_pixels` (selected pixels with both costs, rare mass and rare peak) and `rare_spectra` (input and both reconstructions, all-zero bins dropped and restored for display).

# %% [markdown]
# #### Figure descriptions
#
# Table 1: per population and variant, the W1 change on the two baseline-worst rare-peak pixels against the baseline
# representative (negative = the variant is better); the last row is the change of the other four baseline
# repetitions, the reference for regression to the mean (pixels chosen as the worst of one model are better for
# almost any other model), so a variant helps only when its change is clearly below that row. Table 2: per population and variant, the paired gain of its two most improved pixels.
# Figures: for every variant in `SHOWN_RARE` (the rare-quota variants P4 and, as a reference without single-bin spectra, P1 permutations only; add others to inspect them) and population,
# one pair of rows per pixel: signal above (grey = input, black = baseline, colour = variant), residual below;
# columns = full range, +/- 15 m/z and +/- 60 m/z around the rare peak (dotted line).

# %%
LOWER_IS_BETTER = {'masserstein', 'spectral_angle', 'mse', 'hamming_loss', 'expected_calibration_error', 'brier_score',
                   'within', 'contribution', 'absolute_mass_imbalance', 'bic'}
METRIC_ORDER = ['average_precision', 'micro_average_precision', 'roc_auc', 'micro_roc_auc', 'ap_above_prevalence',
                'precision', 'recall', 'f1', 'micro_precision', 'micro_recall', 'micro_f1', 'micro_prevalence',
                'hamming_loss']
ABS_ORDER = [BASELINE, *VARIANTS]
LABELS_ABS = {**VARIANT_LABELS, **{name: VARIANT_LABELS.get(name, name) for name in ABS_ORDER}}


def better(metric):
    """Direction of a metric: 'lower' or 'higher' is better."""
    return 'lower' if metric in LOWER_IS_BETTER else 'higher'

# %%
rare_pixels = table('rare_spectra_pixels')
rare_spectra_table = table('rare_spectra')
worst = rare_pixels[rare_pixels.pixel_kind == 'baseline_worst'].assign(change=lambda frame: frame.masserstein - frame.masserstein_baseline)
changes = worst.pivot_table(index='variant', columns='population', values='change', aggfunc='mean').reindex(VARIANTS)
reference = worst.drop_duplicates(['population', 'row']).assign(change=lambda frame: frame.masserstein_baseline_others - frame.masserstein_baseline)
changes.loc['baseline, other repetitions (mean)'] = reference.groupby('population').change.mean()
display(changes.round(2))
improved = rare_pixels[rare_pixels.pixel_kind == 'most_improved'].assign(gain=lambda frame: frame.masserstein_baseline - frame.masserstein)
display(improved.pivot_table(index='variant', columns='population', values='gain', aggfunc='mean').reindex(VARIANTS).round(2))
# Out:
# population                          heldout_image  train
# variant
# P0_single                                   -5.79  -4.50
# P1_permutation                              -3.95  -7.24
# P2_joint_base                               -1.93 -10.22
# P2_staged_base                              -6.78   0.67
# P3_joint_overlap                            -4.08   6.09
# P3_staged_overlap                           -3.56   1.00
# P4_joint_rare                               -6.23   1.12
# P4_staged_rare                              -5.89  -2.21
# P5_joint_all                                -5.92  -0.63
# P5_staged_all                               -2.72   0.20
# baseline, other repetitions (mean)          -2.29  -2.18
# population         heldout_image  train
# variant
# P0_single                   6.29   9.95
# P1_permutation              5.88  13.22
# P2_joint_base               4.32  11.63
# P2_staged_base              6.78   9.69
# P3_joint_overlap            5.73   8.44
# P3_staged_overlap           4.81   6.64
# P4_joint_rare               6.73   9.64
# P4_staged_rare              5.89   8.12
# P5_joint_all                5.92   8.15
# P5_staged_all               4.32   7.49

# %%
SHOWN_RARE = ['P4_joint_rare', 'P4_staged_rare', 'P1_permutation']
for variant in SHOWN_RARE:
    for population in ('train', 'heldout_image'):
        shown = rare_spectra_table[(rare_spectra_table.variant == variant) & (rare_spectra_table.population == population)].merge(
            rare_pixels[(rare_pixels.variant == variant) & (rare_pixels.population == population)], on=['variant', 'population', 'row'])
        figure = figures.paired_spectra(shown, variant_label=VARIANT_LABELS.get(variant, variant), variant_color=VARIANT_COLORS[variant],
                                        kinds=('baseline_worst', 'most_improved', 'variant_worst'), center='rare_peak_mz', dense=True, theme=theme)
        figure.suptitle(f'{VARIANT_LABELS.get(variant, variant)} | {EVALUATION_NAMES.get(population, population)}', y=1.0)
        plt.show()

# %% [markdown]
# ### Remarks
#
# - heldout_image: on the two baseline-worst rare-peak pixels (baseline representative W1 16.41, other baseline repetitions 14.12) 10 of 10 fine-tuned variants reduce W1 against the representative, 9 of them also against the other repetitions; P4 joint + rare -6.23; P4 staged + rare -5.89; P1 permutations -3.95.
#   largest single improvement: P2 staged, W1 17.75 -> 10.04 (rare peak 380.2 m/z, present in 2.0 % of the training pixels).
# - train: on the two baseline-worst rare-peak pixels (baseline representative W1 30.92, other baseline repetitions 28.74) 5 of 10 fine-tuned variants reduce W1 against the representative, 4 of them also against the other repetitions; P4 joint + rare +1.12; P4 staged + rare -2.21; P1 permutations -7.24.
#   largest single improvement: P1 permutations, W1 35.63 -> 20.06 (rare peak 103.6 m/z, present in 1.9 % of the training pixels).

# %% [markdown]
# ### Notes

# %% [markdown]
# ## Results / Summary
#
# ### LLM
#
# - **Observed:** as on 200-900: no effect of the rare quota at the unfrozen stage (median rank 79-83 for every variant, baseline 84); at the pretrained stage the quota improves the median rank of rare classes in all four pairs (e.g. P4 joint 44 against P2 joint 60); one negative matched AP cell (P5 staged - P3 staged, frozen).
# - **Interpretation:** the rare quota does not transfer to the fine-tuned model.
#
# **Absolute levels against the real-only baseline** (means over repetitions; 'better' compares means only, without a test; the intervals are in the improvement sections):
#
# - test_combined | average_precision | rare (by stage, variants pooled): baseline 0.6443; others 0.09979-0.6418; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.6418), worst pretrained (0.09979).
# - test_combined | average_precision | rare (unfrozen head, per variant): baseline 0.6443; others 0.6366-0.6536; 1 of 10 better than the baseline; best P0 single bins (0.6536), worst P4 joint + rare (0.6366).
#   best single cell: P0 single bins, fine-tuned, unfrozen head (0.6536 vs baseline 0.6443).
# - test_extended | average_precision | rare (by stage, variants pooled): baseline 0.7025; others 0.1729-0.6976; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.6976), worst pretrained (0.1729).
# - test_extended | average_precision | rare (unfrozen head, per variant): baseline 0.7025; others 0.6872-0.7092; 2 of 10 better than the baseline; best P0 single bins (0.7092), worst P2 joint (0.6872).
#   best single cell: P0 single bins, fine-tuned, unfrozen head (0.7092 vs baseline 0.7025).
# - test_combined | recall | rare (by stage, variants pooled): baseline 0.6638; others 0.005274-0.6734; 1 of 3 better than the baseline; best fine-tuned, unfrozen head (0.6734), worst fine-tuned, frozen head (0.005274).
# - test_combined | recall | rare (unfrozen head, per variant): baseline 0.6638; others 0.6241-0.7063; 7 of 10 better than the baseline; best P4 staged + rare (0.7063), worst P0 single bins (0.6241).
#   best single cell: P4 staged + rare, fine-tuned, unfrozen head (0.7063 vs baseline 0.6638).
# - test_extended | recall | rare (by stage, variants pooled): baseline 0.4966; others 0-0.5026; 1 of 3 better than the baseline; best fine-tuned, unfrozen head (0.5026), worst pretrained (0).
# - test_extended | recall | rare (unfrozen head, per variant): baseline 0.4966; others 0.4806-0.5228; 7 of 10 better than the baseline; best P4 staged + rare (0.5228), worst P1 permutations (0.4806).
#   best single cell: P4 staged + rare, fine-tuned, unfrozen head (0.5228 vs baseline 0.4966).
# - heldout_image | average_precision | other_eligible (by stage, variants pooled): baseline 0.08724; others 0.05764-0.09105; 1 of 3 better than the baseline; best fine-tuned, unfrozen head (0.09105), worst fine-tuned, frozen head (0.05764).
# - heldout_image | average_precision | other_eligible (unfrozen head, per variant): baseline 0.08724; others 0.08506-0.09499; 8 of 10 better than the baseline; best P4 staged + rare (0.09499), worst P1 permutations (0.08506).
#   best single cell: P4 staged + rare, fine-tuned, unfrozen head (0.09499 vs baseline 0.08724).
# - test_combined | average_precision | other_eligible (by stage, variants pooled): baseline 0.9073; others 0.1784-0.9135; 1 of 3 better than the baseline; best fine-tuned, unfrozen head (0.9135), worst pretrained (0.1784).
# - test_combined | average_precision | other_eligible (unfrozen head, per variant): baseline 0.9073; others 0.9076-0.9237; 10 of 10 better than the baseline; best P0 single bins (0.9237), worst P2 joint (0.9076).
#   best single cell: P0 single bins, fine-tuned, unfrozen head (0.9237 vs baseline 0.9073).
# - test_extended | average_precision | other_eligible (by stage, variants pooled): baseline 0.8157; others 0.2542-0.8137; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.8137), worst pretrained (0.2542).
# - test_extended | average_precision | other_eligible (unfrozen head, per variant): baseline 0.8157; others 0.8051-0.8258; 4 of 10 better than the baseline; best P0 single bins (0.8258), worst P5 joint + overlap + rare (0.8051).
#   best single cell: P0 single bins, fine-tuned, unfrozen head (0.8258 vs baseline 0.8157).
# - heldout_image | recall | other_eligible (by stage, variants pooled): baseline 0.007415; others 0-0.007354; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.007354), worst fine-tuned, frozen head (0).
# - heldout_image | recall | other_eligible (unfrozen head, per variant): baseline 0.007415; others 0.003851-0.01237; 5 of 10 better than the baseline; best P5 joint + overlap + rare (0.01237), worst P3 joint + overlap (0.003851).
#   best single cell: P5 joint + overlap + rare, fine-tuned, unfrozen head (0.01237 vs baseline 0.007415).
# - test_combined | recall | other_eligible (by stage, variants pooled): baseline 0.9613; others 0.0002497-0.9625; 1 of 3 better than the baseline; best fine-tuned, unfrozen head (0.9625), worst pretrained (0.0002497).
# - test_combined | recall | other_eligible (unfrozen head, per variant): baseline 0.9613; others 0.9572-0.9655; 7 of 10 better than the baseline; best P3 staged + overlap (0.9655), worst P1 permutations (0.9572).
#   best single cell: P3 staged + overlap, fine-tuned, unfrozen head (0.9655 vs baseline 0.9613).
# - test_extended | recall | other_eligible (by stage, variants pooled): baseline 0.7218; others 6.391e-05-0.72; 0 of 3 better than the baseline; best fine-tuned, unfrozen head (0.72), worst pretrained (6.391e-05).
# - test_extended | recall | other_eligible (unfrozen head, per variant): baseline 0.7218; others 0.7049-0.7375; 4 of 10 better than the baseline; best P3 staged + overlap (0.7375), worst P5 joint + overlap + rare (0.7049).
#   best single cell: P3 staged + overlap, fine-tuned, unfrozen head (0.7375 vs baseline 0.7218).
# - heldout_image: on the two baseline-worst rare-peak pixels (baseline representative W1 16.41, other baseline repetitions 14.12) 10 of 10 fine-tuned variants reduce W1 against the representative, 9 of them also against the other repetitions; P4 joint + rare -6.23; P4 staged + rare -5.89; P1 permutations -3.95.
#   largest single improvement: P2 staged, W1 17.75 -> 10.04 (rare peak 380.2 m/z, present in 2.0 % of the training pixels).
# - train: on the two baseline-worst rare-peak pixels (baseline representative W1 30.92, other baseline repetitions 28.74) 5 of 10 fine-tuned variants reduce W1 against the representative, 4 of them also against the other repetitions; P4 joint + rare +1.12; P4 staged + rare -2.21; P1 permutations -7.24.
#   largest single improvement: P1 permutations, W1 35.63 -> 20.06 (rare peak 103.6 m/z, present in 1.9 % of the training pixels).

# %% [markdown]
# ### Person
