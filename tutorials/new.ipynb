# %%
import m2aia as m2
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import m2aia as m2
#
# File /usr/local/lib/python3.12/site-packages/m2aia/__init__.py:55
#      52 validate_environment()
#      54 # dry-load M2aia binary libraries
# ---> 55 get_library()
#
# File /usr/local/lib/python3.12/site-packages/m2aia/Library.py:69, in get_library()
#      67 def get_library():
#      68     try:
# ---> 69         return load_m2aia_library()
#      70     except SystemExit:
#      71         pass
#
# File /usr/local/lib/python3.12/site-packages/m2aia/Library.py:56, in load_m2aia_library()
#      54 dependencies = []
#      55 for lib_name in target_library_path_parts:
# ---> 56     load_library_dependencies_recursively(search_path, lib_name, dependencies)
#      58 os.environ["M2AIA_LIBRARIES"] = ';'.join(dependencies)
#      59 for dep in dependencies:
#
# ...
