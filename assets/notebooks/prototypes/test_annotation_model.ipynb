# %%
import matplotlib.pyplot as plt
import numpy as np
import os 
from pathlib import Path

# seting global dir
cwd=Path.cwd()
if cwd.parent.name == "notebooks":
    # os.chdir(cwd.parent.parent) 
    os.chdir(cwd.parent.parent.parent) 
os.getcwd()
# Out:
# '/home/maxi7524/repositories/MSIAutoEncoderWrapper'

# %%
# Creating wrapper 

## imports 
from msi_autoencoder_wrapper import MSIAutoEncoderWrapper

## setting workspace
workspace_path = 'workspace'

wrapper = MSIAutoEncoderWrapper(
    project_path='workspace',
)
# Out:
# 2026-07-28 18:23:16,172 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.models.architectures.types.autoencoders.presets'.
# 2026-07-28 18:23:16,174 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 15 implementation module(s) in package 'msi_autoencoder_wrapper.models.architectures.types.autoencoders'.
# 2026-07-28 18:23:16,176 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 0 implementation module(s) in package 'msi_autoencoder_wrapper.models.architectures.types.schema'.
# 2026-07-28 18:23:16,178 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 21 implementation module(s) in package 'msi_autoencoder_wrapper.models.architectures'.
# 2026-07-28 18:23:16,188 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 8 implementation module(s) in package 'msi_autoencoder_wrapper.training.criterions.autoencoder'.
# 2026-07-28 18:23:16,190 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 12 implementation module(s) in package 'msi_autoencoder_wrapper.training.criterions'.
# 2026-07-28 18:23:16,278 | INFO     | msi_autoencoder_wrapper.core.wrapper:70 | MSIAutoEncoderWrapper: Anchoring processing device state: cuda
# 2026-07-28 18:23:16,279 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:48 | Enforcing automatic module discovery for reader and binner registries.
# 2026-07-28 18:23:20,060 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 2 implementation module(s) in package 'msi_autoencoder_wrapper.readers.strategies'.
# 2026-07-28 18:23:20,062 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.binners.binners_strategies'.
# 2026-07-28 18:23:20,063 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.binners.binners_strategies'.
# 2026-07-28 18:23:20,065 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.binners.inverse_strategies'.
# 2026-07-28 18:23:20,067 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.binners.inverse_strategies'.
# 2026-07-28 18:23:20,069 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 12 implementation module(s) in package 'msi_autoencoder_wrapper.training.criterions'.
# 2026-07-28 18:23:20,074 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.models.datasets.strategies'.
# 2026-07-28 18:23:20,075 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 1 implementation module(s) in package 'msi_autoencoder_wrapper.models.datasets.strategies'.
# 2026-07-28 18:23:20,077 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 21 implementation module(s) in package 'msi_autoencoder_wrapper.models.architectures'.
# 2026-07-28 18:23:20,078 | INFO     | msi_autoencoder_wrapper.core.wrapper:83 | MSIAutoEncoderWrapper facade successfully initialized and bound.

# %%
# Reader setup
wrapper.workspace.set_default_image_path('kidney-pilot-v2')
wrapper.context_manager.set_reader('PyImzMLReader') 
wrapper.context_manager.set_binner('LinearBinning', bin_step= 0.1)
wrapper.context_manager.set_inverse_binner('TopPeaksInverseBinner')
# Out:
# 2026-07-28 18:23:20,088 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.getters_and_setters_proxy:93 | Default fallback image anchored: kidney-pilot-v2
# 2026-07-28 18:23:20,090 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.getters_and_setters_proxy:53 | No image name provided. Falling back to default workspace image configuration.
# 2026-07-28 18:23:20,092 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:434 | Resolving system component 'reader' under image context 'kidney-pilot-v2'
# 2026-07-28 18:23:20,707 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:449 | Successfully registered component 'reader' into ledger for image 'kidney-pilot-v2'
# 2026-07-28 18:23:20,709 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.getters_and_setters_proxy:69 | Active image set via direct filesystem path: kidney-pilot-v2 (Location: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/datasets/kidney-pilot-v2)
# 2026-07-28 18:23:20,709 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:434 | Resolving system component 'annotation_reader' under image context 'kidney-pilot-v2'
# 2026-07-28 18:23:20,712 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:449 | Successfully registered component 'annotation_reader' into ledger for image 'kidney-pilot-v2'
# 2026-07-28 18:23:20,714 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.getters_and_setters_proxy:53 | No image name provided. Falling back to default workspace image configuration.
# 2026-07-28 18:23:20,715 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:434 | Resolving system component 'binner' under image context 'kidney-pilot-v2'
# 2026-07-28 18:23:20,716 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.active_context_mixin:111 | Successfully bound active context memory maps for: kidney-pilot-v2
# 2026-07-28 18:23:20,718 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:449 | Successfully registered component 'binner' into ledger for image 'kidney-pilot-v2'
# 2026-07-28 18:23:20,719 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.getters_and_setters_proxy:53 | No image name provided. Falling back to default workspace image configuration.
# 2026-07-28 18:23:20,720 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:434 | Resolving system component 'inverse_binner' under image context 'kidney-pilot-v2'
# 2026-07-28 18:23:20,721 | INFO     | msi_autoencoder_wrapper.core.mixins.context_manager.context_manager_mixin:449 | Successfully registered component 'inverse_binner' into ledger for image 'kidney-pilot-v2'

# %%
# obtain annotation information\
print('Metadata', wrapper.active_context.annotation_reader.get_dataset_metadata())
print('Spectra:', wrapper.active_context.reader.GetNumberOfSpectra())
print('Molecular annotations:', len(wrapper.active_context.annotation_reader.get_annotations()))
print('Annotated spectrum 449 length:', len(wrapper.active_context.annotation_reader.get_spectrum_annotations(449)))
print('Annotated spectrum 449:', wrapper.active_context.annotation_reader.get_spectrum_annotations(449))
# Out:
# 2026-07-28 18:23:20,748 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.active_context_mixin:70 | No active image set. Automatically resolving default workspace context: kidney-pilot-v2
# 2026-07-28 18:23:20,749 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.getters_and_setters_proxy:53 | No image name provided. Falling back to default workspace image configuration.
# 2026-07-28 18:23:20,750 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.active_context_mixin:111 | Successfully bound active context memory maps for: kidney-pilot-v2
# Metadata {'merged_dataset_id': 'kidney-pilot-v2', 'sources': [{'source': 'metaspace', 'dataset_id': '2026-07-27_08h49m39s', 'name': 'C57BL6_Kidney_02-pos', 'local_path': 'workspace/datasets/C57BL6_Kidney_02-pos', 'status': 'materialized', 'updated_at': '2026-07-28T09:47:27.479315+00:00', 'metadata': {'organ': 'kidney', 'organism': 'mouse'}}]}
# Spectra: 5959
# Molecular annotations: 22
# Annotated spectrum 449 length: 22
# Annotated spectrum 449: [{'adduct': 'M+Na', 'annotation_id': '0', 'chemMod': '', 'datasetId': '2026-07-27_08h49m39s', 'datasetName': 'C57BL6_Kidney_02-pos', 'fdr': 0.05, 'formula': 'C27H20O12', 'group': '', 'ion': 'C27H20O12+Na+', 'isobarIons': 'C24H24O13+K+, C22H20F3N3O9S+', 'isobaric_ions_count': '2', 'isomeric_ions_count': '0', 'isomeric_mols_count': '1', 'massError': '6.834860963934858', 'maxIntensity': '1400.379150390625', 'minIntensity': '0', 'moleculeIds': 'HMDB0034035', 'moleculeNames': 'Sagecoumarin', 'msm': '0.83674395', 'mz': 559.084696763, 'offSample': 'false', 'rawOffSampleProb': '0.00015931409143377095', 'rhoChaos': '0.998367770544391', 'rhoSpatial': '0.8894151943004499', 'rhoSpectral': '0.9423180196984413', 'totalIntensity': '2688485.25', 'spectrum_id': 449, 'intensity': 571.135009765625, 'source': 'metaspace', 'source_dataset_id': '2026-07-27_08h49m39s', 'source_spectrum_id': 449}, {'adduct': 'M+H', 'annotation_id': '10', 'chemMod': '', 'datasetId': '2026-07-27_08h49m39s', 'datasetName': 'C57BL6_Kidney_02-pos', 'fdr': 0.05, 'formula': 'C19H20O3', 'group': '', 'ion': 'C19H20O3+H+', 'isobarIons': '', 'isobaric_ions_count': '0', 'isomeric_ions_count': '0', 'isomeric_mols_count': '7', 'massError': '5.426459464601315', 'maxIntensity': '901', 'minIntensity': '0', 'moleculeIds': 'HMDB0038784, HMDB0030599, HMDB0033950, HMDB0035220, HMDB0039071, HMDB0138206, HMDB0141090', 'moleculeNames': '(E)-Arachidin II, 5-[(4-Hydroxypheny)ethenyl]-2-(3-methyl-1-butenyl)-1,3-benzenediol, Parakmerin A, Cryptotanshinone, exo-Dehydrochalepin, (4E)-1,7-bis(4-hydroxyphenyl)hept-4-en-3-one, 1-(4-hydroxyphenyl)-7-phenylheptane-3,5-dione', 'msm': '0.71065813', 'mz': 297.148520935, 'offSample': 'false', 'rawOffSampleProb': '0.00017550360644236207', 'rhoChaos': '0.9982922917256345', 'rhoSpatial': '0.7238195540836116', 'rhoSpectral': '0.9834962702754538', 'totalIntensity': '1725364', 'spectrum_id': 449, 'intensity': 229.6666717529297, 'source': 'metaspace', 'source_dataset_id': '2026-07-27_08h49m39s', 'source_spectrum_id': 449}, {'adduct': 'M[M]+', 'annotation_id': '11', 'chemMod': '', 'datasetId': '2026-07-27_08h49m39s', 'datasetName': 'C57BL6_Kidney_02-pos', 'fdr': 0.05, 'formula': 'C30H46O7', 'group': '', 'ion': 'C30H46O7+', 'isobarIons': 'C24H50NO7P+Na+, C26H48NO7P+H+', 'isobaric_ions_count': '2', 'isomeric_ions_count': '0', 'isomeric_mols_count': '4', 'massError': '5.659414025633079', 'maxIntensity': '1580', 'minIntensity': '0', 'moleculeIds': 'HMDB0034392, HMDB0035304, HMDB0035699, HMDB0039691', 'moleculeNames': 'Perulactone, Ganoderic acid C2, Corosin, Ganolucidic acid C', 'msm': '0.7084589', 'mz': 518.323805215, 'offSample': 'false', 'rawOffSampleProb': '0.000020184152162983082', 'rhoChaos': '0.9986413812623832', 'rhoSpatial': '0.7250033490140805', 'rhoSpectral': '0.9785095907654087', 'totalIntensity': '1803349', 'spectrum_id': 449, 'intensity': 254.03921508789062, 'source': 'metaspace', 'source_dataset_id': '2026-07-27_08h49m39s', 'source_spectrum_id': 449}, {'adduct': 'M+Na', 'annotation_id': '12', 'chemMod': '', 'datasetId': '2026-07-27_08h49m39s', 'datasetName': 'C57BL6_Kidney_02-pos', 'fdr': 0.05, 'formula': 'C46H86NO7P', 'group': '', 'ion': 'C46H86NO7P+Na+', 'isobarIons': 'C48H84NO7P+H+', 'isobaric_ions_count': '1', 'isomeric_ions_count': '0', 'isomeric_mols_count': '9', 'massError': '9.095517132901346', 'maxIntensity': '10067', 'minIntensity': '0', 'moleculeIds': 'HMDB0008359, HMDB0008360, HMDB0008391, HMDB0008423, HMDB0011251, HMDB0011252, HMDB0011283, HMDB0011316, HMDB0013420', 'moleculeNames': 'PC(20:2(11Z,14Z)/P-18:1(11Z)), PC(20:2(11Z,14Z)/P-18:1(9Z)), PC(20:3(5Z,8Z,11Z)/P-18:0), PC(20:3(8Z,11Z,14Z)/P-18:0), PC(P-18:0/20:3(5Z,8Z,11Z)), PC(P-18:0/20:3(8Z,11Z,14Z)), PC(P-18:1(11Z)/20:2(11Z,14Z)), PC(P-18:1(9Z)/20:2(11Z,14Z)), PC(o-18:0/20:4(8Z,11Z,14Z,17Z))', 'msm': '0.7018402', 'mz': 818.6034117749999, 'offSample': 'false', 'rawOffSampleProb': '0.000002447339511491009', 'rhoChaos': '0.9988206434569299', 'rhoSpatial': '0.74714 ...

# %%
# import helpers for creating annotation
from msi_autoencoder_wrapper.models.datasets.class_assignment import (
    build_class_mapping, molecule_key,
)

# create annotation
##  here we iterate through all filter we have so it contains 
molecule_mapping = build_class_mapping(
    molecule_key(item) for item in wrapper.active_context.annotation_reader.get_annotations()
)

## Here we iterate through names to obtain only names (for print purpose only)
molecule_labels = [None] * len(molecule_mapping)
for label, class_index in molecule_mapping.items():
    molecule_labels[class_index] = label

print('Molecular classes:', len(molecule_mapping))
molecule_mapping
# Out:
# Molecular classes: 22
# {'C14H19N3O5|M[M]+': 0,
#  'C15H32O6|M+Na': 1,
#  'C16H20O6|M+H': 2,
#  'C17H18F3NO|M[M]+': 3,
#  'C17H23NO2|M[M]+': 4,
#  'C18H18O3|M+H': 5,
#  'C19H20O3|M+H': 6,
#  'C20H18O14|M+H': 7,
#  'C23H37NO5S|M+NH4': 8,
#  'C24H50NO7P|M+Na': 9,
#  'C25H49NO4|M+H': 10,
#  'C26H42O4|M+K': 11,
#  'C26H48NO7P|M+H': 12,
#  'C27H20O12|M+Na': 13,
#  'C27H45NO4|M+H': 14,
#  'C30H46O7|M[M]+': 15,
#  'C41H74NO8P|M+H': 16,
#  'C42H76NO8P|M+H': 17,
#  'C43H78NO7P|M+H': 18,
#  'C45H74NO8P|M+H': 19,
#  'C46H86NO7P|M+Na': 20,
#  'C48H84NO7P|M+H': 21}

# %% [markdown]
# Model creation

# %%
latent_dim = 128
model_name = 'kidney-annotation-autoencoder'

wrapper.models_manager.set_model_type('autoencoder', model_name)
wrapper.models_manager.set_model_preset(
    'GradualReduction', latent_dim=latent_dim, projection_dim=64
)
wrapper.models_manager.set_head(
    head_id='molecule_primary',
    target_field='molecule',
    strategy='LinearClassificationHead',
    latent_dim=latent_dim,
    output_dim=len(molecule_mapping), # 22 classes for this example
    hidden_dim=64,
    dropout=0.1,
)
wrapper.models_manager.set_dataset(
    'PixelDataset',
    normalization='tic',
    target_specs={
        'molecule': {
            'type': 'multi_label',
            'class_mapping': molecule_mapping,
        },
    },
)
model = wrapper.models_manager.compile_model(run_validation_pass=True)
model
# Out:
# 2026-07-28 18:23:22,724 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:278 | Initiating model preset configuration layout lookup for family: autoencoder, preset: GradualReduction
# 2026-07-28 18:23:22,726 | INFO     | msi_autoencoder_wrapper.models.architectures.types.autoencoders.presets.gradual_reduction_preset:46 | Preset builder initiating hyperparameter execution pipeline analysis.
# 2026-07-28 18:23:26,339 | INFO     | msi_autoencoder_wrapper.models.architectures.utils.presets_utils:88 | Statistical reflection completed. Suggested baseline kernel width: 5 bins
# 2026-07-28 18:23:26,340 | INFO     | msi_autoencoder_wrapper.models.architectures.types.autoencoders.presets.gradual_reduction_preset:86 | Gradual Reduction layout synthesis finalized. Mapped feature width roadmaps: [11001, 3666, 915, 228, 76]
# 2026-07-28 18:23:26,340 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:314 | Preset parsing operational trace: Automatically routing component category 'encoder' using strategy 'CNNEncoder'.
# 2026-07-28 18:23:26,341 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:314 | Preset parsing operational trace: Automatically routing component category 'decoder' using strategy 'CNNDecoder'.
# 2026-07-28 18:23:26,341 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:314 | Preset parsing operational trace: Automatically routing component category 'projector' using strategy 'LinearProjector'.
# 2026-07-28 18:23:26,342 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:326 | Model preset layout 'GradualReduction' successfully staged into the configurations buffer. Graph compilation deferred for user modifications.
# 2026-07-28 18:23:26,343 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:350 | Initializing PyTorch network compilation sequences from buffered blueprints.
# 2026-07-28 18:23:26,344 | INFO     | msi_autoencoder_wrapper.models.architectures.architectures_manager:125 | Initializing multi-component sub-graph resolution phase for model family: autoencoder
# 2026-07-28 18:23:26,347 | INFO     | msi_autoencoder_wrapper.models.architectures.architectures_manager:144 | Instantiating standard component sub-module: Category='encoder' using Strategy='CNNEncoder'.
# 2026-07-28 18:23:26,353 | INFO     | msi_autoencoder_wrapper.models.architectures.architectures_manager:144 | Instantiating standard component sub-module: Category='decoder' using Strategy='CNNDecoder'.
# 2026-07-28 18:23:26,357 | INFO     | msi_autoencoder_wrapper.models.architectures.architectures_manager:144 | Instantiating standard component sub-module: Category='head' using Strategy='LinearClassificationHead'.
# 2026-07-28 18:23:26,359 | INFO     | msi_autoencoder_wrapper.models.architectures.architectures_manager:144 | Instantiating standard component sub-module: Category='projector' using Strategy='LinearProjector'.
# 2026-07-28 18:23:26,361 | INFO     | msi_autoencoder_wrapper.models.architectures.architectures_manager:183 | Injecting resolved computational components ledger dictionary into the master architecture graph.
# 2026-07-28 18:23:26,362 | INFO     | msi_autoencoder_wrapper.models.architectures.types.autoencoders.base_architecture_autoencoder:50 | MSIBaseAutoencoderArchitecture master network graph successfully assembled.
# 2026-07-28 18:23:26,364 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:397 | Compiling and binding dataset target: PixelDataset to the active model graph.
# 2026-07-28 18:23:26,364 | INFO     | msi_autoencoder_wrapper.models.datasets.dataset_manager:56 | Resolving and instantiating dataset strategy 'PixelDataset' from global registry.
# 2026-07-28 18:23:26,858 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.architecture_proxy:443 | MSI Network master graph successfully compiled and migrated onto execution hardware: cuda
# 2026-07-28 18:23:26,860 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 21 implementation module(s) in package 'msi_autoencoder_wrapper.models.architectures'.
# 2026-07-28 18:23:26,862 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.model_runtime_proxy:189 | Bound loaded model functionality to image context 'kidney-pilot-v2'.
# 2026-07-28 18:23:26,863 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.model_runtime_proxy:107 | Attached loaded model 'kidney-annotation-autoencoder' as family 'autoencoder'.
# MSIBaseAutoencoderArchitecture(
#   (encoder): CNNEncoder(
#     (conv_blocks): ModuleList(
#       (0): Sequential(
#         (0): Conv1d(1, 64, kernel_size=(5,), stride=(3,))
#         (1): LayerNorm((3666,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (1): Sequential(
#         (0): Conv1d(64, 32, kernel_size=(7,), stride=(4,))
#         (1): LayerNorm((915,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (2): Sequential(
#         (0): Conv1d(32, 16, kernel_size=(5,), stride=(4,))
#         (1): LayerNorm((228,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (3): Sequential(
#         (0): Conv1d(16, 8, kernel_size=(3,), stride=(3,))
#         (1): LayerNorm((76,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#     )
#     (bottleneck_layer): Sequential(
#       (0): Flatten(start_dim=1, end_dim=-1)
#       (1): Linear(in_features=608, out_features=128, bias=True)
#       (2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (decoder): CNNDecoder(
#     (initial_expansion): Sequential(
#       (0): Linear(in_features=128, out_features=608, bias=True)
#       (1): LayerNorm((608,), eps=1e-05, elementwise_affine=True)
#       (2): ReshapeLayer()
#     )
#     (deconv_blocks): ModuleList(
#       (0): Sequential(
#         (0): ConvTranspose1d(8, 16, kernel_size=(3,), stride=(3,))
#         (1): LayerNorm((228,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (1): Sequential(
#         (0): ConvTranspose1d(16, 32, kernel_size=(5,), stride=(4,), output_padding=(2,))
#         (1): LayerNorm((915,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (2): Sequential(
#         (0): ConvTranspose1d(32, 64, kernel_size=(7,), stride=(4,), output_padding=(3,))
#         (1): LayerNorm((3666,), eps=1e-05, elementwise_affine=True)
#         (2): ReLU()
#       )
#       (3): Sequential(
#         (0): ConvTranspose1d(64, 1, kernel_size=(5,), stride=(3,), output_padding=(1,))
#         (1): Identity()
#         (2): Identity()
#       )
#     )
#   )
#   (projector): LinearProjector(
#     (projection_network): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (2): ReLU()
#       (3): Linear(in_features=128, out_features=64, bias=True)
#     )
#   )
#   (heads): ModuleDict(
#     (molecule): LinearClassificationHead(
#       (network): Sequential(
#         (0): Linear(in_features=128, out_features=64, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=64, out_features=22, bias=True)
#       )
#     )
#   )
# )

# %%
# 

## import 
import torch 

## example run to see model dimensions
dataset = wrapper.active_dataset
spectrum_id, spectrum, targets, target_masks = dataset[449]
with torch.no_grad():
    outputs = model(spectrum.unsqueeze(0).to(wrapper.device))
print('Dataset size:', len(dataset))
print('Spectrum shape:', tuple(spectrum.shape))
print('Positive molecule targets:', int(targets['molecule'].sum().item()))
print('Latent shape:', tuple(outputs['latent_space'].shape))
print('Molecule logits shape:', tuple(outputs['head_molecule_primary'].shape))

## check how many pixel are without molecular label
#TODO - during merge tehre should be opotion for "how many unlabbelled molecules" - be default we should take only annoated pixel (write new imzML and ibd file so it would be clear), for background information we should include unannotataed data. it is imprtant as it is says which label are unresgisterd and how to encode "noise" to retrive similiar values.  
target_counts = torch.stack([dataset[index][2]['molecule'] for index in range(len(dataset))]).sum(0)
print('Pixels without a molecular label:', sum(dataset[index][2]['molecule'].sum() == 0 for index in range(len(dataset))))
print('Positive pixels per class:')
for label, count in zip(molecule_labels, target_counts.tolist()):
    print(f'{count:6.0f}  {label}')
# Out:
# Dataset size: 5959
# Spectrum shape: (11001,)
# Positive molecule targets: 22
# Latent shape: (1, 128)
# Molecule logits shape: (1, 22)
# Pixels without a molecular label: tensor(2426)
# Positive pixels per class:
#   3533  C14H19N3O5|M[M]+
#   3533  C15H32O6|M+Na
#   3533  C16H20O6|M+H
#   3533  C17H18F3NO|M[M]+
#   3533  C17H23NO2|M[M]+
#   3533  C18H18O3|M+H
#   3533  C19H20O3|M+H
#   3533  C20H18O14|M+H
#   3533  C23H37NO5S|M+NH4
#   3533  C24H50NO7P|M+Na
#   3533  C25H49NO4|M+H
#   3533  C26H42O4|M+K
#   3533  C26H48NO7P|M+H
#   3533  C27H20O12|M+Na
#   3532  C27H45NO4|M+H
#   3533  C30H46O7|M[M]+
#   3533  C41H74NO8P|M+H
#   3533  C42H76NO8P|M+H
#   3533  C43H78NO7P|M+H
#   3533  C45H74NO8P|M+H
#   3525  C46H86NO7P|M+Na
#   3525  C48H84NO7P|M+H

# %%
training_config = {
    'seed': 1912,
    'checkpoint': {'enabled': True, 'restore_best': True},
    'phases': [
        {
            'phase_name': 'reconstruction_and_molecule_classification',
            'epochs': 5,
            'batch_size': 16,
            'dataloader': {'num_workers': 0, 'pin_memory': wrapper.device == 'cuda'},
            'gradient_clip_norm': 1.0,
            'freeze': [],
            'optimizer': {
                'type': 'AdamW',
                'params': {'lr': 1e-3, 'weight_decay': 1e-4},
            },
            'criterions': {
                'reconstruction': {
                    # 'mse': {'target': 'MSELoss', 'weight': 1.0, 'params': {}}, # to na ten moment pomijamy 
                    'masserstein': {
                        'target': 'MassersteinLoss',
                        'weight': 1.0,
                        'params': {'sinkhorn_iterations': 30},
                    },
                },
                'heads': {
                    'molecule_primary': {
                        'molecule_bce': {
                            'target': 'MultiLabelBCELoss',
                            'weight': 0.25,
                            'params': {},
                        },
                    },
                },
            },
        },
    ],
}
training_config
# Out:
# {'seed': 1912,
#  'checkpoint': {'enabled': True, 'restore_best': True},
#  'phases': [{'phase_name': 'reconstruction_and_molecule_classification',
#    'epochs': 5,
#    'batch_size': 16,
#    'dataloader': {'num_workers': 0, 'pin_memory': False},
#    'gradient_clip_norm': 1.0,
#    'freeze': [],
#    'optimizer': {'type': 'AdamW',
#     'params': {'lr': 0.001, 'weight_decay': 0.0001}},
#    'criterions': {'reconstruction': {'masserstein': {'target': 'MassersteinLoss',
#       'weight': 1.0,
#       'params': {'sinkhorn_iterations': 30}}},
#     'head': {'molecule_bce': {'target': 'MultiLabelBCELoss',
#       'weight': 0.25,
#       'params': {'head_name': 'molecule', 'target_field': 'molecule'}}}}}]}

# %%
## apply train setup 
resource_report = wrapper.models_manager.estimate_training_resources(
    training_config,
    resource_limits={'ram': 0.65, 'vram': 0.80, 'disk': 1.00},
    auto_adjust_batch_size=True,
)
safe_training_config = resource_report['recommended_training_config']
resource_report
# Out:
# 2026-07-28 18:24:38,083 | INFO     | msi_autoencoder_wrapper.training.resource_estimator:148 | Training resource estimation completed for 1 phase(s).
# Training resource estimate
# - reconstruction_and_molecule_classification: batch 16 -> 16, RAM 859.45 KiB, VRAM 355.06 MiB, fits limits: True
# - disk: 1.20 MiB, fits limit: True
# {'method': 'probe_forward_plus_static_training_state',
#  'safety_factor': 1.25,
#  'available_bytes': {'ram': 9428873216,
#   'vram': 5407506432,
#   'disk': 750484480000},
#  'limit_bytes': {'ram': 6128767590, 'vram': 4326005145, 'disk': 750484480000},
#  'model_bytes': 989548,
#  'estimated_disk_bytes': 1261932,
#  'disk_fits_limit': True,
#  'phases': [{'phase': 'reconstruction_and_molecule_classification',
#    'configured_batch_size': 16,
#    'recommended_batch_size': 16,
#    'estimated_ram_bytes': 880080,
#    'estimated_vram_bytes': 372302800,
#    'fits_limits': True}],
#  'recommended_training_config': {'seed': 1912,
#   'checkpoint': {'enabled': True, 'restore_best': True},
#   'phases': [{'phase_name': 'reconstruction_and_molecule_classification',
#     'epochs': 5,
#     'batch_size': 16,
#     'dataloader': {'num_workers': 0, 'pin_memory': False},
#     'gradient_clip_norm': 1.0,
#     'freeze': [],
#     'optimizer': {'type': 'AdamW',
#      'params': {'lr': 0.001, 'weight_decay': 0.0001}},
#     'criterions': {'reconstruction': {'masserstein': {'target': 'MassersteinLoss',
#        'weight': 1.0,
#        'params': {'sinkhorn_iterations': 30}}},
#      'head': {'molecule_bce': {'target': 'MultiLabelBCELoss',
#        'weight': 0.25,
#        'params': {'head_name': 'molecule', 'target_field': 'molecule'}}}}}]},
#  'limitations': ['Reader-native caches and operating-system activity are not measured.',
#   'CUDA allocator fragmentation can increase actual peak VRAM.',
#   'The estimate is not a substitute for monitoring the first training epoch.']}

# %%
history = wrapper.models_manager.fit(safe_training_config)
# Out:
# 2026-07-28 18:25:31,028 | INFO     | msi_autoencoder_wrapper.core.mixins.models_manager.proxies.training_proxy:133 | Instantiating execution training manager instance.
# 2026-07-28 18:25:31,029 | INFO     | msi_autoencoder_wrapper.training.training_manager:78 | Training lifecycle orchestration triggered. Dispatching execution parameters for model family: autoencoder
# 2026-07-28 18:25:31,031 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:513 | Pre-flight validation successful. Training environment maps verified.
# 2026-07-28 18:25:31,032 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:63 | Enforcing global deterministic execution pipeline using seed token: 1912
# 2026-07-28 18:25:31,042 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:92 | Initiating sequential training loop phase: reconstruction_and_molecule_classification (1/1)
# 2026-07-28 18:25:31,043 | INFO     | msi_autoencoder_wrapper.training.criterions.criterions_manager:253 | Assembling 'reconstruction' objective 'masserstein' with weight 1.0.
# 2026-07-28 18:25:31,045 | INFO     | msi_autoencoder_wrapper.training.criterions.criterions_manager:253 | Assembling 'head' objective 'molecule_bce' with weight 0.25.
# 2026-07-28 18:25:38,718 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:252 | [reconstruction_and_molecule_classification] Epoch 1/5 | Batch
ved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-autoencoder/config/history.json
# 2026-07-28 18:38:07,408 | INFO     | msi_autoencoder_wrapper.core.mixins.workspace.proxies.io_models_proxy:194 | Active model 'kidney-annotation-autoencoder' saved under context 'kidney-pilot-v2'.
# 2026-07-28 18:38:07,409 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:302 | Saved new best checkpoint for phase 'reconstruction_and_molecule_classification' at epoch 5.
# 2026-07-28 18:38:07,410 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:308 | === Epoch Summary [reconstruction_and_molecule_classification] 005/005 | Avg Loss: 0.3502 | Patience: 0/10 | Duration: 169.65 s ===
# 2026-07-28 18:38:07,426 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:329 | Restored the best checkpoint after phase 'reconstruction_and_molecule_classification'.
# 2026-07-28 18:38:07,427 | INFO     | msi_autoencoder_wrapper.training.engine.base_trainer:334 | All configured sequential multi-phase training loops successfully completed.

# %% [markdown]
# Saving results

# %%
latent_path = wrapper.active_context.save_latent(
    loader_config={'batch_size': 64, 'num_workers': 0, 'pin_memory': wrapper.device == 'cuda'},
    activate=False,
)
print('Latent dataset:', latent_path)
# Out:
# 2026-07-28 18:38:26,889 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.autoencoder_context_manager:165 | Initiating sequential image feature mapping over active data stream channels.
# 2026-07-28 18:38:45,395 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.autoencoder_context_manager:171 | Sequential structural image data translation complete.
# 2026-07-28 18:38:46,127 | INFO     | msi_autoencoder_wrapper.latent.imzml_store:94 | Latent imzML/ibd pair saved at: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-autoencoder/latent/kidney-pilot-v2.latent.imzML
# Latent dataset: /home/maxi7524/repositories/MSIAutoEncoderWrapper/workspace/models/kidney-pilot-v2/kidney-annotation-autoencoder/latent/kidney-pilot-v2.latent.imzML

# %%
latents = wrapper.models_manager.autoencoder.transform(
    {'batch_size': 64, 'num_workers': 0, 'pin_memory': wrapper.device == 'cuda'}
)
with torch.no_grad():
    logits = model.heads['molecule_primary'](torch.from_numpy(latents).float().to(wrapper.device))
    probabilities = torch.sigmoid(logits).cpu().numpy()
print('Latents:', latents.shape)
print('Molecule probabilities:', probabilities.shape)
print('Finite:', np.isfinite(latents).all() and np.isfinite(probabilities).all())
# Out:
# 2026-07-28 18:38:46,169 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.autoencoder_context_manager:165 | Initiating sequential image feature mapping over active data stream channels.
# 2026-07-28 18:39:02,194 | INFO     | msi_autoencoder_wrapper.core.mixins.active_context.autoencoder_context_manager:171 | Sequential structural image data translation complete.
# Latents: (5959, 128)
# Molecule probabilities: (5959, 22)
# Finite: True

# %% [markdown]
# Calculating predictions

# %%
spectrum_id = 449
top_indices = np.argsort(probabilities[spectrum_id])[::-1][:5]
predictions = [
    {
        'molecule': molecule_labels[index],
        'probability': float(probabilities[spectrum_id, index]),
        'target': int(dataset[spectrum_id][2]['molecule'][index].item()),
    }
    for index in top_indices
]
predictions
# Out:
# [{'molecule': 'C42H76NO8P|M+H',
#   'probability': 0.9999954700469971,
#   'target': 1},
#  {'molecule': 'C41H74NO8P|M+H',
#   'probability': 0.9999918937683105,
#   'target': 1},
#  {'molecule': 'C18H18O3|M+H', 'probability': 0.9999912977218628, 'target': 1},
#  {'molecule': 'C17H23NO2|M[M]+',
#   'probability': 0.9999909400939941,
#   'target': 1},
#  {'molecule': 'C24H50NO7P|M+Na',
#   'probability': 0.9999904632568359,
#   'target': 1}]

# %% [markdown]
# Analysis
