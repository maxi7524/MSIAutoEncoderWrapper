# %% [markdown]
# # KIdney dataset
#
# Here we are creating dataset for kidney dataset

# %%
import os
from pathlib import Path

current_path = Path.cwd().resolve()
repository_root = next(
    path
    for path in (current_path, *current_path.parents)
    if (path / "pyproject.toml").is_file()
)
os.chdir(repository_root)

repository_root
# Out:
# PosixPath('/home/max/repositories/MSIAutoEncoderWrapper')

# %%
# load dataset
from IPython.display import display

from msi_autoencoder_wrapper.dataset_management.exploration import DatasetExplorer

# REMARK: date i download DB is  12.08.2026 (DD, MM, YYYY) 
explorer = DatasetExplorer(
    source="metaspace",
    # Save the METASPACE dataset catalogue in this directory.
    cache_dir="assets/local/datasets/metaspace",
    # Set to True to request the catalogue again and replace the local file.
    refresh_cache=False,
)

# The same interface can be initialized for PRIDE:
# pride_explorer = DatasetExplorer(source="pride")
# Out:
# 2026-08-12 13:15:37,427 | INFO     | msi_autoencoder_wrapper.utils.module_search:79 | Discovered 5 implementation module(s) in package 'msi_autoencoder_wrapper.dataset_management.sources.strategies'.
# 2026-08-12 13:15:38,787 | INFO     | msi_autoencoder_wrapper.dataset_management.sources.strategies.metaspace:291 | Loaded 19783 METASPACE catalogue records from assets/local/datasets/metaspace/available-datasets.json

# %% [markdown]
# # About kidney
#
# I choosed kidney as it is most countable dataset

# %%
# Replace the key with another enumerable entry from `available_filters`.
organism_values = explorer.get_available_values("organism_part")
display(organism_values.head(30))

# Typical additional inspections:
# display(explorer.get_available_values("organism_part").head(30))
# display(explorer.get_available_values("polarity"))
# display(explorer.get_available_values("analyzer_type").head(30))
# display(explorer.get_available_values("ionisation_source").head(30))
# display(explorer.get_|available_values("maldi_matrix").head(30))
# Out:
#                value             label  count  \
# 0             Kidney            Kidney   4436
# 1              Brain             Brain   2143
# 2          Cell Line         Cell Line    971
# 3              Liver             Liver    945
# 4               Root              Root    870
# 5               Lung              Lung    809
# 6     Whole organism    Whole organism    809
# 7               leaf              leaf    784
# 8             Breast            Breast    514
# 9                N/A               N/A    425
# 10     Kidney Cortex     Kidney Cortex    387
# 11              Skin              Skin    364
# 12             Ovary             Ovary    297
# 13        Lymph node        Lymph node    267
# 14              Stem              Stem    253
# 15             Colon             Colon    237
# 16              Seed              Seed    220
# 17             Cells             Cells    213
# 18              None              None    194
# 19             Heart             Heart    175
# 20              Gill              Gill    149
# 21       rhizosphere       rhizosphere    142
# 22       Wood_fungal       Wood_fungal    127
# 23         standards         standards    124
# 24  Microbial colony  Microbial colony    121
# 25        Epididymis        Epididymis    115
# 26              Spot              Spot    115
# 27       Fibroblasts       Fibroblasts    103
# 28     Root exudates     Root exudates     84
# 29          Pancreas          Pancreas     79
#
#                                              variants
# 0   Kidney (4078), kidney (342), Kidney  (14), kid...
# 1                            Brain (2108), brain (35)
# 2                                     Cell Line (971)
# 3                  Liver (887), liver (51), LIVER (7)
# 4                              Root (457), root (413)
# 5                              Lung (700), lung (109)
# 6           Whole organism (774), whole organism (35)
# 7                              leaf (622), Leaf (162)
# 8                                        Breast (514)
# 9                                  N/A (423), n/a (2)
# 10             Kidney Cortex (386), Kidney cortex (1)
# 11                    Skin (332), SKin (24), skin (8)
# 12                             Ovary (290), ovary (7)
# 13                                   Lymph node (267)
# 14                              Stem (241), stem (12)
# 15                            Colon (181), colon (56)
# 16                              Seed (121), seed (99)
# 17                             Cells (212), cells (1)
# 18                              None (181), none (13)
# 19                Heart (159), heart (13), Heart  (3)
# 20                              Gill (121), gill (28)
# 21                                  rhizosphere (142)
# 22                                  Wood_fungal (127)
# 23                                    standards (124)
# 24                             Microbial colony (121)
# 25                                   Epididymis (115)
# 26                                         Spot (115)
# 27                                  Fibroblasts (103)
# 28             Root exudates (74), Root Exudates (10)
# 29                        Pancreas (78), pancreas (1)

# %%
broad_filters = {
    # Biological metadata
    "organism": "Mouse",
    "organism_part": "kidney",
    "condition": "Wildtype",

    # Acquisition metadata
    "polarity": "Negative",
    # "ionisation_source": "MALDI", - we can normalize this later 

    # Annotation filters
    # "status": "FINISHED",
    "annotation_fdr": 0.1,
    # "has_optical_image": True,
    "min_annotation_count": 1,

}

results = explorer.filter(broad_filters)

display(results)
print(f"Found {len(results)} datasets")
# Out:
# 2026-08-12 13:15:42,068 | INFO     | msi_autoencoder_wrapper.dataset_management.sources.strategies.metaspace:550 | METASPACE cache reduced discovery to 61 candidate datasets
# METASPACE discovery:   0%|          | 0/3 [00:00<?, ?stage/s]
# Current operation:   0%|          | 0/1 [00:00<?, ?operation/s]
# 2026-08-12 13:15:43,151 | INFO     | msi_autoencoder_wrapper.dataset_management.sources.strategies.metaspace:267 | METASPACE discovery accepted 60 datasets and rejected 8708 datasets
# 2026-08-12 13:15:43,153 | INFO     | msi_autoencoder_wrapper.dataset_management.exploration.dataset_explorer:123 | Explorer retained 60 records from source metaspace
#               dataset_id                                               name  \
# 0   2026-04-22_21h03m00s   kidney_test_metabolites_null_mz_shift_10_til_550
# 1   2025-04-14_15h53m53s      00070_lgruber_qcl-msi_data11_glomeruli_wt_rms
# 2   2025-04-14_09h06m15s    00070_lgruber_qcl-msi_het-0717_data3_slide1-rms
# 3   2025-04-14_09h00m43s    00070_lgruber_qcl-msi_het-0707_data5_slide1-rms
# 4   2025-04-14_15h55m50s  00070_lgruber_qcl-msi_timson_glomeruli_data2_w...
# 5   2025-04-14_09h56m19s     00070_lgruber_qcl-msi_wt-4625_data6_slide1-rms
# 6   2025-04-14_10h18m43s     00070_lgruber_qcl-msi_wt-4628_data1_slide1-rms
# 7   2025-07-07_13h56m06s                                    mo6_metabolites
# 8   2025-07-07_13h03m27s  msi2024013_20240909_multiomicsiii_nor_300-1350...
# 9   2025-07-07_10h55m54s  msi2024013_20240909_multiomicsii_nedc 50-650_f...
# 10  2025-07-06_22h07m04s       msi2024013_20240909_multiomicsii_nor 50-1350
# 11  2025-07-06_19h01m02s     msi2024013_20240909_multiomicsii_nedc 300-1350
# 12  2025-07-06_16h31m32s      msi2024013_20240909_multiomicsii_nedc 50-1350
# 13  2025-07-06_15h14m05s       msi2024013_20240909_multiomicsii_nedc 50-650
# 14  2025-06-26_11h11m17s                       kidney_nedc_1-3mg_recryst_m2
# 15  2025-06-26_10h27m59s                       kidney_nedc_1-3mg_recryst_m1
# 16  2025-06-26_10h05m06s                       kidney_nedc_0-5mg_recryst_m2
# 17  2025-06-26_09h26m30s                       kidney_nedc_0-5mg_recryst_m1
# 18  2025-06-25_16h01m21s                         Kidney_NEDC_M2_Thresholded
# 19  2025-06-24_15h36m14s                          Kidney_NEDC_1-3mg_MALDI-2
# 20  2025-06-24_17h32m20s                      2025-06-24_kidney_neg_thin_m2
# 21  2025-06-24_17h05m47s                          Kidney_NEDC_0-5mg_MALDI-2
# 22  2025-06-24_16h31m14s                                  Kidney_NEDC_0-5mg
# 23  2025-06-24_16h02m08s                         2025-06-24_kidney_neg_thin
# 24  2025-06-24_14h51m14s                                  Kidney_NEDC_1-3mg
# 25  2024-06-12_15h33m53s                 NEDC_imaging_kidney_K10_replicate3
# 26  2024-06-12_15h32m57s                  NEDC_imaging_kidney_K8_replicate2
# 27  2024-06-12_15h27m25s                  NEDC_imaging_kidney_K6_replicate1
# 28  2024-05-23_14h25m01s                                K3 vs K6 neg -Jano
# 29  2024-04-10_17h06m19s                                            8223301
# 30  2024-02-20_01h55m56s                                         d28-2014-2
# 31  2024-02-20_01h57m32s                                         d28-2017-2
# 32  2024-02-20_01h54m01s                                           d14-2295
# 33  2024-02-20_01h54m41s                                         d28-2006-2
# 34  2024-02-20_01h53m31s                                           d14-2015
# 35  2024-02-20_01h49m35s                                         d14-2001-2
# 36  2024-02-20_01h48m46s                                          d7-2024-2
# 37  2024-02-20_01h46m58s                                          d7-2020-2
# 38  2024-02-20_01h46m10s                                          d7-2004-2
# 39  2024-02-20_01h45m20s                                          d3-2023-2
# 40  2024-02-20_01h44m07s                                          d3-2012-2
# 41  2024-02-20_01h43m24s                                          d3-2010-2
# 42  2024-02-20_01h42m42s                                            d3-1807
# 43  2024-02-20_01h41m56s                                          d2-2053-2
# 44  2024-02-20_01h40m11s                                          d2-2042-2
# 45  2024-02-20_01h38m59s                                          d2-2018-2
# 46  2024-02-19_05h43m55s                                          d1-2016-2
# 47  2024-02-19_05h42m55s                                          d1-2005-2
# 48  2024-02-19_05h36m42s                                            d1-1829
# 49  2024-02-19_05h21m14s                                            d1-1817
# 50  2024-02-19_05h12m47s                                          con2060-2
# 51  2024-02-19_05h02m33s                                      c2_mus_kidney
# 52  2024-02-19_04h23m32s                                         control_c1
# 53  2022-12-01_15h43m13s  Kidney NEDC_Att35_25-2DFP- TU Dortmund - 20221024
# 54  2022-03-02_09h36m24s              IR_plasma_fresh_kidney_neg_mz300-1000
# 55  2022-03-02_09h12m28s               IR_plasma_FFPE_kidney_neg_mz300-1000
# 56  2022-02-28_12h36m26s                 IR_plasma_FFPE_kidney_neg_mz80-305
# 57  2022-02-28_11h15m58s                IR_plasma_fresh_kidney_neg_mz80-305
# 58  2019-03-19_17h21m15s                            kidney_test_metabolites
# 59  2017-04-20_09h06m22s                             May4_kidney_serial_S25
#
#        source project_accession  \
# 0   metaspace              None
# 1   metaspace              None
# 2   metaspace              None
# 3   metaspace              None
# 4   metaspace              None
# 5   metaspace              None
# 6   metaspace              None
# 7   metaspace              None
# 8   metaspace              None
# 9   metaspace              None
# 10  metaspace              None
# 11  metaspace              None
# 12  metaspace              None
# 13  metaspace              None
# 14  metaspace              None
# 15  metaspace              None
# 16  metaspace              None
# 17  metaspace              None
# 18  metaspace              None
# 19  metaspace              None
# 20  metaspace              None
# 21  metaspace              None
# 22  metaspace              None
# 23  metaspace              None
# 24  metaspace              None
# 25  metaspace              None
# 26  metaspace              None
# 27  metaspace              None
# 28  metaspace              None
# 29  metaspace              None
# 30  metaspace              None
# 31  metaspace              None
# 32  metaspace              None
# 33  metaspace              None
# 34  metaspace              None
# 35  metaspace              None
# 36  metaspace              None
# 37  metaspace              None
# 38  metaspace              None
# 39  metaspace              None
# 40  metaspace              None
# 41  metaspace              None
# 42  metaspace              None
# 43  metaspace              None
# 44  metaspace              None
# 45  metaspace              None
# 46  metaspace              None
# 47  metaspace              None
# 48  metaspace              None
# 49  metaspace              None
# 50  metaspace              None
# 51  metaspace              None
# 52  metaspace              None
# 53  metaspace              None
# 54  metaspace              None
# 55  metaspace              None
# 56  metaspace              None
# 57  metaspace              None
# 58  metaspace              None
# 59  metaspace              None
#
#                                           project_url             organisms  \
# 0   https://metaspace2020.eu/dataset/2026-04-22_21...  Mus musculus (mouse)
# 1   https://metaspace2020.eu/dataset/2025-04-14_15...  Mus musculus (mouse)
# 2   https://metaspace2020.eu/dataset/2025-04-14_09...  Mus musculus (mouse)
# 3   https://metaspace2020.eu/dataset/2025-04-14_09...  Mus musculus (mouse)
# 4   https://metaspace2020.eu/dataset/2025-04-14_15...  Mus musculus (mouse)
# 5   https://metaspace2020.eu/dataset/2025-04-14_09...  Mus musculus (mouse)
# 6   https://metaspace2020.eu/dataset/2025-04-14_10...  Mus musculus (mouse)
# 7   https://metaspace2020.eu/dataset/2025-07-07_13...  Mus musculus (mouse)
# 8   https://metaspace2020.eu/dataset/2025-07-07_13...  Mus musculus (mouse)
# 9   https://metaspace2020.eu/dataset/2025-07-07_10...  Mus musculus (mouse)
# 10  https://metaspace2020.eu/dataset/2025-07-06_22...  Mus musculus (mouse)
# 11  https://metaspace2020.eu/dataset/2025-07-06_19...  Mus musculus (mouse)
# 12  https://metaspace2020.eu/dataset/2025-07-06_16...  Mus musculus (mouse)
# 13  https://metaspace2020.eu/dataset/2025-07-06_15...  Mus musculus (mouse)
# 14  https://metaspace2020.eu/dataset/2025-06-26_11...                 Mouse
# 15  https://metaspace2020.eu/dataset/2025-06-26_10...                 Mouse
# 16  https://metaspace2020.eu/dataset/2025-06-26_10...                 Mouse
# 17  https://metaspace2020.eu/dataset/2025-06-26_09...                 Mouse
# 18  https://metaspace2020.eu/dataset/2025-06-25_16...                 Mouse
# 19  https://metaspace2020.eu/dataset/2025-06-24_15...                 Mouse
# 20  https://metaspace2020.eu/dataset/2025-06-24_17...                 Mouse
# 21  https://metaspace2020.eu/dataset/2025-06-24_17...                 Mouse
# 22  https://metaspace2020.eu/dataset/2025-06-24_16...                 Mouse
# 23  https://metaspace2020.eu/dataset/2025-06-24_16...                 Mouse
# 24  https://metaspace2020.eu/dataset/2025-06-24_14...                 Mouse
# 25  https://metaspace2020.eu/dataset/2024-06-12_15...                 mouse
# 26  https://metaspace2020.eu/dataset/2024-06-12_15...                 mouse
# 27  https://metaspace2020.eu/dataset/2024-06-12_15...                 mouse
# 28  https://metaspace2020.eu/dataset/2024-05-23_14...                 Mouse
# 29  https://metaspace2020.eu/dataset/2024-04-10_17...  Mus musculus (mouse)
# 30  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 31  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 32  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 33  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 34  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 35  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 36  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 37  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 38  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 39  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 40  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 41  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 42  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 43  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 44  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 45  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 46  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 47  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 48  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 49  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 50  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 51  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 52  https://metaspace2020.eu/dataset/2024-02-19_04...  Mus musculus (mouse)
# 53  https://metaspace2020.eu/dataset/2022-12-01_15...  Mus musculus (mouse)
# 54  https://metaspace2020.eu/dataset/2022-03-02_09...  Mus musculus (mouse)
# 55  https://metaspace2020.eu/dataset/2022-03-02_09...  Mus musculus (mouse)
# 56  https://metaspace2020.eu/dataset/2022-02-28_12...  Mus musculus (mouse)
# 57  https://metaspace2020.eu/dataset/2022-02-28_11...  Mus musculus (mouse)
# 58  https://metaspace2020.eu/dataset/2019-03-19_17...  Mus musculus (mouse)
# 59  https://metaspace2020.eu/dataset/2017-04-20_09...  Mus musculus (mouse)
#
#    organism_parts  condition growth_conditions diseases  ...  \
# 0          Kidney   Wildtype             Caged           ...
# 1          Kidney   Wildtype                             ...
# 2          Kidney  Wild type                             ...
# 3          Kidney  Wild type                             ...
# 4          Kidney   Wildtype                             ...
# 5          Kidney   Wildtype                             ...
# 6          Kidney   Wildtype                             ...
# 7          Kidney   Wildtype                             ...
# 8          Kidney   Wildtype                             ...
# 9          Kidney   Wildtype                             ...
# 10         Kidney   Wildtype                             ...
# 11         Kidney   Wildtype                             ...
# 12         Kidney   Wildtype                             ...
# 13         Kidney   Wildtype                             ...
# 14         Kidney   Wildtype                             ...
# 15         Kidney   Wildtype                             ...
# 16         Kidney   Wildtype                             ...
# 17         Kidney   Wildtype                             ...
# 18         Kidney   Wildtype                             ...
# 19         Kidney   Wildtype                             ...
# 20         Kidney   Wildtype                             ...
# 21         Kidney   Wildtype                             ...
# 22         Kidney   Wildtype                             ...
# 23         Kidney   Wildtype                             ...
# 24         Kidney   Wildtype                             ...
# 25         Kidney  Wild type                             ...
# 26         kidney  Wild type                             ...
# 27         Kidney  Wild type                             ...
# 28         Kidney   Wildtype                             ...
# 29         Kidney   Wildtype                             ...
# 30         Kidney   Wildtype               N/A           ...
# 31         Kidney   Wildtype               N/A           ...
# 32         Kidney   Wildtype               N/A           ...
# 33         Kidney   Wildtype               N/A           ...
# 34         Kidney   Wildtype               N/A           ...
# 35         Kidney   Wildtype               N/A           ...
# 36         Kidney   Wildtype               N/A           ...
# 37         Kidney   Wildtype               N/A           ...
# 38         Kidney   Wildtype               N/A           ...
# 39         Kidney   Wildtype               N/A           ...
# 40         Kidney   Wildtype               N/A           ...
# 41         Kidney   Wildtype               N/A           ...
# 42         Kidney   Wildtype               N/A           ...
# 43         Kidney   Wildtype               N/A           ...
# 44         Kidney   Wildtype               N/A           ...
# 45         Kidney   Wildtype               N/A           ...
# 46         Kidney   Wildtype               N/A           ...
# 47         Kidney   Wildtype               N/A           ...
# 48         Kidney   Wildtype               N/A           ...
# 49         Kidney   Wildtype               N/A           ...
# 50         Kidney   Wildtype               N/A           ...
# 51         Kidney   Wildtype               N/A           ...
# 52         Kidney   Wildtype               N/A           ...
# 53         Kidney   Wildtype                             ...
# 54         Kidney   Wildtype             Caged           ...
# 55         Kidney   Wildtype             Caged           ...
# 56         Kidney   Wildtype             Caged           ...
# 57         Kidney   Wildtype             Caged           ...
# 58         Kidney   Wildtype             Caged           ...
# 59         Kidney   Wildtype               N/A           ...
#
#    unannotated_pixel_count annotated_pixel_fraction annotation_fdr  \
# 0                     None                     None            0.1
# 1                     None                     None            0.1
# 2                     None                     None            0.1
# 3                     None                     None            0.1
# 4                     None                     None            0.1
# 5                     None                     None            0.1
# 6                     None                     None            0.1
# 7                     None                     None            0.1
# 8                     None                     None            0.1
# 9                     None                     None            0.1
# 10                    None                     None            0.1
# 11                    None                     None            0.1
# 12                    None                     None            0.1
# 13                    None                     None            0.1
# 14                    None                     None            0.1
# 15                    None                     None            0.1
# 16                    None                     None            0.1
# 17                    None                     None            0.1
# 18                    None                     None            0.1
# 19                    None                     None            0.1
# 20                    None                     None            0.1
# 21                    None                     None            0.1
# 22                    None                     None            0.1
# 23                    None                     None            0.1
# 24                    None                     None            0.1
# 25                    None                     None            0.1
# 26                    None                     None            0.1
# 27                    None                     None            0.1
# 28                    None                     None            0.1
# 29                    None                     None            0.1
# 30                    None                     None            0.1
# 31                    None                     None            0.1
# 32                    None                     None            0.1
# 33                    None                     None            0.1
# 34                    None                     None            0.1
# 35                    None                     None            0.1
# 36                    None                     None            0.1
# 37                    None                     None            0.1
# 38                    None                     None            0.1
# 39                    None                     None            0.1
# 40                    None                     None            0.1
# 41                    None                     None            0.1
# 42                    None                     None            0.1
# 43                    None                     None            0.1
# 44                    None                     None            0.1
# 45                    None                     None            0.1
# 46                    None                     None            0.1
# 47                    None                     None            0.1
# 48                    None                     None            0.1
# 49                    None                     None            0.1
# 50                    None                     None            0.1
# 51                    None                     None            0.1
# 52                    None                     None            0.1
# 53                    None                     None            0.1
# 54                    None                     None            0.1
# 55                    None                     None            0.1
# 56                    None                     None            0.1
# 57                    None                     None            0.1
# 58                    None                     None            0.1
# 59                    None                     None            0.1
#
#     spatial_annotation_count spatial_annotation_database_count  \
# 0                       None                              None
# 1                       None                              None
# 2                       None                              None
# 3                       None                              None
# 4                       None                              None
# 5                       None                              None
# 6                       None                              None
# 7                       None                              None
# 8                       None                              None
# 9                       None                              None
# 10                      None                              None
# 11                      None                              None
# 12                      None                              None
# 13                      None                              None
# 14                      None                              None
# 15                      None                              None
# 16                      None                              None
# 17                      None                              None
# 18                      None                              None
# 19                      None                              None
# 20                      None                              None
# 21                      None                              None
# 22                      None                              None
# 23                      None                              None
# 24                      None                              None
# 25                      None                              None
# 26                      None                              None
# 27                      None                              None
# 28                      None                              None
# 29                      None                              None
# 30                      None                              None
# 31                      None                              None
# 32                      None                              None
# 33                      None                              None
# 34                      None                              None
# 35                      None                              None
# 36                      None                              None
# 37                      None                              None
# 38                      None                              None
# 39                      None                              None
# 40                      None                              None
# 41                      None                              None
# 42                      None                              None
# 43                      None                              None
# 44                      None                              None
# 45                      None                              None
# 46                      None                              None
# 47                      None                              None
# 48                      None                              None
# 49                      None                              None
# 50                      None                              None
# 51                      None                              None
# 52                      None                              None
# 53                      None                              None
# 54                      None                              None
# 55                      None                              None
# 56                      None                              None
# 57                      None                              None
# 58                      None                              None
# 59                      None                              None
#
#    spatial_stats_status molecule_count  unique_molecule_count  \
# 0                  None           None                   None
# 1                  None           None                   None
# 2                  None           None                   None
# 3                  None           None                   None
# 4                  None           None                   None
# 5                  None           None                   None
# 6                  None           None                   None
# 7                  None           None                   None
# 8                  None           None                   None
# 9                  None           None                   None
# 10                 None           None                   None
# 11                 None           None                   None
# 12                 None           None                   None
# 13                 None           None                   None
# 14                 None           None                   None
# 15                 None           None                   None
# 16                 None           None                   None
# 17                 None           None                   None
# 18                 None           None                   None
# 19                 None           None                   None
# 20                 None           None                   None
# 21                 None           None                   None
# 22                 None           None                   None
# 23                 None           None                   None
# 24                 None           None                   None
# 25                 None           None                   None
# 26                 None           None                   None
# 27                 None           None                   None
# 28                 None           None                   None
# 29                 None           None                   None
# 30                 None           None                   None
# 31                 None           None                   None
# 32                 None           None                   None
# 33                 None           None                   None
# 34                 None           None                   None
# 35                 None           None                   None
# 36                 None           None                   None
# 37                 None           None                   None
# 38                 None           None                   None
# 39                 None           None                   None
# 40                 None           None                   None
# 41                 None           None                   None
# 42                 None           None                   None
# 43                 None           None                   None
# 44                 None           None                   None
# 45                 None           None                   None
# 46                 None           None                   None
# 47                 None           None                   None
# 48                 None           None                   None
# 49                 None           None                   None
# 50                 None           None                   None
# 51                 None           None                   None
# 52                 None           None                   None
# 53                 None           None                   None
# 54                 None           None                   None
# 55                 None           None                   None
# 56                 None           None                   None
# 57                 None           None                   None
# 58                 None           None                   None
# 59                 None           None                   None
#
#     unique_molecules excluded
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# 5                       False
# 6                       False
# 7                       False
# 8                       False
# 9                       False
# 10                      False
# 11                      False
# 12                      False
# 13                      False
# 14                      False
# 15                      False
# 16                      False
# 17                      False
# 18                      False
# 19                      False
# 20                      False
# 21                      False
# 22                      False
# 23                      False
# 24                      False
# 25                      False
# 26                      False
# 27                      False
# 28                      False
# 29                      False
# 30                      False
# 31                      False
# 32                      False
# 33                      False
# 34                      False
# 35                      False
# 36                      False
# 37                      False
# 38                      False
# 39                      False
# 40                      False
# 41                      False
# 42                      False
# 43                      False
# 44                      False
# 45                      False
# 46                      False
# 47                      False
# 48                      False
# 49                      False
# 50                      False
# 51                      False
# 52                      False
# 53                      False
# 54                      False
# 55                      False
# 56                      False
# 57                      False
# 58                      False
# 59                      False
#
# [60 rows x 45 columns]
# Found 60 datasets

# %% [markdown]
# Here we can see that proposals that have sense are between

# %%
coverage = explorer.count_mz_range_coverage(
    lower_bounds=[100 * i for i in range(1, 5)],
    upper_bounds=[100 * i for i in range(7, 15)],
)

range_counts_matrix = coverage.pivot(
    index="lower_bound",
    columns="upper_bound",
    values="dataset_count",
)

# from 200 to 900 we obtain 30 datasets, it should be enough
range_counts_matrix
# Out:
# upper_bound  700.0   800.0   900.0   1000.0  1100.0  1200.0  1300.0  1400.0
# lower_bound
# 100.0            15      14       5       3       3       3       0       0
# 200.0            40      39      30       8       8       3       0       0
# 300.0            42      41      32      10       8       3       0       0
# 400.0            50      49      40      18      16      11       8       6

# %%
# this one severs for individual filtering
matching = explorer.select_mz_range(
    min_mz=200,
    max_mz=900,
)
matching
# Out:
#               dataset_id                                              name  \
# 0   2026-04-22_21h03m00s  kidney_test_metabolites_null_mz_shift_10_til_550
# 1   2025-07-06_22h07m04s      msi2024013_20240909_multiomicsii_nor 50-1350
# 2   2025-07-06_16h31m32s     msi2024013_20240909_multiomicsii_nedc 50-1350
# 3   2024-05-23_14h25m01s                               K3 vs K6 neg -Jano
# 4   2024-04-10_17h06m19s                                           8223301
# 5   2024-02-20_01h55m56s                                        d28-2014-2
# 6   2024-02-20_01h57m32s                                        d28-2017-2
# 7   2024-02-20_01h54m01s                                          d14-2295
# 8   2024-02-20_01h54m41s                                        d28-2006-2
# 9   2024-02-20_01h53m31s                                          d14-2015
# 10  2024-02-20_01h49m35s                                        d14-2001-2
# 11  2024-02-20_01h48m46s                                         d7-2024-2
# 12  2024-02-20_01h46m58s                                         d7-2020-2
# 13  2024-02-20_01h46m10s                                         d7-2004-2
# 14  2024-02-20_01h45m20s                                         d3-2023-2
# 15  2024-02-20_01h44m07s                                         d3-2012-2
# 16  2024-02-20_01h43m24s                                         d3-2010-2
# 17  2024-02-20_01h42m42s                                           d3-1807
# 18  2024-02-20_01h41m56s                                         d2-2053-2
# 19  2024-02-20_01h40m11s                                         d2-2042-2
# 20  2024-02-20_01h38m59s                                         d2-2018-2
# 21  2024-02-19_05h43m55s                                         d1-2016-2
# 22  2024-02-19_05h42m55s                                         d1-2005-2
# 23  2024-02-19_05h36m42s                                           d1-1829
# 24  2024-02-19_05h21m14s                                           d1-1817
# 25  2024-02-19_05h12m47s                                         con2060-2
# 26  2024-02-19_05h02m33s                                     c2_mus_kidney
# 27  2024-02-19_04h23m32s                                        control_c1
# 28  2019-03-19_17h21m15s                           kidney_test_metabolites
# 29  2017-04-20_09h06m22s                            May4_kidney_serial_S25
#
#        source project_accession  \
# 0   metaspace              None
# 1   metaspace              None
# 2   metaspace              None
# 3   metaspace              None
# 4   metaspace              None
# 5   metaspace              None
# 6   metaspace              None
# 7   metaspace              None
# 8   metaspace              None
# 9   metaspace              None
# 10  metaspace              None
# 11  metaspace              None
# 12  metaspace              None
# 13  metaspace              None
# 14  metaspace              None
# 15  metaspace              None
# 16  metaspace              None
# 17  metaspace              None
# 18  metaspace              None
# 19  metaspace              None
# 20  metaspace              None
# 21  metaspace              None
# 22  metaspace              None
# 23  metaspace              None
# 24  metaspace              None
# 25  metaspace              None
# 26  metaspace              None
# 27  metaspace              None
# 28  metaspace              None
# 29  metaspace              None
#
#                                           project_url             organisms  \
# 0   https://metaspace2020.eu/dataset/2026-04-22_21...  Mus musculus (mouse)
# 1   https://metaspace2020.eu/dataset/2025-07-06_22...  Mus musculus (mouse)
# 2   https://metaspace2020.eu/dataset/2025-07-06_16...  Mus musculus (mouse)
# 3   https://metaspace2020.eu/dataset/2024-05-23_14...                 Mouse
# 4   https://metaspace2020.eu/dataset/2024-04-10_17...  Mus musculus (mouse)
# 5   https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 6   https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 7   https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 8   https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 9   https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 10  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 11  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 12  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 13  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 14  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 15  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 16  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 17  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 18  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 19  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 20  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 21  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 22  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 23  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 24  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 25  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 26  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 27  https://metaspace2020.eu/dataset/2024-02-19_04...  Mus musculus (mouse)
# 28  https://metaspace2020.eu/dataset/2019-03-19_17...  Mus musculus (mouse)
# 29  https://metaspace2020.eu/dataset/2017-04-20_09...  Mus musculus (mouse)
#
#    organism_parts condition growth_conditions diseases  ...  \
# 0          Kidney  Wildtype             Caged           ...
# 1          Kidney  Wildtype                             ...
# 2          Kidney  Wildtype                             ...
# 3          Kidney  Wildtype                             ...
# 4          Kidney  Wildtype                             ...
# 5          Kidney  Wildtype               N/A           ...
# 6          Kidney  Wildtype               N/A           ...
# 7          Kidney  Wildtype               N/A           ...
# 8          Kidney  Wildtype               N/A           ...
# 9          Kidney  Wildtype               N/A           ...
# 10         Kidney  Wildtype               N/A           ...
# 11         Kidney  Wildtype               N/A           ...
# 12         Kidney  Wildtype               N/A           ...
# 13         Kidney  Wildtype               N/A           ...
# 14         Kidney  Wildtype               N/A           ...
# 15         Kidney  Wildtype               N/A           ...
# 16         Kidney  Wildtype               N/A           ...
# 17         Kidney  Wildtype               N/A           ...
# 18         Kidney  Wildtype               N/A           ...
# 19         Kidney  Wildtype               N/A           ...
# 20         Kidney  Wildtype               N/A           ...
# 21         Kidney  Wildtype               N/A           ...
# 22         Kidney  Wildtype               N/A           ...
# 23         Kidney  Wildtype               N/A           ...
# 24         Kidney  Wildtype               N/A           ...
# 25         Kidney  Wildtype               N/A           ...
# 26         Kidney  Wildtype               N/A           ...
# 27         Kidney  Wildtype               N/A           ...
# 28         Kidney  Wildtype             Caged           ...
# 29         Kidney  Wildtype               N/A           ...
#
#    unannotated_pixel_count annotated_pixel_fraction annotation_fdr  \
# 0                     None                     None            0.1
# 1                     None                     None            0.1
# 2                     None                     None            0.1
# 3                     None                     None            0.1
# 4                     None                     None            0.1
# 5                     None                     None            0.1
# 6                     None                     None            0.1
# 7                     None                     None            0.1
# 8                     None                     None            0.1
# 9                     None                     None            0.1
# 10                    None                     None            0.1
# 11                    None                     None            0.1
# 12                    None                     None            0.1
# 13                    None                     None            0.1
# 14                    None                     None            0.1
# 15                    None                     None            0.1
# 16                    None                     None            0.1
# 17                    None                     None            0.1
# 18                    None                     None            0.1
# 19                    None                     None            0.1
# 20                    None                     None            0.1
# 21                    None                     None            0.1
# 22                    None                     None            0.1
# 23                    None                     None            0.1
# 24                    None                     None            0.1
# 25                    None                     None            0.1
# 26                    None                     None            0.1
# 27                    None                     None            0.1
# 28                    None                     None            0.1
# 29                    None                     None            0.1
#
#     spatial_annotation_count spatial_annotation_database_count  \
# 0                       None                              None
# 1                       None                              None
# 2                       None                              None
# 3                       None                              None
# 4                       None                              None
# 5                       None                              None
# 6                       None                              None
# 7                       None                              None
# 8                       None                              None
# 9                       None                              None
# 10                      None                              None
# 11                      None                              None
# 12                      None                              None
# 13                      None                              None
# 14                      None                              None
# 15                      None                              None
# 16                      None                              None
# 17                      None                              None
# 18                      None                              None
# 19                      None                              None
# 20                      None                              None
# 21                      None                              None
# 22                      None                              None
# 23                      None                              None
# 24                      None                              None
# 25                      None                              None
# 26                      None                              None
# 27                      None                              None
# 28                      None                              None
# 29                      None                              None
#
#    spatial_stats_status molecule_count  unique_molecule_count  \
# 0                  None           None                   None
# 1                  None           None                   None
# 2                  None           None                   None
# 3                  None           None                   None
# 4                  None           None                   None
# 5                  None           None                   None
# 6                  None           None                   None
# 7                  None           None                   None
# 8                  None           None                   None
# 9                  None           None                   None
# 10                 None           None                   None
# 11                 None           None                   None
# 12                 None           None                   None
# 13                 None           None                   None
# 14                 None           None                   None
# 15                 None           None                   None
# 16                 None           None                   None
# 17                 None           None                   None
# 18                 None           None                   None
# 19                 None           None                   None
# 20                 None           None                   None
# 21                 None           None                   None
# 22                 None           None                   None
# 23                 None           None                   None
# 24                 None           None                   None
# 25                 None           None                   None
# 26                 None           None                   None
# 27                 None           None                   None
# 28                 None           None                   None
# 29                 None           None                   None
#
#     unique_molecules excluded
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# 5                       False
# 6                       False
# 7                       False
# 8                       False
# 9                       False
# 10                      False
# 11                      False
# 12                      False
# 13                      False
# 14                      False
# 15                      False
# 16                      False
# 17                      False
# 18                      False
# 19                      False
# 20                      False
# 21                      False
# 22                      False
# 23                      False
# 24                      False
# 25                      False
# 26                      False
# 27                      False
# 28                      False
# 29                      False
#
# [30 rows x 45 columns]

# %%
filters = {
    # Biological and acquisition metadata
    "organism": "Mouse",
    "organism_part": "Kidney",
    "polarity": "Negative",
    "condition": "Wildtype",  # matched tolerantly; also groups "Wildtype", "wildtype", etc.
    "mz_min": 200,
    "mz_max": 900,

    # Annotation filters and molecular statistics
    "annotation_fdr": 0.1,
    "min_annotation_count": 1,
    "include_molecule_stats": True,
    "include_spatial_annotation_stats": True, # REMARK: it filters unique values based on `annotation_fdr`
}

results_kidney = explorer.filter(filters)
# Out:
# 2026-08-12 13:15:52,072 | INFO     | msi_autoencoder_wrapper.dataset_management.sources.strategies.metaspace:550 | METASPACE cache reduced discovery to 61 candidate datasets
# METASPACE discovery:   0%|          | 0/3 [00:00<?, ?stage/s]
# Current operation:   0%|          | 0/1 [00:00<?, ?operation/s]
# 2026-08-12 13:15:52,821 | INFO     | msi_autoencoder_wrapper.dataset_management.sources.strategies.metaspace:221 | METASPACE spatial plan contains 30 datasets and 1255 annotation images
# 2026-08-12 13:16:30,587 | INFO     | msi_autoencoder_wrapper.dataset_management.sources.strategies.metaspace:267 | METASPACE discovery accepted 30 datasets and rejected 8738 datasets
# 2026-08-12 13:16:30,589 | INFO     | msi_autoencoder_wrapper.dataset_management.exploration.dataset_explorer:123 | Explorer retained 30 records from source metaspace

# %%
display(results_kidney)
print(f"Accepted {len(results_kidney)} datasets")
# Out:
#               dataset_id                                              name  \
# 0   2026-04-22_21h03m00s  kidney_test_metabolites_null_mz_shift_10_til_550
# 1   2025-07-06_22h07m04s      msi2024013_20240909_multiomicsii_nor 50-1350
# 2   2025-07-06_16h31m32s     msi2024013_20240909_multiomicsii_nedc 50-1350
# 3   2024-05-23_14h25m01s                               K3 vs K6 neg -Jano
# 4   2024-04-10_17h06m19s                                           8223301
# 5   2024-02-20_01h55m56s                                        d28-2014-2
# 6   2024-02-20_01h57m32s                                        d28-2017-2
# 7   2024-02-20_01h54m01s                                          d14-2295
# 8   2024-02-20_01h54m41s                                        d28-2006-2
# 9   2024-02-20_01h53m31s                                          d14-2015
# 10  2024-02-20_01h49m35s                                        d14-2001-2
# 11  2024-02-20_01h48m46s                                         d7-2024-2
# 12  2024-02-20_01h46m58s                                         d7-2020-2
# 13  2024-02-20_01h46m10s                                         d7-2004-2
# 14  2024-02-20_01h45m20s                                         d3-2023-2
# 15  2024-02-20_01h44m07s                                         d3-2012-2
# 16  2024-02-20_01h43m24s                                         d3-2010-2
# 17  2024-02-20_01h42m42s                                           d3-1807
# 18  2024-02-20_01h41m56s                                         d2-2053-2
# 19  2024-02-20_01h40m11s                                         d2-2042-2
# 20  2024-02-20_01h38m59s                                         d2-2018-2
# 21  2024-02-19_05h43m55s                                         d1-2016-2
# 22  2024-02-19_05h42m55s                                         d1-2005-2
# 23  2024-02-19_05h36m42s                                           d1-1829
# 24  2024-02-19_05h21m14s                                           d1-1817
# 25  2024-02-19_05h12m47s                                         con2060-2
# 26  2024-02-19_05h02m33s                                     c2_mus_kidney
# 27  2024-02-19_04h23m32s                                        control_c1
# 28  2019-03-19_17h21m15s                           kidney_test_metabolites
# 29  2017-04-20_09h06m22s                            May4_kidney_serial_S25
#
#        source project_accession  \
# 0   metaspace              None
# 1   metaspace              None
# 2   metaspace              None
# 3   metaspace              None
# 4   metaspace              None
# 5   metaspace              None
# 6   metaspace              None
# 7   metaspace              None
# 8   metaspace              None
# 9   metaspace              None
# 10  metaspace              None
# 11  metaspace              None
# 12  metaspace              None
# 13  metaspace              None
# 14  metaspace              None
# 15  metaspace              None
# 16  metaspace              None
# 17  metaspace              None
# 18  metaspace              None
# 19  metaspace              None
# 20  metaspace              None
# 21  metaspace              None
# 22  metaspace              None
# 23  metaspace              None
# 24  metaspace              None
# 25  metaspace              None
# 26  metaspace              None
# 27  metaspace              None
# 28  metaspace              None
# 29  metaspace              None
#
#                                           project_url             organisms  \
# 0   https://metaspace2020.eu/dataset/2026-04-22_21...  Mus musculus (mouse)
# 1   https://metaspace2020.eu/dataset/2025-07-06_22...  Mus musculus (mouse)
# 2   https://metaspace2020.eu/dataset/2025-07-06_16...  Mus musculus (mouse)
# 3   https://metaspace2020.eu/dataset/2024-05-23_14...                 Mouse
# 4   https://metaspace2020.eu/dataset/2024-04-10_17...  Mus musculus (mouse)
# 5   https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 6   https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 7   https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 8   https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 9   https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 10  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 11  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 12  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 13  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 14  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 15  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 16  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 17  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 18  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 19  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 20  https://metaspace2020.eu/dataset/2024-02-20_01...  Mus musculus (mouse)
# 21  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 22  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 23  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 24  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 25  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 26  https://metaspace2020.eu/dataset/2024-02-19_05...  Mus musculus (mouse)
# 27  https://metaspace2020.eu/dataset/2024-02-19_04...  Mus musculus (mouse)
# 28  https://metaspace2020.eu/dataset/2019-03-19_17...  Mus musculus (mouse)
# 29  https://metaspace2020.eu/dataset/2017-04-20_09...  Mus musculus (mouse)
#
#    organism_parts condition growth_conditions diseases  ...  \
# 0          Kidney  Wildtype             Caged           ...
# 1          Kidney  Wildtype                             ...
# 2          Kidney  Wildtype                             ...
# 3          Kidney  Wildtype                             ...
# 4          Kidney  Wildtype                             ...
# 5          Kidney  Wildtype               N/A           ...
# 6          Kidney  Wildtype               N/A           ...
# 7          Kidney  Wildtype               N/A           ...
# 8          Kidney  Wildtype               N/A           ...
# 9          Kidney  Wildtype               N/A           ...
# 10         Kidney  Wildtype               N/A           ...
# 11         Kidney  Wildtype               N/A           ...
# 12         Kidney  Wildtype               N/A           ...
# 13         Kidney  Wildtype               N/A           ...
# 14         Kidney  Wildtype               N/A           ...
# 15         Kidney  Wildtype               N/A           ...
# 16         Kidney  Wildtype               N/A           ...
# 17         Kidney  Wildtype               N/A           ...
# 18         Kidney  Wildtype               N/A           ...
# 19         Kidney  Wildtype               N/A           ...
# 20         Kidney  Wildtype               N/A           ...
# 21         Kidney  Wildtype               N/A           ...
# 22         Kidney  Wildtype               N/A           ...
# 23         Kidney  Wildtype               N/A           ...
# 24         Kidney  Wildtype               N/A           ...
# 25         Kidney  Wildtype               N/A           ...
# 26         Kidney  Wildtype               N/A           ...
# 27         Kidney  Wildtype               N/A           ...
# 28         Kidney  Wildtype             Caged           ...
# 29         Kidney  Wildtype               N/A           ...
#
#    unannotated_pixel_count annotated_pixel_fraction annotation_fdr  \
# 0                       75                 0.991254            0.1
# 1                        0                 1.000000            0.1
# 2                       86                 0.998785            0.1
# 3                       67                 0.996666            0.1
# 4                        0                 1.000000            0.1
# 5                        4                 0.999444            0.1
# 6                        6                 0.999217            0.1
# 7                        3                 0.999403            0.1
# 8                        0                 1.000000            0.1
# 9                        0                 1.000000            0.1
# 10                       5                 0.999396            0.1
# 11                      58                 0.992562            0.1
# 12                       0                 1.000000            0.1
# 13                       2                 0.999774            0.1
# 14                      15                 0.998636            0.1
# 15                      68                 0.993780            0.1
# 16                       0                 1.000000            0.1
# 17                       0                 1.000000            0.1
# 18                      88                 0.992736            0.1
# 19                      81                 0.992238            0.1
# 20                      28                 0.997557            0.1
# 21                       1                 0.999891            0.1
# 22                       4                 0.999636            0.1
# 23                       0                 1.000000            0.1
# 24                       0                 1.000000            0.1
# 25                       0                 1.000000            0.1
# 26                      64                 0.992096            0.1
# 27                       2                 0.999734            0.1
# 28                     123                 0.985656            0.1
# 29                    2082                 0.804065            0.1
#
#     spatial_annotation_count spatial_annotation_database_count  \
# 0                          7                                 1
# 1                        118                                 3
# 2                         32                                 2
# 3                        485                                 4
# 4                        216                                 3
# 5                         10                                 3
# 6                         18                                 3
# 7                         14                                 4
# 8                         17                                 4
# 9                         22                                 4
# 10                        17                                 4
# 11                        11                                 4
# 12                        15                                 4
# 13                        11                                 4
# 14                        14                                 4
# 15                        14                                 4
# 16                        15                                 4
# 17                        13                                 4
# 18                         7                                 3
# 19                         8                                 3
# 20                         8                                 4
# 21                        12                                 4
# 22                         8                                 4
# 23                        20                                 4
# 24                        16                                 4
# 25                        14                                 4
# 26                         6                                 3
# 27                        18                                 4
# 28                        16                                 1
# 29                        73                                 2
#
#    spatial_stats_status molecule_count  unique_molecule_count  \
# 0              complete              7                      3
# 1              complete            103                     44
# 2              complete             23                     13
# 3              complete            311                    221
# 4              complete            124                     69
# 5              complete              7                      0
# 6              complete             14                      6
# 7              complete             10                      7
# 8              complete             14                      1
# 9              complete             14                      6
# 10             complete             11                      1
# 11             complete              7                      0
# 12             complete             11                      0
# 13             complete              8                      1
# 14             complete              9                      0
# 15             complete              9                      0
# 16             complete              9                      2
# 17             complete             10                      4
# 18             complete              6                      1
# 19             complete              7                      0
# 20             complete              7                      0
# 21             complete             10                      1
# 22             complete              6                      2
# 23             complete             15                      6
# 24             complete             13                      3
# 25             complete              9                      0
# 26             complete              5                      1
# 27             complete             14                      8
# 28             complete             16                      6
# 29             complete             53                     28
#
#                                      unique_molecules excluded
# 0                 C13H14O3S-H, C24H28O5-H, C24H30O5-H    False
# 1   C10H13N4O8P-H, C10H14N5O8P-H, C10H15N5O10P2-H,...    False
# 2   C21H41O6P-H, C24H47NO10S-H, C26H43NO6+Cl, C34H...    False
# 3   C10H12N2O5-H, C10H12N4O5-H, C10H15NO2S-H, C10H...    False
# 4   C10H14N4O5-H, C10H15N3O5+Cl, C10H20O2-H, C11H2...    False
# 5                                                        False
# 6   C44H81O7P-H, C45H79O12P-H, C46H83O12P-H, C49H8...    False
# 7   C15H19NO9[M]-, C17H12O10S[M]-, C18H12O4[M]-, C...    False
# 8                                      C49H93O12P[M]-    False
# 9   C10H7NO3-H, C14H20N2O3S-H, C43H78NO8P[M]-, C46...    False
# 10                                      C20H20O10[M]-    False
# 11                                                       False
# 12                                                       False
# 13                                      C53H100NO8P-H    False
# 14                                                       False
# 15                                                       False
# 16                      C18H35IO2[M]-, C40H70NO8P[M]-    False
# 17  C10H20O7P2[M]-, C47H93O12P[M]-, C48H93NO13-H, ...    False
# 18                                      C14H30N2O4+Cl    False
# 19                                                       False
# 20                                                       False
# 21                                      C40H79O8P[M]-    False
# 22                         C26H46NO7P-H, C57H86O4[M]-    False
# 23  C42H81O7P[M]-, C47H83O10P-H, C47H88NO8P-H, C49...    False
# 24         C44H79O7P[M]-, C46H79O8P[M]-, C46H80NO7P-H    False
# 25                                                       False
# 26                                      C18H30O3S[M]-    False
# 27  C18H20N2O5+Cl, C43H77NO9-H, C47H91O12P[M]-, C5...    False
# 28  C10H16N2O7-H, C10H17N3O6S-H, C17H30O13-H, C22H...    False
# 29  C10H19O6P-H, C12H22O8-H, C13H18N4O6-H, C15H14N...    False
#
# [30 rows x 45 columns]
# Accepted 30 datasets

# %%
## to gigabyte transfer 
results_kidney['total_size_bytes'].sum() / 10**(9)
# Out:
# np.float64(30.238378985)

# %% [markdown]
# ## 4. Export filters

# %%
output_path = Path(
    "data/kidney_workspace/configs/datasets/kidney.json"
)

exported = explorer.export_selection(
    output_path,
    sort_by="download_size_bytes",
    ascending = False
)

exported
# Out:
# 2026-08-12 13:18:20,888 | INFO     | msi_autoencoder_wrapper.dataset_management.exploration.dataset_explorer:269 | Exported dataset query configuration to data/kidney_workspace/configs/datasets/kidney.json/filter.json
# {'filters': PosixPath('data/kidney_workspace/configs/datasets/kidney.json/filter.json'),
#  'selection': PosixPath('data/kidney_workspace/configs/datasets/kidney.json/selection.json')}
